# %% [markdown]
# ## This notebook prepare raw data into network data for feature extraction

# %%
import pandas as pd
import networkx as nx
import numpy as np
from datetime import date
from glob import glob

from difflib import get_close_matches

# %% [markdown]
# ## Creating US air networks from source data

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}


def state_to_abbr(state):
    return(us_state_abbrev[state]).lower()

# %%
import re
import unicodedata

def strip_accents(text):
    """
    Strip accents from input String.

    :param text: The input string.
    :type text: String.

    :returns: The processed String.
    :rtype: String.
    """
    try:
        text = unicode(text, 'utf-8')
    except (TypeError, NameError): # unicode is a default on python 3 
        pass
    text = unicodedata.normalize('NFD', text)
    text = text.encode('ascii', 'ignore')
    text = text.decode("utf-8")
    return str(text)

def text_to_id(text):
    """
    Convert input text to id.

    :param text: The input string.
    :type text: String.

    :returns: The processed String.
    :rtype: String.
    """
    text = strip_accents(text.lower())
    text = re.sub(r"\d", "", text) 
    text=re.sub(r"^\s+", "", text) 
    text=re.sub(r"\s+$", "", text)
    text = re.sub(r"\s+","_", text, flags = re.I)
    #text = re.sub('[ ]+', '_', text)
    text = re.sub('[^a-zA-Z_-]', '', text)
    return text

# %%
# get distance dataframe
f = '../data/us_air_raw_data/770841524_T_T100D_MARKET_ALL_CARRIER-1.csv'   
df=pd.read_csv(f)
# df = df[df.MONTH==12]
df=df[['YEAR','MONTH','ORIGIN_CITY_NAME','DEST_CITY_NAME','PASSENGERS','DISTANCE']]
df=df.rename(index=str, columns={"ORIGIN_CITY_NAME": "source", "DEST_CITY_NAME": "target",'PASSENGERS':'weight','DISTANCE':'distance'})
df['source']=df.apply(lambda row: text_to_id(str(row.source)), axis=1)
df['target']=df.apply(lambda row: text_to_id(str(row.target)), axis=1)
# df=df[df.weight !=0 ].reset_index()
df=df[['source','target','weight','distance']]
df = df.drop_duplicates(subset=['source','target']).reset_index().drop(columns=['index'])
df.to_pickle('../data/us_air_distance.pkl')
df.head()
# Out:
#              source              target  weight  distance
# 0    new_orleans_la            islip_ny     0.0    1218.0
# 1    new_orleans_la   salt_lake_city_ut     0.0    1428.0
# 2       portland_or  fort_lauderdale_fl     0.0    2694.0
# 3  raleighdurham_nc    san_francisco_ca     0.0    2400.0
# 4        seattle_wa          wichita_ks     0.0    1430.0

# %%
import requests
import json

def get_city_opendata(city, state):
    cmd = f'https://public.opendatasoft.com/api/records/1.0/search/?dataset=cities-and-towns-of-the-united-states&q={city}&sort=pop_2010&facet=state&refine.state={state}'

    res = requests.get(cmd)
    dct = json.loads(res.content)
    records = dct['records']
#     if len(records)>1:
#         record = [i for i in records if i['fields']['name'].upper()== city.upper()]
#         output = record[0]['fields']['pop_2010']
#     else:
    output = records[0]['fields']['pop_2010']
#     return output
    return records

# %%
def get_population(node):    
    full_name = node.replace('/','-')
    search_name =  node.replace('/','-').replace(',',' ')
    cmd = f'https://api.censusreporter.org/1.0/geo/search?q={search_name}'
    res = requests.get(cmd)
    dct = json.loads(res.content)
#     print(dct)
    numbers = []
    for item in list(dct['results']):
        if item['full_name'].split(',')[-1]==full_name.split(',')[-1]:
            numbers.append(item['full_geoid'])
    pop = []
    for number in  numbers: 
        cmd = f'https://api.censusreporter.org/1.0/geo/tiger2019/{number}'
        res = requests.get(cmd)
        dct = json.loads(res.content)
        pop.append(dct['properties']['population'])
    return(max(pop))

# %%
f = '../data/us_air_raw_data/770841524_T_T100D_MARKET_ALL_CARRIER-1.csv'   
df=pd.read_csv(f)
df = df[df.MONTH==12]
df=df[['ORIGIN_CITY_NAME','DEST_CITY_NAME','PASSENGERS','DISTANCE']]
df=df.rename(index=str, columns={"ORIGIN_CITY_NAME": "source", "DEST_CITY_NAME": "target",'PASSENGERS':'weight','DISTANCE':'distance'})
cities = list(set(list(df.source)+list(df.target)))

# %%
cities[2]
# Out:
# 'Muscle Shoals, AL'

# %%
get_population(cities[2])
# Out:
# 13874

# %%
pop_data = dict()
failed_cities = []
for node in cities:
    try:
        pop_data[node]=get_population(node)
    except:
        failed_cities.append(node)

for node in failed_cities:
    try:
        city = node.split(',')[0].split('/')[0]
        state = node.split(',')[1]
        pop_data[node]=get_population()
    except:
        print(node)
# Out:
# Arcata/Eureka, CA
# Ofu, TT
# Lawton/Fort Sill, OK
# Sarasota/Bradenton, FL
# Beaumont/Port Arthur, TX
# Sun Valley/Hailey/Ketchum, ID
# Minneapolis/St. Paul, MN
# Champaign/Urbana, IL
# Naukiti, AK
# New Bedford/Fall River, MA
# Wake Island, TT
# Oceana, VA
# Charleston/Dunbar, WV
# Ithaca/Cortland, NY
# Raleigh/Durham, NC
# West Point, AK
# Manhattan/Ft. Riley, KS
# Akun, AK
# Youngstown/Warren, OH
# Hattiesburg/Laurel, MS
# Seal Bay, AK
# Cape Newenham, AK
# Clarksburg/Fairmont, WV
# Elmira/Corning, NY
# Trading Bay, AK
# Granite Point, AK
# Mission/McAllen/Edinburg, TX
# Deadhorse, AK
# Newburgh/Poughkeepsie, NY
# Jacksonville/Camp Lejeune, NC
# Augusta/Waterville, ME
# Lexington, KY
# Eagle Harbor, AK
# Lebanon-Hanover, NH
# Cape Lisburne, AK
# Montrose/Delta, CO
# Sitkinak, AK
# Kizhuyak, AK
# Martha's Vineyard, MA
# Nashville, TN
# Kuparuk, AK
# Presque Isle/Houlton, ME
# Kona, HI
# Rota, TT
# Port Bailey, AK
# Minchumina, AK
# Charlotte Amalie, VI
# Kalskag, AK
# Greensboro/High Point, NC
# Fitiuta Village, TT
# Chignik Bay, AK
# Sandpoint, AK
# Ashland, WV
# Bloomington/Normal, IL
# Tinian, TT
# Jackson/Vicksburg, MS
# Riverton/Lander, WY
# Galbraith Lake, AK
# Saranac Lake/Lake Placid, NY
# Allentown/Bethlehem/Easton, PA
# Block Island, RI
# Newport News/Williamsburg, VA
# New London/Groton, CT
# Hilton Head, SC
# Port Moller, AK
# Christiansted, VI
# Lazy Bay, AK
# Burlington/Mount Vernon, WA
# West Palm Beach/Palm Beach, FL
# Macon, GA
# St. George Island, AK
# Saginaw/Bay City/Midland, MI
# Shemya, AK
# Saipan, TT
# Boise, ID
# Danger Bay, AK
# Silver City/Hurley, NM
# Utopia, AK
# Uganik, AK
# Terror Lake, AK
# Blue Fox Bay, AK
# Marion/Herrin, IL
# Barter Island, AK
# Dallas/Fort Worth, TX
# Princeton/Bluefield, WV
# Van Nuys, CA
# Sheldon Point, AK
# Salinas/Monterey, CA
# Red Dog, AK
# College Station/Bryan, TX
# Barrow, AK
# Kiluda Bay, AK
# Zachar Bay, AK
# Kitoi Bay, AK
# Bristol/Johnson City/Kingsport, TN
# St. Mary's, AK
# Bornite/Ruby Creek, AK
# Bismarck/Mandan, ND
# May Creek, AK
# Pago Pago, TT
# Fort Jefferson, FL
# New Bern/Morehead/Beaufort, NC
# Cedar Rapids/Iowa City, IA
# Alpine, AK
# Eastsound, WA
# Clarks Point, AK
# North Bend/Coos Bay, OR
# Dora Bay, AK
# Franklin/Oil City, PA
# Scranton/Wilkes-Barre, PA
# Prospect Creek, AK
# Iron Mountain/Kingsfd, MI
# Adak Island, AK
# Hyannis, MA
# Grand Canyon, AZ
# Tin City, AK
# Kamuela, HI
# Guam, TT
# Bend/Redmond, OR
# Hoolehua, HI
# Chicago/Romeoville, IL
# Cape Romanzof, AK
# Mayaguez, PR
# Chomondely Sound, AK
# Tenakee, AK
# Hancock/Houghton, MI
# Toksook, AK
# Gulfport/Biloxi, MS
# Deadhorse1, AK
# Kalaupapa, HI
# Olga Bay, AK
# Port Williams, AK
# Midland/Odessa, TX
# Pasco/Kennewick/Richland, WA

# %%
len(pop_data)/len(cities)

# %%
'Oceana'.split('/')[0]+', '+ "IL"
# Out:
# 'Oceana, IL'

# %%
len(pop_data)/len(cities)
# Out:
# 0.8273195876288659

# %%
get_population('Lexington, KY')
# Out:
# {'results': []}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-415edece0d2e> in <module>
# ----> 1 get_population('Lexington, KY')
#
# <ipython-input-32-a8223640c6b1> in get_population(node)
#      16         dct = json.loads(res.content)
#      17         pop.append(dct['properties']['population'])
# ---> 18     return(max(pop))
#
# ValueError: max() arg is an empty sequence

# %%
# get_city_opendata('Easton', 'PA')

# %%
cities
# Out:
# {'Aberdeen, SD',
#  'Abilene, TX',
#  'Adak Island, AK',
#  'Aguadilla, PR',
#  'Akhiok, AK',
#  'Akiachak, AK',
#  'Akiak, AK',
#  'Akron, OH',
#  'Akun, AK',
#  'Akutan, AK',
#  'Alakanuk, AK',
#  'Alamosa, CO',
#  'Albany, GA',
#  'Albany, NY',
#  'Albuquerque, NM',
#  'Alexandria, LA',
#  'Allakaket, AK',
#  'Allentown/Bethlehem/Easton, PA',
#  'Alliance, NE',
#  'Alpena, MI',
#  'Alpine, AK',
#  'Altoona, PA',
#  'Amarillo, TX',
#  'Ambler, AK',
#  'Anacortes, WA',
#  'Anaktuvuk Pass, AK',
#  'Anchorage, AK',
#  'Angoon, AK',
#  'Aniak, AK',
#  'Anniston, AL',
#  'Anvik, AK',
#  'Appleton, WI',
#  'Arcata/Eureka, CA',
#  'Arctic Village, AK',
#  'Arlington, TX',
#  'Asheville, NC',
#  'Ashland, WV',
#  'Aspen, CO',
#  'Atka, AK',
#  'Atlanta, GA',
#  'Atlantic City, NJ',
#  'Atmautluak, AK',
#  'Atqasuk, AK',
#  'Augusta, GA',
#  'Augusta/Waterville, ME',
#  'Austin, TX',
#  'Bainbridge, GA',
#  'Bakersfield, CA',
#  'Baltimore, MD',
#  'Bangor, ME',
#  'Bar Harbor, ME',
#  'Barrow, AK',
#  'Barter Island, AK',
#  'Baton Rouge, LA',
#  'Bay City, TX',
#  'Beaumont/Port Arthur, TX',
#  'Beaver, AK',
#  'Beckley, WV',
#  'Bedford, MA',
#  'Belleville, IL',
#  'Bellingham, WA',
#  'Beluga, AK',
#  'Bemidji, MN',
#  'Bend, OR',
#  'Bend/Redmond, OR',
#  'Bethel, AK',
#  'Bettles, AK',
#  'Beverly, MA',
#  'Billings, MT',
#  'Binghamton, NY',
#  'Birch Creek, AK',
#  'Birmingham, AL',
#  'Bishop, CA',
#  'Bismarck/Mandan, ND',
#  'Block Island, RI',
#  'Bloomington, IN',
#  'Bloomington/Normal, IL',
#  'Blue Fox Bay, AK',
#  'Boca Raton, FL',
#  'Boise, ID',
#  'Bornite/Ruby Creek, AK',
#  'Boston, MA',
#  'Boulder City, NV',
#  'Bowling Green, KY',
#  'Bozeman, MT',
#  'Bradford, PA',
#  'Brainerd, MN',
#  'Brevig Mission, AK',
#  'Bridgeport, CT',
#  'Bristol/Johnson City/Kingsport, TN',
#  'Broomfield, CO',
#  'Brownsville, TX',
#  'Brownwood, TX',
#  'Brunswick, GA',
#  'Buckland, AK',
#  'Buffalo, NY',
#  'Bullhead City, AZ',
#  'Burbank, CA',
#  'Burlington, IA',
#  'Burlington, VT',
#  'Burlington/Mount Vernon, WA',
#  'Butler, PA',
#  'Butte, MT',
#  'CONCORD, NC',
#  'Camp Springs, MD',
#  'Cape Girardeau, MO',
#  'Cape Lisburne, AK',
#  'Cape Newenham, AK',
#  'Cape Romanzof, AK',
#  'Carlsbad, NM',
#  'Casper, WY',
#  'Cedar City, UT',
#  'Cedar Rapids/Iowa City, IA',
#  'Ceiba, PR',
#  'Central, AK',
#  'Chadron, NE',
#  'Chalkyitsik, AK',
#  'Champaign/Urbana, IL',
#  'Charleston, SC',
#  'Charleston/Dunbar, WV',
#  'Charlotte Amalie, VI',
#  'Charlotte, NC',
#  'Charlottesville, VA',
#  'Chattanooga, TN',
#  'Chefornak, AK',
#  'Chenega, AK',
#  'Chevak, AK',
#  'Cheyenne, WY',
#  'Chicago, IL',
#  'Chicago/Romeoville, IL',
#  'Chicken, AK',
#  'Chico, CA',
#  'Chignik Bay, AK',
#  'Chignik Lagoon, AK',
#  'Chignik, AK',
#  'Chisana, AK',
#  'Chomondely Sound, AK',
#  'Christiansted, VI',
#  'Chuathbaluk, AK',
#  'Cincinnati, OH',
#  'Circle, AK',
#  'Clarks Point, AK',
#  'Clarksburg/Fairmont, WV',
#  'Cleveland, OH',
#  'Clovis, NM',
#  'Cody, WY',
#  'Coffman Cove, AK',
#  'Cold Bay, AK',
#  'Coldfoot, AK',
#  'College Station/Bryan, TX',
#  'Colorado Springs, CO',
#  'Columbia, MO',
#  'Columbia, SC',
#  'Columbia, TN',
#  'Columbus, GA',
#  'Columbus, MS',
#  'Columbus, OH',
#  'Cordova, AK',
#  'Corpus Christi, TX',
#  'Cortez, CO',
#  'Corvallis, OR',
#  'Craig, AK',
#  'Crescent City, CA',
#  'Crooked Creek, AK',
#  'Culebra, PR',
#  'Dallas, TX',
#  'Dallas/Fort Worth, TX',
#  'Danger Bay, AK',
#  'Dayton, OH',
#  'Daytona Beach, FL',
#  'Deadhorse, AK',
#  'Deadhorse1, AK',
#  'Decatur, AL',
#  'Decatur, IL',
#  'Deering, AK',
#  'Del Rio, TX',
#  'Denton, TX',
#  'Denver, CO',
#  'Des Moines, IA',
#  'Destin, FL',
#  'Detroit, MI',
#  'Devils Lake, ND',
#  'Dickinson, ND',
#  'Dillingham, AK',
#  'Dodge City, KS',
#  'Dora Bay, AK',
#  'Dothan, AL',
#  'Dover, DE',
#  'DuBois, PA',
#  'Dubuque, IA',
#  'Duluth, MN',
#  'Durango, CO',
#  'Eagle Harbor, AK',
#  'Eagle, AK',
#  'Eagle, CO',
#  'East Farmingdale, NY',
#  'East Hampton, NY',
#  'Eastsound, WA',
#  'Eau Claire, WI',
#  'Edna Bay, AK',
#  'Eek, AK',
#  'Egegik, AK',
#  'Ekwok, AK',
#  'El Centro, CA',
#  'El Dorado, AR',
#  'El Paso, TX',
#  'Elfin Cove, AK',
#  'Elim, AK',
#  'Elizabeth City, NC',
#  'Elko, NV',
#  'Elmira/Corning, NY',
#  'Emmonak, AK',
#  'Erie, PA',
#  'Escanaba, MI',
#  'Eugene, OR',
#  'Evansville, IN',
#  'Everett, WA',
#  'Excursion Inlet, AK',
#  'Fairbanks, AK',
#  'Fairfield, CA',
#  'False Pass, AK',
#  'Fargo, ND',
#  'Farmington, NM',
#  'Fayetteville, AR',
#  'Fayetteville, NC',
#  'Fitiuta Village, TT',
#  'Flagstaff, AZ',
#  'Flint, MI',
#  'Florence, SC',
#  'Fort Dix, NJ',
#  'Fort Dodge, IA',
#  'Fort Drum, NY',
#  'Fort Jefferson, FL',
#  'Fort Lauderdale, FL',
#  'Fort Leonard Wood, MO',
#  'Fort Myers, FL',
#  'Fort Smith, AR',
#  'Fort Wayne, IN',
#  'Fort Yukon, AK',
#  'Franklin/Oil City, PA',
#  'Frederick, MD',
#  'Fresno, CA',
#  'Friday Harbor, WA',
#  'Gainesville, FL',
#  'Gaithersburg, MD',
#  'Galbraith Lake, AK',
#  'Galena, AK',
#  'Gallup, NM',
#  'Gambell, AK',
#  'Garden City, KS',
#  'Gary, IN',
#  'Gaylord, MI',
#  'Gillette, WY',
#  'Glasgow, MT',
#  'Glendive, MT',
#  'Golovin, AK',
#  'Goodnews Bay, AK',
#  'Grand Canyon, AZ',
#  'Grand Forks, ND',
#  'Grand Island, NE',
#  'Grand Junction, CO',
#  'Grand Rapids, MI',
#  'Granite Point, AK',
#  'Grayling, AK',
#  'Great Falls, MT',
#  'Green Bay, WI',
#  'Greeneville, TN',
#  'Greensboro/High Point, NC',
#  'Greenville, MS',
#  'Greenville, NC',
#  'Greenville, SC',
#  'Greer, SC',
#  'Guam, TT',
#  'Gulfport/Biloxi, MS',
#  'Gulkana, AK',
#  'Gunnison, CO',
#  'Gustavus, AK',
#  'Hagerstown, MD',
#  'Haines, AK',
#  'Hana, HI',
#  'Hancock/Houghton, MI',
#  'Hanford, CA',
#  'Harlingen/San Benito, TX',
#  'Harrisburg, PA',
#  'Harrison, AR',
#  'Hartford, CT',
#  'Hattiesburg/Laurel, MS',
#  'Havre, MT',
#  'Hayden, CO',
#  'Hays, KS',
#  'Healy, AK',
#  'Heber, UT',
#  'Helena, MT',
#  'Hibbing, MN',
#  'Hickory, NC',
#  'Hilo, HI',
#  'Hilton Head, SC',
#  'Hobbs, NM',
#  'Hollis, AK',
#  'Holy Cross, AK',
#  'Homer, AK',
#  'Honolulu, HI',
#  'Hoolehua, HI',
#  'Hoonah, AK',
#  'Hooper Bay, AK',
#  'Hopkinsville, KY',
#  'Hot Springs, AR',
#  'Houston, TX',
#  'Hughes, AK',
#  'Huntsville, AL',
#  'Huslia, AK',
#  'Hyannis, MA',
#  'Hydaburg, AK',
#  'Hyder, AK',
#  'Idaho Falls, ID',
#  'Igiugig, AK',
#  'Iliamna, AK',
#  'Indianapolis, IN',
#  'International Falls, MN',
#  'Inyokern, CA',
#  'Iron Mountain/Kingsfd, MI',
#  'Ironwood, MI',
#  'Islip, NY',
#  'Ithaca/Cortland, NY',
#  'Jackson, MI',
#  'Jackson, TN',
#  'Jackson, WY',
#  'Jackson/Vicksburg, MS',
#  'Jacksonville, FL',
#  'Jacksonville/Camp Lejeune, NC',
#  'Jamestown, ND',
#  'Johnstown, PA',
#  'Jonesboro, AR',
#  'Joplin, MO',
#  'Juneau, AK',
#  'Kahului, HI',
#  'Kake, AK',
#  'Kalamazoo, MI',
#  'Kalaupapa, HI',
#  'Kalispell, MT',
#  'Kalskag, AK',
#  'Kaltag, AK',
#  'Kamuela, HI',
#  'Kansas City, MO',
#  'Kapalua, HI',
#  'Karluk, AK',
#  'Kasaan, AK',
#  'Kasigluk, AK',
#  'Kearney, NE',
#  'Kenai, AK',
#  'Kenmore, WA',
#  'Kennesaw, GA',
#  'Ketchikan, AK',
#  'Key West, FL',
#  'Kiana, AK',
#  'Killeen, TX',
#  'Kiluda Bay, AK',
#  'King Cove, AK',
#  'King Salmon, AK',
#  'Kingman, AZ',
#  'Kipnuk, AK',
#  'Kirksville, MO',
#  'Kitoi Bay, AK',
#  'Kivalina, AK',
#  'Kizhuyak, AK',
#  'Klamath Falls, OR',
#  'Klawock, AK',
#  'Knoxville, TN',
#  'Kobuk, AK',
#  'Kodiak Island, AK',
#  'Kodiak, AK',
#  'Kokhanok, AK',
#  'Koliganek, AK',
#  'Kona, HI',
#  'Kongiganak, AK',
#  'Kotlik, AK',
#  'Kotzebue, AK',
#  'Koyuk, AK',
#  'Koyukuk, AK',
#  'Kuparuk, AK',
#  'Kwethluk, AK',
#  'Kwigillingok, AK',
#  'La Crosse, WI',
#  'La Grande, OR',
#  'Laconia, NH',
#  'Lafayette, IN',
#  'Lafayette, LA',
#  'Lake Charles, LA',
#  'Lake Havasu City, AZ',
#  'Lanai, HI',
#  'Lancaster, PA',
#  'Lansing, MI',
#  'Laramie, WY',
#  'Laredo, TX',
#  'Larsen Bay, AK',
#  'Las Vegas, NV',
#  'Latrobe, PA',
#  'Lawrence, MA',
#  'Lawrenceville, GA',
#  'Lawton/Fort Sill, OK',
#  'Lazy Bay, AK',
#  'Lebanon-Hanover, NH',
#  'Levelock, AK',
#  'Lewisburg, WV',
#  'Lewiston, ID',
#  'Lexington, KY',
#  'Liberal, KS',
#  'Lihue, HI',
#  'Lincoln, NE',
#  'Little Rock, AR',
#  'Logan, UT',
#  'Long Beach, CA',
#  'Longview, TX',
#  'Los Angeles, CA',
#  'Louisville, KY',
#  'Lubbock, TX',
#  'Lynchburg, VA',
#  'Macon, GA',
#  'Madison, WI',
#  'Mammoth Lakes, CA',
#  'Manassas, VA',
#  'Manchester, NH',
#  'Manhattan/Ft. Riley, KS',
#  'Manley Hot Springs, AK',
#  'Manokotak, AK',
#  'Manteo, NC',
#  'Marana, AZ',
#  'Marathon, FL',
#  'Marietta, GA',
#  'Marion/Herrin, IL',
#  'Marquette, MI',
#  'Marshall, AK',
#  "Martha's Vineyard, MA",
#  'Mason City, IA',
#  'Massena, NY',
#  'May Creek, AK',
#  'Mayaguez, PR',
#  'McCarthy, AK',
#  'McCook, NE',
#  'McGrath, AK',
#  'Medford, OR',
#  'Mekoryuk, AK',
#  'Melbourne, FL',
#  'Memphis, TN',
#  'Merced, CA',
#  'Meridian, MS',
#  'Metlakatla, AK',
#  'Miami, FL',
#  'Midland/Odessa, TX',
#  'Milwaukee, WI',
#  'Minchumina, AK',
#  'Minneapolis, MN',
#  'Minneapolis/St. Paul, MN',
#  'Minot, ND',
#  'Minto, AK',
#  'Mission/McAllen/Edinburg, TX',
#  'Missoula, MT',
#  'Moab, UT',
#  'Mobile, AL',
#  'Moline, IL',
#  'Monroe, LA',
#  'Monterey, CA',
#  'Montgomery, AL',
#  'Monticello, NY',
#  'Montrose/Delta, CO',
#  'Morgantown, WV',
#  'Morristown, NJ',
#  'Morrisville, VT',
#  'Moses Lake, WA',
#  'Mosinee, WI',
#  'Mountain View, CA',
#  'Mountain Village, AK',
#  'Murray, KY',
#  'Muscle Shoals, AL',
#  'Muskegon, MI',
#  'Myrtle Beach, SC',
#  'Nantucket, MA',
#  'Nanwalek, AK',
#  'Napa, CA',
#  'Napakiak, AK',
#  'Napaskiak, AK',
#  'Naples, FL',
#  'Nashville, TN',
#  'Naukiti, AK',
#  'Nelson Lagoon, AK',
#  'New Bedford/Fall River, MA',
#  'New Bern/Morehead/Beaufort, NC',
#  'New Haven, CT',
#  'New Iberia, LA',
#  'New London/Groton, CT',
#  'New Orleans, LA',
#  'New Stuyahok, AK',
#  'New York, NY',
#  'Newark, NJ',
#  'Newburgh/Poughkeepsie, NY',
#  'Newport News/Williamsburg, VA',
#  'Newport, OR',
#  'Newport, RI',
#  'Newtok, AK',
#  'Niagara Falls, NY',
#  'Nightmute, AK',
#  'Nikolski, AK',
#  'Noatak, AK',
#  'Nome, AK',
#  'Nondalton, AK',
#  'Noorvik, AK',
#  'Norfolk, VA',
#  'North Bend/Coos Bay, OR',
#  'North Kingstown, RI',
#  'North Platte, NE',
#  'Northampton, MA',
#  'Nuiqsut, AK',
#  'Nulato, AK',
#  'Nunapitchuk, AK',
#  'Oakland, CA',
#  'Oceana, VA',
#  'Ofu, TT',
#  'Ogden, UT',
#  'Ogdensburg, NY',
#  'Oklahoma City, OK',
#  'Old Harbor, AK',
#  'Olga Bay, AK',
#  'Olympia, WA',
#  'Omaha, NE',
#  'Ontario, CA',
#  'Orlando, FL',
#  'Ouzinkie, AK',
#  'Owensboro, KY',
#  'Paducah, KY',
#  'Page, AZ',
#  'Pago Pago, TT',
#  'Palm Springs, CA',
#  'Palmer, AK',
#  'Panama City, FL',
#  'Parkersburg, WV',
#  'Pasco/Kennewick/Richland, WA',
#  'Peach Springs, AZ',
#  'Pedro Bay, AK',
#  'Pelican, AK',
#  'Pellston, MI',
#  'Pendleton, OR',
#  'Pensacola, FL',
#  'Peoria, IL',
#  'Perryville, AK',
#  'Peru, IN',
#  'Petaluma, CA',
#  'Petersburg, AK',
#  'Philadelphia, PA',
#  'Phoenix, AZ',
#  'Pierre, SD',
#  'Pilot Point, AK',
#  'Pilot Station, AK',
#  'Pittsburgh, PA',
#  'Platinum, AK',
#  'Plattsburgh, NY',
#  'Pocatello, ID',
#  'Point Baker, AK',
#  'Point Hope, AK',
#  'Point Lay, AK',
#  'Ponce, PR',
#  'Pontiac, MI',
#  'Port Alexander, AK',
#  'Port Alsworth, AK',
#  'Port Angeles, WA',
#  'Port Bailey, AK',
#  'Port Graham, AK',
#  'Port Heiden, AK',
#  'Port Lions, AK',
#  'Port Moller, AK',
#  'Port Protection, AK',
#  'Port Williams, AK',
#  'Portland, ME',
#  'Portland, OR',
#  'Portsmouth, NH',
#  'Prescott, AZ',
#  'Presque Isle/Houlton, ME',
#  'Princeton/Bluefield, WV',
#  'Prospect Creek, AK',
#  'Providence, RI',
#  'Provincetown, MA',
#  'Provo, UT',
#  'Pueblo, CO',
#  'Pullman, WA',
#  'Punta Gorda, FL',
#  'Quincy, IL',
#  'Quinhagak, AK',
#  'Raleigh/Durham, NC',
#  'Rampart, AK',
#  'Rapid City, SD',
#  'Reading, PA',
#  'Red Devil, AK',
#  'Red Dog, AK',
#  'Redding, CA',
#  'Reno, NV',
#  'Rhinelander, WI',
#  'Richmond, VA',
#  'Riverside, CA',
#  'Riverton/Lander, WY',
#  'Roanoke, VA',
#  'Rochester, MN',
#  'Rochester, NY',
#  'Rock Springs, WY',
#  'Rockford, IL',
#  'Rockland, ME',
#  'Rocky Mount, NC',
#  'Roseburg, OR',
#  'Roswell, NM',
#  'Rota, TT',
#  'Roxboro, NC',
#  'Ruby, AK',
#  'Russian Mission, AK',
#  'Rutland, VT',
#  'Sacramento, CA',
#  'Saginaw/Bay City/Midland, MI',
#  'Saipan, TT',
#  'Salem, OR',
#  'Salina, KS',
#  'Salinas/Monterey, CA',
#  'Salisbury, MD',
#  'Salmon, ID',
#  'Salt Lake City, UT',
#  'San Angelo, TX',
#  'San Antonio, TX',
#  'San Bernardino, CA',
#  'San Diego, CA',
#  'San Francisco, CA',
#  'San Jose, CA',
#  'San Juan, PR',
#  'San Luis Obispo, CA',
#  'Sandpoint, AK',
#  'Sanford, FL',
#  'Santa Ana, CA',
#  'Santa Barbara, CA',
#  'Santa Fe, NM',
#  'Santa Maria, CA',
#  'Santa Rosa, CA',
#  'Saranac Lake/Lake Placid, NY',
#  'Sarasota/Bradenton, FL',
#  'Sault Ste. Marie, MI',
#  'Savannah, GA',
#  'Savoonga, AK',
#  'Scammon Bay, AK',
#  'Scottsbluff, NE',
#  'Scranton/Wilkes-Barre, PA',
#  'Seal Bay, AK',
#  'Seattle, WA',
#  'Selawik, AK',
#  'Seldovia, AK',
#  'Shageluk, AK',
#  'Shaktoolik, AK',
#  'Sheldon Point, AK',
#  'Shemya, AK',
#  'Sheridan, WY',
#  'Shishmaref, AK',
#  'Show Low, AZ',
#  'Shreveport, LA',
#  'Shungnak, AK',
#  'Sidney, MT',
#  'Silver City/Hurley, NM',
#  'Sioux City, IA',
#  'Sioux Falls, SD',
#  'Sitka, AK',
#  'Sitkinak, AK',
#  'Skagway, AK',
#  'Skwentna, AK',
#  'Sleetmute, AK',
#  'Smyrna, TN',
#  'South Bend, IN',
#  'South Naknek, AK',
#  'Spokane, WA',
#  'Springfield, IL',
#  'Springfield, MO',
#  'St. Cloud, MN',
#  'St. George Island, AK',
#  'St. George, UT',
#  'St. Louis, MO',
#  "St. Mary's, AK",
#  'St. Michael, AK',
#  'St. Paul, AK',
#  'St. Petersburg, FL',
#  'State College, PA',
#  'Staunton, VA',
#  'Stebbins, AK',
#  'Stevens Village, AK',
#  'Stillwater, OK',
#  'Stockton, CA',
#  'Stony River, AK',
#  'Stuart, FL',
#  'Sun Valley/Hailey/Ketchum, ID',
#  'Syracuse, NY',
#  'Tacoma, WA',
#  'Tallahassee, FL',
#  'Tampa, FL',
#  'Tanana, AK',
#  'Tatitlek, AK',
#  'Teller, AK',
#  'Telluride, CO',
#  'Tenakee, AK',
#  'Terror Lake, AK',
#  'Teterboro, NJ',
#  'Texarkana, AR',
#  'Thermal, CA',
#  'Thief River Falls, MN',
#  'Thorne Bay, AK',
#  'Tin City, AK',
#  'Tinian, TT',
#  'Togiak, AK',
#  'Tok, AK',
#  'Toksook, AK',
#  'Toledo, OH',
#  'Tonopah, NV',
#  'Trading Bay, AK',
#  'Traverse City, MI',
#  'Trenton, NJ',
#  'Tucson, AZ',
#  'Tulsa, OK',
#  'Tuluksak, AK',
#  'Tuntutuliak, AK',
#  'Tununak, AK',
#  'Tupelo, MS',
#  'Tuscaloosa, AL',
#  'Twin Falls, ID',
#  'Twin Hills, AK',
#  'Tyler, TX',
#  'Tyonek, AK',
#  'Uganik, AK',
#  'Ugashik, AK',
#  'Ukiah, CA',
#  'Unalakleet, AK',
#  'Unalaska, AK',
#  'Utopia, AK',
#  'Valdez, AK',
#  'Valdosta, GA',
#  'Valparaiso, FL',
#  'Valparaiso, IN',
#  'Van Nuys, CA',
#  'Venetie, AK',
#  'Vernal, UT',
#  'Vero Beach, FL',
#  'Victoria, TX',
#  'Vieques, PR',
#  'Visalia, CA',
#  'Waco, TX',
#  'Wainwright, AK',
#  'Wake Island, TT',
#  'Wales, AK',
#  'Walla Walla, WA',
#  'Washington, DC',
#  'Waterbury, CT',
#  'Waterloo, IA',
#  'Watertown, NY',
#  'Wausau, WI',
#  'Wenatchee, WA',
#  'West Palm Beach, FL',
#  'West Palm Beach/Palm Beach, FL',
#  'West Point, AK',
#  'Westerly, RI',
#  'Whale Pass, AK',
#  'White Mountain, AK',
#  'White Plains, NY',
#  'Wichita Falls, TX',
#  'Wichita, KS',
#  'Williamsport, PA',
#  'Williston, ND',
#  'Wilmington, NC',
#  'Wilmington, OH',
#  'Winston-Salem, NC',
#  'Wolf Point, MT',
#  'Worcester, MA',
#  'Wrangell, AK',
#  'Yakima, WA',
#  'Yakutat, AK',
#  'York, PA',
#  'Youngstown/Warren, OH',
#  'Yuma, AZ',
#  'Zachar Bay, AK'}

# %%
#get population
population = pd.read_csv('../data/Airports2.csv').sort_values('Fly_date')
population.head()
# Out:
#         Origin_airport Destination_airport     Origin_city Destination_city  \
# 730469             SEA                 ORD     Seattle, WA      Chicago, IL
# 448453             CLE                 EWR   Cleveland, OH       Newark, NJ
# 1458454            CRW                 ROA  Charleston, WV      Roanoke, VA
# 448454             CLE                 EWR   Cleveland, OH       Newark, NJ
# 448455             CLE                 EWR   Cleveland, OH       Newark, NJ
#
#          Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 730469         1713   4410       30      1721  1990-01-01            5154164
# 448453         1476   4619       31       404  1990-01-01            2103367
# 1458454         388   2100       21       114  1990-01-01             307480
# 448454         1337   3348       31       404  1990-01-01            2103367
# 448455         2787   4888       52       404  1990-01-01            2103367
#
#          Destination_population  Org_airport_lat  Org_airport_long  \
# 730469                 16395048        47.449001       -122.308998
# 448453                 16868983        41.411701        -81.849800
# 1458454                  269195        38.373100        -81.593201
# 448454                 16868983        41.411701        -81.849800
# 448455                 16868983        41.411701        -81.849800
#
#          Dest_airport_lat  Dest_airport_long
# 730469          41.978600         -87.904800
# 448453          40.692501         -74.168701
# 1458454         37.325500         -79.975403
# 448454          40.692501         -74.168701
# 448455          40.692501         -74.168701

# %%
f = '../data/us_air_raw_data/770841524_T_T100D_MARKET_ALL_CARRIER-1.csv'   
df=pd.read_csv(f)
df=df[df.MONTH==12]
df.head()
# Out:
#       PASSENGERS  DISTANCE UNIQUE_CARRIER     UNIQUE_CARRIER_NAME  \
# 7640         0.0    1167.0             WN  Southwest Airlines Co.
# 7641         0.0     470.0             WN  Southwest Airlines Co.
# 7642         0.0     562.0             WN  Southwest Airlines Co.
# 7643         0.0    2306.0             WN  Southwest Airlines Co.
# 7644         0.0     333.0             WN  Southwest Airlines Co.
#
#       ORIGIN_AIRPORT_ID ORIGIN     ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# 7640              11618    EWR           Newark, NJ               NJ
# 7641              11697    FLL  Fort Lauderdale, FL               FL
# 7642              11996    GSP            Greer, SC               SC
# 7643              12264    IAD       Washington, DC               VA
# 7644              12278    ICT          Wichita, KS               KS
#
#       DEST_AIRPORT_ID DEST   DEST_CITY_NAME DEST_STATE_ABR  YEAR  MONTH  \
# 7640            13495  MSY  New Orleans, LA             LA  2018     12
# 7641            10994  CHS   Charleston, SC             SC  2018     12
# 7642            13232  MDW      Chicago, IL             IL  2018     12
# 7643            14747  SEA      Seattle, WA             WA  2018     12
# 7644            11259  DAL       Dallas, TX             TX  2018     12
#
#       Unnamed: 14
# 7640          NaN
# 7641          NaN
# 7642          NaN
# 7643          NaN
# 7644          NaN

# %%
A = set(list(df.ORIGIN_CITY_NAME)+list(df.DEST_CITY_NAME))
B = set(list(population.Origin_city)+list(population.Destination_city))

# %%
len([i for i in A if i not in B])/len(A)
# Out:
# 0.5773195876288659

# %%
edges = pd.read_pickle('../data/ranked_edges.pkl')
nodes = list(set(list(edges[0])+list(edges[1])))
nodes_full_name = list(set(list(data.source.unique())+list(data.target.unique())))
nodes_key_name = [text_to_id(str(i)) for i in nodes_full_name]
nodes_city_name = [i[:-4].split('/') for i in nodes_full_name]
nodes_state_name = [i[-2:] for i in nodes_full_name]

# %%
nodes
# Out:
# ['gambell_ak',
#  'nuiqsut_ak',
#  'albany_ga',
#  'savoonga_ak',
#  'salmon_id',
#  'ambler_ak',
#  'koyukuk_ak',
#  'gulfportbiloxi_ms',
#  'miami_fl',
#  'west_palm_beachpalm_beach_fl',
#  'chicago_il',
#  'kenmore_wa',
#  'charlotte_nc',
#  'kearney_ne',
#  'russian_mission_ak',
#  'thermal_ca',
#  'laredo_tx',
#  'port_alsworth_ak',
#  'anaktuvuk_pass_ak',
#  'indianapolis_in',
#  'kingman_az',
#  'augusta_ga',
#  'trenton_nj',
#  'manley_hot_springs_ak',
#  'coffman_cove_ak',
#  'shemya_ak',
#  'detroit_mi',
#  'rapid_city_sd',
#  'gainesville_fl',
#  'rochester_mn',
#  'valparaiso_fl',
#  'tanana_ak',
#  'tyonek_ak',
#  'red_dog_ak',
#  'bradford_pa',
#  'parkersburg_wv',
#  'alakanuk_ak',
#  'pascokennewickrichland_wa',
#  'ogden_ut',
#  'plattsburgh_ny',
#  'boulder_city_nv',
#  'hancockhoughton_mi',
#  'alpine_ak',
#  'gulkana_ak',
#  'reading_pa',
#  'kwigillingok_ak',
#  'dickinson_nd',
#  'pueblo_co',
#  'sheldon_point_ak',
#  'hollis_ak',
#  'sandpoint_ak',
#  'lanai_hi',
#  'baton_rouge_la',
#  'yakima_wa',
#  'trading_bay_ak',
#  'fresno_ca',
#  'sheridan_wy',
#  'chignik_ak',
#  'tyler_tx',
#  'kokhanok_ak',
#  'hughes_ak',
#  'hydaburg_ak',
#  'new_haven_ct',
#  'port_bailey_ak',
#  'ketchikan_ak',
#  'bainbridge_ga',
#  'stillwater_ok',
#  'terror_lake_ak',
#  'huslia_ak',
#  'south_naknek_ak',
#  'baltimore_md',
#  'saginawbay_citymidland_mi',
#  'cedar_city_ut',
#  'alliance_ne',
#  'point_lay_ak',
#  'clarksburgfairmont_wv',
#  'memphis_tn',
#  'lake_charles_la',
#  'valparaiso_in',
#  'salem_or',
#  'portland_me',
#  'burlingtonmount_vernon_wa',
#  'carlsbad_nm',
#  'massena_ny',
#  'oklahoma_city_ok',
#  'bemidji_mn',
#  'chevak_ak',
#  'gary_in',
#  'mccarthy_ak',
#  'corpus_christi_tx',
#  'ponce_pr',
#  'arlington_tx',
#  'ogdensburg_ny',
#  'charlottesville_va',
#  'saranac_lakelake_placid_ny',
#  'morristown_nj',
#  'greenville_ms',
#  'kotzebue_ak',
#  'sioux_city_ia',
#  'jackson_wy',
#  'east_farmingdale_ny',
#  'allakaket_ak',
#  'thorne_bay_ak',
#  'laramie_wy',
#  'jackson_tn',
#  'lansing_mi',
#  'twin_hills_ak',
#  'latrobe_pa',
#  'ouzinkie_ak',
#  'eagle_co',
#  'napakiak_ak',
#  'wales_ak',
#  'bloomington_in',
#  'el_dorado_ar',
#  'kitoi_bay_ak',
#  'crooked_creek_ak',
#  'beaver_ak',
#  'reno_nv',
#  'lawrence_ma',
#  'iron_mountainkingsfd_mi',
#  'akutan_ak',
#  'evansville_in',
#  'montrosedelta_co',
#  'boston_ma',
#  'jacksonvicksburg_ms',
#  'fayetteville_nc',
#  'butler_pa',
#  'asheville_nc',
#  'lebanon-hanover_nh',
#  'cheyenne_wy',
#  'kalispell_mt',
#  'newport_newswilliamsburg_va',
#  'saipan_tt',
#  'college_stationbryan_tx',
#  'kalamazoo_mi',
#  'kalskag_ak',
#  'victoria_tx',
#  'wilmington_nc',
#  'logan_ut',
#  'orlando_fl',
#  'tuluksak_ak',
#  'grand_rapids_mi',
#  'mekoryuk_ak',
#  'traverse_city_mi',
#  'nome_ak',
#  'tinian_tt',
#  'hartford_ct',
#  'kivalina_ak',
#  'kuparuk_ak',
#  'dover_de',
#  'central_ak',
#  'peru_in',
#  'little_rock_ar',
#  'savannah_ga',
#  'egegik_ak',
#  'chadron_ne',
#  'petersburg_ak',
#  'beckley_wv',
#  'new_stuyahok_ak',
#  'kwethluk_ak',
#  'bar_harbor_me',
#  'wrangell_ak',
#  'granite_point_ak',
#  'spokane_wa',
#  'camp_springs_md',
#  'kenai_ak',
#  'anacortes_wa',
#  'bloomingtonnormal_il',
#  'gaylord_mi',
#  'lafayette_in',
#  'allentownbethlehemeaston_pa',
#  'anvik_ak',
#  'waco_tx',
#  'sleetmute_ak',
#  'san_luis_obispo_ca',
#  'macon_ga',
#  'aberdeen_sd',
#  'north_platte_ne',
#  'white_mountain_ak',
#  'destin_fl',
#  'gunnison_co',
#  'blue_fox_bay_ak',
#  'bridgeport_ct',
#  'fairbanks_ak',
#  'philadelphia_pa',
#  'old_harbor_ak',
#  'atlantic_city_nj',
#  'rock_springs_wy',
#  'block_island_ri',
#  'kobuk_ak',
#  'kamuela_hi',
#  'gustavus_ak',
#  'san_angelo_tx',
#  'dillingham_ak',
#  'chalkyitsik_ak',
#  'st_petersburg_fl',
#  'circle_ak',
#  'hyder_ak',
#  'appleton_wi',
#  'liberal_ks',
#  'culebra_pr',
#  'provincetown_ma',
#  'nanwalek_ak',
#  'fort_dix_nj',
#  'marana_az',
#  'wenatchee_wa',
#  'holy_cross_ak',
#  'florence_sc',
#  'san_diego_ca',
#  'dubois_pa',
#  'santa_barbara_ca',
#  'killeen_tx',
#  'klamath_falls_or',
#  'shungnak_ak',
#  'ugashik_ak',
#  'kona_hi',
#  'galbraith_lake_ak',
#  'smyrna_tn',
#  'dayton_oh',
#  'new_bedfordfall_river_ma',
#  'columbus_ms',
#  'mason_city_ia',
#  'midlandodessa_tx',
#  'fort_smith_ar',
#  'telluride_co',
#  'islip_ny',
#  'bozeman_mt',
#  'vieques_pr',
#  'mayaguez_pr',
#  'duluth_mn',
#  'nantucket_ma',
#  'jackson_mi',
#  'minto_ak',
#  'san_jose_ca',
#  'heber_ut',
#  'platinum_ak',
#  'buckland_ak',
#  'st_george_island_ak',
#  'riverside_ca',
#  'dora_bay_ak',
#  'jacksonville_fl',
#  'albuquerque_nm',
#  'fargo_nd',
#  'del_rio_tx',
#  'salina_ks',
#  'kongiganak_ak',
#  'san_francisco_ca',
#  'pendleton_or',
#  'marshall_ak',
#  'hilton_head_sc',
#  'hoolehua_hi',
#  'melbourne_fl',
#  'brownsville_tx',
#  'decatur_al',
#  'klawock_ak',
#  'petaluma_ca',
#  'birch_creek_ak',
#  'bangor_me',
#  'page_az',
#  'daytona_beach_fl',
#  'scrantonwilkes-barre_pa',
#  'owensboro_ky',
#  'fort_leonard_wood_mo',
#  'el_paso_tx',
#  'muskegon_mi',
#  'ukiah_ca',
#  'moses_lake_wa',
#  'monticello_ny',
#  'greenville_nc',
#  'alamosa_co',
#  'casper_wy',
#  'chattanooga_tn',
#  'phoenix_az',
#  'wichita_ks',
#  'provo_ut',
#  'hattiesburglaurel_ms',
#  'eagle_harbor_ak',
#  'aspen_co',
#  'cody_wy',
#  'nightmute_ak',
#  'williamsport_pa',
#  'gallup_nm',
#  'koliganek_ak',
#  'winston-salem_nc',
#  'coldfoot_ak',
#  'portsmouth_nh',
#  'elmiracorning_ny',
#  'pilot_station_ak',
#  'akiachak_ak',
#  'harrison_ar',
#  'fort_jefferson_fl',
#  'cincinnati_oh',
#  'cordova_ak',
#  'joplin_mo',
#  'rota_tt',
#  'mountain_view_ca',
#  'stebbins_ak',
#  'port_protection_ak',
#  'prospect_creek_ak',
#  'roswell_nm',
#  'marionherrin_il',
#  'napaskiak_ak',
#  'new_york_ny',
#  'hobbs_nm',
#  'mosinee_wi',
#  'anchorage_ak',
#  'valdosta_ga',
#  'northampton_ma',
#  'new_iberia_la',
#  'visalia_ca',
#  'fort_yukon_ak',
#  'columbus_ga',
#  'rivertonlander_wy',
#  'roanoke_va',
#  'st_marys_ak',
#  'akiak_ak',
#  'rutland_vt',
#  'lake_havasu_city_az',
#  'angoon_ak',
#  'elim_ak',
#  'aniak_ak',
#  'ceiba_pr',
#  'vero_beach_fl',
#  'missionmcallenedinburg_tx',
#  'lawrenceville_ga',
#  'farmington_nm',
#  'chignik_lagoon_ak',
#  'kapalua_hi',
#  'shreveport_la',
#  'olympia_wa',
#  'decatur_il',
#  'bethel_ak',
#  'teterboro_nj',
#  'la_crosse_wi',
#  'burlington_ia',
#  'st_paul_ak',
#  'lihue_hi',
#  'paducah_ky',
#  'vernal_ut',
#  'naukiti_ak',
#  'broomfield_co',
#  'marathon_fl',
#  'lubbock_tx',
#  'thief_river_falls_mn',
#  'hyannis_ma',
#  'rocky_mount_nc',
#  'albany_ny',
#  'kiana_ak',
#  'elko_nv',
#  'point_baker_ak',
#  'elfin_cove_ak',
#  'myrtle_beach_sc',
#  'grand_junction_co',
#  'cape_romanzof_ak',
#  'escanaba_mi',
#  'ithacacortland_ny',
#  'toledo_oh',
#  'lynchburg_va',
#  'st_cloud_mn',
#  'wichita_falls_tx',
#  'seattle_wa',
#  'atmautluak_ak',
#  'cortez_co',
#  'burlington_vt',
#  'cold_bay_ak',
#  'minneapolisst_paul_mn',
#  'cape_lisburne_ak',
#  'honolulu_hi',
#  'springfield_mo',
#  'noatak_ak',
#  'rockford_il',
#  'raleighdurham_nc',
#  'atka_ak',
#  'murray_ky',
#  'palm_springs_ca',
#  'north_kingstown_ri',
#  'lancaster_pa',
#  'unalakleet_ak',
#  'pago_pago_tt',
#  'hickory_nc',
#  'santa_maria_ca',
#  'huntsville_al',
#  'brainerd_mn',
#  'santa_fe_nm',
#  'glasgow_mt',
#  'eau_claire_wi',
#  'stevens_village_ak',
#  'new_orleans_la',
#  'ontario_ca',
#  'augustawaterville_me',
#  'devils_lake_nd',
#  'muscle_shoals_al',
#  'pullman_wa',
#  'st_louis_mo',
#  'denver_co',
#  'port_alexander_ak',
#  'pontiac_mi',
#  'las_vegas_nv',
#  'waterbury_ct',
#  'dallasfort_worth_tx',
#  'port_williams_ak',
#  'tucson_az',
#  'missoula_mt',
#  'madison_wi',
#  'portland_or',
#  'jonesboro_ar',
#  'green_bay_wi',
#  'eastsound_wa',
#  'peach_springs_az',
#  'hot_springs_ar',
#  'corvallis_or',
#  'los_angeles_ca',
#  'youngstownwarren_oh',
#  'stuart_fl',
#  'false_pass_ak',
#  'prescott_az',
#  'tonopah_nv',
#  'ruby_ak',
#  'yuma_az',
#  'wilmington_oh',
#  'key_west_fl',
#  'new_bernmoreheadbeaufort_nc',
#  'rampart_ak',
#  'twin_falls_id',
#  'bishop_ca',
#  'yakutat_ak',
#  'karluk_ak',
#  'port_moller_ak',
#  'danger_bay_ak',
#  'sioux_falls_sd',
#  'minot_nd',
#  'moab_ut',
#  'newtok_ak',
#  'nikolski_ak',
#  'mountain_village_ak',
#  'salisbury_md',
#  'monroe_la',
#  'deering_ak',
#  'skwentna_ak',
#  'inyokern_ca',
#  'hibbing_mn',
#  'chefornak_ak',
#  'syracuse_ny',
#  'manassas_va',
#  'gaithersburg_md',
#  'cedar_rapidsiowa_city_ia',
#  'minneapolis_mn',
#  'shageluk_ak',
#  'lafayette_la',
#  'golovin_ak',
#  'chenega_ak',
#  'north_bendcoos_bay_or',
#  'white_plains_ny',
#  'pelican_ak',
#  'anniston_al',
#  'international_falls_mn',
#  'goodnews_bay_ak',
#  'whale_pass_ak',
#  'hoonah_ak',
#  'chisana_ak',
#  'montgomery_al',
#  'edna_bay_ak',
#  'manteo_nc',
#  'merced_ca',
#  'butte_mt',
#  'garden_city_ks',
#  'kalaupapa_hi',
#  'lincoln_ne',
#  'cape_girardeau_mo',
#  'sitka_ak',
#  'pellston_mi',
#  'tatitlek_ak',
#  'friday_harbor_wa',
#  'king_salmon_ak',
#  'bakersfield_ca',
#  'havre_mt',
#  'san_bernardino_ca',
#  'hanford_ca',
#  'selawik_ak',
#  'stockton_ca',
#  'akron_oh',
#  'cape_newenham_ak',
#  'point_hope_ak',
#  'pierre_sd',
#  'eek_ak',
#  'wolf_point_mt',
#  'washington_dc',
#  'stony_river_ak',
#  'mcgrath_ak',
#  'laconia_nh',
#  'bend_or',
#  'fort_lauderdale_fl',
#  'mammoth_lakes_ca',
#  'staunton_va',
#  'longview_tx',
#  'concord_nc',
#  'flint_mi',
#  'uganik_ak',
#  'scottsbluff_ne',
#  'kirksville_mo',
#  'nunapitchuk_ak',
#  'helena_mt',
#  'chomondely_sound_ak',
#  'medford_or',
#  'show_low_az',
#  'bellingham_wa',
#  'guam_tt',
#  'bay_city_tx',
#  'louisville_ky',
#  'greensborohigh_point_nc',
#  'lazy_bay_ak',
#  'westerly_ri',
#  'punta_gorda_fl',
#  'craig_ak',
#  'perryville_ak',
#  'marthas_vineyard_ma',
#  'akun_ak',
#  'shaktoolik_ak',
#  'levelock_ak',
#  'noorvik_ak',
#  'van_nuys_ca',
#  'bowling_green_ky',
#  'chignik_bay_ak',
#  'cleveland_oh',
#  'roxboro_nc',
#  'pocatello_id',
#  'ofu_tt',
#  'newburghpoughkeepsie_ny',
#  'nondalton_ak',
#  'greenville_sc',
#  'sarasotabradenton_fl',
#  'tampa_fl',
#  'fairfield_ca',
#  'nashville_tn',
#  'everett_wa',
#  'may_creek_ak',
#  'morgantown_wv',
#  'lewiston_id',
#  'rochester_ny',
#  'walla_walla_wa',
#  'ekwok_ak',
#  'brevig_mission_ak',
#  'bendredmond_or',
#  'mobile_al',
#  'seal_bay_ak',
#  'kasigluk_ak',
#  'norfolk_va',
#  'elizabeth_city_nc',
#  'hilo_hi',
#  'quinhagak_ak',
#  'greer_sc',
#  'kahului_hi',
#  'koyuk_ak',
#  'waterloo_ia',
#  'excursion_inlet_ak',
#  'kipnuk_ak',
#  'abilene_tx',
#  'niagara_falls_ny',
#  'borniteruby_creek_ak',
#  'colorado_springs_co',
#  'beaumontport_arthur_tx',
#  'hana_hi',
#  'aguadilla_pr',
#  'wausau_wi',
#  'hayden_co',
#  'sidney_mt',
#  'kiluda_bay_ak',
#  'redding_ca',
#  'atqasuk_ak',
#  'alexandria_la',
#  'rockland_me',
#  'west_palm_beach_fl',
#  'greeneville_tn',
#  'salt_lake_city_ut',
#  'naples_fl',
#  'flagstaff_az',
#  'manhattanft_riley_ks',
#  'bismarckmandan_nd',
#  'marietta_ga',
#  'galena_ak',
#  'kaltag_ak',
#  'napa_ca',
#  'barrow_ak',
#  'la_grande_or',
#  'gillette_wy',
#  'manokotak_ak',
#  'tuntutuliak_ak',
#  'pedro_bay_ak',
#  'columbus_oh',
#  'bettles_ak',
#  'ironwood_mi',
#  'olga_bay_ak',
#  'metlakatla_ak',
#  'nulato_ak',
#  'tok_ak',
#  'milwaukee_wi',
#  'columbia_mo',
#  'kansas_city_mo',
#  'red_devil_ak',
#  'jacksonvillecamp_lejeune_nc',
#  'houston_tx',
#  'dodge_city_ks',
#  'zachar_bay_ak',
#  'oceana_va',
#  'toksook_ak',
#  'roseburg_or',
#  'boise_id',
#  'durango_co',
#  'new_londongroton_ct',
#  'williston_nd',
#  'scammon_bay_ak',
#  'tulsa_ok',
#  'ashland_wv',
#  'alpena_mi',
#  'hays_ks',
#  'hooper_bay_ak',
#  'state_college_pa',
#  'utopia_ak',
#  'arcataeureka_ca',
#  'oakland_ca',
#  'rhinelander_wi',
#  'grand_island_ne',
#  'fitiuta_village_tt',
#  'newport_ri',
#  'lawtonfort_sill_ok',
#  'silver_cityhurley_nm',
#  'meridian_ms',
#  'teller_ak',
#  'harlingensan_benito_tx',
#  'santa_rosa_ca',
#  'nelson_lagoon_ak',
#  'sitkinak_ak',
#  'charlestondunbar_wv',
#  'barter_island_ak',
#  'harrisburg_pa',
#  'omaha_ne',
#  'charlotte_amalie_vi',
#  'morrisville_vt',
#  'el_centro_ca',
#  'manchester_nh',
#  'providence_ri',
#  'princetonbluefield_wv',
#  'seldovia_ak',
#  'marquette_mi',
#  'tin_city_ak',
#  'austin_tx',
#  'dubuque_ia',
#  'glendive_mt',
#  'crescent_city_ca',
#  'great_falls_mt',
#  'kodiak_ak',
#  'larsen_bay_ak',
#  'tuscaloosa_al',
#  'san_antonio_tx',
#  'columbia_sc',
#  'san_juan_pr',
#  'newark_nj',
#  'springfield_il',
#  'west_point_ak',
#  'sun_valleyhaileyketchum_id',
#  'columbia_tn',
#  'binghamton_ny',
#  'togiak_ak',
#  'belleville_il',
#  'panama_city_fl',
#  'salinasmonterey_ca',
#  'worcester_ma',
#  'kasaan_ak',
#  'grand_canyon_az',
#  'kake_ak',
#  'boca_raton_fl',
#  'port_angeles_wa',
#  'brownwood_tx',
#  'lewisburg_wv',
#  'port_graham_ak',
#  'moline_il',
#  'brunswick_ga',
#  'venetie_ak',
#  'sacramento_ca',
#  'st_michael_ak',
#  'kodiak_island_ak',
#  'deadhorse_ak',
#  'birmingham_al',
#  'wake_island_tt',
#  'st_george_ut',
#  'champaignurbana_il',
#  'kotlik_ak',
#  'kennesaw_ga',
#  'mccook_ne',
#  'wainwright_ak',
#  'santa_ana_ca',
#  'erie_pa',
#  'york_pa',
#  'chicagoromeoville_il',
#  'charleston_sc',
#  'frederick_md',
#  'minchumina_ak',
#  'eagle_ak',
#  'altoona_pa',
#  'chicken_ak',
#  'fayetteville_ar',
#  'clarks_point_ak',
#  'eugene_or',
#  'tenakee_ak',
#  'presque_islehoulton_me',
#  'bullhead_city_az',
#  'hopkinsville_ky',
#  'chuathbaluk_ak',
#  'watertown_ny',
#  'sanford_fl',
#  'grayling_ak',
#  'fort_wayne_in',
#  'clovis_nm',
#  'pittsburgh_pa',
#  'knoxville_tn',
#  'newport_or',
#  'monterey_ca',
#  'port_heiden_ak',
#  'pensacola_fl',
#  'beluga_ak',
#  'chico_ca',
#  'unalaska_ak',
#  'buffalo_ny',
#  'south_bend_in',
#  'bristoljohnson_citykingsport_tn',
#  'johnstown_pa',
#  'burbank_ca',
#  'texarkana_ar',
#  'beverly_ma',
#  'east_hampton_ny',
#  'long_beach_ca',
#  'juneau_ak',
#  'palmer_ak',
#  'igiugig_ak',
#  'billings_mt',
#  'skagway_ak',
#  'quincy_il',
#  'healy_ak',
#  'arctic_village_ak',
#  'fort_dodge_ia',
#  'grand_forks_nd',
#  'lexington_ky',
#  'akhiok_ak',
#  'pilot_point_ak',
#  'adak_island_ak',
#  'dothan_al',
#  'jamestown_nd',
#  'iliamna_ak',
#  'hagerstown_md',
#  'denton_tx',
#  'shishmaref_ak',
#  'tallahassee_fl',
#  'christiansted_vi',
#  'tupelo_ms',
#  'haines_ak',
#  'tununak_ak',
#  'amarillo_tx',
#  'richmond_va',
#  'homer_ak',
#  'peoria_il',
#  'franklinoil_city_pa',
#  'emmonak_ak',
#  'des_moines_ia',
#  'tacoma_wa',
#  'fort_myers_fl',
#  'valdez_ak',
#  'fort_drum_ny',
#  'port_lions_ak',
#  'sault_ste_marie_mi',
#  'kizhuyak_ak',
#  'dallas_tx',
#  'idaho_falls_id',
#  'king_cove_ak',
#  'atlanta_ga',
#  'bedford_ma']

# %%
new_nodes_city_name = []
for cities in nodes_city_name:
    new_cities = []
    new_cities = new_cities+cities
    for city in cities:
        cs = city.replace('Island','').replace('North','').replace('Bay','')\
        .replace('East','').replace('West','').replace('South','').replace('Port','').replace('Lake','').strip()
        if city!=cs:
            new_cities.append(cs)
        for c in cs.replace('-',' ').split(' '):
            if c!=cs:
                new_cities.append(c)
    new_nodes_city_name.append(new_cities)
nodes_city_name = new_nodes_city_name

# %%
nodes_population = {}
not_found = []
for key,cities,state in zip(nodes_key_name,nodes_city_name,nodes_state_name):
    if key in nodes:
        nodes_population[key] = []
        if len(cities)>1:
            for city in cities:
                try:
                    nodes_population[key].append(get_city_opendata(city, state))
                except:
                    not_found.append(key)
                    print(key,city,state)
                    nodes_population[key].append(np.nan)
        else:
            city = cities[0]
            try:
                nodes_population[key].append(get_city_opendata(city, state))
            except:
                not_found.append(key)
                print(key,city,state)
                nodes_population[key].append(np.nan)
# Out:
# utopia_ak Utopia AK
# north_kingstown_ri North Kingstown RI
# north_kingstown_ri Kingstown RI
# cape_lisburne_ak Cape Lisburne AK
# cape_lisburne_ak Lisburne AK
# fort_drum_ny Fort Drum NY
# fort_drum_ny Drum NY
# zachar_bay_ak Zachar Bay AK
# zachar_bay_ak Zachar AK
# granite_point_ak Granite Point AK
# granite_point_ak Granite AK
# mammoth_lakes_ca Mammoth s CA
# adak_island_ak Adak Island AK
# twin_hills_ak Twin Hills AK
# twin_hills_ak Twin AK
# twin_hills_ak Hills AK
# manhattanft_riley_ks Ft. Riley KS
# manhattanft_riley_ks Ft. KS
# akun_ak Akun AK
# alpine_ak Alpine AK
# hoolehua_hi Hoolehua HI
# birch_creek_ak Birch Creek AK
# birch_creek_ak Birch AK
# tinian_tt Tinian TT
# cape_romanzof_ak Cape Romanzof AK
# cape_romanzof_ak Romanzof AK
# westerly_ri erly RI
# kuparuk_ak Kuparuk AK
# east_farmingdale_ny East Farmingdale NY
# prospect_creek_ak Prospect Creek AK
# prospect_creek_ak Prospect AK
# fitiuta_village_tt Fitiuta Village TT
# fitiuta_village_tt Fitiuta TT
# fitiuta_village_tt Village TT
# port_bailey_ak Port Bailey AK
# port_bailey_ak Bailey AK
# lazy_bay_ak Lazy Bay AK
# lazy_bay_ak Lazy AK
# blue_fox_bay_ak Blue Fox Bay AK
# blue_fox_bay_ak Blue Fox AK
# blue_fox_bay_ak Blue AK
# eagle_harbor_ak Eagle Harbor AK
# chomondely_sound_ak Chomondely Sound AK
# chomondely_sound_ak Chomondely AK
# chomondely_sound_ak Sound AK
# lawtonfort_sill_ok Fort Sill OK
# lawtonfort_sill_ok Sill OK
# st_michael_ak St. Michael AK
# nelson_lagoon_ak Nelson Lagoon AK
# nelson_lagoon_ak Nelson AK
# sheldon_point_ak Sheldon Point AK
# sheldon_point_ak Sheldon AK
# ofu_tt Ofu TT
# seal_bay_ak Seal Bay AK
# seal_bay_ak Seal AK
# sandpoint_ak Sandpoint AK
# kapalua_hi Kapalua HI
# barter_island_ak Barter Island AK
# barter_island_ak Barter AK
# dora_bay_ak Dora Bay AK
# dora_bay_ak Dora AK
# van_nuys_ca Van Nuys CA
# van_nuys_ca Nuys CA
# olga_bay_ak Olga Bay AK
# olga_bay_ak Olga AK
# sitkinak_ak Sitkinak AK
# whale_pass_ak Whale Pass AK
# whale_pass_ak Whale AK
# rota_tt Rota TT
# port_williams_ak Port Williams AK
# port_williams_ak Williams AK
# portland_or land OR
# northampton_ma ampton MA
# shemya_ak Shemya AK
# chenega_ak Chenega AK
# port_alexander_ak Port Alexander AK
# port_alexander_ak Alexander AK
# st_paul_ak St. Paul AK
# port_protection_ak Port Protection AK
# port_protection_ak Protection AK
# ashland_wv Ashland WV
# sault_ste_marie_mi Sault Ste. Marie MI
# lanai_hi Lanai HI
# st_petersburg_fl St. Petersburg FL
# st_george_island_ak St. George Island AK
# st_george_island_ak St. George AK
# west_point_ak West Point AK
# iron_mountainkingsfd_mi Kingsfd MI
# pago_pago_tt Pago Pago TT
# pago_pago_tt Pago TT
# pago_pago_tt Pago TT
# saipan_tt Saipan TT
# cape_newenham_ak Cape Newenham AK
# cape_newenham_ak Newenham AK
# marthas_vineyard_ma Martha's Vineyard MA
# marthas_vineyard_ma Martha's MA
# st_marys_ak St. Mary's AK
# wake_island_tt Wake Island TT
# wake_island_tt Wake TT
# portsmouth_nh smouth NH
# deadhorse_ak Deadhorse1 AK
# kitoi_bay_ak Kitoi Bay AK
# kitoi_bay_ak Kitoi AK
# nanwalek_ak Nanwalek AK
# chignik_bay_ak Chignik Bay AK
# guam_tt Guam TT
# fort_jefferson_fl Fort Jefferson FL
# oceana_va Oceana VA
# fairbanks_ak Fairbanks1 AK
# block_island_ri Block Island RI
# block_island_ri Block RI
# danger_bay_ak Danger Bay AK
# danger_bay_ak Danger AK
# kiluda_bay_ak Kiluda Bay AK
# kiluda_bay_ak Kiluda AK
# clarks_point_ak Clarks Point AK
# clarks_point_ak Clarks AK
# portland_me land ME
# st_george_ut St. George UT
# terror_lake_ak Terror Lake AK
# terror_lake_ak Terror AK
# jacksonvillecamp_lejeune_nc Camp Lejeune NC
# jacksonvillecamp_lejeune_nc Camp NC
# jacksonvillecamp_lejeune_nc Lejeune NC
# lihue_hi Lihue HI
# naukiti_ak Naukiti AK
# trading_bay_ak Trading Bay AK
# trading_bay_ak Trading AK
# uganik_ak Uganik AK
# kizhuyak_ak Kizhuyak AK
# eastsound_wa sound WA
# kona_hi Kona HI
# lebanon-hanover_nh Lebanon-Hanover NH
# borniteruby_creek_ak Bornite AK
# borniteruby_creek_ak Ruby Creek AK
# kamuela_hi Kamuela HI
# galbraith_lake_ak Galbraith Lake AK
# galbraith_lake_ak Galbraith AK

# %%
population = {}
for n,p in nodes_population.items():
    if len(p)==0:
        num = np.nan
    else:
        num = np.nan
        for i in p:
            if i>0:
                num = i
                break
    population[n]=num 
#     population[n]=np.nanmean(p)

# %%
manual_nodes = [i for i in nodes if i not in nodes_key_name]
manual_population = [16075,113383,57941,76639]
for n, p in zip(manual_nodes,manual_population):
    population[n]=p

# %%
len(nodes)
# Out:
# 775

# %%
len([i for i in population.values() if i>0])
# Out:
# 713

# %%
pd.DataFrame.from_dict(population,orient='index').to_pickle('../data/us_air_population_3.pkl')

# %%
edges = pd.read_pickle('../data/ranked_edges.pkl')

# %%
nodes = list(set(list(edges[0])+list(edges[1])))

# %%
population = pd.read_csv('../data/us_pop_2010.csv',encoding='latin-1').sort_values(by="NAME")
population['STNAME'] = population['STNAME'].apply(state_to_abbr)
population['NAME'] = population.apply(lambda row: text_to_id(str(row.NAME))+'_'+str(row.STNAME), axis=1)

# %%
population.head(5)
# Out:
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT                 NAME  \
# 36216      61     27     111      0     100       0   aastad_township_mn
# 67925      50     45       1      0       0       0  abbeville_county_sc
# 67656     162     45       0    100       0       0    abbeville_city_sc
# 1         162      1       0    124       0       0    abbeville_city_al
# 27235     157     22     113    100       0       0    abbeville_city_la
#
#       STNAME CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 36216     mn           213                213              213
# 67925     sc         25417              25417            25354
# 67656     sc          5237               5237             5224
# 1         al          2688               2688             2689
# 27235     la         12257              12258            12277
#
#        POPESTIMATE2011
# 36216              213
# 67925            25161
# 67656             5183
# 1                 2704
# 27235            12316

# %%
# list(population.NAME.unique())

# %%
city= 'San+Francisco'
state = 'CA'
# cmd = f'https://public.opendatasoft.com/api/records/1.0/search/?dataset=cities-and-towns-of-the-united-states&q={city}&sort=-pop_2010&facet=state&refine.state={state}'
cmd = 'https://public.opendatasoft.com/api/records/1.0/search/?dataset=cities-and-towns-of-the-united-states&q=santa+fe&sort=pop_2010&facet=state&refine.state=NM'
res = requests.get(cmd)
dct = json.loads(res.content)
records = dct['records']
if len(records)>1:
    record = [i['fields']['name'].upper() for i in records if i['fields']['name'].upper()== city.upper()]
    output = record['fields']['pop_2010']
else:
    output = records[0]['fields']['pop_2010']
output
# Out:
# 67947.0

# %%
{'bloomingtonnormal_il':76610,
 'marthas_vineyard_ma': 15000,
 'lawtonfort_sill_ok': 96867,
 'north_bendcoos_bay_or':9695,
 'midlandodessa_tx':99940,
 'bismarckmandan_nd':61272,
}

# %%
out_list = []
for n in nodes:
    name_str = n.split('_')
    city = ' '.join(name_str[:-1])
    state = name_str[-1].upper()
    try:
        out = get_city_opendata(city, state)
    except:
        print(n)
        out = np.nan
    out_list.append(out)
# Out:
# bloomingtonnormal_il
# guam_tt
# kuparuk_ak
# marthas_vineyard_ma
# dallasfort_worth_tx
# sault_ste_marie_mi
# lawtonfort_sill_ok
# north_bendcoos_bay_or
# kamuela_hi
# kiluda_bay_ak
# port_williams_ak
# cape_newenham_ak
# midlandodessa_tx
# chignik_bay_ak
# bismarckmandan_nd
# st_marys_ak
# sheldon_point_ak
# utopia_ak
# alpine_ak
# st_michael_ak
# ashland_wv
# lebanon-hanover_nh
# wake_island_tt
# cedar_rapidsiowa_city_ia
# van_nuys_ca
# bendredmond_or
# kitoi_bay_ak
# birch_creek_ak
# princetonbluefield_wv
# oceana_va
# fitiuta_village_tt
# barter_island_ak
# sitkinak_ak
# kapalua_hi
# naukiti_ak
# lazy_bay_ak
# new_bedfordfall_river_ma
# youngstownwarren_oh
# block_island_ri
# hattiesburglaurel_ms
# cape_lisburne_ak
# nanwalek_ak
# prospect_creek_ak
# sarasotabradenton_fl
# newport_newswilliamsburg_va
# danger_bay_ak
# eagle_harbor_ak
# beaumontport_arthur_tx
# whale_pass_ak
# twin_hills_ak
# zachar_bay_ak
# scrantonwilkes-barre_pa
# allentownbethlehemeaston_pa
# manhattanft_riley_ks
# north_kingstown_ri
# port_alexander_ak
# tinian_tt
# uganik_ak
# pago_pago_tt
# chicagoromeoville_il
# sandpoint_ak
# lanai_hi
# saipan_tt
# jacksonvillecamp_lejeune_nc
# saranac_lakelake_placid_ny
# hoolehua_hi
# olga_bay_ak
# new_londongroton_ct
# newburghpoughkeepsie_ny
# missionmcallenedinburg_tx
# charlestondunbar_wv
# new_bernmoreheadbeaufort_nc
# augustawaterville_me
# burlingtonmount_vernon_wa
# terror_lake_ak
# raleighdurham_nc
# chenega_ak
# dora_bay_ak
# jacksonvicksburg_ms
# west_point_ak
# arcataeureka_ca
# fort_jefferson_fl
# trading_bay_ak
# fort_drum_ny
# pascokennewickrichland_wa
# granite_point_ak
# greensborohigh_point_nc
# kizhuyak_ak
# minneapolisst_paul_mn
# west_palm_beachpalm_beach_fl
# iron_mountainkingsfd_mi
# harlingensan_benito_tx
# cape_romanzof_ak
# nelson_lagoon_ak
# saginawbay_citymidland_mi
# sun_valleyhaileyketchum_id
# elmiracorning_ny
# st_petersburg_fl
# st_paul_ak
# st_george_ut
# blue_fox_bay_ak
# clarks_point_ak
# college_stationbryan_tx
# presque_islehoulton_me
# chomondely_sound_ak
# borniteruby_creek_ak
# lihue_hi
# rivertonlander_wy
# kona_hi
# franklinoil_city_pa
# bristoljohnson_citykingsport_tn
# adak_island_ak
# ofu_tt
# gulfportbiloxi_ms
# silver_cityhurley_nm
# shemya_ak
# east_farmingdale_ny
# montrosedelta_co
# rota_tt
# akun_ak
# hancockhoughton_mi
# galbraith_lake_ak
# clarksburgfairmont_wv
# ithacacortland_ny
# champaignurbana_il
# st_george_island_ak
# marionherrin_il
# port_bailey_ak
# seal_bay_ak
# salinasmonterey_ca
# port_protection_ak

# %%
# Out:
# 0.8141935483870968

# %%
len(nodes)
# Out:
# 775

# %%
len([i for i in data_out.values() if i>0])
# Out:
# 512

# %%
data_out = dict(zip(nodes,out_list))
pd.DataFrame.from_dict(data_out,orient='index').to_pickle('../data/us_air_population_2.pkl')

# %%
Y,N=0,0
for n in nodes:
    state = n[-2::]
    city = n[::-3]
    df_temp = population.copy()
    df_temp = df_temp[df_temp.STNAME==state]
    match_df = df_temp[df_temp.NAME.str.contains(city)]
    match_city = list(match_df.NAME)
    match_pop = list(match_df.CENSUS2010POP)
    if len(match_city)!=0:
        Y+=1
#         print(n,'******',list(zip(match_city,match_pop)))
    else:
        N +=1
        print(n,'>>>>>>>')
# Out:
# peru_in >>>>>>>
# valparaiso_in >>>>>>>
# greenville_ms >>>>>>>
# port_protection_ak >>>>>>>
# hoolehua_hi >>>>>>>
# adak_island_ak >>>>>>>
# wrangell_ak >>>>>>>
# shageluk_ak >>>>>>>
# kiana_ak >>>>>>>
# marietta_ga >>>>>>>
# vero_beach_fl >>>>>>>
# concord_nc >>>>>>>
# bakersfield_ca >>>>>>>
# santa_fe_nm >>>>>>>
# chenega_ak >>>>>>>
# perryville_ak >>>>>>>
# santa_rosa_ca >>>>>>>
# akron_oh >>>>>>>
# roanoke_va >>>>>>>
# hibbing_mn >>>>>>>
# columbus_oh >>>>>>>
# key_west_fl >>>>>>>
# niagara_falls_ny >>>>>>>
# rockland_me >>>>>>>
# corvallis_or >>>>>>>
# helena_mt >>>>>>>
# colorado_springs_co >>>>>>>
# boca_raton_fl >>>>>>>
# milwaukee_wi >>>>>>>
# anchorage_ak >>>>>>>
# north_platte_ne >>>>>>>
# norfolk_va >>>>>>>
# los_angeles_ca >>>>>>>
# nashville_tn >>>>>>>
# green_bay_wi >>>>>>>
# alakanuk_ak >>>>>>>
# gillette_wy >>>>>>>
# togiak_ak >>>>>>>
# cape_lisburne_ak >>>>>>>
# franklinoil_city_pa >>>>>>>
# sanford_fl >>>>>>>
# cape_girardeau_mo >>>>>>>
# excursion_inlet_ak >>>>>>>
# farmington_nm >>>>>>>
# sun_valleyhaileyketchum_id >>>>>>>
# allentownbethlehemeaston_pa >>>>>>>
# kalaupapa_hi >>>>>>>
# waco_tx >>>>>>>
# yuma_az >>>>>>>
# provincetown_ma >>>>>>>
# white_mountain_ak >>>>>>>
# roswell_nm >>>>>>>
# hana_hi >>>>>>>
# bullhead_city_az >>>>>>>
# old_harbor_ak >>>>>>>
# lake_havasu_city_az >>>>>>>
# salisbury_md >>>>>>>
# pocatello_id >>>>>>>
# albany_ny >>>>>>>
# seldovia_ak >>>>>>>
# jacksonvillecamp_lejeune_nc >>>>>>>
# tulsa_ok >>>>>>>
# charlotte_amalie_vi >>>>>>>
# metlakatla_ak >>>>>>>
# hydaburg_ak >>>>>>>
# healy_ak >>>>>>>
# rutland_vt >>>>>>>
# baltimore_md >>>>>>>
# tok_ak >>>>>>>
# harrison_ar >>>>>>>
# wausau_wi >>>>>>>
# miami_fl >>>>>>>
# ironwood_mi >>>>>>>
# frederick_md >>>>>>>
# angoon_ak >>>>>>>
# buffalo_ny >>>>>>>
# muscle_shoals_al >>>>>>>
# jackson_mi >>>>>>>
# billings_mt >>>>>>>
# port_angeles_wa >>>>>>>
# west_palm_beach_fl >>>>>>>
# burbank_ca >>>>>>>
# chignik_ak >>>>>>>
# victoria_tx >>>>>>>
# cape_newenham_ak >>>>>>>
# cheyenne_wy >>>>>>>
# harrisburg_pa >>>>>>>
# birch_creek_ak >>>>>>>
# petaluma_ca >>>>>>>
# bettles_ak >>>>>>>
# naukiti_ak >>>>>>>
# twin_hills_ak >>>>>>>
# rapid_city_sd >>>>>>>
# jackson_tn >>>>>>>
# eagle_co >>>>>>>
# evansville_in >>>>>>>
# kalskag_ak >>>>>>>
# shishmaref_ak >>>>>>>
# kenmore_wa >>>>>>>
# tyonek_ak >>>>>>>
# pueblo_co >>>>>>>
# valdez_ak >>>>>>>
# york_pa >>>>>>>
# fort_drum_ny >>>>>>>
# iliamna_ak >>>>>>>
# brainerd_mn >>>>>>>
# waterloo_ia >>>>>>>
# friday_harbor_wa >>>>>>>
# brunswick_ga >>>>>>>
# lafayette_in >>>>>>>
# lafayette_la >>>>>>>
# shemya_ak >>>>>>>
# pascokennewickrichland_wa >>>>>>>
# anniston_al >>>>>>>
# lawtonfort_sill_ok >>>>>>>
# clovis_nm >>>>>>>
# crescent_city_ca >>>>>>>
# savoonga_ak >>>>>>>
# glendive_mt >>>>>>>
# aniak_ak >>>>>>>
# akiak_ak >>>>>>>
# holy_cross_ak >>>>>>>
# scammon_bay_ak >>>>>>>
# hyannis_ma >>>>>>>
# glasgow_mt >>>>>>>
# prospect_creek_ak >>>>>>>
# vieques_pr >>>>>>>
# joplin_mo >>>>>>>
# fargo_nd >>>>>>>
# point_lay_ak >>>>>>>
# santa_ana_ca >>>>>>>
# rivertonlander_wy >>>>>>>
# augusta_ga >>>>>>>
# kipnuk_ak >>>>>>>
# newtok_ak >>>>>>>
# kona_hi >>>>>>>
# igiugig_ak >>>>>>>
# ponce_pr >>>>>>>
# fort_smith_ar >>>>>>>
# cody_wy >>>>>>>
# roxboro_nc >>>>>>>
# butte_mt >>>>>>>
# iron_mountainkingsfd_mi >>>>>>>
# sidney_mt >>>>>>>
# memphis_tn >>>>>>>
# sioux_city_ia >>>>>>>
# oakland_ca >>>>>>>
# bar_harbor_me >>>>>>>
# orlando_fl >>>>>>>
# portland_me >>>>>>>
# fayetteville_nc >>>>>>>
# alexandria_la >>>>>>>
# anacortes_wa >>>>>>>
# telluride_co >>>>>>>
# latrobe_pa >>>>>>>
# homer_ak >>>>>>>
# egegik_ak >>>>>>>
# san_luis_obispo_ca >>>>>>>
# newport_newswilliamsburg_va >>>>>>>
# pilot_station_ak >>>>>>>
# duluth_mn >>>>>>>
# fairbanks_ak >>>>>>>
# abilene_tx >>>>>>>
# mammoth_lakes_ca >>>>>>>
# ugashik_ak >>>>>>>
# palmer_ak >>>>>>>
# silver_cityhurley_nm >>>>>>>
# toksook_ak >>>>>>>
# sitka_ak >>>>>>>
# honolulu_hi >>>>>>>
# salinasmonterey_ca >>>>>>>
# atlantic_city_nj >>>>>>>
# emmonak_ak >>>>>>>
# monroe_la >>>>>>>
# hancockhoughton_mi >>>>>>>
# columbia_mo >>>>>>>
# fort_jefferson_fl >>>>>>>
# florence_sc >>>>>>>
# williston_nd >>>>>>>
# san_juan_pr >>>>>>>
# missoula_mt >>>>>>>
# napakiak_ak >>>>>>>
# port_lions_ak >>>>>>>
# terror_lake_ak >>>>>>>
# dallasfort_worth_tx >>>>>>>
# block_island_ri >>>>>>>
# levelock_ak >>>>>>>
# springfield_mo >>>>>>>
# phoenix_az >>>>>>>
# port_graham_ak >>>>>>>
# mccook_ne >>>>>>>
# charlotte_nc >>>>>>>
# fresno_ca >>>>>>>
# jackson_wy >>>>>>>
# bemidji_mn >>>>>>>
# fitiuta_village_tt >>>>>>>
# chadron_ne >>>>>>>
# chignik_lagoon_ak >>>>>>>
# dickinson_nd >>>>>>>
# fayetteville_ar >>>>>>>
# sault_ste_marie_mi >>>>>>>
# buckland_ak >>>>>>>
# pago_pago_tt >>>>>>>
# kodiak_island_ak >>>>>>>
# tyler_tx >>>>>>>
# westerly_ri >>>>>>>
# kizhuyak_ak >>>>>>>
# st_marys_ak >>>>>>>
# hyder_ak >>>>>>>
# stebbins_ak >>>>>>>
# kahului_hi >>>>>>>
# bozeman_mt >>>>>>>
# chalkyitsik_ak >>>>>>>
# providence_ri >>>>>>>
# gustavus_ak >>>>>>>
# gainesville_fl >>>>>>>
# midlandodessa_tx >>>>>>>
# eastsound_wa >>>>>>>
# newburghpoughkeepsie_ny >>>>>>>
# bendredmond_or >>>>>>>
# ogdensburg_ny >>>>>>>
# burlington_vt >>>>>>>
# washington_dc >>>>>>>
# olga_bay_ak >>>>>>>
# kuparuk_ak >>>>>>>
# belleville_il >>>>>>>
# fort_wayne_in >>>>>>>
# lazy_bay_ak >>>>>>>
# south_bend_in >>>>>>>
# sheldon_point_ak >>>>>>>
# oceana_va >>>>>>>
# haines_ak >>>>>>>
# arcataeureka_ca >>>>>>>
# nightmute_ak >>>>>>>
# hoonah_ak >>>>>>>
# granite_point_ak >>>>>>>
# omaha_ne >>>>>>>
# el_paso_tx >>>>>>>
# gaylord_mi >>>>>>>
# teterboro_nj >>>>>>>
# cedar_city_ut >>>>>>>
# king_cove_ak >>>>>>>
# kingman_az >>>>>>>
# riverside_ca >>>>>>>
# goodnews_bay_ak >>>>>>>
# college_stationbryan_tx >>>>>>>
# kiluda_bay_ak >>>>>>>
# akhiok_ak >>>>>>>
# st_cloud_mn >>>>>>>
# pellston_mi >>>>>>>
# golovin_ak >>>>>>>
# meridian_ms >>>>>>>
# chignik_bay_ak >>>>>>>
# albuquerque_nm >>>>>>>
# lewisburg_wv >>>>>>>
# lewiston_id >>>>>>>
# texarkana_ar >>>>>>>
# laredo_tx >>>>>>>
# circle_ak >>>>>>>
# lancaster_pa >>>>>>>
# kansas_city_mo >>>>>>>
# bishop_ca >>>>>>>
# dayton_oh >>>>>>>
# ketchikan_ak >>>>>>>
# mountain_view_ca >>>>>>>
# monterey_ca >>>>>>>
# tuscaloosa_al >>>>>>>
# nuiqsut_ak >>>>>>>
# liberal_ks >>>>>>>
# bedford_ma >>>>>>>
# arctic_village_ak >>>>>>>
# everett_wa >>>>>>>
# tin_city_ak >>>>>>>
# pittsburgh_pa >>>>>>>
# unalakleet_ak >>>>>>>
# mosinee_wi >>>>>>>
# lanai_hi >>>>>>>
# pullman_wa >>>>>>>
# utopia_ak >>>>>>>
# klamath_falls_or >>>>>>>
# noorvik_ak >>>>>>>
# naples_fl >>>>>>>
# point_hope_ak >>>>>>>
# chico_ca >>>>>>>
# barter_island_ak >>>>>>>
# skagway_ak >>>>>>>
# killeen_tx >>>>>>>
# gulfportbiloxi_ms >>>>>>>
# traverse_city_mi >>>>>>>
# daytona_beach_fl >>>>>>>
# kirksville_mo >>>>>>>
# shungnak_ak >>>>>>>
# greenville_sc >>>>>>>
# minneapolis_mn >>>>>>>
# thief_river_falls_mn >>>>>>>
# st_louis_mo >>>>>>>
# detroit_mi >>>>>>>
# tucson_az >>>>>>>
# princetonbluefield_wv >>>>>>>
# culebra_pr >>>>>>>
# owensboro_ky >>>>>>>
# kwigillingok_ak >>>>>>>
# moses_lake_wa >>>>>>>
# sleetmute_ak >>>>>>>
# visalia_ca >>>>>>>
# long_beach_ca >>>>>>>
# tununak_ak >>>>>>>
# austin_tx >>>>>>>
# fort_dodge_ia >>>>>>>
# alliance_ne >>>>>>>
# new_londongroton_ct >>>>>>>
# asheville_nc >>>>>>>
# huntsville_al >>>>>>>
# winston-salem_nc >>>>>>>
# lawrence_ma >>>>>>>
# portland_or >>>>>>>
# shreveport_la >>>>>>>
# vernal_ut >>>>>>>
# boise_id >>>>>>>
# bridgeport_ct >>>>>>>
# cedar_rapidsiowa_city_ia >>>>>>>
# christiansted_vi >>>>>>>
# eau_claire_wi >>>>>>>
# hartford_ct >>>>>>>
# baton_rouge_la >>>>>>>
# nelson_lagoon_ak >>>>>>>
# hilton_head_sc >>>>>>>
# kobuk_ak >>>>>>>
# port_heiden_ak >>>>>>>
# port_bailey_ak >>>>>>>
# san_antonio_tx >>>>>>>
# st_george_ut >>>>>>>
# pendleton_or >>>>>>>
# eagle_harbor_ak >>>>>>>
# yakima_wa >>>>>>>
# uganik_ak >>>>>>>
# south_naknek_ak >>>>>>>
# dodge_city_ks >>>>>>>
# lynchburg_va >>>>>>>
# craig_ak >>>>>>>
# brownsville_tx >>>>>>>
# roseburg_or >>>>>>>
# beckley_wv >>>>>>>
# new_bedfordfall_river_ma >>>>>>>
# new_orleans_la >>>>>>>
# watertown_ny >>>>>>>
# philadelphia_pa >>>>>>>
# rochester_mn >>>>>>>
# inyokern_ca >>>>>>>
# whale_pass_ak >>>>>>>
# sitkinak_ak >>>>>>>
# stony_river_ak >>>>>>>
# danger_bay_ak >>>>>>>
# bay_city_tx >>>>>>>
# san_diego_ca >>>>>>>
# guam_tt >>>>>>>
# charlottesville_va >>>>>>>
# wales_ak >>>>>>>
# pedro_bay_ak >>>>>>>
# alpine_ak >>>>>>>
# bowling_green_ky >>>>>>>
# tacoma_wa >>>>>>>
# twin_falls_id >>>>>>>
# chefornak_ak >>>>>>>
# pontiac_mi >>>>>>>
# kapalua_hi >>>>>>>
# kitoi_bay_ak >>>>>>>
# youngstownwarren_oh >>>>>>>
# escanaba_mi >>>>>>>
# venetie_ak >>>>>>>
# worcester_ma >>>>>>>
# lihue_hi >>>>>>>
# brevig_mission_ak >>>>>>>
# koyukuk_ak >>>>>>>
# hughes_ak >>>>>>>
# bloomington_in >>>>>>>
# wainwright_ak >>>>>>>
# cortez_co >>>>>>>
# grand_forks_nd >>>>>>>
# knoxville_tn >>>>>>>
# indianapolis_in >>>>>>>
# cincinnati_oh >>>>>>>
# parkersburg_wv >>>>>>>
# beaver_ak >>>>>>>
# marana_az >>>>>>>
# montgomery_al >>>>>>>
# newport_or >>>>>>>
# jamestown_nd >>>>>>>
# columbia_tn >>>>>>>
# el_dorado_ar >>>>>>>
# missionmcallenedinburg_tx >>>>>>>
# chicagoromeoville_il >>>>>>>
# tinian_tt >>>>>>>
# beverly_ma >>>>>>>
# clarks_point_ak >>>>>>>
# thorne_bay_ak >>>>>>>
# fort_leonard_wood_mo >>>>>>>
# newport_ri >>>>>>>
# minot_nd >>>>>>>
# bradford_pa >>>>>>>
# chuathbaluk_ak >>>>>>>
# ukiah_ca >>>>>>>
# napaskiak_ak >>>>>>>
# ashland_wv >>>>>>>
# stillwater_ok >>>>>>>
# islip_ny >>>>>>>
# panama_city_fl >>>>>>>
# rochester_ny >>>>>>>
# st_michael_ak >>>>>>>
# cordova_ak >>>>>>>
# may_creek_ak >>>>>>>
# palm_springs_ca >>>>>>>
# jacksonvicksburg_ms >>>>>>>
# laconia_nh >>>>>>>
# eagle_ak >>>>>>>
# chicago_il >>>>>>>
# stevens_village_ak >>>>>>>
# selawik_ak >>>>>>>
# burlingtonmount_vernon_wa >>>>>>>
# dothan_al >>>>>>>
# gulkana_ak >>>>>>>
# tuluksak_ak >>>>>>>
# chevak_ak >>>>>>>
# east_farmingdale_ny >>>>>>>
# flagstaff_az >>>>>>>
# bellingham_wa >>>>>>>
# hanford_ca >>>>>>>
# destin_fl >>>>>>>
# chicken_ak >>>>>>>
# atmautluak_ak >>>>>>>
# rhinelander_wi >>>>>>>
# grand_rapids_mi >>>>>>>
# grand_canyon_az >>>>>>>
# new_bernmoreheadbeaufort_nc >>>>>>>
# aguadilla_pr >>>>>>>
# tonopah_nv >>>>>>>
# waterbury_ct >>>>>>>
# camp_springs_md >>>>>>>
# skwentna_ak >>>>>>>
# fort_myers_fl >>>>>>>
# north_kingstown_ri >>>>>>>
# portsmouth_nh >>>>>>>
# champaignurbana_il >>>>>>>
# medford_or >>>>>>>
# wake_island_tt >>>>>>>
# hayden_co >>>>>>>
# marquette_mi >>>>>>>
# smyrna_tn >>>>>>>
# hattiesburglaurel_ms >>>>>>>
# columbus_ms >>>>>>>
# cape_romanzof_ak >>>>>>>
# st_petersburg_fl >>>>>>>
# walla_walla_wa >>>>>>>
# east_hampton_ny >>>>>>>
# gunnison_co >>>>>>>
# dora_bay_ak >>>>>>>
# fairfield_ca >>>>>>>
# sacramento_ca >>>>>>>
# coldfoot_ak >>>>>>>
# ceiba_pr >>>>>>>
# oklahoma_city_ok >>>>>>>
# morrisville_vt >>>>>>>
# saipan_tt >>>>>>>
# bethel_ak >>>>>>>
# cold_bay_ak >>>>>>>
# kotlik_ak >>>>>>>
# red_devil_ak >>>>>>>
# mccarthy_ak >>>>>>>
# trenton_nj >>>>>>>
# manhattanft_riley_ks >>>>>>>
# koliganek_ak >>>>>>>
# kotzebue_ak >>>>>>>
# muskegon_mi >>>>>>>
# san_francisco_ca >>>>>>>
# atqasuk_ak >>>>>>>
# denton_tx >>>>>>>
# casper_wy >>>>>>>
# fort_dix_nj >>>>>>>
# rocky_mount_nc >>>>>>>
# west_palm_beachpalm_beach_fl >>>>>>>
# las_vegas_nv >>>>>>>
# lexington_ky >>>>>>>
# alamosa_co >>>>>>>
# false_pass_ak >>>>>>>
# shaktoolik_ak >>>>>>>
# charleston_sc >>>>>>>
# port_alexander_ak >>>>>>>
# akutan_ak >>>>>>>
# marthas_vineyard_ma >>>>>>>
# beaumontport_arthur_tx >>>>>>>
# pensacola_fl >>>>>>>
# elko_nv >>>>>>>
# williamsport_pa >>>>>>>
# harlingensan_benito_tx >>>>>>>
# augustawaterville_me >>>>>>>
# sioux_falls_sd >>>>>>>
# crooked_creek_ak >>>>>>>
# manley_hot_springs_ak >>>>>>>
# aberdeen_sd >>>>>>>
# nunapitchuk_ak >>>>>>>
# borniteruby_creek_ak >>>>>>>
# reno_nv >>>>>>>
# international_falls_mn >>>>>>>
# northampton_ma >>>>>>>
# koyuk_ak >>>>>>>
# logan_ut >>>>>>>
# santa_maria_ca >>>>>>>
# atlanta_ga >>>>>>>
# elmiracorning_ny >>>>>>>
# decatur_al >>>>>>>
# mayaguez_pr >>>>>>>
# marshall_ak >>>>>>>
# gary_in >>>>>>>
# syracuse_ny >>>>>>>
# chisana_ak >>>>>>>
# charlestondunbar_wv >>>>>>>
# noatak_ak >>>>>>>
# karluk_ak >>>>>>>
# kake_ak >>>>>>>
# minto_ak >>>>>>>
# raleighdurham_nc >>>>>>>
# barrow_ak >>>>>>>
# grand_junction_co >>>>>>>
# teller_ak >>>>>>>
# dubuque_ia >>>>>>>
# kalamazoo_mi >>>>>>>
# myrtle_beach_sc >>>>>>>
# san_jose_ca >>>>>>>
# san_angelo_tx >>>>>>>
# morgantown_wv >>>>>>>
# blue_fox_bay_ak >>>>>>>
# melbourne_fl >>>>>>>
# ontario_ca >>>>>>>
# wilmington_oh >>>>>>>
# arlington_tx >>>>>>>
# appleton_wi >>>>>>>
# garden_city_ks >>>>>>>
# coffman_cove_ak >>>>>>>
# mason_city_ia >>>>>>>
# ithacacortland_ny >>>>>>>
# sarasotabradenton_fl >>>>>>>
# mekoryuk_ak >>>>>>>
# quinhagak_ak >>>>>>>
# presque_islehoulton_me >>>>>>>
# tuntutuliak_ak >>>>>>>
# manchester_nh >>>>>>>
# thermal_ca >>>>>>>
# allakaket_ak >>>>>>>
# del_rio_tx >>>>>>>
# rockford_il >>>>>>>
# morristown_nj >>>>>>>
# deering_ak >>>>>>>
# laramie_wy >>>>>>>
# brownwood_tx >>>>>>>
# chomondely_sound_ak >>>>>>>
# springfield_il >>>>>>>
# king_salmon_ak >>>>>>>
# larsen_bay_ak >>>>>>>
# jonesboro_ar >>>>>>>
# tallahassee_fl >>>>>>>
# savannah_ga >>>>>>>
# kearney_ne >>>>>>>
# west_point_ak >>>>>>>
# juneau_ak >>>>>>>
# nikolski_ak >>>>>>>
# dover_de >>>>>>>
# sandpoint_ak >>>>>>>
# new_york_ny >>>>>>>
# state_college_pa >>>>>>>
# rota_tt >>>>>>>
# kasigluk_ak >>>>>>>
# zachar_bay_ak >>>>>>>
# wenatchee_wa >>>>>>>
# hopkinsville_ky >>>>>>>
# saranac_lakelake_placid_ny >>>>>>>
# trading_bay_ak >>>>>>>
# platinum_ak >>>>>>>
# point_baker_ak >>>>>>>
# massena_ny >>>>>>>
# napa_ca >>>>>>>
# durango_co >>>>>>>
# minneapolisst_paul_mn >>>>>>>
# tatitlek_ak >>>>>>>
# white_plains_ny >>>>>>>
# ekwok_ak >>>>>>>
# bend_or >>>>>>>
# lincoln_ne >>>>>>>
# tenakee_ak >>>>>>>
# sheridan_wy >>>>>>>
# mcgrath_ak >>>>>>>
# eek_ak >>>>>>>
# birmingham_al >>>>>>>
# lawrenceville_ga >>>>>>>
# marionherrin_il >>>>>>>
# fort_lauderdale_fl >>>>>>>
# central_ak >>>>>>>
# wichita_falls_tx >>>>>>>
# page_az >>>>>>>
# nantucket_ma >>>>>>>
# bainbridge_ga >>>>>>>
# elizabeth_city_nc >>>>>>>
# hagerstown_md >>>>>>>
# bismarckmandan_nd >>>>>>>
# scrantonwilkes-barre_pa >>>>>>>
# nanwalek_ak >>>>>>>
# rock_springs_wy >>>>>>>
# new_haven_ct >>>>>>>
# greer_sc >>>>>>>
# plattsburgh_ny >>>>>>>
# erie_pa >>>>>>>
# boulder_city_nv >>>>>>>
# el_centro_ca >>>>>>>
# altoona_pa >>>>>>>
# kennesaw_ga >>>>>>>
# show_low_az >>>>>>>
# stuart_fl >>>>>>>
# elfin_cove_ak >>>>>>>
# idaho_falls_id >>>>>>>
# rampart_ak >>>>>>>
# ruby_ak >>>>>>>
# north_bendcoos_bay_or >>>>>>>
# petersburg_ak >>>>>>>
# monticello_ny >>>>>>>
# kalispell_mt >>>>>>>
# wilmington_nc >>>>>>>
# pelican_ak >>>>>>>
# kodiak_ak >>>>>>>
# pilot_point_ak >>>>>>>
# greensborohigh_point_nc >>>>>>>
# ofu_tt >>>>>>>
# scottsbluff_ne >>>>>>>
# new_iberia_la >>>>>>>
# greenville_nc >>>>>>>
# peach_springs_az >>>>>>>
# alpena_mi >>>>>>>
# san_bernardino_ca >>>>>>>
# quincy_il >>>>>>>
# greeneville_tn >>>>>>>
# grayling_ak >>>>>>>
# akiachak_ak >>>>>>>
# longview_tx >>>>>>>
# devils_lake_nd >>>>>>>
# wolf_point_mt >>>>>>>
# anaktuvuk_pass_ak >>>>>>>
# la_crosse_wi >>>>>>>
# dallas_tx >>>>>>>
# bristoljohnson_citykingsport_tn >>>>>>>
# binghamton_ny >>>>>>>
# louisville_ky >>>>>>>
# seattle_wa >>>>>>>
# lansing_mi >>>>>>>
# decatur_il >>>>>>>
# st_george_island_ak >>>>>>>
# little_rock_ar >>>>>>>
# des_moines_ia >>>>>>>
# paducah_ky >>>>>>>
# lubbock_tx >>>>>>>
# van_nuys_ca >>>>>>>
# hooper_bay_ak >>>>>>>
# valdosta_ga >>>>>>>
# columbus_ga >>>>>>>
# klawock_ak >>>>>>>
# atka_ak >>>>>>>
# chattanooga_tn >>>>>>>
# kongiganak_ak >>>>>>>
# amarillo_tx >>>>>>>
# reading_pa >>>>>>>
# kasaan_ak >>>>>>>
# cleveland_oh >>>>>>>
# gallup_nm >>>>>>>
# burlington_ia >>>>>>>
# great_falls_mt >>>>>>>
# gaithersburg_md >>>>>>>
# ogden_ut >>>>>>>
# madison_wi >>>>>>>
# hickory_nc >>>>>>>
# dillingham_ak >>>>>>>
# hollis_ak >>>>>>>
# hobbs_nm >>>>>>>
# lake_charles_la >>>>>>>
# newark_nj >>>>>>>
# jacksonville_fl >>>>>>>
# nondalton_ak >>>>>>>
# new_stuyahok_ak >>>>>>>
# galbraith_lake_ak >>>>>>>
# santa_barbara_ca >>>>>>>
# kaltag_ak >>>>>>>
# red_dog_ak >>>>>>>
# broomfield_co >>>>>>>
# minchumina_ak >>>>>>>
# houston_tx >>>>>>>
# albany_ga >>>>>>>
# stockton_ca >>>>>>>
# saginawbay_citymidland_mi >>>>>>>
# hot_springs_ar >>>>>>>
# salt_lake_city_ut >>>>>>>
# tampa_fl >>>>>>>
# valparaiso_fl >>>>>>>
# redding_ca >>>>>>>
# montrosedelta_co >>>>>>>
# grand_island_ne >>>>>>>
# elim_ak >>>>>>>
# la_grande_or >>>>>>>
# punta_gorda_fl >>>>>>>
# gambell_ak >>>>>>>
# murray_ky >>>>>>>
# kwethluk_ak >>>>>>>
# prescott_az >>>>>>>
# spokane_wa >>>>>>>
# st_paul_ak >>>>>>>
# hilo_hi >>>>>>>
# kivalina_ak >>>>>>>
# richmond_va >>>>>>>
# ouzinkie_ak >>>>>>>
# port_alsworth_ak >>>>>>>
# anvik_ak >>>>>>>
# mountain_village_ak >>>>>>>
# staunton_va >>>>>>>
# salmon_id >>>>>>>
# kamuela_hi >>>>>>>
# wichita_ks >>>>>>>
# port_moller_ak >>>>>>>
# seal_bay_ak >>>>>>>
# kokhanok_ak >>>>>>>
# russian_mission_ak >>>>>>>
# corpus_christi_tx >>>>>>>
# unalaska_ak >>>>>>>
# fort_yukon_ak >>>>>>>
# manokotak_ak >>>>>>>
# bloomingtonnormal_il >>>>>>>
# port_williams_ak >>>>>>>
# tupelo_ms >>>>>>>
# ambler_ak >>>>>>>
# edna_bay_ak >>>>>>>
# deadhorse_ak >>>>>>>
# carlsbad_nm >>>>>>>
# moab_ut >>>>>>>
# lebanon-hanover_nh >>>>>>>
# marathon_fl >>>>>>>
# yakutat_ak >>>>>>>
# olympia_wa >>>>>>>
# clarksburgfairmont_wv >>>>>>>

# %%
print(Y,N)
# Out:
# 33 742

# %%
# Out:
#       SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  \
# 1265      50      2      20      0       0       0
# 1112     162      2       0   3000       0       0
# 1266     157      2      20   3000       0       0
# 1325     157      2     130  99990       0       0
# 1124     162      2       0  12680       0       0
# 1271     157      2      50  12680       0       0
# 1414     157      2     270  13230       0       0
# 1125     162      2       0  13230       0       0
# 1335     157      2     164  13550       0       0
# 1126     162      2       0  13550       0       0
# 1127     162      2       0  14330       0       0
# 1272     157      2      50  14330       0       0
# 1161     162      2       0  36540       0       0
# 1316     157      2     122  36540       0       0
# 1322      50      2     130      0       0       0
# 1167     162      2       0  38970       0       0
# 1323     157      2     130  38970       0       0
# 1281     157      2      50  56680       0       0
# 1201     162      2       0  56680       0       0
# 1219     162      2       0  66360       0       0
# 1355     157      2     180  66360       0       0
#
#                                          NAME STNAME CENSUS2010POP  \
# 1265                anchorage_municipality_ak     ak        291826
# 1112                anchorage_municipality_ak     ak        291826
# 1266                anchorage_municipality_ak     ak        291826
# 1325  balance_of_ketchikan_gateway_borough_ak     ak          5016
# 1124                        chefornak_city_ak     ak           418
# 1271                        chefornak_city_ak     ak           418
# 1414                           chevak_city_ak     ak           938
# 1125                           chevak_city_ak     ak           938
# 1335                          chignik_city_ak     ak            91
# 1126                          chignik_city_ak     ak            91
# 1127                      chuathbaluk_city_ak     ak           118
# 1272                      chuathbaluk_city_ak     ak           118
# 1161                         kachemak_city_ak     ak             X
# 1316                         kachemak_city_ak     ak             X
# 1322             ketchikan_gateway_borough_ak     ak         13477
# 1167                        ketchikan_city_ak     ak          8050
# 1323                        ketchikan_city_ak     ak          8050
# 1281                      nunapitchuk_city_ak     ak           496
# 1201                      nunapitchuk_city_ak     ak           496
# 1219                       st_michael_city_ak     ak           401
# 1355                       st_michael_city_ak     ak           401
#
#       ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011
# 1265             291826           293356           295570
# 1112             291826           293356           295570
# 1266             291826           293356           295570
# 1325               5016             5035             5059
# 1124                418              420              429
# 1271                418              420              429
# 1414                938              943              963
# 1125                938              943              963
# 1335                 91               91               93
# 1126                 91               91               93
# 1127                118              119              120
# 1272                118              119              120
# 1161                472              474              479
# 1316                472              474              479
# 1322              13477            13531            13593
# 1167               8050             8083             8119
# 1323               8050             8083             8119
# 1281                496              498              508
# 1201                496              498              508
# 1219                401              404              416
# 1355                401              404              416

# %%
city_pop_dict = population[['NAME','CENSUS2010POP']].set_index('NAME').to_dict()['CENSUS2010POP']
cities  = list(city_pop_dict.keys())

def get_pop_by_city(c):
    if c in cities:
        return int(city_pop_dict[c])
    else:
        return np.nan
    
def city_get_population(c):
    matching_cities = get_close_matches(c,[i for i in cities if i[-2::]==c[-2::]])
#     print([i[0:length] for i in cities if i[-2::]==c[-2::]])
    print(c,matching_cities)
    if len(matching_cities)>0:
        return(get_pop_by_city(matching_cities[0]))
    else:
        return np.nan

# %%
get_close_matches('denver',cities)
# Out:
# ['denver_town_in', 'denver_city_ia', 'denver_city_co']

# %%
# nodes = data[['source','ORIGIN']].set_index('source').to_dict()['ORIGIN']
# nodes_temp = data[['target','DEST']].set_index('target').to_dict()['DEST']
# nodes.update(nodes_temp)

# %%
out_data = {}
for n in nodes:
    out_data[n] = city_get_population(n)
# Out:
# peru_in ['peru_city_in', 'peru_city_pt_in', 'perry_county_in']
# valparaiso_in ['valparaiso_city_in', 'valparaiso_city_pt_in', 'earl_park_town_in']
# greenville_ms ['greenville_city_ms', 'eden_village_ms', 'big_creek_village_ms']
# port_protection_ak ['north_pole_city_ak', 'port_lions_city_ak', 'point_hope_city_ak']
# hoolehua_hi []
# adak_island_ak ['adak_city_ak', 'kodiak_island_borough_ak']
# wrangell_ak []
# shageluk_ak ['shageluk_city_ak', 'alaska_ak']
# kiana_ak ['kiana_city_ak', 'kivalina_city_ak']
# marietta_ga ['marietta_city_ga', 'martin_town_ga', 'darien_city_ga']
# vero_beach_fl ['vero_beach_city_fl', 'riviera_beach_city_fl', 'beverly_beach_town_fl']
# concord_nc ['concord_city_nc', 'macon_county_nc', 'conover_city_nc']
# bakersfield_ca ['bakersfield_city_ca', 'fairfield_city_ca']
# santa_fe_nm ['santa_fe_city_nm', 'santa_fe_county_nm', 'santa_rosa_city_nm']
# chenega_ak []
# perryville_ak []
# santa_rosa_ca ['santa_rosa_city_ca', 'santa_maria_city_ca', 'santa_clara_city_ca']
# akron_oh ['akron_city_oh', 'marion_city_oh', 'lake_county_oh']
# roanoke_va ['roanoke_city_va', 'roanoke_county_va', 'onancock_town_va']
# hibbing_mn ['hibbing_city_mn']
# columbus_oh ['columbus_city_oh', 'columbus_city_pt_oh', 'columbiana_county_oh']
# key_west_fl ['key_west_city_fl', 'lake_wales_city_fl']
# niagara_falls_ny ['niagara_falls_city_ny', 'niagara_town_ny', 'niagara_county_ny']
# rockland_me ['rockland_city_me', 'oakland_town_me', 'poland_town_me']
# corvallis_or ['corvallis_city_or', 'cornelius_city_or', 'jordan_valley_city_or']
# helena_mt ['helena_city_mt', 'east_helena_city_mt', 'plevna_town_mt']
# colorado_springs_co ['colorado_springs_city_co', 'colorado_co', 'glenwood_springs_city_co']
# boca_raton_fl ['boca_raton_city_fl', 'noma_town_fl', 'ocean_ridge_town_fl']
# milwaukee_wi ['milwaukee_city_wi', 'milwaukee_county_wi', 'milwaukee_city_pt_wi']
# anchorage_ak ['anchorage_municipality_ak']
# north_platte_ne ['north_platte_city_ne', 'north_loup_village_ne', 'nora_village_ne']
# norfolk_va ['norfolk_city_va']
# los_angeles_ca ['los_angeles_city_ca', 'los_angeles_county_ca', 'los_banos_city_ca']
# nashville_tn ['smithville_city_tn', 'graysville_town_tn', 'enville_town_tn']
# green_bay_wi ['green_bay_town_wi', 'green_bay_city_wi', 'green_county_wi']
# alakanuk_ak ['alakanuk_city_ak', 'alaska_ak', 'allakaket_city_ak']
# gillette_wy ['gillette_city_wy']
# togiak_ak ['togiak_city_ak', 'kodiak_city_ak']
# cape_lisburne_ak []
# franklinoil_city_pa ['franklin_city_pa', 'franklin_county_pa', 'arnold_city_pa']
# sanford_fl ['sanford_city_fl', 'florida_fl', 'branford_town_fl']
# cape_girardeau_mo ['cape_girardeau_city_mo', 'cape_girardeau_county_mo', 'cape_girardeau_city_pt_mo']
# excursion_inlet_ak ['anderson_city_ak', 'houston_city_ak']
# farmington_nm ['farmington_city_nm', 'springer_town_nm', 'hagerman_town_nm']
# sun_valleyhaileyketchum_id ['sun_valley_city_id']
# galena_ak ['galena_city_ak', 'alaska_ak', 'aleknagik_city_ak']
# allentownbethlehemeaston_pa ['east_bethlehem_township_pa', 'north_bethlehem_township_pa', 'bethlehem_township_pa']
# kalaupapa_hi []
# waco_tx ['waco_city_tx', 'ward_county_tx', 'weslaco_city_tx']
# yuma_az ['yuma_city_az', 'yuma_county_az']
# huslia_ak ['huslia_city_ak', 'hughes_city_ak']
# provincetown_ma ['provincetown_town_ma', 'princeton_town_ma', 'erving_town_ma']
# white_mountain_ak ['white_mountain_city_ak']
# roswell_nm ['roswell_city_nm', 'melrose_village_nm', 'house_village_nm']
# hana_hi ['hawaii_hi']
# bullhead_city_az ['bullhead_city_city_az', 'yuma_city_az', 'mesa_city_az']
# old_harbor_ak ['old_harbor_city_ak']
# lake_havasu_city_az ['lake_havasu_city_city_az', 'nogales_city_az', 'douglas_city_az']
# salisbury_md ['salisbury_city_md', 'gaithersburg_city_md', 'smithsburg_town_md']
# pocatello_id ['pocatello_city_id', 'pocatello_city_pt_id']
# albany_ny ['albany_city_ny', 'albany_county_ny', 'elba_town_ny']
# seldovia_ak ['seldovia_city_ak']
# jacksonvillecamp_lejeune_nc ['jacksonville_city_nc', 'ansonville_town_nc']
# tulsa_ok ['tulsa_city_ok', 'tulsa_county_ok', 'tulsa_city_pt_ok']
# charlotte_amalie_vi []
# metlakatla_ak ['alaska_ak']
# hydaburg_ak ['hydaburg_city_ak']
# healy_ak ['eagle_city_ak', 'chevak_city_ak', 'bethel_city_ak']
# rutland_vt ['rutland_town_vt', 'rutland_city_vt', 'rutland_county_vt']
# baltimore_md ['baltimore_city_md', 'baltimore_county_md']
# tok_ak ['togiak_city_ak']
# harrison_ar ['harrison_city_ar', 'harrell_town_ar', 'sherrill_town_ar']
# wausau_wi ['wausau_town_wi', 'wausau_city_wi', 'wausaukee_town_wi']
# miami_fl ['miami_city_fl', 'miramar_city_fl', 'midway_city_fl']
# ironwood_mi ['ironwood_city_mi', 'rockwood_city_mi', 'iron_county_mi']
# frederick_md ['frederick_city_md', 'frederick_county_md']
# angoon_ak ['angoon_city_ak']
# buffalo_ny ['buffalo_city_ny']
# muscle_shoals_al ['muscle_shoals_city_al']
# jackson_mi ['jackson_city_mi', 'jackson_county_mi', 'backus_township_mi']
# billings_mt ['billings_city_mt']
# port_angeles_wa ['port_angeles_city_wa', 'spangle_city_wa']
# west_palm_beach_fl ['west_palm_beach_city_fl', 'south_palm_beach_town_fl', 'palm_beach_town_fl']
# burbank_ca ['burbank_city_ca', 'brisbane_city_ca']
# chignik_ak ['chignik_city_ak', 'craig_city_ak']
# victoria_tx ['victoria_city_tx', 'victoria_county_tx', 'vidor_city_tx']
# cape_newenham_ak []
# cheyenne_wy ['cheyenne_city_wy']
# harrisburg_pa ['harrisburg_city_pa', 'harrisville_borough_pa', 'charleroi_borough_pa']
# birch_creek_ak []
# petaluma_ca ['petaluma_city_ca']
# bettles_ak ['bettles_city_ak']
# naukiti_ak ['emmonak_city_ak', 'atqasuk_city_ak', 'atka_city_ak']
# twin_hills_ak []
# rapid_city_sd ['rapid_city_city_sd', 'dell_rapids_city_sd', 'lead_city_sd']
# jackson_tn ['jackson_city_tn', 'jackson_county_tn', 'jacksboro_town_tn']
# eagle_co ['eagle_town_co', 'eagle_county_co', 'flagler_town_co']
# evansville_in ['evansville_city_in', 'evansville_city_pt_in', 'zanesville_town_in']
# kalskag_ak ['alaska_ak', 'kaltag_city_ak', 'upper_kalskag_city_ak']
# shishmaref_ak ['shishmaref_city_ak']
# kenmore_wa ['kenmore_city_wa']
# tyonek_ak []
# pueblo_co ['pueblo_city_co', 'pueblo_county_co']
# johnstown_pa ['johnstown_city_pa', 'jones_township_pa', 'jenks_township_pa']
# valdez_ak ['valdez_city_ak']
# york_pa ['york_city_pa', 'york_county_pa', 'york_township_pa']
# fort_drum_ny ['fort_edward_town_ny']
# iliamna_ak ['kivalina_city_ak', 'kiana_city_ak']
# brainerd_mn ['brainerd_city_mn', 'ranier_city_mn', 'racine_city_mn']
# waterloo_ia ['waterloo_city_ia', 'wapello_county_ia', 'waterville_city_ia']
# friday_harbor_wa ['friday_harbor_town_wa', 'grays_harbor_county_wa', 'oak_harbor_city_wa']
# brunswick_ga ['brunswick_city_ga', 'barwick_city_ga', 'bostwick_city_ga']
# lafayette_in ['lafayette_city_in', 'lafayette_city_pt_in', 'lafayette_township_in']
# denver_co ['denver_city_co', 'denver_county_co', 'center_town_co']
# lafayette_la ['lafayette_city_la', 'lafayette_parish_la']
# shemya_ak []
# pascokennewickrichland_wa ['kennewick_city_wa']
# anniston_al ['anniston_city_al', 'banks_town_al', 'kansas_town_al']
# dubois_pa ['dubois_city_pa', 'duboistown_borough_pa']
# lawtonfort_sill_ok ['lawton_city_ok']
# clovis_nm ['clovis_city_nm']
# nome_ak ['nome_city_ak', 'homer_city_ak']
# crescent_city_ca ['crescent_city_city_ca', 'ceres_city_ca', 'fresno_city_ca']
# savoonga_ak ['savoonga_city_ak']
# glendive_mt ['glendive_city_mt']
# salem_or ['salem_city_or', 'salem_city_pt_or', 'nehalem_city_or']
# aniak_ak ['aniak_city_ak', 'alaska_ak', 'anvik_city_ak']
# akiak_ak ['akiak_city_ak', 'alaska_ak', 'napakiak_city_ak']
# holy_cross_ak ['holy_cross_city_ak']
# scammon_bay_ak ['scammon_bay_city_ak', 'saxman_city_ak', 'emmonak_city_ak']
# hyannis_ma ['lynn_city_ma']
# glasgow_mt ['glasgow_city_mt', 'plains_town_mt', 'lima_town_mt']
# prospect_creek_ak []
# vieques_pr []
# joplin_mo ['joplin_city_mo', 'joplin_city_pt_mo']
# fargo_nd ['fargo_city_nd', 'fargo_township_nd', 'west_fargo_city_nd']
# point_lay_ak ['sand_point_city_ak', 'point_hope_city_ak', 'pilot_point_city_ak']
# santa_ana_ca ['santa_ana_city_ca', 'santa_paula_city_ca', 'santa_maria_city_ca']
# rivertonlander_wy ['riverton_city_wy', 'rock_river_town_wy', 'bear_river_town_wy']
# augusta_ga ['attapulgus_city_ga']
# kipnuk_ak []
# newtok_ak ['ekwok_city_ak', 'new_stuyahok_city_ak']
# kona_hi []
# igiugig_ak []
# ponce_pr []
# fort_smith_ar ['fort_smith_city_ar', 'oxford_city_ar', 'norfork_city_ar']
# cody_wy ['cody_city_wy']
# roxboro_nc ['roxboro_city_nc', 'roseboro_town_nc', 'tarboro_town_nc']
# butte_mt []
# iron_mountainkingsfd_mi ['iron_mountain_city_mi', 'iron_county_mi']
# sidney_mt ['sidney_city_mt']
# memphis_tn ['memphis_city_tn']
# sioux_city_ia ['sioux_county_ia', 'stout_city_ia', 'salix_city_ia']
# oakland_ca ['oakland_city_ca', 'orland_city_ca', 'woodland_city_ca']
# bar_harbor_me ['bar_harbor_town_me', 'boothbay_harbor_town_me', 'winter_harbor_town_me']
# havre_mt ['havre_city_mt', 'harlem_city_mt']
# orlando_fl ['orlando_city_fl', 'oakland_town_fl', 'marineland_town_fl']
# portland_me ['portland_city_me', 'poland_town_me', 'orland_town_me']
# fayetteville_nc ['fayetteville_city_nc', 'hayesville_town_nc', 'gatesville_town_nc']
# provo_ut ['provo_city_ut']
# alexandria_la ['alexandria_city_la', 'ashland_village_la', 'allen_parish_la']
# anacortes_wa ['anacortes_city_wa', 'naches_town_wa', 'algona_city_wa']
# bangor_me ['bangor_city_me', 'sebago_town_me', 'blaine_town_me']
# telluride_co ['telluride_town_co']
# latrobe_pa ['latrobe_city_pa']
# homer_ak ['homer_city_ak', 'nome_city_ak']
# egegik_ak ['egegik_city_ak', 'eagle_city_ak', 'eek_city_ak']
# san_luis_obispo_ca ['san_luis_obispo_city_ca', 'san_luis_obispo_county_ca', 'balance_of_san_luis_obispo_county_ca']
# newport_newswilliamsburg_va ['newport_news_city_va', 'williamsburg_city_va']
# pilot_station_ak ['pilot_station_city_ak', 'pilot_point_city_ak']
# duluth_mn ['duluth_city_mn', 'duluth_township_mn', 'douglas_county_mn']
# fairbanks_ak ['fairbanks_city_ak']
# abilene_tx ['abilene_city_tx', 'abilene_city_pt_tx', 'sabine_county_tx']
# mammoth_lakes_ca ['mammoth_lakes_town_ca']
# ugashik_ak ['alaska_ak']
# palmer_ak ['palmer_city_ak', 'ambler_city_ak']
# silver_cityhurley_nm ['silver_city_town_nm', 'sierra_county_nm']
# toksook_ak ['toksook_bay_city_ak']
# sitka_ak ['alaska_ak', 'atka_city_ak']
# honolulu_hi ['honolulu_county_hi', 'urban_honolulu_cdp_hi']
# salinasmonterey_ca ['salinas_city_ca', 'san_ramon_city_ca', 'monterey_city_ca']
# atlantic_city_nj ['atlantic_county_nj', 'atlantic_city_city_nj', 'passaic_city_nj']
# emmonak_ak ['emmonak_city_ak']
# monroe_la ['monroe_city_la', 'west_monroe_city_la', 'marion_town_la']
# hancockhoughton_mi ['hancock_township_mi', 'hancock_city_mi', 'houghton_city_mi']
# columbia_mo ['columbia_city_mo', 'tuscumbia_town_mo', 'holcomb_city_mo']
# fort_jefferson_fl ['jefferson_county_fl', 'fort_myers_beach_town_fl', 'fort_white_town_fl']
# florence_sc ['florence_city_sc', 'florence_county_sc', 'laurens_city_sc']
# williston_nd ['williston_city_nd', 'willis_township_nd', 'williams_township_nd']
# san_juan_pr []
# missoula_mt ['missoula_city_mt', 'missoula_county_mt']
# napakiak_ak ['napakiak_city_ak', 'napaskiak_city_ak', 'alaska_ak']
# port_lions_ak ['port_lions_city_ak', 'port_heiden_city_ak']
# terror_lake_ak []
# dallasfort_worth_tx ['fort_worth_city_tx', 'dallas_county_tx', 'dallas_city_tx']
# block_island_ri ['rhode_island_ri']
# levelock_ak []
# springfield_mo ['springfield_city_mo', 'springfield_city_pt_mo', 'springfield_township_mo']
# phoenix_az ['phoenix_city_az']
# port_graham_ak []
# mccook_ne ['mccook_city_ne']
# charlotte_nc ['charlotte_city_nc', 'shallotte_town_nc']
# fresno_ca ['fresno_city_ca', 'fresno_county_ca']
# jackson_wy ['jackson_town_wy', 'basin_town_wy', 'baggs_town_wy']
# bemidji_mn ['bemidji_city_mn', 'bemidji_township_mn', 'beltrami_city_mn']
# fitiuta_village_tt []
# chadron_ne ['chadron_city_ne', 'chase_county_ne', 'cedar_county_ne']
# chignik_lagoon_ak ['chignik_city_ak']
# dickinson_nd ['dickinson_city_nd', 'dickey_county_nd', 'hankinson_city_nd']
# fayetteville_ar ['fayetteville_city_ar', 'batesville_city_ar', 'prattsville_town_ar']
# sault_ste_marie_mi ['sault_ste_marie_city_mi']
# buckland_ak ['buckland_city_ak']
# pago_pago_tt []
# kodiak_island_ak ['kodiak_island_borough_ak', 'kodiak_city_ak', 'balance_of_kodiak_island_borough_ak']
# tyler_tx ['tyler_city_tx', 'tyler_county_tx', 'taylor_city_tx']
# westerly_ri ['westerly_town_ri']
# kizhuyak_ak []
# st_marys_ak ['st_marys_city_ak', 'st_michael_city_ak', 'st_paul_city_ak']
# hyder_ak []
# stebbins_ak ['stebbins_city_ak']
# butler_pa ['butler_city_pa', 'butler_county_pa', 'butler_township_pa']
# kahului_hi []
# bozeman_mt ['bozeman_city_mt', 'montana_mt']
# chalkyitsik_ak ['chevak_city_ak', 'alaska_ak', 'chuathbaluk_city_ak']
# providence_ri ['providence_city_ri', 'providence_county_ri', 'east_providence_city_ri']
# gustavus_ak ['gustavus_city_ak']
# gainesville_fl ['gainesville_city_fl', 'pinecrest_village_fl', 'graceville_city_fl']
# midlandodessa_tx ['midland_county_tx', 'midland_city_tx', 'odessa_city_tx']
# eastsound_wa ['asotin_county_wa', 'stevens_county_wa']
# newburghpoughkeepsie_ny ['poughkeepsie_town_ny', 'poughkeepsie_city_ny', 'newburgh_town_ny']
# bendredmond_or ['redmond_city_or', 'oregon_or']
# ogdensburg_ny ['ogdensburg_city_ny', 'johnsburg_town_ny', 'greenburgh_town_ny']
# burlington_vt ['burlington_city_vt', 'berlin_town_vt', 'alburg_town_vt']
# washington_dc ['washington_city_dc']
# olga_bay_ak ['cold_bay_city_ak', 'togiak_city_ak', 'larsen_bay_city_ak']
# kuparuk_ak []
# belleville_il ['belleville_city_il', 'bellevue_village_il', 'kell_village_il']
# fort_wayne_in ['fort_wayne_city_in', 'fort_wayne_city_pt_in', 'oxford_town_in']
# lazy_bay_ak ['larsen_bay_city_ak', 'alaska_ak']
# south_bend_in ['south_bend_city_in', 'south_bend_city_pt_in', 'south_whitley_town_in']
# sheldon_point_ak ['sand_point_city_ak', 'pilot_point_city_ak', 'shageluk_city_ak']
# oceana_va ['boyce_town_va']
# haines_ak ['haines_borough_ak']
# arcataeureka_ca ['eureka_city_ca', 'arcata_city_ca']
# nightmute_ak ['nightmute_city_ak', 'wainwright_city_ak']
# flint_mi ['flint_city_mi', 'flushing_city_mi', 'saline_city_mi']
# hoonah_ak ['hoonah_city_ak']
# granite_point_ak ['sand_point_city_ak', 'pilot_point_city_ak', 'aniak_city_ak']
# omaha_ne ['omaha_city_ne', 'omaha_township_ne']
# el_paso_tx ['el_paso_city_tx', 'el_paso_county_tx', 'texas_tx']
# gaylord_mi ['gaylord_city_mi', 'taylor_city_mi']
# teterboro_nj ['teterboro_borough_nj', 'chester_borough_nj', 'elmer_borough_nj']
# moline_il ['moline_city_il', 'moline_city_pt_il', 'moline_township_il']
# cedar_city_ut ['cedar_city_city_ut', 'draper_city_ut', 'beaver_city_ut']
# king_cove_ak ['king_cove_city_ak', 'kiana_city_ak']
# kingman_az ['kingman_city_az', 'pima_town_az']
# riverside_ca ['riverside_city_ca', 'riverside_county_ca', 'riverbank_city_ca']
# goodnews_bay_ak ['goodnews_bay_city_ak', 'angoon_city_ak', 'thorne_bay_city_ak']
# college_stationbryan_tx ['college_station_city_tx', 'moore_station_city_tx', 'coolidge_town_tx']
# kiluda_bay_ak ['kivalina_city_ak', 'cold_bay_city_ak', 'kiana_city_ak']
# akhiok_ak ['akhiok_city_ak', 'akiak_city_ak']
# st_cloud_mn ['st_cloud_city_mn', 'st_cloud_city_pt_mn', 'west_cook_ut_mn']
# pellston_mi ['pellston_village_mi', 'wells_township_mi', 'ellis_township_mi']
# golovin_ak ['golovin_city_ak']
# meridian_ms ['meridian_city_ms', 'merigold_town_ms']
# chignik_bay_ak ['chignik_city_ak', 'shungnak_city_ak']
# albuquerque_nm ['albuquerque_city_nm']
# lewisburg_wv ['lewisburg_city_wv', 'rowlesburg_town_wv', 'newburg_town_wv']
# lewiston_id ['lewiston_city_id', 'lewis_county_id', 'weston_city_id']
# texarkana_ar ['texarkana_city_ar', 'arkansas_ar', 'arkansas_county_ar']
# laredo_tx ['laredo_city_tx', 'clarendon_city_tx', 'mildred_town_tx']
# circle_ak []
# lancaster_pa ['lancaster_city_pa', 'lancaster_county_pa', 'lancaster_township_pa']
# kansas_city_mo ['kansas_city_city_mo', 'ava_city_mo', 'warsaw_city_mo']
# bishop_ca ['bishop_city_ca']
# dayton_oh ['dayton_city_oh', 'darby_township_oh', 'clayton_city_oh']
# nulato_ak ['nulato_city_ak', 'huslia_city_ak']
# ketchikan_ak ['ketchikan_city_ak', 'ketchikan_gateway_borough_ak']
# mountain_view_ca ['mountain_view_city_ca', 'montclair_city_ca', 'fountain_valley_city_ca']
# monterey_ca ['monterey_city_ca', 'monterey_county_ca', 'monte_sereno_city_ca']
# tuscaloosa_al ['tuscaloosa_city_al', 'tuscaloosa_county_al', 'tallapoosa_county_al']
# nuiqsut_ak ['nuiqsut_city_ak', 'nunam_iqua_city_ak']
# liberal_ks ['liberal_city_ks', 'liberal_township_ks', 'liebenthal_city_ks']
# bedford_ma ['bedford_town_ma', 'medford_city_ma', 'new_bedford_city_ma']
# arctic_village_ak ['mountain_village_city_ak']
# everett_wa ['everett_city_wa', 'everson_city_wa', 'leavenworth_city_wa']
# tin_city_ak ['kiana_city_ak', 'stebbins_city_ak', 'platinum_city_ak']
# pittsburgh_pa ['pittsburgh_city_pa', 'paint_borough_pa', 'wattsburg_borough_pa']
# unalakleet_ak ['unalakleet_city_ak', 'unalaska_city_ak', 'alaska_ak']
# mosinee_wi ['mosinee_town_wi', 'mosinee_city_wi', 'menominee_town_wi']
# lanai_hi ['hawaii_hi']
# pullman_wa ['pullman_city_wa', 'lyman_town_wa']
# utopia_ak ['togiak_city_ak', 'nulato_city_ak']
# klamath_falls_or ['klamath_falls_city_or', 'klamath_county_or']
# noorvik_ak ['noorvik_city_ak', 'anvik_city_ak']
# naples_fl ['naples_city_fl']
# point_hope_ak ['point_hope_city_ak']
# chico_ca ['chico_city_ca', 'chino_city_ca']
# barter_island_ak ['barrow_city_ak']
# skagway_ak ['alaska_ak', 'savoonga_city_ak', 'kiana_city_ak']
# aspen_co ['aspen_city_co', 'fraser_town_co', 'haswell_town_co']
# killeen_tx ['killeen_city_tx', 'gillespie_county_tx', 'pleak_village_tx']
# gulfportbiloxi_ms ['gulfport_city_ms']
# traverse_city_mi ['traverse_city_city_mi', 'traverse_city_city_pt_mi', 'fraser_city_mi']
# daytona_beach_fl ['daytona_beach_city_fl', 'dania_beach_city_fl', 'daytona_beach_shores_city_fl']
# kirksville_mo ['kirksville_city_mo', 'oaks_village_mo', 'kingsville_city_mo']
# shungnak_ak ['shungnak_city_ak']
# greenville_sc ['greenville_city_sc', 'greenville_county_sc', 'greeleyville_town_sc']
# minneapolis_mn ['minneapolis_city_mn', 'minnesota_mn', 'minneota_city_mn']
# thief_river_falls_mn ['thief_river_falls_city_mn', 'third_river_township_mn', 'river_falls_township_mn']
# st_louis_mo ['st_louis_city_mo', 'st_louis_county_mo', 'lake_st_louis_city_mo']
# detroit_mi ['detroit_city_mi', 'troy_city_mi', 'dearborn_city_mi']
# tucson_az ['tucson_city_az', 'tusayan_town_az', 'south_tucson_city_az']
# princetonbluefield_wv ['princeton_city_wv', 'bluefield_city_wv']
# boston_ma ['boston_city_ma', 'otis_town_ma', 'boylston_town_ma']
# culebra_pr []
# owensboro_ky ['owensboro_city_ky', 'brownsboro_farm_city_ky', 'owen_county_ky']
# kwigillingok_ak []
# moses_lake_wa ['moses_lake_city_wa', 'bonney_lake_city_wa', 'medical_lake_city_wa']
# sleetmute_ak []
# visalia_ca ['visalia_city_ca', 'salinas_city_ca', 'vista_city_ca']
# long_beach_ca ['long_beach_city_ca', 'solana_beach_city_ca', 'laguna_beach_city_ca']
# tununak_ak ['shungnak_city_ak']
# austin_tx ['austin_city_tx', 'austin_county_tx', 'justin_city_tx']
# fort_dodge_ia ['fort_dodge_city_ia', 'fort_madison_city_ia']
# alliance_ne ['alliance_city_ne', 'papillion_city_ne', 'axtell_village_ne']
# new_londongroton_ct ['new_london_town_ct', 'new_london_county_ct', 'new_london_city_ct']
# asheville_nc ['asheville_city_nc', 'nashville_town_nc', 'marshville_town_nc']
# huntsville_al ['huntsville_city_al', 'huntsville_city_pt_al', 'guntersville_city_al']
# winston-salem_nc ['winston-salem_city_nc', 'windsor_town_nc', 'erwin_town_nc']
# lawrence_ma ['lawrence_city_ma', 'ware_town_ma']
# portland_or ['portland_city_or', 'portland_city_pt_or', 'oakland_city_or']
# shreveport_la ['shreveport_city_la', 'shreveport_city_pt_la']
# vernal_ut ['vernal_city_ut', 'riverdale_city_ut', 'vernon_town_ut']
# boise_id ['boise_county_id', 'dubois_city_id', 'boise_city_city_id']
# bridgeport_ct ['bridgeport_town_ct', 'bridgeport_city_ct', 'woodbridge_town_ct']
# cedar_rapidsiowa_city_ia ['cedar_rapids_city_ia', 'rock_rapids_city_ia', 'coon_rapids_city_ia']
# christiansted_vi []
# eau_claire_wi ['eau_claire_city_wi', 'eau_claire_county_wi', 'eau_claire_city_pt_wi']
# hartford_ct ['hartford_town_ct', 'hartford_city_ct', 'hartford_county_ct']
# baton_rouge_la ['baton_rouge_city_la', 'west_baton_rouge_parish_la', 'east_baton_rouge_parish_la']
# nelson_lagoon_ak []
# hilton_head_sc ['hilton_head_island_town_sc', 'hilda_town_sc']
# kobuk_ak ['kobuk_city_ak', 'koyuk_city_ak', 'koyukuk_city_ak']
# port_heiden_ak ['port_heiden_city_ak', 'port_lions_city_ak', 'point_hope_city_ak']
# port_bailey_ak ['port_alexander_city_ak', 'thorne_bay_city_ak', 'port_lions_city_ak']
# san_antonio_tx ['san_antonio_city_tx', 'san_antonio_city_pt_tx', 'santa_anna_town_tx']
# st_george_ut ['st_george_city_ut']
# pendleton_or ['pendleton_city_or', 'glendale_city_or', 'dayville_town_or']
# eagle_harbor_ak ['old_harbor_city_ak', 'eagle_city_ak', 'denali_borough_ak']
# yakima_wa ['yakima_city_wa', 'yakima_county_wa']
# uganik_ak ['anvik_city_ak', 'aniak_city_ak', 'galena_city_ak']
# peoria_il ['peoria_city_il', 'peoria_county_il', 'peoria_city_pt_il']
# south_naknek_ak []
# dodge_city_ks ['ogden_city_ks', 'bogue_city_ks', 'dodge_city_city_ks']
# lynchburg_va ['lynchburg_city_va', 'blacksburg_town_va']
# craig_ak ['craig_city_ak', 'mcgrath_city_ak', 'cordova_city_ak']
# brownsville_tx ['brownsville_city_tx', 'bartonville_town_tx', 'rosser_village_tx']
# roseburg_or ['roseburg_city_or', 'coburg_city_or', 'harrisburg_city_or']
# beckley_wv ['beckley_city_wv', 'berkeley_county_wv', 'belle_town_wv']
# new_bedfordfall_river_ma ['new_bedford_city_ma', 'fall_river_city_ma']
# new_orleans_la ['new_orleans_city_la', 'orleans_parish_la', 'new_roads_city_la']
# watertown_ny ['waterloo_town_ny', 'ward_town_ny', 'watertown_town_ny']
# philadelphia_pa ['philadelphia_city_pa', 'philadelphia_county_pa', 'new_philadelphia_borough_pa']
# hays_ks ['hays_city_ks', 'kansas_ks', 'haven_city_ks']
# rochester_mn ['rochester_city_mn', 'rochester_township_mn', 'manchester_city_mn']
# inyokern_ca ['inyo_county_ca', 'windsor_town_ca']
# whale_pass_ak ['false_pass_city_ak', 'alaska_ak', 'newhalen_city_ak']
# sitkinak_ak []
# stony_river_ak ['houston_city_ak']
# danger_bay_ak ['anderson_city_ak']
# bay_city_tx ['brady_city_tx', 'barry_city_tx', 'bailey_city_tx']
# san_diego_ca ['san_diego_city_ca', 'san_diego_county_ca', 'san_mateo_city_ca']
# guam_tt []
# charlottesville_va ['charlottesville_city_va', 'scottsville_town_va', 'lovettsville_town_va']
# wales_ak ['wales_city_ak', 'alaska_ak']
# pedro_bay_ak ['hooper_bay_city_ak']
# alpine_ak []
# bowling_green_ky ['bowling_green_city_ky']
# tacoma_wa ['tacoma_city_wa']
# twin_falls_id ['twin_falls_city_id', 'twin_falls_county_id', 'post_falls_city_id']
# chefornak_ak ['chefornak_city_ak', 'chevak_city_ak']
# salina_ks ['salina_city_ks', 'saline_county_ks', 'sylvia_city_ks']
# pontiac_mi ['pontiac_city_mi', 'ionia_city_mi', 'portage_city_mi']
# kapalua_hi []
# kitoi_bay_ak ['kaktovik_city_ak', 'togiak_city_ak', 'eek_city_ak']
# youngstownwarren_oh ['youngstown_city_oh', 'youngstown_city_pt_oh', 'johnstown_village_oh']
# escanaba_mi ['escanaba_city_mi', 'escanaba_township_mi']
# venetie_ak []
# columbia_sc ['columbia_city_sc', 'columbia_city_pt_sc', 'west_columbia_city_sc']
# worcester_ma ['worcester_city_ma', 'worcester_county_ma', 'rochester_town_ma']
# lihue_hi []
# brevig_mission_ak ['brevig_mission_city_ak', 'russian_mission_city_ak']
# koyukuk_ak ['koyukuk_city_ak', 'koyuk_city_ak', 'mekoryuk_city_ak']
# hughes_ak ['hughes_city_ak']
# bloomington_in ['bloomington_city_in', 'bloomingdale_town_in', 'bloomington_city_pt_in']
# wainwright_ak ['wainwright_city_ak', 'haines_borough_ak']
# cortez_co ['cortez_city_co', 'victor_city_co', 'colorado_co']
# grand_forks_nd ['grand_forks_city_nd', 'grand_forks_county_nd', 'grand_forks_township_nd']
# knoxville_tn ['knoxville_city_tn', 'enville_town_tn', 'nolensville_town_tn']
# indianapolis_in ['indianapolis_city_in', 'indiana_in', 'indianapolis_city_balance_in']
# cincinnati_oh ['cincinnati_city_oh', 'celina_city_oh', 'conneaut_city_oh']
# parkersburg_wv ['parkersburg_city_wv', 'petersburg_city_wv', 'clarksburg_city_wv']
# beaver_ak []
# marana_az ['marana_town_az', 'arizona_az', 'marana_town_pt_az']
# montgomery_al ['montgomery_city_al', 'montgomery_county_al']
# newport_or ['newport_city_or', 'newberg_city_or', 'waldport_city_or']
# jamestown_nd ['jamestown_city_nd', 'acme_township_nd', 'james_hill_township_nd']
# columbia_tn ['columbia_city_tn']
# el_dorado_ar ['el_dorado_city_ar', 'weldon_town_ar', 'eudora_city_ar']
# missionmcallenedinburg_tx ['mission_city_tx']
# chicagoromeoville_il ['chicago_ridge_village_il', 'harmon_village_il', 'hidalgo_village_il']
# tinian_tt []
# beverly_ma ['beverly_city_ma', 'revere_city_ma', 'everett_city_ma']
# clarks_point_ak ['clarks_point_city_ak', 'fairbanks_city_ak', 'chevak_city_ak']
# thorne_bay_ak ['thorne_bay_city_ak', 'hooper_bay_city_ak', 'homer_city_ak']
# fort_leonard_wood_mo ['mount_leonard_town_mo', 'leadwood_city_mo']
# newport_ri ['newport_city_ri', 'newport_county_ri', 'new_shoreham_town_ri']
# minot_nd ['minot_city_nd', 'milnor_city_nd', 'minto_city_nd']
# bradford_pa ['bradford_city_pa', 'bradford_county_pa', 'bradford_township_pa']
# chuathbaluk_ak ['chuathbaluk_city_ak']
# ukiah_ca ['ukiah_city_ca']
# napaskiak_ak ['napaskiak_city_ak', 'napakiak_city_ak', 'alaska_ak']
# ashland_wv ['bradshaw_town_wv']
# stillwater_ok ['stillwater_city_ok', 'sweetwater_town_ok', 'stigler_city_ok']
# islip_ny ['islip_town_ny']
# panama_city_fl ['panama_city_city_fl', 'palatka_city_fl', 'tampa_city_fl']
# rochester_ny ['rochester_town_ny', 'rochester_city_ny', 'chester_town_ny']
# st_michael_ak ['st_michael_city_ak']
# cordova_ak ['cordova_city_ak']
# may_creek_ak []
# palm_springs_ca ['palm_springs_city_ca', 'palm_desert_city_ca', 'santa_fe_springs_city_ca']
# jacksonvicksburg_ms ['vicksburg_city_ms', 'jackson_county_ms', 'jackson_city_ms']
# laconia_nh ['laconia_city_nh', 'franconia_town_nh', 'lebanon_city_nh']
# kenai_ak ['kenai_city_ak', 'kiana_city_ak', 'nenana_city_ak']
# eagle_ak ['eagle_city_ak']
# chicago_il ['chicago_city_il', 'chicago_city_pt_il', 'west_chicago_city_il']
# stevens_village_ak []
# selawik_ak ['selawik_city_ak', 'alaska_ak']
# burlingtonmount_vernon_wa ['mount_vernon_city_wa', 'burlington_city_wa', 'farmington_town_wa']
# dothan_al ['dothan_city_al', 'dothan_city_pt_al', 'waldo_town_al']
# gulkana_ak ['kiana_city_ak']
# tuluksak_ak []
# chevak_ak ['chevak_city_ak', 'kachemak_city_ak', 'chefornak_city_ak']
# east_farmingdale_ny ['farmingdale_village_ny', 'east_aurora_village_ny', 'east_hampton_village_ny']
# flagstaff_az ['flagstaff_city_az']
# bellingham_wa ['bellingham_city_wa']
# hanford_ca ['hanford_city_ca', 'california_ca']
# destin_fl ['destin_city_fl', 'esto_town_fl', 'desoto_county_fl']
# chicken_ak []
# atmautluak_ak ['alaska_ak']
# rhinelander_wi ['rhinelander_city_wi', 'rhine_town_wi', 'ridgeland_village_wi']
# grand_rapids_mi ['grand_rapids_city_mi', 'east_grand_rapids_city_mi', 'eaton_rapids_city_mi']
# grand_canyon_az ['casa_grande_city_az', 'graham_county_az', 'gila_bend_town_az']
# new_bernmoreheadbeaufort_nc []
# aguadilla_pr []
# tonopah_nv []
# waterbury_ct ['waterbury_town_ct', 'waterbury_city_ct', 'canterbury_town_ct']
# camp_springs_md ['clear_spring_town_md', 'mardela_springs_town_md']
# skwentna_ak ['alaska_ak']
# toledo_oh ['toledo_city_oh', 'ohio_oh']
# fort_myers_fl ['fort_myers_city_fl', 'fort_myers_beach_town_fl', 'fort_meade_city_fl']
# north_kingstown_ri ['north_kingstown_town_ri', 'south_kingstown_town_ri', 'north_providence_town_ri']
# portsmouth_nh ['portsmouth_city_nh', 'plymouth_town_nh']
# champaignurbana_il ['champaign_county_il', 'champaign_city_il', 'champaign_township_il']
# medford_or ['medford_city_or']
# wake_island_tt []
# hayden_co ['hayden_town_co', 'walden_town_co', 'rye_town_co']
# marquette_mi ['marquette_city_mi', 'marquette_county_mi', 'marquette_township_mi']
# smyrna_tn ['smyrna_town_tn', 'selmer_town_tn']
# hattiesburglaurel_ms ['hattiesburg_city_ms', 'hattiesburg_city_pt_ms']
# columbus_ms ['columbus_city_ms', 'columbia_city_ms']
# cape_romanzof_ak []
# st_petersburg_fl ['st_petersburg_city_fl', 'leesburg_city_fl']
# walla_walla_wa ['walla_walla_city_wa', 'walla_walla_county_wa', 'balance_of_walla_walla_county_wa']
# east_hampton_ny ['east_hampton_town_ny', 'east_hampton_village_ny', 'easton_town_ny']
# gunnison_co ['gunnison_city_co', 'gunnison_county_co', 'nunn_town_co']
# dora_bay_ak ['thorne_bay_city_ak', 'hooper_bay_city_ak', 'cordova_city_ak']
# fairfield_ca ['fairfield_city_ca', 'bakersfield_city_ca', 'greenfield_city_ca']
# tanana_ak ['tanana_city_ak', 'alaska_ak', 'nenana_city_ak']
# sacramento_ca ['sacramento_city_ca', 'sacramento_county_ca', 'west_sacramento_city_ca']
# coldfoot_ak ['cordova_city_ak']
# ceiba_pr []
# oklahoma_city_ok ['oklahoma_county_ok', 'oklahoma_city_city_ok', 'oklahoma_ok']
# morrisville_vt ['morrisville_village_vt', 'orleans_village_vt', 'cambridge_village_vt']
# saipan_tt []
# bethel_ak ['bethel_city_ak', 'bethel_census_area_ak']
# cold_bay_ak ['cold_bay_city_ak', 'old_harbor_city_ak', 'cordova_city_ak']
# kotlik_ak ['kotlik_city_ak', 'kodiak_city_ak']
# red_devil_ak []
# mccarthy_ak ['mcgrath_city_ak', 'nome_city_ak', 'elim_city_ak']
# trenton_nj ['trenton_city_nj', 'kearny_town_nj', 'green_township_nj']
# manhattanft_riley_ks ['manhattan_city_ks', 'manhattan_city_pt_ks', 'manhattan_township_ks']
# koliganek_ak ['kotlik_city_ak', 'kodiak_city_ak']
# kotzebue_ak ['kotzebue_city_ak']
# muskegon_mi ['muskegon_city_mi', 'muskegon_county_mi', 'north_muskegon_city_mi']
# san_francisco_ca ['san_francisco_city_ca', 'san_francisco_county_ca', 'south_san_francisco_city_ca']
# atqasuk_ak ['atqasuk_city_ak', 'alaska_ak']
# denton_tx ['denton_city_tx', 'venus_town_tx', 'trent_town_tx']
# casper_wy ['casper_city_wy']
# fort_dix_nj []
# rocky_mount_nc ['rocky_mount_city_nc', 'rocky_mount_city_pt_nc', 'polk_county_nc']
# west_palm_beachpalm_beach_fl ['west_palm_beach_city_fl', 'south_palm_beach_town_fl', 'north_palm_beach_village_fl']
# las_vegas_nv ['las_vegas_city_nv', 'north_las_vegas_city_nv']
# lexington_ky ['fleming_county_ky', 'arlington_city_ky', 'wellington_city_ky']
# alamosa_co ['alamosa_city_co', 'alamosa_county_co', 'alma_town_co']
# false_pass_ak ['false_pass_city_ak', 'alaska_ak']
# shaktoolik_ak ['shaktoolik_city_ak', 'kaktovik_city_ak']
# charleston_sc ['charleston_city_sc', 'charleston_county_sc', 'charleston_city_pt_sc']
# port_alexander_ak ['port_alexander_city_ak', 'port_heiden_city_ak']
# eugene_or ['eugene_city_or', 'oregon_or']
# akutan_ak ['akutan_city_ak']
# marthas_vineyard_ma []
# beaumontport_arthur_tx ['beaumont_city_tx', 'port_arthur_city_tx', 'port_arthur_city_pt_tx']
# pensacola_fl ['pensacola_city_fl']
# elko_nv ['elko_city_nv', 'elko_county_nv']
# williamsport_pa ['williamsport_city_pa', 'williams_township_pa', 'williamstown_borough_pa']
# harlingensan_benito_tx ['harlingen_city_tx', 'san_benito_city_tx', 'ballinger_city_tx']
# augustawaterville_me ['waterville_city_me', 'augusta_city_me', 'sangerville_town_me']
# sioux_falls_sd ['sioux_falls_city_sd', 'sioux_falls_city_pt_sd', 'sioux_valley_township_sd']
# crooked_creek_ak []
# manley_hot_springs_ak []
# aberdeen_sd ['aberdeen_city_sd', 'aberdeen_township_sd', 'albee_town_sd']
# nunapitchuk_ak ['nunapitchuk_city_ak']
# macon_ga ['macon_city_ga', 'macon_county_ga', 'lamar_county_ga']
# borniteruby_creek_ak []
# reno_nv ['reno_city_nv']
# international_falls_mn ['international_falls_city_mn']
# northampton_ma ['northampton_city_ma', 'wrentham_town_ma', 'southampton_town_ma']
# koyuk_ak ['koyuk_city_ak', 'koyukuk_city_ak', 'mekoryuk_city_ak']
# logan_ut ['logan_city_ut', 'loa_town_ut', 'morgan_city_ut']
# santa_maria_ca ['santa_maria_city_ca', 'santa_clarita_city_ca', 'santa_clara_city_ca']
# atlanta_ga ['atlanta_city_ga', 'atlanta_city_pt_ga', 'albany_city_ga']
# elmiracorning_ny ['elmira_town_ny', 'elmira_city_ny', 'corning_town_ny']
# decatur_al ['decatur_city_al', 'decatur_city_pt_al']
# mayaguez_pr []
# marshall_ak ['marshall_city_ak']
# gary_in ['gary_city_in', 'gary_city_pt_in', 'garrett_city_in']
# syracuse_ny ['syracuse_city_ny', 'east_syracuse_village_ny', 'north_syracuse_village_ny']
# chisana_ak ['kiana_city_ak']
# charlestondunbar_wv ['charleston_city_wv', 'charles_town_city_wv', 'preston_county_wv']
# noatak_ak ['alaska_ak', 'manokotak_city_ak']
# karluk_ak []
# kake_ak ['kake_city_ak', 'alaska_ak']
# minto_ak []
# raleighdurham_nc ['raleigh_city_nc', 'durham_city_nc']
# barrow_ak ['barrow_city_ak']
# grand_junction_co ['grand_junction_city_co', 'grand_county_co', 'granada_town_co']
# teller_ak ['teller_city_ak']
# dubuque_ia ['dubuque_city_ia', 'dubuque_county_ia']
# kalamazoo_mi ['kalamazoo_city_mi', 'kalamazoo_county_mi', 'kalamo_township_mi']
# myrtle_beach_sc ['myrtle_beach_city_sc', 'north_myrtle_beach_city_sc']
# akun_ak ['akutan_city_ak', 'alaska_ak']
# san_jose_ca ['san_jose_city_ca', 'santa_rosa_city_ca', 'san_marcos_city_ca']
# san_angelo_tx ['san_angelo_city_tx', 'san_leanna_village_tx', 'santa_anna_town_tx']
# morgantown_wv ['morgantown_city_wv', 'man_town_wv', 'mason_town_wv']
# blue_fox_bay_ak []
# melbourne_fl ['melbourne_city_fl', 'west_melbourne_city_fl', 'melbourne_beach_town_fl']
# ontario_ca ['ontario_city_ca', 'oxnard_city_ca', 'fontana_city_ca']
# wilmington_oh ['wilmington_city_oh', 'wheeling_township_oh', 'wellington_village_oh']
# arlington_tx ['arlington_city_tx', 'avinger_town_tx', 'runge_town_tx']
# appleton_wi ['maple_town_wi', 'appleton_city_wi', 'naples_town_wi']
# garden_city_ks ['gardner_city_ks', 'ogden_city_ks', 'green_city_ks']
# coffman_cove_ak ['coffman_cove_city_ak']
# merced_ca ['merced_city_ca', 'merced_county_ca', 'commerce_city_ca']
# mason_city_ia ['manson_city_ia', 'marion_city_ia', 'dawson_city_ia']
# ithacacortland_ny ['ithaca_town_ny', 'ithaca_city_ny', 'hartland_town_ny']
# sarasotabradenton_fl ['sarasota_county_fl', 'sarasota_city_fl', 'bradenton_city_fl']
# mekoryuk_ak ['mekoryuk_city_ak', 'koyuk_city_ak', 'koyukuk_city_ak']
# quinhagak_ak ['quinhagak_city_ak']
# presque_islehoulton_me ['presque_isle_city_me', 'deer_isle_town_me', 'roque_bluffs_town_me']
# tuntutuliak_ak []
# manchester_nh ['manchester_city_nh', 'chester_town_nh', 'winchester_town_nh']
# thermal_ca []
# allakaket_ak ['allakaket_city_ak', 'alaska_ak', 'alakanuk_city_ak']
# del_rio_tx ['del_rio_city_tx', 'iredell_city_tx', 'delta_county_tx']
# rockford_il ['rockford_city_il', 'rockford_city_pt_il', 'rockford_township_il']
# morristown_nj ['morristown_town_nj', 'morris_township_nj', 'morris_county_nj']
# deering_ak ['deering_city_ak']
# laramie_wy ['laramie_city_wy', 'laramie_county_wy', 'fort_laramie_town_wy']
# brownwood_tx ['brownwood_city_tx', 'brownsboro_city_tx', 'brown_county_tx']
# chomondely_sound_ak []
# springfield_il ['springfield_city_il', 'springfield_city_pt_il', 'springfield_township_il']
# king_salmon_ak []
# beluga_ak []
# larsen_bay_ak ['larsen_bay_city_ak', 'alaska_ak', 'anderson_city_ak']
# jonesboro_ar ['jonesboro_city_ar', 'johnson_county_ar', 'joiner_city_ar']
# tallahassee_fl ['tallahassee_city_fl', 'callahan_town_fl']
# savannah_ga ['savannah_city_ga', 'avalon_town_ga']
# kearney_ne ['kearney_city_ne', 'kearney_county_ne', 'cedar_county_ne']
# west_point_ak ['wales_city_ak', 'sand_point_city_ak', 'st_paul_city_ak']
# juneau_ak []
# nikolski_ak ['nikolai_city_ak', 'alaska_ak']
# manassas_va ['manassas_city_va', 'manassas_park_city_va']
# dover_de ['dover_city_de', 'delaware_de']
# sandpoint_ak ['sand_point_city_ak', 'anderson_city_ak', 'seward_city_ak']
# new_york_ny ['new_york_ny', 'new_york_city_ny', 'new_york_county_ny']
# state_college_pa ['state_college_borough_pa']
# rota_tt []
# kasigluk_ak ['alaska_ak']
# zachar_bay_ak ['kachemak_city_ak']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-305-0a90a150edcc> in <module>
#       1 out_data = {}
#       2 for n in nodes:
# ----> 3     out_data[n] = city_get_population(n)
#
# <ipython-input-288-b82d7791852e> in city_get_population(c)
#      13     print(c,matching_cities)
#      14     if len(matching_cities)>0:
# ---> 15         return(get_pop_by_city(matching_cities[0]))
#      16     else:
#      17         return np.nan
#
# <ipython-input-288-b82d7791852e> in get_pop_by_city(c)
#       4 def get_pop_by_city(c):
#       5     if c in cities:
# ----> 6         return int(city_pop_dict[c])
#       7     else:
#       8         return np.nan
#
# ValueError: invalid literal for int() with base 10: 'X'

# %%
len(out_data)
# Out:
# 600

# %%
pd.DataFrame.from_dict(out_data,orient='index').to_pickle('../data/us_air_population_1.pkl')

# %%
out_data
# Out:
# {'peru_in': 11417,
#  'valparaiso_in': 31730,
#  'greenville_ms': 34400,
#  'port_protection_ak': 2117,
#  'hoolehua_hi': nan,
#  'adak_island_ak': 326,
#  'wrangell_ak': nan,
#  'shageluk_ak': 83,
#  'kiana_ak': 361,
#  'marietta_ga': 56579,
#  'vero_beach_fl': 15220,
#  'concord_nc': 79066,
#  'bakersfield_ca': 347483,
#  'santa_fe_nm': 67947,
#  'chenega_ak': nan,
#  'perryville_ak': nan,
#  'santa_rosa_ca': 167815,
#  'akron_oh': 199110,
#  'roanoke_va': 97032,
#  'hibbing_mn': 16361,
#  'columbus_oh': 787033,
#  'key_west_fl': 24649,
#  'niagara_falls_ny': 50193,
#  'rockland_me': 7297,
#  'corvallis_or': 54462,
#  'helena_mt': 28190,
#  'colorado_springs_co': 416427,
#  'boca_raton_fl': 84392,
#  'milwaukee_wi': 0,
#  'anchorage_ak': 291826,
#  'north_platte_ne': 24733,
#  'norfolk_va': 242803,
#  'los_angeles_ca': 3792621,
#  'nashville_tn': 4530,
#  'green_bay_wi': 2035,
#  'alakanuk_ak': 677,
#  'gillette_wy': 29087,
#  'togiak_ak': 817,
#  'cape_lisburne_ak': nan,
#  'franklinoil_city_pa': 6545,
#  'sanford_fl': 53570,
#  'cape_girardeau_mo': 37941,
#  'excursion_inlet_ak': 246,
#  'farmington_nm': 45877,
#  'sun_valleyhaileyketchum_id': 1406,
#  'galena_ak': 470,
#  'allentownbethlehemeaston_pa': 2354,
#  'kalaupapa_hi': nan,
#  'waco_tx': 124805,
#  'yuma_az': 93064,
#  'huslia_ak': 275,
#  'provincetown_ma': 2942,
#  'white_mountain_ak': 190,
#  'roswell_nm': 48366,
#  'hana_hi': 1360301,
#  'bullhead_city_az': 39540,
#  'old_harbor_ak': 218,
#  'lake_havasu_city_az': 52527,
#  'salisbury_md': 30343,
#  'pocatello_id': 54255,
#  'albany_ny': 97856,
#  'seldovia_ak': 255,
#  'jacksonvillecamp_lejeune_nc': 70145,
#  'tulsa_ok': 391906,
#  'charlotte_amalie_vi': nan,
#  'metlakatla_ak': 710231,
#  'hydaburg_ak': 376,
#  'healy_ak': 86,
#  'rutland_vt': 4054,
#  'baltimore_md': 620961,
#  'tok_ak': 817,
#  'harrison_ar': 12943,
#  'wausau_wi': 2229,
#  'miami_fl': 399457,
#  'ironwood_mi': 5387,
#  'frederick_md': 65239,
#  'angoon_ak': 459,
#  'buffalo_ny': 261310,
#  'muscle_shoals_al': 13146,
#  'jackson_mi': 33534,
#  'billings_mt': 104170,
#  'port_angeles_wa': 19038,
#  'west_palm_beach_fl': 99919,
#  'burbank_ca': 103340,
#  'chignik_ak': 91,
#  'victoria_tx': 62592,
#  'cape_newenham_ak': nan,
#  'cheyenne_wy': 59466,
#  'harrisburg_pa': 49528,
#  'birch_creek_ak': nan,
#  'petaluma_ca': 57941,
#  'bettles_ak': 12,
#  'naukiti_ak': 762,
#  'twin_hills_ak': nan,
#  'rapid_city_sd': 67956,
#  'jackson_tn': 65211,
#  'eagle_co': 6508,
#  'evansville_in': 117429,
#  'kalskag_ak': 710231,
#  'shishmaref_ak': 563,
#  'kenmore_wa': 20460,
#  'tyonek_ak': nan,
#  'pueblo_co': 106595,
#  'johnstown_pa': 20978,
#  'valdez_ak': 3976,
#  'york_pa': 43718,
#  'fort_drum_ny': 6371,
#  'iliamna_ak': 374,
#  'brainerd_mn': 13590,
#  'waterloo_ia': 68406,
#  'friday_harbor_wa': 2162,
#  'brunswick_ga': 15383,
#  'lafayette_in': 67140,
#  'denver_co': 600158,
#  'lafayette_la': 120623,
#  'shemya_ak': nan,
#  'pascokennewickrichland_wa': 73917,
#  'anniston_al': 23106,
#  'dubois_pa': 7794,
#  'lawtonfort_sill_ok': 96867,
#  'clovis_nm': 37775,
#  'nome_ak': 3598,
#  'crescent_city_ca': 7643,
#  'savoonga_ak': 671,
#  'glendive_mt': 4935,
#  'salem_or': 154637,
#  'aniak_ak': 501,
#  'akiak_ak': 346,
#  'holy_cross_ak': 178,
#  'scammon_bay_ak': 474,
#  'hyannis_ma': 90329,
#  'glasgow_mt': 3250,
#  'prospect_creek_ak': nan,
#  'vieques_pr': nan,
#  'joplin_mo': 50150,
#  'fargo_nd': 105549,
#  'point_lay_ak': 976,
#  'santa_ana_ca': 324528,
#  'rivertonlander_wy': 10615,
#  'augusta_ga': 449,
#  'kipnuk_ak': nan,
#  'newtok_ak': 115,
#  'kona_hi': nan,
#  'igiugig_ak': nan,
#  'ponce_pr': nan,
#  'fort_smith_ar': 86209,
#  'cody_wy': 9520,
#  'roxboro_nc': 8362,
#  'butte_mt': nan,
#  'iron_mountainkingsfd_mi': 7624,
#  'sidney_mt': 5191,
#  'memphis_tn': 646889,
#  'sioux_city_ia': 33704,
#  'oakland_ca': 390724,
#  'bar_harbor_me': 5235,
#  'havre_mt': 9310,
#  'orlando_fl': 238300,
#  'portland_me': 66194,
#  'fayetteville_nc': 200564,
#  'provo_ut': 112488,
#  'alexandria_la': 47723,
#  'anacortes_wa': 15778,
#  'bangor_me': 33039,
#  'telluride_co': 2325,
#  'latrobe_pa': 8338,
#  'homer_ak': 5003,
#  'egegik_ak': 109,
#  'san_luis_obispo_ca': 45119,
#  'newport_newswilliamsburg_va': 180719,
#  'pilot_station_ak': 568,
#  'duluth_mn': 86265,
#  'fairbanks_ak': 31535,
#  'abilene_tx': 117063,
#  'mammoth_lakes_ca': 8234,
#  'ugashik_ak': 710231,
#  'palmer_ak': 5937,
#  'silver_cityhurley_nm': 10315,
#  'toksook_ak': 590,
#  'sitka_ak': 710231,
#  'honolulu_hi': 953207,
#  'salinasmonterey_ca': 150441,
#  'atlantic_city_nj': 274549,
#  'emmonak_ak': 762,
#  'monroe_la': 48815,
#  'hancockhoughton_mi': 461,
#  'columbia_mo': 108500,
#  'fort_jefferson_fl': 14761,
#  'florence_sc': 37056,
#  'williston_nd': 14716,
#  'san_juan_pr': nan,
#  'missoula_mt': 66788,
#  'napakiak_ak': 354,
#  'port_lions_ak': 194,
#  'terror_lake_ak': nan,
#  'dallasfort_worth_tx': 741206,
#  'block_island_ri': 1052567,
#  'levelock_ak': nan,
#  'springfield_mo': 159498,
#  'phoenix_az': 1445632,
#  'port_graham_ak': nan,
#  'mccook_ne': 7698,
#  'charlotte_nc': 731424,
#  'fresno_ca': 494665,
#  'jackson_wy': 9577,
#  'bemidji_mn': 13431,
#  'fitiuta_village_tt': nan,
#  'chadron_ne': 5851,
#  'chignik_lagoon_ak': 91,
#  'dickinson_nd': 17787,
#  'fayetteville_ar': 73580,
#  'sault_ste_marie_mi': 14144,
#  'buckland_ak': 416,
#  'pago_pago_tt': nan,
#  'kodiak_island_ak': 13592,
#  'tyler_tx': 96900,
#  'westerly_ri': 22787,
#  'kizhuyak_ak': nan,
#  'st_marys_ak': 507,
#  'hyder_ak': nan,
#  'stebbins_ak': 556,
#  'butler_pa': 13757,
#  'kahului_hi': nan,
#  'bozeman_mt': 37280,
#  'chalkyitsik_ak': 938,
#  'providence_ri': 178042,
#  'gustavus_ak': 442,
#  'gainesville_fl': 124354,
#  'midlandodessa_tx': 136872,
#  'eastsound_wa': 21623,
#  'newburghpoughkeepsie_ny': 43341,
#  'bendredmond_or': 26215,
#  'ogdensburg_ny': 11128,
#  'burlington_vt': 42417,
#  'washington_dc': 601723,
#  'olga_bay_ak': 108,
#  'kuparuk_ak': nan,
#  'belleville_il': 44478,
#  'fort_wayne_in': 253691,
#  'lazy_bay_ak': 87,
#  'south_bend_in': 101168,
#  'sheldon_point_ak': 976,
#  'oceana_va': 589,
#  'haines_ak': 2508,
#  'arcataeureka_ca': 27191,
#  'nightmute_ak': 280,
#  'flint_mi': 102434,
#  'hoonah_ak': 760,
#  'granite_point_ak': 976,
#  'omaha_ne': 408958,
#  'el_paso_tx': 649121,
#  'gaylord_mi': 3645,
#  'teterboro_nj': 67,
#  'moline_il': 43483,
#  'cedar_city_ut': 28857,
#  'king_cove_ak': 938,
#  'kingman_az': 28068,
#  'riverside_ca': 303871,
#  'goodnews_bay_ak': 243,
#  'college_stationbryan_tx': 93857,
#  'kiluda_bay_ak': 374,
#  'akhiok_ak': 71,
#  'st_cloud_mn': 65842,
#  'pellston_mi': 822,
#  'golovin_ak': 156,
#  'meridian_ms': 41148,
#  'chignik_bay_ak': 91,
#  'albuquerque_nm': 545852,
#  'lewisburg_wv': 3830,
#  'lewiston_id': 31894,
#  'texarkana_ar': 29919,
#  'laredo_tx': 236091,
#  'circle_ak': nan,
#  'lancaster_pa': 59322,
#  'kansas_city_mo': 459787,
#  'bishop_ca': 3879,
#  'dayton_oh': 141527,
#  'nulato_ak': 264,
#  'ketchikan_ak': 8050,
#  'mountain_view_ca': 74066,
#  'monterey_ca': 27810,
#  'tuscaloosa_al': 90468,
#  'nuiqsut_ak': 402,
#  'liberal_ks': 20525,
#  'bedford_ma': 13320,
#  'arctic_village_ak': 813,
#  'everett_wa': 103019,
#  'tin_city_ak': 361,
#  'pittsburgh_pa': 305704,
#  'unalakleet_ak': 688,
#  'mosinee_wi': 2174,
#  'lanai_hi': 1360301,
#  'pullman_wa': 29799,
#  'utopia_ak': 817,
#  'klamath_falls_or': 20840,
#  'noorvik_ak': 668,
#  'naples_fl': 19537,
#  'point_hope_ak': 674,
#  'chico_ca': 86187,
#  'barter_island_ak': 4212,
#  'skagway_ak': 710231,
#  'aspen_co': 6658,
#  'killeen_tx': 127921,
#  'gulfportbiloxi_ms': 67793,
#  'traverse_city_mi': 14674,
#  'daytona_beach_fl': 61005,
#  'kirksville_mo': 17505,
#  'shungnak_ak': 262,
#  'greenville_sc': 58409,
#  'minneapolis_mn': 382578,
#  'thief_river_falls_mn': 8573,
#  'st_louis_mo': 319294,
#  'detroit_mi': 713777,
#  'tucson_az': 520116,
#  'princetonbluefield_wv': 6432,
#  'boston_ma': 617594,
#  'culebra_pr': nan,
#  'owensboro_ky': 57265,
#  'kwigillingok_ak': nan,
#  'moses_lake_wa': 20366,
#  'sleetmute_ak': nan,
#  'visalia_ca': 124442,
#  'long_beach_ca': 462257,
#  'tununak_ak': 262,
#  'austin_tx': 790390,
#  'fort_dodge_ia': 25206,
#  'alliance_ne': 8491,
#  'new_londongroton_ct': 27620,
#  'asheville_nc': 83393,
#  'huntsville_al': 180105,
#  'winston-salem_nc': 229617,
#  'lawrence_ma': 76377,
#  'portland_or': 583776,
#  'shreveport_la': 199311,
#  'vernal_ut': 9089,
#  'boise_id': 7028,
#  'bridgeport_ct': 144229,
#  'cedar_rapidsiowa_city_ia': 126326,
#  'christiansted_vi': nan,
#  'eau_claire_wi': 65883,
#  'hartford_ct': 124775,
#  'baton_rouge_la': 229493,
#  'nelson_lagoon_ak': nan,
#  'hilton_head_sc': 37099,
#  'kobuk_ak': 151,
#  'port_heiden_ak': 102,
#  'port_bailey_ak': 52,
#  'san_antonio_tx': 1327407,
#  'st_george_ut': 72897,
#  'pendleton_or': 16612,
#  'eagle_harbor_ak': 218,
#  'yakima_wa': 91067,
#  'uganik_ak': 85,
#  'peoria_il': 115007,
#  'south_naknek_ak': nan,
#  'dodge_city_ks': 2087,
#  'lynchburg_va': 75568,
#  'craig_ak': 1201,
#  'brownsville_tx': 175023,
#  'roseburg_or': 21181,
#  'beckley_wv': 17614,
#  'new_bedfordfall_river_ma': 95072,
#  'new_orleans_la': 343829,
#  'watertown_ny': 7642,
#  'philadelphia_pa': 1526006,
#  'hays_ks': 20510,
#  'rochester_mn': 106769,
#  'inyokern_ca': 18546,
#  'whale_pass_ak': 35,
#  'sitkinak_ak': nan,
#  'stony_river_ak': 1912,
#  'danger_bay_ak': 246,
#  'bay_city_tx': 5528,
#  'san_diego_ca': 1307402,
#  'guam_tt': nan,
#  'charlottesville_va': 43475,
#  'wales_ak': 145,
#  'pedro_bay_ak': 1093,
#  'alpine_ak': nan,
#  'bowling_green_ky': 58067,
#  'tacoma_wa': 198397,
#  'twin_falls_id': 44125,
#  'chefornak_ak': 418,
#  'salina_ks': 47707,
#  'pontiac_mi': 59515,
#  'kapalua_hi': nan,
#  'kitoi_bay_ak': 239,
#  'youngstownwarren_oh': 66971,
#  'escanaba_mi': 12616,
#  'venetie_ak': nan,
#  'columbia_sc': 129272,
#  'worcester_ma': 181045,
#  'lihue_hi': nan,
#  'brevig_mission_ak': 388,
#  'koyukuk_ak': 96,
#  'hughes_ak': 77,
#  'bloomington_in': 80405,
#  'wainwright_ak': 556,
#  'cortez_co': 8482,
#  'grand_forks_nd': 52838,
#  'knoxville_tn': 178874,
#  'indianapolis_in': 829718,
#  'cincinnati_oh': 296943,
#  'parkersburg_wv': 31492,
#  'beaver_ak': nan,
#  'marana_az': 34961,
#  'montgomery_al': 205764,
#  'newport_or': 9989,
#  'jamestown_nd': 15427,
#  'columbia_tn': 34681,
#  'el_dorado_ar': 18884,
#  'missionmcallenedinburg_tx': 77058,
#  'chicagoromeoville_il': 14305,
#  'tinian_tt': nan,
#  'beverly_ma': 39502,
#  'clarks_point_ak': 62,
#  'thorne_bay_ak': 471,
#  'fort_leonard_wood_mo': 87,
#  'newport_ri': 24672,
#  'minot_nd': 40888,
#  'bradford_pa': 8770,
#  'chuathbaluk_ak': 118,
#  'ukiah_ca': 16075,
#  'napaskiak_ak': 405,
#  'ashland_wv': 337,
#  'stillwater_ok': 45688,
#  'islip_ny': 335543,
#  'panama_city_fl': 36484,
#  'rochester_ny': 7313,
#  'st_michael_ak': 401,
#  'cordova_ak': 2239,
#  'may_creek_ak': nan,
#  'palm_springs_ca': 44552,
#  'jacksonvicksburg_ms': 23856,
#  'laconia_nh': 15951,
#  'kenai_ak': 7100,
#  'eagle_ak': 86,
#  'chicago_il': 0,
#  'stevens_village_ak': nan,
#  'selawik_ak': 829,
#  'burlingtonmount_vernon_wa': 31743,
#  'dothan_al': 65496,
#  'gulkana_ak': 361,
#  'tuluksak_ak': nan,
#  'chevak_ak': 938,
#  'east_farmingdale_ny': 8189,
#  'flagstaff_az': 65870,
#  'bellingham_wa': 80885,
#  'hanford_ca': 53967,
#  'destin_fl': 12305,
#  'chicken_ak': nan,
#  'atmautluak_ak': 710231,
#  'rhinelander_wi': 7798,
#  'grand_rapids_mi': 188040,
#  'grand_canyon_az': 48571,
#  'new_bernmoreheadbeaufort_nc': nan,
#  'aguadilla_pr': nan,
#  'tonopah_nv': nan,
#  'waterbury_ct': 110366,
#  'camp_springs_md': 358,
#  'skwentna_ak': 710231,
#  'toledo_oh': 287208,
#  'fort_myers_fl': 62298,
#  'north_kingstown_ri': 26486,
#  'portsmouth_nh': 20779,
#  'champaignurbana_il': 201081,
#  'medford_or': 74907,
#  'wake_island_tt': nan,
#  'hayden_co': 1810,
#  'marquette_mi': 21355,
#  'smyrna_tn': 39974,
#  'hattiesburglaurel_ms': 45989,
#  'columbus_ms': 23640,
#  'cape_romanzof_ak': nan,
#  'st_petersburg_fl': 244769,
#  'walla_walla_wa': 31731,
#  'east_hampton_ny': 21457,
#  'gunnison_co': 5854,
#  'dora_bay_ak': 471,
#  'fairfield_ca': 105321,
#  'tanana_ak': 246,
#  'sacramento_ca': 466488,
#  'coldfoot_ak': 2239,
#  'ceiba_pr': nan,
#  'oklahoma_city_ok': 718633,
#  'morrisville_vt': 1958,
#  'saipan_tt': nan,
#  'bethel_ak': 6080,
#  'cold_bay_ak': 108,
#  'kotlik_ak': 577,
#  'red_devil_ak': nan,
#  'mccarthy_ak': 346,
#  'trenton_nj': 84913,
#  'manhattanft_riley_ks': 52281,
#  'koliganek_ak': 577,
#  'kotzebue_ak': 3201,
#  'muskegon_mi': 38401,
#  'san_francisco_ca': 805235,
#  'atqasuk_ak': 233,
#  'denton_tx': 113383,
#  'casper_wy': 55316,
#  'fort_dix_nj': nan,
#  'rocky_mount_nc': 57477,
#  'west_palm_beachpalm_beach_fl': 99919,
#  'las_vegas_nv': 583756,
#  'lexington_ky': 14348,
#  'alamosa_co': 8780,
#  'false_pass_ak': 35,
#  'shaktoolik_ak': 251,
#  'charleston_sc': 120083,
#  'port_alexander_ak': 52,
#  'eugene_or': 156185,
#  'akutan_ak': 1027,
#  'marthas_vineyard_ma': nan,
#  'beaumontport_arthur_tx': 118296,
#  'pensacola_fl': 51923,
#  'elko_nv': 18297,
#  'williamsport_pa': 29381,
#  'harlingensan_benito_tx': 64849,
#  'augustawaterville_me': 15722,
#  'sioux_falls_sd': 132793,
#  'crooked_creek_ak': nan,
#  'manley_hot_springs_ak': nan,
#  'aberdeen_sd': 26091,
#  'nunapitchuk_ak': 496,
#  'macon_ga': 91351,
#  'borniteruby_creek_ak': nan,
#  'reno_nv': 225221,
#  'international_falls_mn': 6424,
#  'northampton_ma': 28549,
#  'koyuk_ak': 332,
#  'logan_ut': 48174,
#  'santa_maria_ca': 99553,
#  'atlanta_ga': 420003,
#  'elmiracorning_ny': 6934,
#  'decatur_al': 55683,
#  'mayaguez_pr': nan,
#  'marshall_ak': 414,
#  'gary_in': 80294,
#  'syracuse_ny': 145170,
#  'chisana_ak': 361,
#  'charlestondunbar_wv': 51400,
#  'noatak_ak': 710231,
#  'karluk_ak': nan,
#  'kake_ak': 557,
#  'minto_ak': nan,
#  'raleighdurham_nc': 403892,
#  'barrow_ak': 4212,
#  'grand_junction_co': 58566,
#  'teller_ak': 229,
#  'dubuque_ia': 57637,
#  'kalamazoo_mi': 74262,
#  'myrtle_beach_sc': 27109,
#  'akun_ak': 1027,
#  'san_jose_ca': 945942,
#  'san_angelo_tx': 93200,
#  'morgantown_wv': 29660,
#  'blue_fox_bay_ak': nan,
#  'melbourne_fl': 76068,
#  'ontario_ca': 163924,
#  'wilmington_oh': 12520,
#  'arlington_tx': 365438,
#  'appleton_wi': 744,
#  'garden_city_ks': 19123,
#  'coffman_cove_ak': 176,
#  'merced_ca': 78958,
#  'mason_city_ia': 1690,
#  'ithacacortland_ny': 19930,
#  'sarasotabradenton_fl': 379448,
#  'mekoryuk_ak': 191,
#  'quinhagak_ak': 669,
#  'presque_islehoulton_me': 9692,
#  'tuntutuliak_ak': nan,
#  'manchester_nh': 109565,
#  'thermal_ca': nan,
#  'allakaket_ak': 105,
#  'del_rio_tx': 35591,
#  'rockford_il': 152871,
#  'morristown_nj': 18411,
#  'deering_ak': 122,
#  'laramie_wy': 30816,
#  'brownwood_tx': 19288,
#  'chomondely_sound_ak': nan,
#  'springfield_il': 116250,
#  'king_salmon_ak': nan,
#  'beluga_ak': nan,
#  'larsen_bay_ak': 87,
#  'jonesboro_ar': 67263,
#  'tallahassee_fl': 181376,
#  'savannah_ga': 136286,
#  'kearney_ne': 30787,
#  'west_point_ak': 145,
#  'juneau_ak': nan,
#  'nikolski_ak': 94,
#  'manassas_va': 37821,
#  'dover_de': 36047,
#  'sandpoint_ak': 976,
#  'new_york_ny': 19378102,
#  'state_college_pa': 42034,
#  'rota_tt': nan,
#  'kasigluk_ak': 710231}

# %%
# get_close_matches('denver',cities)

# %%
# population[population.STNAME=='nv']

# %%
len(out_data)-len([i for i in out_data.values() if type(i)==int])
# Out:
# 72

# %%
pop = pd.read_csv('../data/Airports2.csv').sort_values('Fly_date')
# pop['year'] = pop.apply(lambda row: int(str(row.Fly_date)[0:4]), axis=1)
# pop['Origin_city']=pop.apply(lambda row: text_to_id(str(row.Origin_city)), axis=1)
# pop['Destination_city']=pop.apply(lambda row: text_to_id(str(row.Destination_city)), axis=1)

# %%
pop.head()
# Out:
#         Origin_airport Destination_airport     Origin_city Destination_city  \
# 730469             SEA                 ORD     Seattle, WA      Chicago, IL
# 448453             CLE                 EWR   Cleveland, OH       Newark, NJ
# 1458454            CRW                 ROA  Charleston, WV      Roanoke, VA
# 448454             CLE                 EWR   Cleveland, OH       Newark, NJ
# 448455             CLE                 EWR   Cleveland, OH       Newark, NJ
#
#          Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 730469         1713   4410       30      1721  1990-01-01            5154164
# 448453         1476   4619       31       404  1990-01-01            2103367
# 1458454         388   2100       21       114  1990-01-01             307480
# 448454         1337   3348       31       404  1990-01-01            2103367
# 448455         2787   4888       52       404  1990-01-01            2103367
#
#          Destination_population  Org_airport_lat  Org_airport_long  \
# 730469                 16395048        47.449001       -122.308998
# 448453                 16868983        41.411701        -81.849800
# 1458454                  269195        38.373100        -81.593201
# 448454                 16868983        41.411701        -81.849800
# 448455                 16868983        41.411701        -81.849800
#
#          Dest_airport_lat  Dest_airport_long
# 730469          41.978600         -87.904800
# 448453          40.692501         -74.168701
# 1458454         37.325500         -79.975403
# 448454          40.692501         -74.168701
# 448455          40.692501         -74.168701

# %%
city_pop_dict = pop[['Origin_city','Origin_population']].set_index('Origin_city').to_dict()['Origin_population']
city_temp_dict = pop[['Destination_city','Destination_population']].set_index('Destination_city').to_dict()['Destination_population']
city_pop_dict.update(city_temp_dict)

cities  = list(city_pop_dict.keys())

def get_pop_by_city(c):
    if c in cities:
        return city_pop_dict[c]
    else:
        return 0
    
def city_get_population(c):
    matching_cities = get_close_matches(c,[i for i in cities if i[-2::]==c[-2::]])
    print(c,matching_cities)
    if len(matching_cities)>0:
        return(get_pop_by_city(matching_cities[0]))
    else:
        return 0

airport_pop_dict = pop[['Origin_airport','Origin_population']].groupby('Origin_airport').max().to_dict()['Origin_population']
airport_temp_dict = pop[['Destination_airport','Destination_population']].groupby('Destination_airport').max().to_dict()['Destination_population']
airport_pop_dict.update(airport_temp_dict)

def get_population(airport,c):
    if airport in list(airport_pop_dict.keys()):
        return(airport_pop_dict[airport])
    else:
        return city_get_population(c)
    
# def get_population(airport,city):
#     numbers = list(pop[pop.Origin_airport==airport].sort_values(by='Fly_date')['Origin_population'])
#     if len(numbers)>0:
#         return numbers[-1]
#     else:
#         numbers = list(pop[pop.Destination_airport==airport].sort_values(by='Fly_date')['Destination_population'])
#         if len(numbers)>0:
#             return numbers[-1]
#         else:
#             return city_get_population(city)

# %%
data.head()
# Out:
#    weight  distance UNIQUE_CARRIER   UNIQUE_CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0     1.0    1491.0             DL  Delta Air Lines Inc.              11292
# 1     1.0     236.0             DL  Delta Air Lines Inc.              12889
# 2     1.0     522.0             DL  Delta Air Lines Inc.              14771
# 3     1.0     842.0             DL  Delta Air Lines Inc.              15304
# 4     1.0     184.0             MQ             Envoy Air              10721
#
#   ORIGIN            source ORIGIN_STATE_ABR  DEST_AIRPORT_ID DEST  \
# 0    DEN         denver_co               CO            10821  BWI
# 1    LAS      las_vegas_nv               NV            12892  LAX
# 2    SFO  san_francisco_ca               CA            10713  BOI
# 3    TPA          tampa_fl               FL            10821  BWI
# 4    BOS         boston_ma               MA            12953  LGA
#
#            target DEST_STATE_ABR  YEAR  MONTH  Unnamed: 14
# 0    baltimore_md             MD  2018     11          NaN
# 1  los_angeles_ca             CA  2018     11          NaN
# 2        boise_id             ID  2018     11          NaN
# 3    baltimore_md             MD  2018     11          NaN
# 4     new_york_ny             NY  2018     11          NaN

# %%
pop.head()
# Out:
#   Origin_airport Destination_airport   Origin_city Destination_city  \
# 0            MHK                 AMW  manhattan_ks          ames_ia
# 1            EUG                 RDM     eugene_or          bend_or
# 2            EUG                 RDM     eugene_or          bend_or
# 3            EUG                 RDM     eugene_or          bend_or
# 4            MFR                 RDM    medford_or          bend_or
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long  \
# 0                   86219        39.140999        -96.670799
# 1                   76034        44.124599       -123.211998
# 2                   76034        44.124599       -123.211998
# 3                   76034        44.124599       -123.211998
# 4                   76034        42.374199       -122.873001
#
#    Dest_airport_lat  Dest_airport_long
# 0               NaN                NaN
# 1         44.254101        -121.150001
# 2         44.254101        -121.150001
# 3         44.254101        -121.150001
# 4         44.254101        -121.150001

# %%
sorted(set(list(pop.Origin_city)))
# Out:
# ['aberdeen_sd',
#  'abilene_tx',
#  'akron_oh',
#  'alamogordo_nm',
#  'albany_ga',
#  'albany_ny',
#  'albany_or',
#  'albuquerque_nm',
#  'alexandria_la',
#  'alexandria_mn',
#  'allentown_pa',
#  'alpena_mi',
#  'altoona_pa',
#  'altus_ok',
#  'amarillo_tx',
#  'americus_ga',
#  'ames_ia',
#  'anchorage_ak',
#  'anderson_in',
#  'anderson_sc',
#  'anniston_al',
#  'appleton_wi',
#  'ardmore_ok',
#  'asheville_nc',
#  'astoria_or',
#  'athens_ga',
#  'athens_oh',
#  'athens_tn',
#  'atlanta_ga',
#  'atlantic_city_nj',
#  'auburn_al',
#  'auburn_in',
#  'augusta_ga',
#  'augusta_me',
#  'austin_tx',
#  'bakersfield_ca',
#  'baltimore_md',
#  'bangor_me',
#  'batesville_ar',
#  'baton_rouge_la',
#  'battle_creek_mi',
#  'bay_city_tx',
#  'beaumont_tx',
#  'beckley_wv',
#  'bedford_in',
#  'bellefontaine_oh',
#  'bellingham_wa',
#  'bemidji_mn',
#  'bend_or',
#  'bennington_vt',
#  'big_rapids_mi',
#  'big_spring_tx',
#  'billings_mt',
#  'binghamton_ny',
#  'birmingham_al',
#  'bishop_ca',
#  'bismarck_nd',
#  'bloomington_il',
#  'bloomington_in',
#  'blytheville_ar',
#  'borger_tx',
#  'boston_ma',
#  'bowling_green_ky',
#  'bozeman_mt',
#  'bradford_pa',
#  'brainerd_mn',
#  'branson_mo',
#  'bremerton_wa',
#  'bridgeport_ct',
#  'brigham_city_ut',
#  'brookings_or',
#  'brookings_sd',
#  'brownsville_tx',
#  'brownwood_tx',
#  'brunswick_ga',
#  'buffalo_ny',
#  'burlington_ia',
#  'burlington_vt',
#  'butte_mt',
#  'cadillac_mi',
#  'cape_girardeau_mo',
#  'carbondale_il',
#  'carlsbad_nm',
#  'casper_wy',
#  'cedar_city_ut',
#  'cedar_rapids_ia',
#  'champaign_il',
#  'charleston_sc',
#  'charleston_wv',
#  'charlotte_nc',
#  'charlottesville_va',
#  'chattanooga_tn',
#  'cheyenne_wy',
#  'chicago_il',
#  'chico_ca',
#  'chillicothe_oh',
#  'cincinnati_oh',
#  'clarksburg_wv',
#  'cleveland_oh',
#  'clinton_ia',
#  'clovis_nm',
#  'college_station_tx',
#  'colorado_springs_co',
#  'columbia_mo',
#  'columbia_sc',
#  'columbia_tn',
#  'columbus_ga',
#  'columbus_in',
#  'columbus_ms',
#  'columbus_oh',
#  'connersville_in',
#  'corpus_christi_tx',
#  'corsicana_tx',
#  'crescent_city_ca',
#  'crossville_tn',
#  'cumberland_md',
#  'dallas_tx',
#  'dalton_ga',
#  'danville_il',
#  'danville_ky',
#  'davenport_ia',
#  'dayton_oh',
#  'decatur_al',
#  'decatur_il',
#  'del_rio_tx',
#  'des_moines_ia',
#  'detroit_mi',
#  'dickinson_nd',
#  'dodge_city_ks',
#  'dothan_al',
#  'dover_de',
#  'dubuque_ia',
#  'duluth_mn',
#  'duncan_ok',
#  'durango_co',
#  'dyersburg_tn',
#  'eagle_pass_tx',
#  'eau_claire_wi',
#  'el_centro_ca',
#  'el_dorado_ar',
#  'el_paso_tx',
#  'elizabeth_city_nc',
#  'elizabethtown_ky',
#  'elkhart_in',
#  'elko_nv',
#  'ellensburg_wa',
#  'elmira_ny',
#  'enid_ok',
#  'erie_pa',
#  'escanaba_mi',
#  'eugene_or',
#  'eureka_ca',
#  'evansville_in',
#  'fairbanks_ak',
#  'fallon_nv',
#  'fargo_nd',
#  'farmington_nm',
#  'fayetteville_ar',
#  'fayetteville_nc',
#  'fergus_falls_mn',
#  'findlay_oh',
#  'flagstaff_az',
#  'flint_mi',
#  'florence_sc',
#  'fort_dodge_ia',
#  'fort_lauderdale_fl',
#  'fort_leonard_wood_mo',
#  'fort_smith_ar',
#  'fort_wayne_in',
#  'frankfort_ky',
#  'freeport_il',
#  'fremont_ne',
#  'fresno_ca',
#  'gadsden_al',
#  'gainesville_fl',
#  'gainesville_ga',
#  'galesburg_il',
#  'gallup_nm',
#  'garden_city_ks',
#  'gary_in',
#  'georgetown_sc',
#  'gillette_wy',
#  'glasgow_ky',
#  'glens_falls_ny',
#  'goldsboro_nc',
#  'grand_forks_nd',
#  'grand_island_ne',
#  'grand_junction_co',
#  'grand_rapids_mi',
#  'great_bend_ks',
#  'great_falls_mt',
#  'green_bay_wi',
#  'greeneville_tn',
#  'greensboro_nc',
#  'greenville_ms',
#  'greenville_nc',
#  'greenville_sc',
#  'greenwood_ms',
#  'greenwood_sc',
#  'grenada_ms',
#  'gulfport_ms',
#  'hagerstown_md',
#  'hanford_ca',
#  'harrisburg_pa',
#  'harrison_ar',
#  'hartford_ct',
#  'hastings_ne',
#  'hattiesburg_ms',
#  'havre_mt',
#  'hays_ks',
#  'helena_mt',
#  'hickory_nc',
#  'hilo_hi',
#  'hobbs_nm',
#  'holland_mi',
#  'honolulu_hi',
#  'hot_springs_ar',
#  'houma_la',
#  'houston_tx',
#  'hudson_ny',
#  'huntsville_al',
#  'huron_sd',
#  'hutchinson_ks',
#  'idaho_falls_id',
#  'indianapolis_in',
#  'iron_mountain_mi',
#  'ithaca_ny',
#  'jackson_mi',
#  'jackson_ms',
#  'jackson_tn',
#  'jackson_wy',
#  'jacksonville_fl',
#  'jacksonville_nc',
#  'jamestown_nd',
#  'jamestown_ny',
#  'jefferson_city_mo',
#  'johnstown_pa',
#  'jonesboro_ar',
#  'joplin_mo',
#  'juneau_ak',
#  'kahului_hi',
#  'kalamazoo_mi',
#  'kalispell_mt',
#  'kankakee_il',
#  'kansas_city_mo',
#  'kearney_ne',
#  'ketchikan_ak',
#  'key_west_fl',
#  'killeen_tx',
#  'kinston_nc',
#  'kirksville_mo',
#  'klamath_falls_or',
#  'knoxville_tn',
#  'kodiak_ak',
#  'kokomo_in',
#  'la_crosse_wi',
#  'la_grande_or',
#  'laconia_nh',
#  'lafayette_in',
#  'lafayette_la',
#  'lake_charles_la',
#  'lake_city_fl',
#  'lake_havasu_city_az',
#  'lakeland_fl',
#  'lancaster_pa',
#  'lansing_mi',
#  'laramie_wy',
#  'laredo_tx',
#  'las_cruces_nm',
#  'las_vegas_nv',
#  'laurel_ms',
#  'lawrence_ks',
#  'lawrenceburg_tn',
#  'lawton_ok',
#  'lewisburg_tn',
#  'lewiston_id',
#  'lewiston_me',
#  'lexington_ky',
#  'lexington_ne',
#  'liberal_ks',
#  'lima_oh',
#  'lincoln_ne',
#  'little_rock_ar',
#  'lock_haven_pa',
#  'logan_ut',
#  'london_ky',
#  'longview_tx',
#  'los_alamos_nm',
#  'los_angeles_ca',
#  'lubbock_tx',
#  'lynchburg_va',
#  'macon_ga',
#  'madera_ca',
#  'madison_wi',
#  'madisonville_ky',
#  'manchester_nh',
#  'manhattan_ks',
#  'mankato_mn',
#  'mansfield_oh',
#  'marion_il',
#  'marion_in',
#  'marion_oh',
#  'marquette_mi',
#  'marshall_mn',
#  'marshall_mo',
#  'marshall_tx',
#  'mason_city_ia',
#  'medford_or',
#  'memphis_tn',
#  'merced_ca',
#  'meridian_ms',
#  'miami_fl',
#  'miami_ok',
#  'midland_tx',
#  'milwaukee_wi',
#  'minneapolis_mn',
#  'minot_nd',
#  'missoula_mt',
#  'mitchell_sd',
#  'mobile_al',
#  'modesto_ca',
#  'monroe_la',
#  'montgomery_al',
#  'montrose_co',
#  'morgantown_wv',
#  'morristown_tn',
#  'moses_lake_wa',
#  'mount_pleasant_mi',
#  'mount_sterling_ky',
#  'mount_vernon_il',
#  'mount_vernon_wa',
#  'mountain_home_ar',
#  'mountain_home_id',
#  'muncie_in',
#  'muskegon_mi',
#  'myrtle_beach_sc',
#  'nacogdoches_tx',
#  'napa_ca',
#  'naples_fl',
#  'nashville_tn',
#  'new_bern_nc',
#  'new_haven_ct',
#  'new_iberia_la',
#  'new_orleans_la',
#  'new_york_ny',
#  'newark_nj',
#  'nogales_az',
#  'norfolk_ne',
#  'north_platte_ne',
#  'oak_harbor_wa',
#  'oakland_ca',
#  'ocala_fl',
#  'ogden_ut',
#  'ogdensburg_ny',
#  'oklahoma_city_ok',
#  'olympia_wa',
#  'omaha_ne',
#  'oneonta_ny',
#  'orlando_fl',
#  'oshkosh_wi',
#  'ottumwa_ia',
#  'owatonna_mn',
#  'owensboro_ky',
#  'oxnard_ca',
#  'paducah_ky',
#  'panama_city_fl',
#  'paris_tn',
#  'parkersburg_wv',
#  'pendleton_or',
#  'pensacola_fl',
#  'peoria_il',
#  'peru_in',
#  'philadelphia_pa',
#  'phoenix_az',
#  'pierre_sd',
#  'pine_bluff_ar',
#  'pittsburgh_pa',
#  'pittsfield_ma',
#  'plattsburgh_ny',
#  'pocatello_id',
#  'ponca_city_ok',
#  'port_angeles_wa',
#  'portland_me',
#  'portland_or',
#  'portsmouth_oh',
#  'poughkeepsie_ny',
#  'prescott_az',
#  'price_ut',
#  'providence_ri',
#  'provo_ut',
#  'pueblo_co',
#  'pullman_wa',
#  'punta_gorda_fl',
#  'quincy_il',
#  'raleigh_nc',
#  'rapid_city_sd',
#  'reading_pa',
#  'redding_ca',
#  'reno_nv',
#  'rexburg_id',
#  'richmond_in',
#  'richmond_va',
#  'riverside_ca',
#  'riverton_wy',
#  'roanoke_va',
#  'rochester_mn',
#  'rochester_ny',
#  'rock_springs_wy',
#  'rockford_il',
#  'rockland_me',
#  'rocky_mount_nc',
#  'rome_ga',
#  'roseburg_or',
#  'roswell_nm',
#  'ruidoso_nm',
#  'russellville_ar',
#  'rutland_vt',
#  'sacramento_ca',
#  'safford_az',
#  'saginaw_mi',
#  'salem_or',
#  'salina_ks',
#  'salisbury_md',
#  'salisbury_nc',
#  'salt_lake_city_ut',
#  'san_angelo_tx',
#  'san_antonio_tx',
#  'san_diego_ca',
#  'san_francisco_ca',
#  'san_jose_ca',
#  'san_luis_obispo_ca',
#  'sandusky_oh',
#  'santa_ana_ca',
#  'santa_barbara_ca',
#  'santa_fe_nm',
#  'santa_rosa_ca',
#  'savannah_ga',
#  'scottsbluff_ne',
#  'scranton_pa',
#  'searcy_ar',
#  'seattle_wa',
#  'sebastian_fl',
#  'sedalia_mo',
#  'selma_al',
#  'seymour_in',
#  'sheboygan_wi',
#  'shelby_nc',
#  'shelbyville_tn',
#  'shelton_wa',
#  'sheridan_wy',
#  'show_low_az',
#  'shreveport_la',
#  'sikeston_mo',
#  'silver_city_nm',
#  'sioux_city_ia',
#  'sioux_falls_sd',
#  'south_bend_in',
#  'spartanburg_sc',
#  'spokane_wa',
#  'springfield_il',
#  'springfield_mo',
#  'springfield_oh',
#  'st_cloud_mn',
#  'st_george_ut',
#  'st_joseph_mo',
#  'st_louis_mo',
#  'starkville_ms',
#  'state_college_pa',
#  'statesboro_ga',
#  'statesville_nc',
#  'staunton_va',
#  'sterling_il',
#  'stillwater_ok',
#  'stockton_ca',
#  'storm_lake_ia',
#  'sturgis_mi',
#  'sumter_sc',
#  'sweetwater_tx',
#  'syracuse_ny',
#  'tacoma_wa',
#  'talladega_al',
#  'tallahassee_fl',
#  'tampa_fl',
#  'taos_nm',
#  'terre_haute_in',
#  'tifton_ga',
#  'toledo_oh',
#  'topeka_ks',
#  'traverse_city_mi',
#  'trenton_nj',
#  'truckee_ca',
#  'tucson_az',
#  'tullahoma_tn',
#  'tulsa_ok',
#  'tupelo_ms',
#  'tuscaloosa_al',
#  'twin_falls_id',
#  'tyler_tx',
#  'ukiah_ca',
#  'union_city_tn',
#  'utica_ny',
#  'uvalde_tx',
#  'valdosta_ga',
#  'vernal_ut',
#  'victoria_tx',
#  'visalia_ca',
#  'waco_tx',
#  'walla_walla_wa',
#  'wapakoneta_oh',
#  'warrensburg_mo',
#  'washington_court_house_oh',
#  'washington_dc',
#  'waterloo_ia',
#  'watertown_ny',
#  'watertown_sd',
#  'wausau_wi',
#  'wenatchee_wa',
#  'west_palm_beach_fl',
#  'wheeling_wv',
#  'wichita_falls_tx',
#  'wichita_ks',
#  'williamsport_pa',
#  'williston_nd',
#  'wilmington_de',
#  'wilmington_nc',
#  'wilmington_oh',
#  'winchester_va',
#  'wooster_oh',
#  'worcester_ma',
#  'yakima_wa',
#  'yankton_sd',
#  'york_pa',
#  'youngstown_oh',
#  'yuma_az',
#  'zanesville_oh']

# %%
data[data.Origin_population==0]

# %%
data[data.Destination_population==0]

# %%
data.head()
# Out:
#    weight  distance UNIQUE_CARRIER   UNIQUE_CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0     1.0    1491.0             DL  Delta Air Lines Inc.              11292
# 1     1.0     236.0             DL  Delta Air Lines Inc.              12889
# 2     1.0     522.0             DL  Delta Air Lines Inc.              14771
# 3     1.0     842.0             DL  Delta Air Lines Inc.              15304
# 4     1.0     184.0             MQ             Envoy Air              10721
#
#   ORIGIN            source ORIGIN_STATE_ABR  DEST_AIRPORT_ID DEST  \
# 0    DEN         denver_co               CO            10821  BWI
# 1    LAS      las_vegas_nv               NV            12892  LAX
# 2    SFO  san_francisco_ca               CA            10713  BOI
# 3    TPA          tampa_fl               FL            10821  BWI
# 4    BOS         boston_ma               MA            12953  LGA
#
#            target DEST_STATE_ABR  YEAR  MONTH  Unnamed: 14  Origin_population  \
# 0    baltimore_md             MD  2018     11          NaN                  0
# 1  los_angeles_ca             CA  2018     11          NaN            1902834
# 2        boise_id             ID  2018     11          NaN            8635706
# 3    baltimore_md             MD  2018     11          NaN            2747272
# 4     new_york_ny             NY  2018     11          NaN            9177360
#
#    Destination_population
# 0                 2690886
# 1                25749594
# 2                       0
# 3                 2690886
# 4                38139592

# %%
data = data[['source','target','weight','distance']]

# %%
data.head()
# Out:
#    weight  distance UNIQUE_CARRIER   UNIQUE_CARRIER_NAME  ORIGIN_AIRPORT_ID  \
# 0     1.0    1491.0             DL  Delta Air Lines Inc.              11292
# 1     1.0     236.0             DL  Delta Air Lines Inc.              12889
# 2     1.0     522.0             DL  Delta Air Lines Inc.              14771
# 3     1.0     842.0             DL  Delta Air Lines Inc.              15304
# 4     1.0     184.0             MQ             Envoy Air              10721
#
#   ORIGIN            source ORIGIN_STATE_ABR  DEST_AIRPORT_ID DEST  \
# 0    DEN         denver_co               CO            10821  BWI
# 1    LAS      las_vegas_nv               NV            12892  LAX
# 2    SFO  san_francisco_ca               CA            10713  BOI
# 3    TPA          tampa_fl               FL            10821  BWI
# 4    BOS         boston_ma               MA            12953  LGA
#
#            target DEST_STATE_ABR  YEAR  MONTH  Unnamed: 14  Origin_population  \
# 0    baltimore_md             MD  2018     11          NaN                  0
# 1  los_angeles_ca             CA  2018     11          NaN            1902834
# 2        boise_id             ID  2018     11          NaN            8635706
# 3    baltimore_md             MD  2018     11          NaN            2747272
# 4     new_york_ny             NY  2018     11          NaN            9177360
#
#    Destination_population
# 0                 2690886
# 1                25749594
# 2                       0
# 3                 2690886
# 4                38139592

# %%
df = pd.read_csv(f)
df.head()
# Out:
#    PASSENGERS  DISTANCE UNIQUE_CARRIER     UNIQUE_CARRIER_NAME  \
# 0         0.0    1218.0             WN  Southwest Airlines Co.
# 1         0.0    1428.0             WN  Southwest Airlines Co.
# 2         0.0    2694.0             WN  Southwest Airlines Co.
# 3         0.0    2400.0             WN  Southwest Airlines Co.
# 4         0.0    1430.0             WN  Southwest Airlines Co.
#
#    ORIGIN_AIRPORT_ID ORIGIN    ORIGIN_CITY_NAME ORIGIN_STATE_ABR  \
# 0              13495    MSY     New Orleans, LA               LA
# 1              13495    MSY     New Orleans, LA               LA
# 2              14057    PDX        Portland, OR               OR
# 3              14492    RDU  Raleigh/Durham, NC               NC
# 4              14747    SEA         Seattle, WA               WA
#
#    DEST_AIRPORT_ID DEST       DEST_CITY_NAME DEST_STATE_ABR  YEAR  MONTH  \
# 0            12391  ISP            Islip, NY             NY  2018     11
# 1            14869  SLC   Salt Lake City, UT             UT  2018     11
# 2            11697  FLL  Fort Lauderdale, FL             FL  2018     11
# 3            14771  SFO    San Francisco, CA             CA  2018     11
# 4            12278  ICT          Wichita, KS             KS  2018     11
#
#    Unnamed: 14
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df[df.Destination_population==np.nan]
# Out:
# Empty DataFrame
# Columns: [weight, distance, UNIQUE_CARRIER, UNIQUE_CARRIER_NAME, ORIGIN_AIRPORT_ID, ORIGIN, source, ORIGIN_STATE_ABR, DEST_AIRPORT_ID, DEST, target, DEST_STATE_ABR, YEAR, MONTH, Unnamed: 14, Origin_population, Destination_population]
# Index: []

# %%
pop = data.groupby(['source','target']).sum()['weight']

# %%
pop.to_pickle('../data/us_air_mirgration.pkl')

# %%
pop = pd.read_csv('../data/Airports2.csv')
pop.head()
# Out:
#   Origin_airport Destination_airport    Origin_city Destination_city  \
# 0            MHK                 AMW  Manhattan, KS         Ames, IA
# 1            EUG                 RDM     Eugene, OR         Bend, OR
# 2            EUG                 RDM     Eugene, OR         Bend, OR
# 3            EUG                 RDM     Eugene, OR         Bend, OR
# 4            MFR                 RDM    Medford, OR         Bend, OR
#
#    Passengers  Seats  Flights  Distance    Fly_date  Origin_population  \
# 0          21     30        1       254  2008-10-01             122049
# 1          41    396       22       103  1990-11-01             284093
# 2          88    342       19       103  1990-12-01             284093
# 3          11     72        4       103  1990-10-01             284093
# 4           0     18        1       156  1990-02-01             147300
#
#    Destination_population  Org_airport_lat  Org_airport_long  \
# 0                   86219        39.140999        -96.670799
# 1                   76034        44.124599       -123.211998
# 2                   76034        44.124599       -123.211998
# 3                   76034        44.124599       -123.211998
# 4                   76034        42.374199       -122.873001
#
#    Dest_airport_lat  Dest_airport_long
# 0               NaN                NaN
# 1         44.254101        -121.150001
# 2         44.254101        -121.150001
# 3         44.254101        -121.150001
# 4         44.254101        -121.150001

# %%
pop = pop[['Origin_city','Destination_city','Origin_population','Destination_population']]
pop['Origin_city']=pop.apply(lambda row: text_to_id(str(row.Origin_city)), axis=1)
pop['Destination_city']=pop.apply(lambda row: text_to_id(str(row.Destination_city)), axis=1)

# %%
pop.head()
# Out:
#     Origin_city Destination_city  Origin_population  Destination_population
# 0  manhattan_ks          ames_ia             122049                   86219
# 1     eugene_or          bend_or             284093                   76034
# 2     eugene_or          bend_or             284093                   76034
# 3     eugene_or          bend_or             284093                   76034
# 4    medford_or          bend_or             147300                   76034

# %%
pop_dict.update(dict2)

# %%
a[-2::]
# Out:
# 'il'

# %%
cities  = list(pop_dict.keys())
matching_cities = {}
for e in ranked_edges:
    a,b = e
    matching_cities[a]=get_close_matches(a,[i for i in cities if i[-2::]==a[-2::]])[0]
    matching_cities[b]=get_close_matches(b,[i for i in cities if i[-2::]==b[-2::]])[0]


#     print(get_pop(a),get_pop(b))
# Out:
# gulfportbiloxi_ms ['gulfport_ms']
# springfield_mo ['springfield_mo']
# sanford_fl ['orlando_fl']
# flint_mi ['flint_mi', 'lansing_mi']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# asheville_nc ['asheville_nc', 'statesville_nc', 'jacksonville_nc']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# waco_tx ['waco_tx', 'laredo_tx']
# kona_hi []
# van_nuys_ca ['san_jose_ca', 'santa_ana_ca']
# sanford_fl ['orlando_fl']
# clarksburgfairmont_wv ['clarksburg_wv', 'parkersburg_wv']
# savoonga_ak []
# unalakleet_ak []
# shreveport_la ['shreveport_la']
# midlandodessa_tx ['midland_tx', 'andrews_tx']
# minneapolis_mn ['minneapolis_mn']
# hopkinsville_ky ['danville_ky', 'madisonville_ky']
# burbank_ca ['eureka_ca']
# pontiac_mi []
# galena_ak []
# unalakleet_ak []
# ontario_ca ['oxnard_ca', 'santa_rosa_ca', 'el_centro_ca']
# billings_mt ['billings_mt']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# plattsburgh_ny ['plattsburgh_ny']
# bullhead_city_az []
# eugene_or ['eugene_or', 'bend_or', 'roseburg_or']
# los_angeles_ca ['los_angeles_ca']
# provo_ut ['provo_ut', 'price_ut']
# madison_wi ['madison_wi', 'racine_wi']
# billings_mt ['billings_mt']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# knoxville_tn ['knoxville_tn', 'nashville_tn', 'crossville_tn']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# tallahassee_fl ['tallahassee_fl']
# baltimore_md ['baltimore_md']
# myrtle_beach_sc ['myrtle_beach_sc']
# sanford_fl ['orlando_fl']
# springfield_mo ['springfield_mo']
# sanford_fl ['orlando_fl']
# bismarckmandan_nd ['bismarck_nd']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# jonesboro_ar ['jonesboro_ar']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# muscle_shoals_al ['tuscaloosa_al']
# las_vegas_nv ['las_vegas_nv']
# page_az []
# sioux_falls_sd ['sioux_falls_sd']
# sanford_fl ['orlando_fl']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# pago_pago_tt []
# abilene_tx ['abilene_tx', 'killeen_tx', 'uvalde_tx']
# spokane_wa ['spokane_wa', 'port_angeles_wa', 'seattle_wa']
# fort_wayne_in ['fort_wayne_in']
# south_bend_in ['south_bend_in']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# eugene_or ['eugene_or', 'bend_or', 'roseburg_or']
# levelock_ak []
# igiugig_ak []
# hayden_co []
# casper_wy ['casper_wy', 'sheridan_wy']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# lafayette_in ['lafayette_in']
# appleton_wi ['appleton_wi']
# madison_wi ['madison_wi', 'racine_wi']
# st_petersburg_fl []
# hagerstown_md ['hagerstown_md', 'easton_md']
# houston_tx ['houston_tx', 'austin_tx']
# victoria_tx ['victoria_tx', 'corsicana_tx']
# bozeman_mt ['bozeman_mt']
# missoula_mt ['missoula_mt']
# south_bend_in ['south_bend_in']
# clarksburgfairmont_wv ['clarksburg_wv', 'parkersburg_wv']
# milwaukee_wi ['milwaukee_wi']
# fargo_nd ['fargo_nd']
# shreveport_la ['shreveport_la']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# washington_dc ['washington_dc']
# wilmington_nc ['wilmington_nc', 'kinston_nc']
# denver_co []
# san_luis_obispo_ca ['san_luis_obispo_ca', 'san_jose_ca', 'san_diego_ca']
# las_vegas_nv ['las_vegas_nv']
# durango_co ['durango_co']
# gulfportbiloxi_ms ['gulfport_ms']
# columbus_oh ['columbus_oh']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# fort_dodge_ia ['fort_dodge_ia']
# dillingham_ak []
# goodnews_bay_ak []
# kodiak_ak ['kodiak_ak']
# homer_ak ['anchorage_ak']
# fairbanks_ak ['fairbanks_ak']
# central_ak []
# buffalo_ny ['buffalo_ny']
# white_plains_ny []
# barrow_ak []
# kiana_ak ['kodiak_ak', 'ketchikan_ak', 'fairbanks_ak']
# brownsville_tx ['brownsville_tx', 'longview_tx', 'brownwood_tx']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# kodiak_ak ['kodiak_ak']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# tulsa_ok ['tulsa_ok', 'altus_ok']
# jackson_wy ['jackson_wy']
# shreveport_la ['shreveport_la']
# rocky_mount_nc ['rocky_mount_nc']
# greer_sc ['greenwood_sc', 'greenville_sc', 'florence_sc']
# lafayette_in ['lafayette_in']
# lafayette_in ['lafayette_in']
# murray_ky []
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# colorado_springs_co ['colorado_springs_co']
# bullhead_city_az []
# la_crosse_wi ['la_crosse_wi', 'eau_claire_wi']
# state_college_pa ['state_college_pa']
# south_bend_in ['south_bend_in']
# south_bend_in ['south_bend_in']
# teterboro_nj []
# hartford_ct ['hartford_ct']
# hickory_nc ['hickory_nc']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# aspen_co ['sterling_co']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# san_luis_obispo_ca ['san_luis_obispo_ca', 'san_jose_ca', 'san_diego_ca']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# bay_city_tx ['bay_city_tx']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# anacortes_wa []
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# sacramento_ca ['sacramento_ca', 'el_centro_ca', 'fresno_ca']
# gulfportbiloxi_ms ['gulfport_ms']
# flint_mi ['flint_mi', 'lansing_mi']
# santa_ana_ca ['santa_ana_ca', 'santa_rosa_ca', 'santa_barbara_ca']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# chicago_il ['chicago_il', 'champaign_il']
# sioux_city_ia ['sioux_city_ia', 'mason_city_ia']
# smyrna_tn []
# latrobe_pa ['lancaster_pa', 'altoona_pa']
# bullhead_city_az []
# corpus_christi_tx ['corpus_christi_tx']
# denver_co []
# gillette_wy ['gillette_wy']
# pensacola_fl ['pensacola_fl', 'punta_gorda_fl', 'ocala_fl']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# cleveland_oh ['cleveland_oh']
# chicago_il ['chicago_il', 'champaign_il']
# bismarckmandan_nd ['bismarck_nd']
# st_petersburg_fl []
# des_moines_ia ['des_moines_ia', 'ames_ia']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# wichita_ks ['wichita_ks']
# oakland_ca ['oakland_ca', 'oxnard_ca', 'visalia_ca']
# salinasmonterey_ca ['salinas_ca']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# reading_pa ['reading_pa', 'meadville_pa']
# sioux_falls_sd ['sioux_falls_sd']
# indianapolis_in ['indianapolis_in']
# memphis_tn ['memphis_tn', 'paris_tn']
# lafayette_la ['lafayette_la']
# phoenix_az ['phoenix_az']
# yuma_az ['yuma_az']
# las_vegas_nv ['las_vegas_nv']
# asheville_nc ['asheville_nc', 'statesville_nc', 'jacksonville_nc']
# buffalo_ny ['buffalo_ny']
# bowling_green_ky ['bowling_green_ky']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# ponce_pr []
# phoenix_az ['phoenix_az']
# st_cloud_mn ['st_cloud_mn']
# cedar_rapidsiowa_city_ia ['cedar_rapids_ia']
# lafayette_in ['lafayette_in']
# homer_ak ['anchorage_ak']
# mcgrath_ak []
# teterboro_nj []
# binghamton_ny ['binghamton_ny', 'jamestown_ny']
# dallasfort_worth_tx ['dallas_tx']
# durango_co ['durango_co']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# toledo_oh ['toledo_oh']
# ketchikan_ak ['ketchikan_ak']
# craig_ak ['anchorage_ak']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# johnstown_pa ['johnstown_pa', 'allentown_pa', 'scranton_pa']
# columbia_sc ['columbia_sc']
# myrtle_beach_sc ['myrtle_beach_sc']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# islip_ny []
# baltimore_md ['baltimore_md']
# hagerstown_md ['hagerstown_md', 'easton_md']
# raleighdurham_nc ['raleigh_nc']
# atlantic_city_nj ['atlantic_city_nj']
# billings_mt ['billings_mt']
# cody_wy []
# charlotte_nc ['charlotte_nc']
# white_plains_ny []
# baltimore_md ['baltimore_md']
# macon_ga ['macon_ga', 'dalton_ga', 'waycross_ga']
# roanoke_va ['roanoke_va']
# richmond_va ['richmond_va']
# san_juan_pr []
# columbia_sc ['columbia_sc']
# gary_in ['gary_in', 'marion_in', 'auburn_in']
# youngstownwarren_oh ['youngstown_oh']
# sanford_fl ['orlando_fl']
# syracuse_ny ['syracuse_ny']
# manchester_nh ['manchester_nh']
# presque_islehoulton_me []
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# stockton_ca ['stockton_ca']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# new_york_ny ['new_york_ny']
# daytona_beach_fl ['west_palm_beach_fl']
# boston_ma ['boston_ma']
# rockland_me ['rockland_me', 'portland_me']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# jackson_wy ['jackson_wy']
# bethel_ak []
# koyuk_ak ['kodiak_ak']
# albany_ga ['albany_ga', 'atlanta_ga', 'dalton_ga']
# pensacola_fl ['pensacola_fl', 'punta_gorda_fl', 'ocala_fl']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# teterboro_nj []
# greensborohigh_point_nc ['greensboro_nc']
# greer_sc ['greenwood_sc', 'greenville_sc', 'florence_sc']
# charleston_sc ['charleston_sc', 'anderson_sc']
# vero_beach_fl ['west_palm_beach_fl']
# buffalo_ny ['buffalo_ny']
# boise_id []
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# port_angeles_wa ['port_angeles_wa', 'spokane_wa']
# scrantonwilkes-barre_pa ['scranton_pa']
# bangor_me ['bangor_me']
# portland_me ['portland_me', 'rockland_me']
# bangor_me ['bangor_me']
# east_farmingdale_ny []
# worcester_ma ['worcester_ma']
# kona_hi []
# kapalua_hi ['kahului_hi']
# denver_co []
# north_platte_ne ['north_platte_ne']
# sanford_fl ['orlando_fl']
# jacksonvicksburg_ms ['jackson_ms', 'hattiesburg_ms']
# corvallis_or []
# newport_or ['portland_or', 'medford_or']
# sanford_fl ['orlando_fl']
# appleton_wi ['appleton_wi']
# phoenix_az ['phoenix_az']
# show_low_az ['show_low_az']
# mobile_al ['mobile_al']
# kalamazoo_mi ['kalamazoo_mi']
# oakland_ca ['oakland_ca', 'oxnard_ca', 'visalia_ca']
# merced_ca ['merced_ca', 'madera_ca', 'eureka_ca']
# providence_ri ['providence_ri']
# spokane_wa ['spokane_wa', 'port_angeles_wa', 'seattle_wa']
# shreveport_la ['shreveport_la']
# dover_de ['dover_de']
# charlottesville_va ['charlottesville_va']
# greer_sc ['greenwood_sc', 'greenville_sc', 'florence_sc']
# memphis_tn ['memphis_tn', 'paris_tn']
# destin_fl ['sebastian_fl', 'key_west_fl']
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# nantucket_ma []
# bozeman_mt ['bozeman_mt']
# long_beach_ca []
# phoenix_az ['phoenix_az']
# belleville_il ['danville_il']
# miami_fl ['miami_fl', 'tampa_fl']
# missionmcallenedinburg_tx []
# harlingensan_benito_tx []
# fort_wayne_in ['fort_wayne_in']
# sanford_fl ['orlando_fl']
# fayetteville_ar ['fayetteville_ar', 'batesville_ar', 'blytheville_ar']
# charlotte_nc ['charlotte_nc']
# newport_newswilliamsburg_va []
# phoenix_az ['phoenix_az']
# bakersfield_ca ['bakersfield_ca', 'riverside_ca', 'merced_ca']
# las_vegas_nv ['las_vegas_nv']
# monterey_ca ['merced_ca', 'oxnard_ca', 'madera_ca']
# deadhorse_ak ['anchorage_ak']
# noorvik_ak ['kodiak_ak']
# madison_wi ['madison_wi', 'racine_wi']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# indianapolis_in ['indianapolis_in']
# flint_mi ['flint_mi', 'lansing_mi']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# bowling_green_ky ['bowling_green_ky']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# riverside_ca ['riverside_ca', 'bakersfield_ca']
# philadelphia_pa ['philadelphia_pa']
# pontiac_mi []
# sanford_fl ['orlando_fl']
# norfolk_va ['roanoke_va']
# cleveland_oh ['cleveland_oh']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# boston_ma ['boston_ma']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# omaha_ne ['omaha_ne']
# miami_fl ['miami_fl', 'tampa_fl']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# white_plains_ny []
# washington_dc ['washington_dc']
# montgomery_al ['montgomery_al']
# denver_co []
# bakersfield_ca ['bakersfield_ca', 'riverside_ca', 'merced_ca']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# south_bend_in ['south_bend_in']
# bloomingtonnormal_il ['bloomington_il']
# boise_id []
# cleveland_oh ['cleveland_oh']
# sarasotabradenton_fl []
# gulfportbiloxi_ms ['gulfport_ms']
# sanford_fl ['orlando_fl']
# deadhorse_ak ['anchorage_ak']
# kivalina_ak ['ketchikan_ak', 'kodiak_ak']
# nome_ak ['anchorage_ak', 'juneau_ak']
# russian_mission_ak []
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# grand_rapids_mi ['grand_rapids_mi', 'big_rapids_mi']
# sioux_falls_sd ['sioux_falls_sd']
# louisville_ky ['madisonville_ky', 'danville_ky']
# dallasfort_worth_tx ['dallas_tx']
# sioux_city_ia ['sioux_city_ia', 'mason_city_ia']
# kansas_city_mo ['kansas_city_mo']
# richmond_va ['richmond_va']
# philadelphia_pa ['philadelphia_pa']
# salisbury_md ['salisbury_md']
# east_farmingdale_ny []
# laconia_nh ['laconia_nh']
# tuscaloosa_al ['tuscaloosa_al']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# charleston_sc ['charleston_sc', 'anderson_sc']
# portland_me ['portland_me', 'rockland_me']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# eagle_co []
# kenai_ak ['ketchikan_ak']
# nome_ak ['anchorage_ak', 'juneau_ak']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# rochester_ny ['rochester_ny']
# cincinnati_oh ['cincinnati_oh']
# morristown_nj ['trenton_nj']
# barrow_ak []
# savoonga_ak []
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# appleton_wi ['appleton_wi']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# miami_fl ['miami_fl', 'tampa_fl']
# bullhead_city_az []
# tucson_az ['tucson_az']
# bloomingtonnormal_il ['bloomington_il']
# fort_wayne_in ['fort_wayne_in']
# miami_fl ['miami_fl', 'tampa_fl']
# peru_in ['peru_in']
# tucson_az ['tucson_az']
# bellingham_wa ['bellingham_wa', 'ellensburg_wa']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# white_plains_ny []
# minneapolis_mn ['minneapolis_mn']
# lincoln_ne ['lincoln_ne', 'lexington_ne', 'norfolk_ne']
# bullhead_city_az []
# wichita_ks ['wichita_ks']
# gulfportbiloxi_ms ['gulfport_ms']
# daytona_beach_fl ['west_palm_beach_fl']
# norfolk_va ['roanoke_va']
# manteo_nc ['wilmington_nc', 'kinston_nc']
# napa_ca ['napa_ca', 'oxnard_ca', 'madera_ca']
# thermal_ca ['eureka_ca']
# valparaiso_fl []
# belleville_il ['danville_il']
# rivertonlander_wy ['riverton_wy']
# sheridan_wy ['sheridan_wy', 'casper_wy']
# syracuse_ny ['syracuse_ny']
# roanoke_va ['roanoke_va']
# grand_rapids_mi ['grand_rapids_mi', 'big_rapids_mi']
# ithacacortland_ny ['ithaca_ny']
# albany_ny ['albany_ny']
# state_college_pa ['state_college_pa']
# lubbock_tx ['lubbock_tx']
# wichita_ks ['wichita_ks']
# newark_nj ['newark_nj']
# clarksburgfairmont_wv ['clarksburg_wv', 'parkersburg_wv']
# bullhead_city_az []
# minot_nd ['minot_nd', 'dickinson_nd']
# anchorage_ak ['anchorage_ak']
# manokotak_ak ['kodiak_ak']
# memphis_tn ['memphis_tn', 'paris_tn']
# marana_az ['yuma_az']
# charlotte_nc ['charlotte_nc']
# asheville_nc ['asheville_nc', 'statesville_nc', 'jacksonville_nc']
# rochester_ny ['rochester_ny']
# white_plains_ny []
# fairbanks_ak ['fairbanks_ak']
# borniteruby_creek_ak []
# rockford_il ['rockford_il']
# madison_wi ['madison_wi', 'racine_wi']
# savoonga_ak []
# teller_ak []
# marthas_vineyard_ma []
# waterbury_ct []
# st_petersburg_fl []
# norfolk_va ['roanoke_va']
# los_angeles_ca ['los_angeles_ca']
# missoula_mt ['missoula_mt']
# hartford_ct ['hartford_ct']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# jacksonvicksburg_ms ['jackson_ms', 'hattiesburg_ms']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# evansville_in ['evansville_in', 'connersville_in']
# buffalo_ny ['buffalo_ny']
# lafayette_in ['lafayette_in']
# lubbock_tx ['lubbock_tx']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# hartford_ct ['hartford_ct']
# bridgeport_ct ['bridgeport_ct']
# minneapolis_mn ['minneapolis_mn']
# thief_river_falls_mn ['fergus_falls_mn']
# anchorage_ak ['anchorage_ak']
# beluga_ak []
# charlotte_nc ['charlotte_nc']
# peoria_il ['peoria_il', 'sterling_il', 'freeport_il']
# shreveport_la ['shreveport_la']
# birmingham_al ['birmingham_al']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# sarasotabradenton_fl []
# kona_hi []
# hana_hi []
# baltimore_md ['baltimore_md']
# ashland_wv []
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# norfolk_va ['roanoke_va']
# manassas_va []
# elizabeth_city_nc ['elizabeth_city_nc']
# sanford_fl ['orlando_fl']
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# anchorage_ak ['anchorage_ak']
# fort_yukon_ak []
# albany_ny ['albany_ny']
# ogdensburg_ny ['ogdensburg_ny']
# burbank_ca ['eureka_ca']
# teterboro_nj []
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# grand_rapids_mi ['grand_rapids_mi', 'big_rapids_mi']
# chicago_il ['chicago_il', 'champaign_il']
# columbia_mo ['columbia_mo', 'joplin_mo']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# jackson_wy ['jackson_wy']
# los_angeles_ca ['los_angeles_ca']
# prescott_az ['prescott_az']
# adak_island_ak []
# anchorage_ak ['anchorage_ak']
# white_plains_ny []
# morrisville_vt []
# akun_ak ['kodiak_ak', 'juneau_ak']
# akutan_ak ['ketchikan_ak']
# cleveland_oh ['cleveland_oh']
# erie_pa ['erie_pa', 'meadville_pa']
# minneapolis_mn ['minneapolis_mn']
# peoria_il ['peoria_il', 'sterling_il', 'freeport_il']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# jackson_tn ['jackson_tn']
# buffalo_ny ['buffalo_ny']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# cincinnati_oh ['cincinnati_oh']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# state_college_pa ['state_college_pa']
# ithacacortland_ny ['ithaca_ny']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# palm_springs_ca ['salinas_ca']
# shreveport_la ['shreveport_la']
# evansville_in ['evansville_in', 'connersville_in']
# new_york_ny ['new_york_ny']
# dayton_oh ['dayton_oh', 'akron_oh', 'marion_oh']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# allentownbethlehemeaston_pa ['allentown_pa']
# norfolk_va ['roanoke_va']
# montgomery_al ['montgomery_al']
# los_angeles_ca ['los_angeles_ca']
# merced_ca ['merced_ca', 'madera_ca', 'eureka_ca']
# new_york_ny ['new_york_ny']
# montrosedelta_co ['montrose_co']
# pensacola_fl ['pensacola_fl', 'punta_gorda_fl', 'ocala_fl']
# miami_fl ['miami_fl', 'tampa_fl']
# providence_ri ['providence_ri']
# fort_wayne_in ['fort_wayne_in']
# charlotte_nc ['charlotte_nc']
# daytona_beach_fl ['west_palm_beach_fl']
# new_york_ny ['new_york_ny']
# nantucket_ma []
# minneapolis_mn ['minneapolis_mn']
# helena_mt ['helena_mt']
# denver_co []
# helena_mt ['helena_mt']
# hartford_ct ['hartford_ct']
# clarksburgfairmont_wv ['clarksburg_wv', 'parkersburg_wv']
# madison_wi ['madison_wi', 'racine_wi']
# wausau_wi ['wausau_wi']
# memphis_tn ['memphis_tn', 'paris_tn']
# flint_mi ['flint_mi', 'lansing_mi']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# south_bend_in ['south_bend_in']
# gulfportbiloxi_ms ['gulfport_ms']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# indianapolis_in ['indianapolis_in']
# smyrna_tn []
# philadelphia_pa ['philadelphia_pa']
# wilmington_nc ['wilmington_nc', 'kinston_nc']
# memphis_tn ['memphis_tn', 'paris_tn']
# harrison_ar ['harrison_ar']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# peoria_il ['peoria_il', 'sterling_il', 'freeport_il']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# state_college_pa ['state_college_pa']
# minneapolis_mn ['minneapolis_mn']
# international_falls_mn []
# washington_dc ['washington_dc']
# dayton_oh ['dayton_oh', 'akron_oh', 'marion_oh']
# reno_nv ['reno_nv', 'elko_nv']
# midlandodessa_tx ['midland_tx', 'andrews_tx']
# charlotte_nc ['charlotte_nc']
# lexington_ky ['lexington_ky', 'london_ky']
# fort_myers_fl ['fort_lauderdale_fl']
# richmond_va ['richmond_va']
# albany_ga ['albany_ga', 'atlanta_ga', 'dalton_ga']
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# albuquerque_nm ['albuquerque_nm']
# carlsbad_nm ['carlsbad_nm', 'clovis_nm']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# madison_wi ['madison_wi', 'racine_wi']
# minneapolis_mn ['minneapolis_mn']
# aspen_co ['sterling_co']
# omaha_ne ['omaha_ne']
# kearney_ne ['kearney_ne']
# tucson_az ['tucson_az']
# provo_ut ['provo_ut', 'price_ut']
# deadhorse_ak ['anchorage_ak']
# kiana_ak ['kodiak_ak', 'ketchikan_ak', 'fairbanks_ak']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# baton_rouge_la ['baton_rouge_la', 'monroe_la']
# indianapolis_in ['indianapolis_in']
# pontiac_mi []
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# spokane_wa ['spokane_wa', 'port_angeles_wa', 'seattle_wa']
# houston_tx ['houston_tx', 'austin_tx']
# charlestondunbar_wv ['charleston_wv']
# chicago_il ['chicago_il', 'champaign_il']
# jacksonvicksburg_ms ['jackson_ms', 'hattiesburg_ms']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# bendredmond_or ['pendleton_or', 'bend_or']
# sitka_ak ['ketchikan_ak']
# kake_ak ['kodiak_ak']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# portland_me ['portland_me', 'rockland_me']
# cleveland_oh ['cleveland_oh']
# rockford_il ['rockford_il']
# eagle_co []
# jackson_mi ['jackson_mi']
# louisville_ky ['madisonville_ky', 'danville_ky']
# kona_hi []
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# baton_rouge_la ['baton_rouge_la', 'monroe_la']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# sanford_fl ['orlando_fl']
# elmiracorning_ny ['elmira_ny']
# charlotte_nc ['charlotte_nc']
# new_bernmoreheadbeaufort_nc []
# fort_lauderdale_fl ['fort_lauderdale_fl']
# syracuse_ny ['syracuse_ny']
# teterboro_nj []
# broomfield_co []
# sanford_fl ['orlando_fl']
# tulsa_ok ['tulsa_ok', 'altus_ok']
# newark_nj ['newark_nj']
# knoxville_tn ['knoxville_tn', 'nashville_tn', 'crossville_tn']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# lafayette_in ['lafayette_in']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# appleton_wi ['appleton_wi']
# manchester_nh ['manchester_nh']
# elmiracorning_ny ['elmira_ny']
# newark_nj ['newark_nj']
# plattsburgh_ny ['plattsburgh_ny']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# teterboro_nj []
# sioux_falls_sd ['sioux_falls_sd']
# memphis_tn ['memphis_tn', 'paris_tn']
# bullhead_city_az []
# madison_wi ['madison_wi', 'racine_wi']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# moline_il ['marion_il', 'sterling_il']
# new_york_ny ['new_york_ny']
# ponce_pr []
# phoenix_az ['phoenix_az']
# stockton_ca ['stockton_ca']
# houston_tx ['houston_tx', 'austin_tx']
# springfield_mo ['springfield_mo']
# greensborohigh_point_nc ['greensboro_nc']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# pullman_wa ['pullman_wa', 'spokane_wa', 'olympia_wa']
# huntsville_al ['huntsville_al']
# shreveport_la ['shreveport_la']
# dallas_tx ['dallas_tx', 'eagle_pass_tx', 'midland_tx']
# college_stationbryan_tx ['college_station_tx']
# bullhead_city_az []
# green_bay_wi ['green_bay_wi']
# new_york_ny ['new_york_ny']
# roanoke_va ['roanoke_va']
# dayton_oh ['dayton_oh', 'akron_oh', 'marion_oh']
# south_bend_in ['south_bend_in']
# hartford_ct ['hartford_ct']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# fort_yukon_ak []
# chalkyitsik_ak []
# chicago_il ['chicago_il', 'champaign_il']
# asheville_nc ['asheville_nc', 'statesville_nc', 'jacksonville_nc']
# milwaukee_wi ['milwaukee_wi']
# santa_ana_ca ['santa_ana_ca', 'santa_rosa_ca', 'santa_barbara_ca']
# albuquerque_nm ['albuquerque_nm']
# montrosedelta_co ['montrose_co']
# houston_tx ['houston_tx', 'austin_tx']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# madison_wi ['madison_wi', 'racine_wi']
# lexington_ky ['lexington_ky', 'london_ky']
# chicago_il ['chicago_il', 'champaign_il']
# lewisburg_wv ['clarksburg_wv', 'parkersburg_wv']
# anchorage_ak ['anchorage_ak']
# huntsville_al ['huntsville_al']
# kansas_city_mo ['kansas_city_mo']
# missionmcallenedinburg_tx []
# minneapolis_mn ['minneapolis_mn']
# springfield_mo ['springfield_mo']
# memphis_tn ['memphis_tn', 'paris_tn']
# rochester_mn ['rochester_mn']
# las_vegas_nv ['las_vegas_nv']
# yakima_wa ['yakima_wa', 'tacoma_wa', 'olympia_wa']
# sanford_fl ['orlando_fl']
# ashland_wv []
# fort_lauderdale_fl ['fort_lauderdale_fl']
# ashland_wv []
# gulfportbiloxi_ms ['gulfport_ms']
# peoria_il ['peoria_il', 'sterling_il', 'freeport_il']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# jackson_wy ['jackson_wy']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# valparaiso_in ['marion_in']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# augusta_ga ['augusta_ga', 'valdosta_ga', 'atlanta_ga']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# smyrna_tn []
# shreveport_la ['shreveport_la']
# palm_springs_ca ['salinas_ca']
# columbus_oh ['columbus_oh']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# st_petersburg_fl []
# appleton_wi ['appleton_wi']
# charlotte_nc ['charlotte_nc']
# binghamton_ny ['binghamton_ny', 'jamestown_ny']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# key_west_fl ['key_west_fl', 'lake_city_fl']
# anchorage_ak ['anchorage_ak']
# guam_tt []
# washington_dc ['washington_dc']
# tallahassee_fl ['tallahassee_fl']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# asheville_nc ['asheville_nc', 'statesville_nc', 'jacksonville_nc']
# cape_girardeau_mo ['cape_girardeau_mo']
# quincy_il ['quincy_il']
# las_vegas_nv ['las_vegas_nv']
# santa_maria_ca ['santa_ana_ca', 'santa_rosa_ca', 'santa_barbara_ca']
# washington_dc ['washington_dc']
# valparaiso_fl []
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# lewiston_id ['lewiston_id']
# reno_nv ['reno_nv', 'elko_nv']
# wichita_ks ['wichita_ks']
# houston_tx ['houston_tx', 'austin_tx']
# bedford_ma []
# las_vegas_nv ['las_vegas_nv']
# south_bend_in ['south_bend_in']
# milwaukee_wi ['milwaukee_wi']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# newark_nj ['newark_nj']
# asheville_nc ['asheville_nc', 'statesville_nc', 'jacksonville_nc']
# flint_mi ['flint_mi', 'lansing_mi']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# bozeman_mt ['bozeman_mt']
# valparaiso_in ['marion_in']
# bethel_ak []
# sleetmute_ak []
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# bullhead_city_az []
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# north_bendcoos_bay_or []
# king_salmon_ak []
# unalakleet_ak []
# sioux_falls_sd ['sioux_falls_sd']
# wichita_ks ['wichita_ks']
# buffalo_ny ['buffalo_ny']
# ithacacortland_ny ['ithaca_ny']
# kansas_city_mo ['kansas_city_mo']
# gary_in ['gary_in', 'marion_in', 'auburn_in']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# lafayette_la ['lafayette_la']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# gary_in ['gary_in', 'marion_in', 'auburn_in']
# miami_fl ['miami_fl', 'tampa_fl']
# boca_raton_fl ['ocala_fl', 'orlando_fl']
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# greer_sc ['greenwood_sc', 'greenville_sc', 'florence_sc']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# kenai_ak ['ketchikan_ak']
# valdez_ak []
# sanford_fl ['orlando_fl']
# fargo_nd ['fargo_nd']
# boston_ma ['boston_ma']
# rutland_vt ['rutland_vt']
# phoenix_az ['phoenix_az']
# san_luis_obispo_ca ['san_luis_obispo_ca', 'san_jose_ca', 'san_diego_ca']
# harlingensan_benito_tx []
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# memphis_tn ['memphis_tn', 'paris_tn']
# stillwater_ok ['stillwater_ok']
# alamosa_co []
# denver_co []
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# riverside_ca ['riverside_ca', 'bakersfield_ca']
# los_angeles_ca ['los_angeles_ca']
# fayetteville_ar ['fayetteville_ar', 'batesville_ar', 'blytheville_ar']
# providence_ri ['providence_ri']
# teterboro_nj []
# st_petersburg_fl []
# bangor_me ['bangor_me']
# birmingham_al ['birmingham_al']
# brunswick_ga ['brunswick_ga']
# dallasfort_worth_tx ['dallas_tx']
# waco_tx ['waco_tx', 'laredo_tx']
# plattsburgh_ny ['plattsburgh_ny']
# st_petersburg_fl []
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# concord_nc ['hickory_nc']
# minneapolis_mn ['minneapolis_mn']
# champaignurbana_il ['champaign_il']
# st_petersburg_fl []
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# medford_or ['medford_or']
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# rockford_il ['rockford_il']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# santa_barbara_ca ['santa_barbara_ca', 'santa_ana_ca', 'santa_rosa_ca']
# king_salmon_ak []
# egegik_ak []
# smyrna_tn []
# teterboro_nj []
# philadelphia_pa ['philadelphia_pa']
# fort_wayne_in ['fort_wayne_in']
# washington_dc ['washington_dc']
# pontiac_mi []
# omaha_ne ['omaha_ne']
# corpus_christi_tx ['corpus_christi_tx']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# flint_mi ['flint_mi', 'lansing_mi']
# houston_tx ['houston_tx', 'austin_tx']
# savannah_ga ['savannah_ga', 'atlanta_ga', 'albany_ga']
# sacramento_ca ['sacramento_ca', 'el_centro_ca', 'fresno_ca']
# allentownbethlehemeaston_pa ['allentown_pa']
# greer_sc ['greenwood_sc', 'greenville_sc', 'florence_sc']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# st_marys_ak []
# nuiqsut_ak []
# omaha_ne ['omaha_ne']
# st_petersburg_fl []
# kahului_hi ['kahului_hi', 'honolulu_hi']
# medford_or ['medford_or']
# philadelphia_pa ['philadelphia_pa']
# san_bernardino_ca ['san_diego_ca', 'san_francisco_ca', 'santa_ana_ca']
# tucson_az ['tucson_az']
# pascokennewickrichland_wa ['kennewick_wa']
# memphis_tn ['memphis_tn', 'paris_tn']
# great_falls_mt ['great_falls_mt']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# raleighdurham_nc ['raleigh_nc']
# st_petersburg_fl []
# elmiracorning_ny ['elmira_ny']
# casper_wy ['casper_wy', 'sheridan_wy']
# rock_springs_wy ['rock_springs_wy']
# houston_tx ['houston_tx', 'austin_tx']
# gunnison_co ['grand_junction_co']
# bullhead_city_az []
# st_cloud_mn ['st_cloud_mn']
# gulfportbiloxi_ms ['gulfport_ms']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# elko_nv ['elko_nv', 'reno_nv', 'fallon_nv']
# sanford_fl ['orlando_fl']
# cedar_rapidsiowa_city_ia ['cedar_rapids_ia']
# philadelphia_pa ['philadelphia_pa']
# white_plains_ny []
# norfolk_va ['roanoke_va']
# salisbury_md ['salisbury_md']
# st_petersburg_fl []
# fort_wayne_in ['fort_wayne_in']
# bethel_ak []
# buckland_ak []
# washington_dc ['washington_dc']
# bedford_ma []
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# bethel_ak []
# dillingham_ak []
# gulfportbiloxi_ms ['gulfport_ms']
# little_rock_ar ['little_rock_ar']
# charleston_sc ['charleston_sc', 'anderson_sc']
# manchester_nh ['manchester_nh']
# richmond_va ['richmond_va']
# toledo_oh ['toledo_oh']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# fargo_nd ['fargo_nd']
# minneapolis_mn ['minneapolis_mn']
# pascokennewickrichland_wa ['kennewick_wa']
# milwaukee_wi ['milwaukee_wi']
# iron_mountainkingsfd_mi ['iron_mountain_mi']
# chefornak_ak ['anchorage_ak']
# kipnuk_ak ['kodiak_ak']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# cincinnati_oh ['cincinnati_oh']
# san_bernardino_ca ['san_diego_ca', 'san_francisco_ca', 'santa_ana_ca']
# fargo_nd ['fargo_nd']
# thief_river_falls_mn ['fergus_falls_mn']
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# lihue_hi []
# milwaukee_wi ['milwaukee_wi']
# long_beach_ca []
# ontario_ca ['oxnard_ca', 'santa_rosa_ca', 'el_centro_ca']
# lexington_ky ['lexington_ky', 'london_ky']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# morristown_nj ['trenton_nj']
# chicken_ak ['ketchikan_ak']
# tok_ak ['kodiak_ak']
# little_rock_ar ['little_rock_ar']
# missionmcallenedinburg_tx []
# denver_co []
# laramie_wy ['laramie_wy']
# sanford_fl ['orlando_fl']
# peoria_il ['peoria_il', 'sterling_il', 'freeport_il']
# albuquerque_nm ['albuquerque_nm']
# silver_cityhurley_nm ['silver_city_nm']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# owensboro_ky ['owensboro_ky']
# harlingensan_benito_tx []
# shreveport_la ['shreveport_la']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# belleville_il ['danville_il']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# bedford_ma []
# dallasfort_worth_tx ['dallas_tx']
# texarkana_ar []
# rochester_ny ['rochester_ny']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# charlotte_nc ['charlotte_nc']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# unalaska_ak ['juneau_ak']
# cold_bay_ak ['kodiak_ak']
# newark_nj ['newark_nj']
# syracuse_ny ['syracuse_ny']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# rockford_il ['rockford_il']
# baltimore_md ['baltimore_md']
# kalamazoo_mi ['kalamazoo_mi']
# charlotte_nc ['charlotte_nc']
# augusta_ga ['augusta_ga', 'valdosta_ga', 'atlanta_ga']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# hilo_hi ['hilo_hi']
# las_vegas_nv ['las_vegas_nv']
# idaho_falls_id ['idaho_falls_id', 'twin_falls_id']
# newark_nj ['newark_nj']
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# charleston_sc ['charleston_sc', 'anderson_sc']
# everett_wa ['seattle_wa']
# denver_co []
# moline_il ['marion_il', 'sterling_il']
# state_college_pa ['state_college_pa']
# cleveland_oh ['cleveland_oh']
# gulfportbiloxi_ms ['gulfport_ms']
# savannah_ga ['savannah_ga', 'atlanta_ga', 'albany_ga']
# charlotte_nc ['charlotte_nc']
# pontiac_mi []
# boston_ma ['boston_ma']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# aniak_ak ['kodiak_ak', 'fairbanks_ak', 'anchorage_ak']
# toksook_ak ['kodiak_ak']
# sanford_fl ['orlando_fl']
# belleville_il ['danville_il']
# brownwood_tx ['brownwood_tx', 'brownsville_tx']
# san_angelo_tx ['san_angelo_tx', 'san_antonio_tx']
# jacksonvicksburg_ms ['jackson_ms', 'hattiesburg_ms']
# lafayette_la ['lafayette_la']
# sioux_falls_sd ['sioux_falls_sd']
# kansas_city_mo ['kansas_city_mo']
# white_plains_ny []
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# kenai_ak ['ketchikan_ak']
# dillingham_ak []
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# sanford_fl ['orlando_fl']
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# bozeman_mt ['bozeman_mt']
# scammon_bay_ak []
# unalakleet_ak []
# las_vegas_nv ['las_vegas_nv']
# belleville_il ['danville_il']
# noorvik_ak ['kodiak_ak']
# red_dog_ak []
# oakland_ca ['oakland_ca', 'oxnard_ca', 'visalia_ca']
# great_falls_mt ['great_falls_mt']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# butte_mt ['butte_mt']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# montgomery_al ['montgomery_al']
# louisville_ky ['madisonville_ky', 'danville_ky']
# peoria_il ['peoria_il', 'sterling_il', 'freeport_il']
# cincinnati_oh ['cincinnati_oh']
# valparaiso_fl []
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# pocatello_id ['pocatello_id']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# destin_fl ['sebastian_fl', 'key_west_fl']
# anchorage_ak ['anchorage_ak']
# everett_wa ['seattle_wa']
# kansas_city_mo ['kansas_city_mo']
# daytona_beach_fl ['west_palm_beach_fl']
# fort_myers_fl ['fort_lauderdale_fl']
# reno_nv ['reno_nv', 'elko_nv']
# syracuse_ny ['syracuse_ny']
# dayton_oh ['dayton_oh', 'akron_oh', 'marion_oh']
# billings_mt ['billings_mt']
# saipan_tt []
# bullhead_city_az []
# rapid_city_sd ['rapid_city_sd']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# grand_junction_co ['grand_junction_co']
# sanford_fl ['orlando_fl']
# bangor_me ['bangor_me']
# deadhorse_ak ['anchorage_ak']
# chuathbaluk_ak []
# reno_nv ['reno_nv', 'elko_nv']
# little_rock_ar ['little_rock_ar']
# boston_ma ['boston_ma']
# saranac_lakelake_placid_ny []
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# santa_rosa_ca ['santa_rosa_ca', 'santa_ana_ca', 'santa_barbara_ca']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# kona_hi []
# hilo_hi ['hilo_hi']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# valparaiso_fl []
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# huntsville_al ['huntsville_al']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# baton_rouge_la ['baton_rouge_la', 'monroe_la']
# mobile_al ['mobile_al']
# new_york_ny ['new_york_ny']
# palm_springs_ca ['salinas_ca']
# omaha_ne ['omaha_ne']
# birmingham_al ['birmingham_al']
# bullhead_city_az []
# moline_il ['marion_il', 'sterling_il']
# ontario_ca ['oxnard_ca', 'santa_rosa_ca', 'el_centro_ca']
# santa_barbara_ca ['santa_barbara_ca', 'santa_ana_ca', 'santa_rosa_ca']
# denver_co []
# medford_or ['medford_or']
# denver_co []
# knoxville_tn ['knoxville_tn', 'nashville_tn', 'crossville_tn']
# philadelphia_pa ['philadelphia_pa']
# charlotte_amalie_vi []
# sanford_fl ['orlando_fl']
# portsmouth_nh []
# minneapolis_mn ['minneapolis_mn']
# abilene_tx ['abilene_tx', 'killeen_tx', 'uvalde_tx']
# st_petersburg_fl []
# syracuse_ny ['syracuse_ny']
# miami_fl ['miami_fl', 'tampa_fl']
# columbus_ga ['columbus_ga']
# st_marys_ak []
# hooper_bay_ak []
# louisville_ky ['madisonville_ky', 'danville_ky']
# lafayette_la ['lafayette_la']
# akiachak_ak ['kodiak_ak', 'ketchikan_ak', 'fairbanks_ak']
# fairbanks_ak ['fairbanks_ak']
# charlestondunbar_wv ['charleston_wv']
# latrobe_pa ['lancaster_pa', 'altoona_pa']
# eugene_or ['eugene_or', 'bend_or', 'roseburg_or']
# roseburg_or ['roseburg_or', 'eugene_or']
# columbus_oh ['columbus_oh']
# st_petersburg_fl []
# buffalo_ny ['buffalo_ny']
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# kenai_ak ['ketchikan_ak']
# point_hope_ak []
# fort_myers_fl ['fort_lauderdale_fl']
# latrobe_pa ['lancaster_pa', 'altoona_pa']
# guam_tt []
# wake_island_tt []
# norfolk_va ['roanoke_va']
# grand_rapids_mi ['grand_rapids_mi', 'big_rapids_mi']
# los_angeles_ca ['los_angeles_ca']
# medford_or ['medford_or']
# bullhead_city_az []
# tulsa_ok ['tulsa_ok', 'altus_ok']
# brownsville_tx ['brownsville_tx', 'longview_tx', 'brownwood_tx']
# tallahassee_fl ['tallahassee_fl']
# anchorage_ak ['anchorage_ak']
# new_stuyahok_ak []
# grand_island_ne ['grand_island_ne']
# kearney_ne ['kearney_ne']
# shageluk_ak ['anchorage_ak']
# unalakleet_ak []
# louisville_ky ['madisonville_ky', 'danville_ky']
# san_bernardino_ca ['san_diego_ca', 'san_francisco_ca', 'santa_ana_ca']
# phoenix_az ['phoenix_az']
# missionmcallenedinburg_tx []
# chicago_il ['chicago_il', 'champaign_il']
# fayetteville_ar ['fayetteville_ar', 'batesville_ar', 'blytheville_ar']
# minneapolis_mn ['minneapolis_mn']
# pontiac_mi []
# boston_ma ['boston_ma']
# lexington_ky ['lexington_ky', 'london_ky']
# chicago_il ['chicago_il', 'champaign_il']
# kahului_hi ['kahului_hi', 'honolulu_hi']
# atlantic_city_nj ['atlantic_city_nj']
# camp_springs_md []
# minneapolis_mn ['minneapolis_mn']
# ironwood_mi []
# charlotte_nc ['charlotte_nc']
# baton_rouge_la ['baton_rouge_la', 'monroe_la']
# elim_ak []
# st_michael_ak []
# bethel_ak []
# homer_ak ['anchorage_ak']
# buffalo_ny ['buffalo_ny']
# scrantonwilkes-barre_pa ['scranton_pa']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# valparaiso_fl []
# iliamna_ak []
# king_salmon_ak []
# milwaukee_wi ['milwaukee_wi']
# mosinee_wi ['milwaukee_wi', 'racine_wi', 'madison_wi']
# providence_ri ['providence_ri']
# san_juan_pr []
# las_vegas_nv ['las_vegas_nv']
# shreveport_la ['shreveport_la']
# bethel_ak []
# napaskiak_ak ['kodiak_ak']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# harlingensan_benito_tx []
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# washington_dc ['washington_dc']
# huntsville_al ['huntsville_al']
# st_michael_ak []
# unalakleet_ak []
# sacramento_ca ['sacramento_ca', 'el_centro_ca', 'fresno_ca']
# redding_ca ['redding_ca', 'merced_ca', 'fresno_ca']
# burbank_ca ['eureka_ca']
# cleveland_oh ['cleveland_oh']
# barrow_ak []
# chuathbaluk_ak []
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# st_petersburg_fl []
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# marathon_fl []
# dayton_oh ['dayton_oh', 'akron_oh', 'marion_oh']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# gary_in ['gary_in', 'marion_in', 'auburn_in']
# anchorage_ak ['anchorage_ak']
# larsen_bay_ak []
# bethel_ak []
# cape_newenham_ak []
# kotzebue_ak []
# savoonga_ak []
# oakland_ca ['oakland_ca', 'oxnard_ca', 'visalia_ca']
# lihue_hi []
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# richmond_va ['richmond_va']
# rochester_ny ['rochester_ny']
# elmiracorning_ny ['elmira_ny']
# st_petersburg_fl []
# toledo_oh ['toledo_oh']
# aguadilla_pr []
# miami_fl ['miami_fl', 'tampa_fl']
# sioux_falls_sd ['sioux_falls_sd']
# phoenix_az ['phoenix_az']
# kotzebue_ak []
# nome_ak ['anchorage_ak', 'juneau_ak']
# buffalo_ny ['buffalo_ny']
# mobile_al ['mobile_al']
# indianapolis_in ['indianapolis_in']
# parkersburg_wv ['parkersburg_wv', 'clarksburg_wv']
# milwaukee_wi ['milwaukee_wi']
# presque_islehoulton_me []
# houston_tx ['houston_tx', 'austin_tx']
# lake_charles_la ['lake_charles_la', 'new_orleans_la']
# mobile_al ['mobile_al']
# richmond_va ['richmond_va']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# rapid_city_sd ['rapid_city_sd']
# houston_tx ['houston_tx', 'austin_tx']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# boston_ma ['boston_ma']
# hayden_co []
# fort_lauderdale_fl ['fort_lauderdale_fl']
# concord_nc ['hickory_nc']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# mammoth_lakes_ca []
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# missoula_mt ['missoula_mt']
# des_moines_ia ['des_moines_ia', 'ames_ia']
# portland_me ['portland_me', 'rockland_me']
# cincinnati_oh ['cincinnati_oh']
# fort_dix_nj []
# concord_nc ['hickory_nc']
# greeneville_tn ['greeneville_tn', 'nashville_tn', 'knoxville_tn']
# hancockhoughton_mi []
# escanaba_mi ['escanaba_mi', 'saginaw_mi', 'ann_arbor_mi']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# dubois_pa []
# fort_lauderdale_fl ['fort_lauderdale_fl']
# marathon_fl []
# memphis_tn ['memphis_tn', 'paris_tn']
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# miami_fl ['miami_fl', 'tampa_fl']
# key_west_fl ['key_west_fl', 'lake_city_fl']
# newark_nj ['newark_nj']
# cedar_rapidsiowa_city_ia ['cedar_rapids_ia']
# new_stuyahok_ak []
# koliganek_ak ['kodiak_ak']
# dallasfort_worth_tx ['dallas_tx']
# el_dorado_ar ['el_dorado_ar']
# las_vegas_nv ['las_vegas_nv']
# santa_rosa_ca ['santa_rosa_ca', 'santa_ana_ca', 'santa_barbara_ca']
# miami_fl ['miami_fl', 'tampa_fl']
# gainesville_fl ['gainesville_fl', 'jacksonville_fl']
# yakima_wa ['yakima_wa', 'tacoma_wa', 'olympia_wa']
# moses_lake_wa ['moses_lake_wa', 'seattle_wa']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# vero_beach_fl ['west_palm_beach_fl']
# cedar_rapidsiowa_city_ia ['cedar_rapids_ia']
# great_falls_mt ['great_falls_mt']
# fairbanks_ak ['fairbanks_ak']
# healy_ak []
# manchester_nh ['manchester_nh']
# grand_rapids_mi ['grand_rapids_mi', 'big_rapids_mi']
# miami_fl ['miami_fl', 'tampa_fl']
# columbia_sc ['columbia_sc']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# laredo_tx ['laredo_tx', 'midland_tx', 'andrews_tx']
# san_jose_ca ['san_jose_ca', 'santa_rosa_ca', 'san_diego_ca']
# rockford_il ['rockford_il']
# boston_ma ['boston_ma']
# bar_harbor_me ['bangor_me']
# chicago_il ['chicago_il', 'champaign_il']
# columbia_sc ['columbia_sc']
# minneapolis_mn ['minneapolis_mn']
# knoxville_tn ['knoxville_tn', 'nashville_tn', 'crossville_tn']
# sioux_falls_sd ['sioux_falls_sd']
# st_petersburg_fl []
# akiak_ak ['kodiak_ak', 'fairbanks_ak', 'ketchikan_ak']
# newtok_ak []
# washington_dc ['washington_dc']
# lansing_mi ['lansing_mi', 'flint_mi', 'saginaw_mi']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# fayetteville_nc ['fayetteville_nc', 'statesville_nc', 'asheville_nc']
# columbus_ga ['columbus_ga']
# dayton_oh ['dayton_oh', 'akron_oh', 'marion_oh']
# greenville_sc ['greenville_sc', 'greenwood_sc']
# rocky_mount_nc ['rocky_mount_nc']
# albuquerque_nm ['albuquerque_nm']
# miami_fl ['miami_fl', 'tampa_fl']
# philadelphia_pa ['philadelphia_pa']
# watertown_ny ['watertown_ny', 'jamestown_ny']
# bullhead_city_az []
# allentownbethlehemeaston_pa ['allentown_pa']
# chicago_il ['chicago_il', 'champaign_il']
# rochester_mn ['rochester_mn']
# fort_myers_fl ['fort_lauderdale_fl']
# key_west_fl ['key_west_fl', 'lake_city_fl']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# barrow_ak []
# barter_island_ak []
# white_plains_ny []
# hickory_nc ['hickory_nc']
# dallasfort_worth_tx ['dallas_tx']
# palm_springs_ca ['salinas_ca']
# gulfportbiloxi_ms ['gulfport_ms']
# greensborohigh_point_nc ['greensboro_nc']
# manchester_nh ['manchester_nh']
# rockford_il ['rockford_il']
# phoenix_az ['phoenix_az']
# madison_wi ['madison_wi', 'racine_wi']
# west_palm_beachpalm_beach_fl ['west_palm_beach_fl']
# mobile_al ['mobile_al']
# white_plains_ny []
# hagerstown_md ['hagerstown_md', 'easton_md']
# san_juan_pr []
# harlingensan_benito_tx []
# greensborohigh_point_nc ['greensboro_nc']
# rochester_ny ['rochester_ny']
# phoenix_az ['phoenix_az']
# ogden_ut ['ogden_ut', 'logan_ut']
# denver_co []
# huntsville_al ['huntsville_al']
# santa_ana_ca ['santa_ana_ca', 'santa_rosa_ca', 'santa_barbara_ca']
# bellingham_wa ['bellingham_wa', 'ellensburg_wa']
# buffalo_ny ['buffalo_ny']
# flint_mi ['flint_mi', 'lansing_mi']
# phoenix_az ['phoenix_az']
# st_george_ut ['st_george_ut', 'ogden_ut']
# las_vegas_nv ['las_vegas_nv']
# springfield_mo ['springfield_mo']
# st_petersburg_fl []
# bloomingtonnormal_il ['bloomington_il']
# akron_oh ['akron_oh', 'marion_oh', 'dayton_oh']
# columbia_sc ['columbia_sc']
# gulfportbiloxi_ms ['gulfport_ms']
# baltimore_md ['baltimore_md']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# honolulu_hi ['honolulu_hi', 'kahului_hi']
# akron_oh ['akron_oh', 'marion_oh', 'dayton_oh']
# gulfportbiloxi_ms ['gulfport_ms']
# melbourne_fl []
# portland_me ['portland_me', 'rockland_me']
# ogdensburg_ny ['ogdensburg_ny']
# sanford_fl ['orlando_fl']
# anchorage_ak ['anchorage_ak']
# granite_point_ak []
# kansas_city_mo ['kansas_city_mo']
# valparaiso_fl []
# kenai_ak ['ketchikan_ak']
# scammon_bay_ak []
# denver_co []
# manassas_va []
# los_angeles_ca ['los_angeles_ca']
# eagle_co []
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# flint_mi ['flint_mi', 'lansing_mi']
# islip_ny []
# portland_me ['portland_me', 'rockland_me']
# pellston_mi ['alpena_mi']
# sault_ste_marie_mi ['battle_creek_mi']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# flint_mi ['flint_mi', 'lansing_mi']
# albuquerque_nm ['albuquerque_nm']
# logan_ut ['logan_ut', 'ogden_ut']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# harrisburg_pa ['harrisburg_pa', 'pittsburgh_pa']
# punta_gorda_fl ['punta_gorda_fl', 'pensacola_fl']
# springfield_il ['springfield_il', 'sterling_il']
# alexandria_la ['alexandria_la']
# richmond_va ['richmond_va']
# dallasfort_worth_tx ['dallas_tx']
# columbia_mo ['columbia_mo', 'joplin_mo']
# lubbock_tx ['lubbock_tx']
# albuquerque_nm ['albuquerque_nm']
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# palm_springs_ca ['salinas_ca']
# houston_tx ['houston_tx', 'austin_tx']
# fayetteville_ar ['fayetteville_ar', 'batesville_ar', 'blytheville_ar']
# fairbanks_ak ['fairbanks_ak']
# anaktuvuk_pass_ak []
# minneapolis_mn ['minneapolis_mn']
# hibbing_mn []
# bullhead_city_az []
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# kotlik_ak ['kodiak_ak', 'ketchikan_ak']
# st_michael_ak []
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# albany_ga ['albany_ga', 'atlanta_ga', 'dalton_ga']
# louisville_ky ['madisonville_ky', 'danville_ky']
# dover_de ['dover_de']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# kirksville_mo ['kirksville_mo']
# philadelphia_pa ['philadelphia_pa']
# bedford_ma []
# providence_ri ['providence_ri']
# charlottesville_va ['charlottesville_va']
# louisville_ky ['madisonville_ky', 'danville_ky']
# bangor_me ['bangor_me']
# buffalo_ny ['buffalo_ny']
# cincinnati_oh ['cincinnati_oh']
# ketchikan_ak ['ketchikan_ak']
# hollis_ak []
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# mountain_view_ca []
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# shreveport_la ['shreveport_la']
# spokane_wa ['spokane_wa', 'port_angeles_wa', 'seattle_wa']
# bangor_me ['bangor_me']
# rockford_il ['rockford_il']
# san_bernardino_ca ['san_diego_ca', 'san_francisco_ca', 'santa_ana_ca']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# bullhead_city_az []
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# portland_me ['portland_me', 'rockland_me']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# newburghpoughkeepsie_ny ['poughkeepsie_ny']
# burlington_vt ['burlington_vt', 'bennington_vt']
# portland_me ['portland_me', 'rockland_me']
# chicago_il ['chicago_il', 'champaign_il']
# clarksburgfairmont_wv ['clarksburg_wv', 'parkersburg_wv']
# kansas_city_mo ['kansas_city_mo']
# chattanooga_tn ['chattanooga_tn']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# fort_wayne_in ['fort_wayne_in']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# del_rio_tx ['del_rio_tx', 'el_paso_tx', 'laredo_tx']
# greeneville_tn ['greeneville_tn', 'nashville_tn', 'knoxville_tn']
# waco_tx ['waco_tx', 'laredo_tx']
# madison_wi ['madison_wi', 'racine_wi']
# cedar_rapidsiowa_city_ia ['cedar_rapids_ia']
# chattanooga_tn ['chattanooga_tn']
# knoxville_tn ['knoxville_tn', 'nashville_tn', 'crossville_tn']
# bemidji_mn ['bemidji_mn']
# brainerd_mn ['brainerd_mn']
# albuquerque_nm ['albuquerque_nm']
# bullhead_city_az []
# springfield_mo ['springfield_mo']
# wichita_ks ['wichita_ks']
# tucson_az ['tucson_az']
# killeen_tx ['killeen_tx', 'abilene_tx', 'midland_tx']
# charlotte_nc ['charlotte_nc']
# key_west_fl ['key_west_fl', 'lake_city_fl']
# barrow_ak []
# nome_ak ['anchorage_ak', 'juneau_ak']
# fairbanks_ak ['fairbanks_ak']
# birch_creek_ak []
# albany_ny ['albany_ny']
# omaha_ne ['omaha_ne']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# altoona_pa ['altoona_pa', 'allentown_pa', 'scranton_pa']
# st_petersburg_fl []
# allentownbethlehemeaston_pa ['allentown_pa']
# denver_co []
# palm_springs_ca ['salinas_ca']
# st_petersburg_fl []
# kansas_city_mo ['kansas_city_mo']
# dallasfort_worth_tx ['dallas_tx']
# college_stationbryan_tx ['college_station_tx']
# pittsburgh_pa ['pittsburgh_pa', 'harrisburg_pa']
# little_rock_ar ['little_rock_ar']
# abilene_tx ['abilene_tx', 'killeen_tx', 'uvalde_tx']
# dallasfort_worth_tx ['dallas_tx']
# baltimore_md ['baltimore_md']
# johnstown_pa ['johnstown_pa', 'allentown_pa', 'scranton_pa']
# homer_ak ['anchorage_ak']
# unalakleet_ak []
# columbia_sc ['columbia_sc']
# ...
# indianapolis_in ['indianapolis_in']
# newark_nj ['newark_nj']
# denver_co []
# memphis_tn ['memphis_tn', 'paris_tn']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# anchorage_ak ['anchorage_ak']
# unalakleet_ak []
# houston_tx ['houston_tx', 'austin_tx']
# las_vegas_nv ['las_vegas_nv']
# philadelphia_pa ['philadelphia_pa']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# columbus_oh ['columbus_oh']
# denver_co []
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# philadelphia_pa ['philadelphia_pa']
# denver_co []
# new_york_ny ['new_york_ny']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# charlotte_nc ['charlotte_nc']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# minneapolis_mn ['minneapolis_mn']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# boston_ma ['boston_ma']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# las_vegas_nv ['las_vegas_nv']
# denver_co []
# louisville_ky ['madisonville_ky', 'danville_ky']
# memphis_tn ['memphis_tn', 'paris_tn']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# denver_co []
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# washington_dc ['washington_dc']
# baltimore_md ['baltimore_md']
# phoenix_az ['phoenix_az']
# oakland_ca ['oakland_ca', 'oxnard_ca', 'visalia_ca']
# minneapolis_mn ['minneapolis_mn']
# houston_tx ['houston_tx', 'austin_tx']
# dallasfort_worth_tx ['dallas_tx']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# dallasfort_worth_tx ['dallas_tx']
# phoenix_az ['phoenix_az']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# las_vegas_nv ['las_vegas_nv']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# baltimore_md ['baltimore_md']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# dallasfort_worth_tx ['dallas_tx']
# cleveland_oh ['cleveland_oh']
# memphis_tn ['memphis_tn', 'paris_tn']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# charlotte_nc ['charlotte_nc']
# baltimore_md ['baltimore_md']
# philadelphia_pa ['philadelphia_pa']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# memphis_tn ['memphis_tn', 'paris_tn']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# denver_co []
# ontario_ca ['oxnard_ca', 'santa_rosa_ca', 'el_centro_ca']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# denver_co []
# burbank_ca ['eureka_ca']
# denver_co []
# boston_ma ['boston_ma']
# new_york_ny ['new_york_ny']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# charlotte_nc ['charlotte_nc']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# los_angeles_ca ['los_angeles_ca']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# denver_co []
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# philadelphia_pa ['philadelphia_pa']
# kansas_city_mo ['kansas_city_mo']
# houston_tx ['houston_tx', 'austin_tx']
# phoenix_az ['phoenix_az']
# dallasfort_worth_tx ['dallas_tx']
# charlotte_nc ['charlotte_nc']
# las_vegas_nv ['las_vegas_nv']
# raleighdurham_nc ['raleigh_nc']
# memphis_tn ['memphis_tn', 'paris_tn']
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# houston_tx ['houston_tx', 'austin_tx']
# kansas_city_mo ['kansas_city_mo']
# chicago_il ['chicago_il', 'champaign_il']
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# memphis_tn ['memphis_tn', 'paris_tn']
# louisville_ky ['madisonville_ky', 'danville_ky']
# phoenix_az ['phoenix_az']
# chicago_il ['chicago_il', 'champaign_il']
# boston_ma ['boston_ma']
# dallasfort_worth_tx ['dallas_tx']
# miami_fl ['miami_fl', 'tampa_fl']
# las_vegas_nv ['las_vegas_nv']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# anchorage_ak ['anchorage_ak']
# barrow_ak []
# houston_tx ['houston_tx', 'austin_tx']
# san_jose_ca ['san_jose_ca', 'santa_rosa_ca', 'san_diego_ca']
# memphis_tn ['memphis_tn', 'paris_tn']
# philadelphia_pa ['philadelphia_pa']
# dallas_tx ['dallas_tx', 'eagle_pass_tx', 'midland_tx']
# las_vegas_nv ['las_vegas_nv']
# minneapolis_mn ['minneapolis_mn']
# memphis_tn ['memphis_tn', 'paris_tn']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# charlotte_nc ['charlotte_nc']
# memphis_tn ['memphis_tn', 'paris_tn']
# louisville_ky ['madisonville_ky', 'danville_ky']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# los_angeles_ca ['los_angeles_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# tucson_az ['tucson_az']
# phoenix_az ['phoenix_az']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# sacramento_ca ['sacramento_ca', 'el_centro_ca', 'fresno_ca']
# memphis_tn ['memphis_tn', 'paris_tn']
# columbus_oh ['columbus_oh']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# cleveland_oh ['cleveland_oh']
# denver_co []
# raleighdurham_nc ['raleigh_nc']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# las_vegas_nv ['las_vegas_nv']
# dallasfort_worth_tx ['dallas_tx']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# phoenix_az ['phoenix_az']
# seattle_wa ['seattle_wa', 'wenatchee_wa', 'moses_lake_wa']
# los_angeles_ca ['los_angeles_ca']
# phoenix_az ['phoenix_az']
# denver_co []
# hartford_ct ['hartford_ct']
# dallasfort_worth_tx ['dallas_tx']
# newark_nj ['newark_nj']
# chicago_il ['chicago_il', 'champaign_il']
# albuquerque_nm ['albuquerque_nm']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# washington_dc ['washington_dc']
# anchorage_ak ['anchorage_ak']
# toksook_ak ['kodiak_ak']
# denver_co []
# sacramento_ca ['sacramento_ca', 'el_centro_ca', 'fresno_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# memphis_tn ['memphis_tn', 'paris_tn']
# charlotte_nc ['charlotte_nc']
# denver_co []
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# phoenix_az ['phoenix_az']
# memphis_tn ['memphis_tn', 'paris_tn']
# indianapolis_in ['indianapolis_in']
# memphis_tn ['memphis_tn', 'paris_tn']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# memphis_tn ['memphis_tn', 'paris_tn']
# denver_co []
# minneapolis_mn ['minneapolis_mn']
# chicago_il ['chicago_il', 'champaign_il']
# chicago_il ['chicago_il', 'champaign_il']
# santa_ana_ca ['santa_ana_ca', 'santa_rosa_ca', 'santa_barbara_ca']
# denver_co []
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# denver_co []
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# dallasfort_worth_tx ['dallas_tx']
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# los_angeles_ca ['los_angeles_ca']
# oakland_ca ['oakland_ca', 'oxnard_ca', 'visalia_ca']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# charlotte_nc ['charlotte_nc']
# chicago_il ['chicago_il', 'champaign_il']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# houston_tx ['houston_tx', 'austin_tx']
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# denver_co []
# phoenix_az ['phoenix_az']
# charlotte_nc ['charlotte_nc']
# chicago_il ['chicago_il', 'champaign_il']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# providence_ri ['providence_ri']
# chicago_il ['chicago_il', 'champaign_il']
# washington_dc ['washington_dc']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# washington_dc ['washington_dc']
# denver_co []
# indianapolis_in ['indianapolis_in']
# memphis_tn ['memphis_tn', 'paris_tn']
# baltimore_md ['baltimore_md']
# denver_co []
# santa_ana_ca ['santa_ana_ca', 'santa_rosa_ca', 'santa_barbara_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# jacksonville_fl ['jacksonville_fl', 'gainesville_fl']
# dallasfort_worth_tx ['dallas_tx']
# columbus_oh ['columbus_oh']
# dallasfort_worth_tx ['dallas_tx']
# memphis_tn ['memphis_tn', 'paris_tn']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# denver_co []
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# el_paso_tx ['el_paso_tx', 'eagle_pass_tx', 'del_rio_tx']
# denver_co []
# san_francisco_ca ['san_francisco_ca', 'santa_ana_ca', 'san_diego_ca']
# phoenix_az ['phoenix_az']
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# new_york_ny ['new_york_ny']
# philadelphia_pa ['philadelphia_pa']
# houston_tx ['houston_tx', 'austin_tx']
# los_angeles_ca ['los_angeles_ca']
# chicago_il ['chicago_il', 'champaign_il']
# louisville_ky ['madisonville_ky', 'danville_ky']
# dallasfort_worth_tx ['dallas_tx']
# houston_tx ['houston_tx', 'austin_tx']
# denver_co []
# cleveland_oh ['cleveland_oh']
# los_angeles_ca ['los_angeles_ca']
# san_diego_ca ['san_diego_ca', 'san_jose_ca', 'san_francisco_ca']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# denver_co []
# las_vegas_nv ['las_vegas_nv']
# anchorage_ak ['anchorage_ak']
# kotlik_ak ['kodiak_ak', 'ketchikan_ak']
# chicago_il ['chicago_il', 'champaign_il']
# omaha_ne ['omaha_ne']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# birmingham_al ['birmingham_al']
# memphis_tn ['memphis_tn', 'paris_tn']
# washington_dc ['washington_dc']
# chicago_il ['chicago_il', 'champaign_il']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# chicago_il ['chicago_il', 'champaign_il']
# milwaukee_wi ['milwaukee_wi']
# memphis_tn ['memphis_tn', 'paris_tn']
# buffalo_ny ['buffalo_ny']
# washington_dc ['washington_dc']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# minneapolis_mn ['minneapolis_mn']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# san_jose_ca ['san_jose_ca', 'santa_rosa_ca', 'san_diego_ca']
# dallasfort_worth_tx ['dallas_tx']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# memphis_tn ['memphis_tn', 'paris_tn']
# houston_tx ['houston_tx', 'austin_tx']
# chicago_il ['chicago_il', 'champaign_il']
# kansas_city_mo ['kansas_city_mo']
# denver_co []
# los_angeles_ca ['los_angeles_ca']
# phoenix_az ['phoenix_az']
# portland_or ['portland_or', 'la_grande_or', 'albany_or']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# houston_tx ['houston_tx', 'austin_tx']
# dallasfort_worth_tx ['dallas_tx']
# denver_co []
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# denver_co []
# memphis_tn ['memphis_tn', 'paris_tn']
# phoenix_az ['phoenix_az']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# chicago_il ['chicago_il', 'champaign_il']
# dallasfort_worth_tx ['dallas_tx']
# chicago_il ['chicago_il', 'champaign_il']
# charlotte_nc ['charlotte_nc']
# las_vegas_nv ['las_vegas_nv']
# philadelphia_pa ['philadelphia_pa']
# las_vegas_nv ['las_vegas_nv']
# minneapolis_mn ['minneapolis_mn']
# phoenix_az ['phoenix_az']
# charlotte_nc ['charlotte_nc']
# houston_tx ['houston_tx', 'austin_tx']
# chicago_il ['chicago_il', 'champaign_il']
# charleston_sc ['charleston_sc', 'anderson_sc']
# chicago_il ['chicago_il', 'champaign_il']
# raleighdurham_nc ['raleigh_nc']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# indianapolis_in ['indianapolis_in']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# denver_co []
# chicago_il ['chicago_il', 'champaign_il']
# birmingham_al ['birmingham_al']
# dallasfort_worth_tx ['dallas_tx']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']
# denver_co []
# baltimore_md ['baltimore_md']
# anchorage_ak ['anchorage_ak']
# st_marys_ak []
# anchorage_ak ['anchorage_ak']
# bethel_ak []
# chicago_il ['chicago_il', 'champaign_il']
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# denver_co []
# salt_lake_city_ut ['salt_lake_city_ut', 'cedar_city_ut']
# chicago_il ['chicago_il', 'champaign_il']
# buffalo_ny ['buffalo_ny']
# memphis_tn ['memphis_tn', 'paris_tn']
# las_vegas_nv ['las_vegas_nv']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# dallasfort_worth_tx ['dallas_tx']
# baltimore_md ['baltimore_md']
# denver_co []
# new_orleans_la ['new_orleans_la', 'new_iberia_la', 'lake_charles_la']
# chicago_il ['chicago_il', 'champaign_il']
# columbus_oh ['columbus_oh']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# chicago_il ['chicago_il', 'champaign_il']
# denver_co []
# nashville_tn ['nashville_tn', 'shelbyville_tn', 'knoxville_tn']
# chicago_il ['chicago_il', 'champaign_il']
# houston_tx ['houston_tx', 'austin_tx']
# minneapolis_mn ['minneapolis_mn']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# newark_nj ['newark_nj']
# chicago_il ['chicago_il', 'champaign_il']
# chicago_il ['chicago_il', 'champaign_il']
# dallas_tx ['dallas_tx', 'eagle_pass_tx', 'midland_tx']
# houston_tx ['houston_tx', 'austin_tx']
# san_antonio_tx ['san_antonio_tx', 'san_angelo_tx']
# minneapolis_mn ['minneapolis_mn']
# denver_co []
# dallasfort_worth_tx ['dallas_tx']
# louisville_ky ['madisonville_ky', 'danville_ky']
# fort_lauderdale_fl ['fort_lauderdale_fl']
# chicago_il ['chicago_il', 'champaign_il']
# orlando_fl ['orlando_fl', 'ocala_fl', 'lakeland_fl']
# washington_dc ['washington_dc']
# chicago_il ['chicago_il', 'champaign_il']
# baltimore_md ['baltimore_md']
# chicago_il ['chicago_il', 'champaign_il']
# ontario_ca ['oxnard_ca', 'santa_rosa_ca', 'el_centro_ca']
# dallasfort_worth_tx ['dallas_tx']
# new_york_ny ['new_york_ny']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# denver_co []
# kansas_city_mo ['kansas_city_mo']
# chicago_il ['chicago_il', 'champaign_il']
# denver_co []
# minneapolis_mn ['minneapolis_mn']
# las_vegas_nv ['las_vegas_nv']
# charlotte_nc ['charlotte_nc']
# washington_dc ['washington_dc']
# dallasfort_worth_tx ['dallas_tx']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# new_york_ny ['new_york_ny']
# chicago_il ['chicago_il', 'champaign_il']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# houston_tx ['houston_tx', 'austin_tx']
# chicago_il ['chicago_il', 'champaign_il']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# chicago_il ['chicago_il', 'champaign_il']
# las_vegas_nv ['las_vegas_nv']
# chicago_il ['chicago_il', 'champaign_il']
# st_louis_mo ['st_louis_mo', 'st_joseph_mo']
# newark_nj ['newark_nj']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# philadelphia_pa ['philadelphia_pa']
# tampa_fl ['tampa_fl', 'ocala_fl', 'miami_fl']
# houston_tx ['houston_tx', 'austin_tx']
# denver_co []
# memphis_tn ['memphis_tn', 'paris_tn']
# chicago_il ['chicago_il', 'champaign_il']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# columbus_oh ['columbus_oh']
# houston_tx ['houston_tx', 'austin_tx']
# baltimore_md ['baltimore_md']
# philadelphia_pa ['philadelphia_pa']
# raleighdurham_nc ['raleigh_nc']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# kansas_city_mo ['kansas_city_mo']
# chicago_il ['chicago_il', 'champaign_il']
# oklahoma_city_ok ['oklahoma_city_ok', 'ponca_city_ok']
# denver_co []
# dallas_tx ['dallas_tx', 'eagle_pass_tx', 'midland_tx']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# louisville_ky ['madisonville_ky', 'danville_ky']
# chicago_il ['chicago_il', 'champaign_il']
# philadelphia_pa ['philadelphia_pa']
# charlotte_nc ['charlotte_nc']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# chicago_il ['chicago_il', 'champaign_il']
# detroit_mi ['detroit_mi', 'sturgis_mi']
# chicago_il ['chicago_il', 'champaign_il']
# san_jose_ca ['san_jose_ca', 'santa_rosa_ca', 'san_diego_ca']
# washington_dc ['washington_dc']
# denver_co []
# anchorage_ak ['anchorage_ak']
# kenai_ak ['ketchikan_ak']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# raleighdurham_nc ['raleigh_nc']
# memphis_tn ['memphis_tn', 'paris_tn']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# atlanta_ga ['atlanta_ga', 'albany_ga', 'valdosta_ga']
# philadelphia_pa ['philadelphia_pa']
# chicago_il ['chicago_il', 'champaign_il']
# sacramento_ca ['sacramento_ca', 'el_centro_ca', 'fresno_ca']
# chicago_il ['chicago_il', 'champaign_il']
# austin_tx ['austin_tx', 'houston_tx', 'abilene_tx']

# %%
data.to_pickle('/home/weihua/Research/Link_Dynamics/data/us_air_distance.pkl')

# %%
def removed_end(text):
    return '_'.join(text.split('_')[0:-2])

# %%
ranked_edges = pd.read_pickle('../data/ranked_edges.pkl').values.tolist()
ranked_edges = [tuple(i) for i in ranked_edges]

# %%
ranked_edges[0:2]
# Out:
# [('gulfportbiloxi_ms', 'springfield_mo'), ('sanford_fl', 'flint_mi')]

# %%
population  = pd.read_csv('../data/usa_population.csv',encoding='latin-1').sort_values(by='NAME')
population['NAME'] = population['NAME'].apply(text_to_id)
population['STNAME'] = population['STNAME'].apply(state_to_abbr)
population
# Out:
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 36175      61     27     111      0     100       0             1        A
# 67558      50     45       1      0       0       0             0        A
# 67287     162     45       0    100       0       0             0        A
# 1         162      1       0    124       0       0             0        A
# 27279     157     22     113    100       0       0             1        A
# 7425      157     13     315    184       0       0             1        A
# 5998      162     13       0    184       0       0             0        A
# 26595     162     22       0    100       0       0             0        A
# 759       157      1      67    124       0       0             1        A
# 67559     157     45       1    100       0       0             1        A
# 38526     157     28      71    100       0       0             1        A
# 38022     162     28       0    100       0       0             0        A
# 27769      61     23      21      0     100       0             1        A
# 79454      61     55      73      0     100       0             0        F
# 78194      61     55      19      0     100       0             0        F
# 77211     162     55       0    100       0       0             0        A
# 79455      71     55      73    100     100       0             1        A
# 79432     157     55      73    100       0       0             0        A
# 78180     157     55      19    100       0       0             0        A
# 78195      71     55      19    100     100       0             1        A
# 73319     157     48     217    100       0       0             1        A
# 71182     162     48       0    100       0       0             0        A
# 66122      61     42     105      0     108       0             1        A
# 61448     162     42       0    116       0       0             0        A
# 62477      71     42       1    116     116       0             1        A
# 62462     157     42       1    116       0       0             0        A
# 62476      61     42       1      0     116       0             0        F
# 24444     157     20     155    100       0       0             0        A
# 24519      71     20     155    100   77175       0             1        A
# 21268     162     20       0    100       0       0             0        A
# ...       ...    ...     ...    ...     ...     ...           ...      ...
# 37343      61     27     145      0   72256       0             1        A
# 53535      61     38      95      0   88220       0             1        A
# 16113      61     18      11      0   86372       0             0        F
# 15884     162     18       0  86372       0       0             0        A
# 16086     157     18      11  86372       0       0             0        A
# 16114      71     18      11  86372   86372       0             1        A
# 58988      71     39     157  88168   42182       0             1        A
# 58960     157     39     157  88168       0       0             0        A
# 54832     162     39       0  88168       0       0             0        A
# 5447      162     12       0  79250       0       0             0        A
# 5611      157     12      49  79250       0       0             1        A
# 14091      61     17     161      0   84246       0             0        A
# 37597      71     27     157  72310   72310       0             1        A
# 33417     162     27       0  72310       0       0             0        A
# 37557     157     27     157  72310       0       0             0        A
# 37596      61     27     157      0   72310       0             0        F
# 37595      61     27     157      0   72292       0             1        A
# 34782      71     27      49  72328   72328       0             1        A
# 33418     162     27       0  72328       0       0             0        A
# 34781      61     27      49      0   72328       0             0        F
# 34741     157     27      49  72328       0       0             0        A
# 34783      61     27      49      0   72346       0             1        A
# 21895     162     20       0  81025       0       0             0        A
# 24658     157     20     163  81025       0       0             0        A
# 24682      71     20     163  81025   71243       0             1        A
# 20052     162     19       0  87690       0       0             0        A
# 20433     157     19      61  87690       0       0             1        A
# 20641     157     19      97  87690       0       0             1        A
# 27198     157     22      85  83685       0       0             1        A
# 26898     162     22       0  83685       0       0             0        A
#
#                       NAME STNAME  ... POPESTIMATE2010  POPESTIMATE2011  \
# 36175      aastad_township     mn  ...             213              213
# 67558     abbeville_county     sc  ...           25328            25081
# 67287       abbeville_city     sc  ...            5233             5178
# 1           abbeville_city     al  ...            2699             2694
# 27279       abbeville_city     la  ...           12225            12181
# 7425        abbeville_city     ga  ...            2982             2951
# 5998        abbeville_city     ga  ...            2982             2951
# 26595       abbeville_city     la  ...           12225            12181
# 759         abbeville_city     al  ...            2699             2694
# 67559       abbeville_city     sc  ...            5233             5178
# 38526       abbeville_town     ms  ...             414              423
# 38022       abbeville_town     ms  ...             414              423
# 27769           abbot_town     me  ...             714              706
# 79454      abbotsford_city     wi  ...             678              684
# 78194      abbotsford_city     wi  ...            1621             1617
# 77211      abbotsford_city     wi  ...            2299             2301
# 79455   abbotsford_city_pt     wi  ...             678              684
# 79432   abbotsford_city_pt     wi  ...             678              684
# 78180   abbotsford_city_pt     wi  ...            1621             1617
# 78195   abbotsford_city_pt     wi  ...            1621             1617
# 73319          abbott_city     tx  ...             362              362
# 71182          abbott_city     tx  ...             362              362
# 66122      abbott_township     pa  ...             242              242
# 61448  abbottstown_borough     pa  ...            1011             1011
# 62477  abbottstown_borough     pa  ...            1011             1011
# 62462  abbottstown_borough     pa  ...            1011             1011
# 62476  abbottstown_borough     pa  ...            1011             1011
# 24444       abbyville_city     ks  ...              89               89
# 24519       abbyville_city     ks  ...              89               89
# 21268       abbyville_city     ks  ...              89               89
# ...                    ...    ...  ...             ...              ...
# 37343        zion_township     mn  ...             333              336
# 53535        zion_township     nd  ...              50               51
# 16113      zionsville_town     in  ...           24491            24550
# 15884      zionsville_town     in  ...           24491            24550
# 16086      zionsville_town     in  ...           24491            24550
# 16114      zionsville_town     in  ...           24491            24550
# 58988         zoar_village     oh  ...             169              171
# 58960         zoar_village     oh  ...             169              171
# 54832         zoar_village     oh  ...             169              171
# 5447    zolfo_springs_town     fl  ...            1805             1803
# 5611    zolfo_springs_town     fl  ...            1805             1803
# 14091        zuma_township     il  ...             755              755
# 37597    zumbro_falls_city     mn  ...             207              222
# 33417    zumbro_falls_city     mn  ...             207              222
# 37557    zumbro_falls_city     mn  ...             207              222
# 37596    zumbro_falls_city     mn  ...             207              222
# 37595      zumbro_township     mn  ...             727              723
# 34782        zumbrota_city     mn  ...            3281             3280
# 33418        zumbrota_city     mn  ...            3281             3280
# 34781        zumbrota_city     mn  ...            3281             3280
# 34741        zumbrota_city     mn  ...            3281             3280
# 34783    zumbrota_township     mn  ...             586              584
# 21895          zurich_city     ks  ...              99               99
# 24658          zurich_city     ks  ...              99               99
# 24682          zurich_city     ks  ...              99               99
# 20052         zwingle_city     ia  ...              90               90
# 20433      zwingle_city_pt     ia  ...              64               64
# 20641      zwingle_city_pt     ia  ...              26               26
# 27198          zwolle_town     la  ...            1983             1996
# 26898          zwolle_town     la  ...            1983             1996
#
#        POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# 36175              212              212              212              211
# 67558            25019            24899            24795            24796
# 67287             5162             5131             5109             5089
# 1                 2643             2628             2608             2600
# 27279            12326            12379            12356            12357
# 7425              2932             2933             2862             2929
# 5998              2932             2933             2862             2929
# 26595            12326            12379            12356            12357
# 759               2643             2628             2608             2600
# 67559             5162             5131             5109             5089
# 38526              429              428              425              428
# 38022              429              428              425              428
# 27769              702              698              692              684
# 79454              672              675              670              659
# 78194             1603             1603             1594             1591
# 77211             2275             2278             2264             2250
# 79455              672              675              670              659
# 79432              672              675              670              659
# 78180             1603             1603             1594             1591
# 78195             1603             1603             1594             1591
# 73319              361              355              354              354
# 71182              361              355              354              354
# 66122              243              242              237              236
# 61448             1008             1007             1010             1013
# 62477             1008             1007             1010             1013
# 62462             1008             1007             1010             1013
# 62476             1008             1007             1010             1013
# 24444               90               90               89               89
# 24519               90               90               89               89
# 21268               90               90               89               89
# ...                ...              ...              ...              ...
# 37343              336              340              344              347
# 53535               51               51               51               50
# 16113            25195            25994            26228            26648
# 15884            25195            25994            26228            26648
# 16086            25195            25994            26228            26648
# 16114            25195            25994            26228            26648
# 58988              173              175              177              177
# 58960              173              175              177              177
# 54832              173              175              177              177
# 5447              1782             1772             1771             1763
# 5611              1782             1772             1771             1763
# 14091              758              757              755              749
# 37597              230              239              239              239
# 33417              230              239              239              239
# 37557              230              239              239              239
# 37596              230              239              239              239
# 37595              722              724              725              720
# 34782             3299             3324             3335             3352
# 33418             3299             3324             3335             3352
# 34781             3299             3324             3335             3352
# 34741             3299             3324             3335             3352
# 34783              585              586              584              584
# 21895              100              100              100               99
# 24658              100              100              100               99
# 24682              100              100              100               99
# 20052               91               90               90               90
# 20433               65               65               65               65
# 20641               26               25               25               25
# 27198             1986             1979             1965             1972
# 26898             1986             1979             1965             1972
#
#        POPESTIMATE2016  POPESTIMATE2017  POPESTIMATE2018  POPESTIMATE2019
# 36175              212              212              213              213
# 67558            24657            24567            24587            24527
# 67287             5051             5035             5032             5014
# 1                 2584             2575             2571             2560
# 27279            12357            12246            12177            12038
# 7425              2767             2783             2800             2684
# 5998              2767             2783             2800             2684
# 26595            12357            12246            12177            12038
# 759               2584             2575             2571             2560
# 67559             5051             5035             5032             5014
# 38526              423              427              421              423
# 38022              423              427              421              423
# 27769              682              678              675              677
# 79454              653              652              656              640
# 78194             1592             1596             1597             1593
# 77211             2245             2248             2253             2233
# 79455              653              652              656              640
# 79432              653              652              656              640
# 78180             1592             1596             1597             1593
# 78195             1592             1596             1597             1593
# 73319              356              361              365              369
# 71182              356              361              365              369
# 66122              234              232              229              228
# 61448             1015             1021             1026             1026
# 62477             1015             1021             1026             1026
# 62462             1015             1021             1026             1026
# 62476             1015             1021             1026             1026
# 24444               88               86               85               85
# 24519               88               86               85               85
# 21268               88               86               85               85
# ...                ...              ...              ...              ...
# 37343              350              351              354              358
# 53535               51               50               49               49
# 16113            26895            27454            27941            28357
# 15884            26895            27454            27941            28357
# 16086            26895            27454            27941            28357
# 16114            26895            27454            27941            28357
# 58988              177              176              178              178
# 58960              177              176              178              178
# 54832              177              176              178              178
# 5447              1770             1786             1785             1773
# 5611              1770             1786             1785             1773
# 14091              745              739              735              731
# 37597              237              240              240              239
# 33417              237              240              240              239
# 37557              237              240              240              239
# 37596              237              240              240              239
# 37595              722              727              728              728
# 34782             3380             3410             3448             3501
# 33418             3380             3410             3448             3501
# 34781             3380             3410             3448             3501
# 34741             3380             3410             3448             3501
# 34783              585              585              583              581
# 21895               97               96               95               93
# 24658               97               96               95               93
# 24682               97               96               95               93
# 20052               91               91               91               92
# 20433               66               66               66               67
# 20641               25               25               25               25
# 27198             1957             1942             1939             1937
# 26898             1957             1942             1939             1937
#
# [81434 rows x 22 columns]

# %%
population = population[population.SUMLEV>=170]

# %%
population.head(20)
# Out:
#        SUMLEV  STATE  COUNTY  PLACE  COUSUB  CONCIT  PRIMGEO_FLAG FUNCSTAT  \
# 4653      170      9       0      0       0   47500             0        A
# 6536      170     13       0      0       0    3436             0        A
# 6537      170     13       0      0       0    4200             0        A
# 15885     170     18       0      0       0   36000             0        A
# 21896     170     20       0      0       0   28410             0        A
# 25833     170     21       0      0       0   48003             0        A
# 41720     170     30       0      0       0   11390             0        A
# 70602     170     47       0      0       0   52004             0        A
#
#                                                   NAME STNAME  ...  \
# 4653                                      milford_city     ct  ...
# 6536           athens-clarke_county_unified_government     ga  ...
# 6537   augusta-richmond_county_consolidated_government     ga  ...
# 15885                                indianapolis_city     in  ...
# 21896                greeley_county_unified_government     ks  ...
# 25833      louisvillejefferson_county_metro_government     ky  ...
# 41720                                 butte-silver_bow     mt  ...
# 70602       nashville-davidson_metropolitan_government     tn  ...
#
#       POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 4653            52797            52874            53054            53159
# 6536           117403           118229           119891           120888
# 6537           201115           200568           201742           201335
# 15885          830841           836991           844910           854203
# 21896            1190             1187             1199             1213
# 25833          742054           746361           751629           759183
# 41720           34230            34405            34474            34574
# 70602          627746           635918           649344           660179
#
#        POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# 4653             53487            53648            54065            54355
# 6536            120386           123561           124905           126815
# 6537            201287           201451           201949           201673
# 15885           859730           863319           868704           873179
# 21896             1231             1232             1208             1160
# 25833           761725           764946           767464           769828
# 41720            34752            34691            34696            34811
# 70602           669611           679793           685829           687159
#
#        POPESTIMATE2018  POPESTIMATE2019
# 4653             54697            54747
# 6536            127268           128331
# 6537            201667           202518
# 15885           880739           886220
# 21896             1163             1166
# 25833           768101           766757
# 41720            34739            34915
# 70602           690516           694144
#
# [8 rows x 22 columns]

# %%
list(population.NAME)
# Out:
# ['milford_city',
#  'athens-clarke_county_unified_government',
#  'augusta-richmond_county_consolidated_government',
#  'indianapolis_city',
#  'greeley_county_unified_government',
#  'louisvillejefferson_county_metro_government',
#  'butte-silver_bow',
#  'nashville-davidson_metropolitan_government']

# %%
city = data.source[10]
cities = list(population['NAME'])

# %%
get_close_matches(city[0:-3],cities)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-261cb3648f82> in <module>
#       1 from difflib import get_close_matches
# ----> 2 get_close_matches(city[0:-3],cities)
#
# NameError: name 'city' is not defined

# %%
population[population.NAME=='south_bend_city'].T
# Out:
#                              15789            18434            76204  \
# SUMLEV                         162              157              162
# STATE                           18               18               53
# COUNTY                           0              141                0
# PLACE                        71000            71000            65625
# COUSUB                           0                0                0
# CONCIT                           0                0                0
# PRIMGEO_FLAG                     0                0                0
# FUNCSTAT                         A                A                A
# NAME               south_bend_city  south_bend_city  south_bend_city
# STNAME                     Indiana          Indiana       Washington
# CENSUS2010POP               101168           101168             1637
# ESTIMATESBASE2010           101249           101249             1633
# POPESTIMATE2010             101197           101197             1631
# POPESTIMATE2011             101224           101224             1630
# POPESTIMATE2012             101056           101056             1609
# POPESTIMATE2013             101226           101226             1587
# POPESTIMATE2014             101489           101489             1592
# POPESTIMATE2015             101687           101687             1610
# POPESTIMATE2016             101996           101996             1636
# POPESTIMATE2017             102021           102021             1660
# POPESTIMATE2018             101971           101971             1677
# POPESTIMATE2019             102026           102026             1698
#
#                              76469
# SUMLEV                         157
# STATE                           53
# COUNTY                          49
# PLACE                        65625
# COUSUB                           0
# CONCIT                           0
# PRIMGEO_FLAG                     1
# FUNCSTAT                         A
# NAME               south_bend_city
# STNAME                  Washington
# CENSUS2010POP                 1637
# ESTIMATESBASE2010             1633
# POPESTIMATE2010               1631
# POPESTIMATE2011               1630
# POPESTIMATE2012               1609
# POPESTIMATE2013               1587
# POPESTIMATE2014               1592
# POPESTIMATE2015               1610
# POPESTIMATE2016               1636
# POPESTIMATE2017               1660
# POPESTIMATE2018               1677
# POPESTIMATE2019               1698

# %%
cities = list(population['NAME'])
out_data = {}
for key in set(list(data.source)+list(data.target)):
    city = key[0:-3]
    match = get_close_matches(city,cities)
    if len(match)>0:
        out_data[key]= (match[0],list(population[population.NAME==match[0]].POPESTIMATE2019)[0])
        print(key,match[0],list(population[population.NAME==match[0]].STNAME)[0],end='\n')
    else:
        out_data[key] = None
# Out:
# yakutat_ak akutan_city Alaska
# fairfield_ia fairfield_town Connecticut
# tupelo_ms tupelo_town Arkansas
# las_cruces_nm las_cruces_city New Mexico
# augustawaterville_me augusta_village Illinois
# augusta_ga augusta_town Missouri
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-bb3fe0c86aa4> in <module>
#       3 for key in set(list(data.source)+list(data.target)):
#       4     city = key[0:-3]
# ----> 5     match = get_close_matches(city,cities)
#       6     if len(match)>0:
#       7         out_data[key]= (match[0],list(population[population.NAME==match[0]].POPESTIMATE2019)[0])
#
# ~/anaconda3/lib/python3.6/difflib.py in get_close_matches(word, possibilities, n, cutoff)
#     726         if s.real_quick_ratio() >= cutoff and \
#     727            s.quick_ratio() >= cutoff and \
# --> 728            s.ratio() >= cutoff:
#     729             result.append((s.ratio(), x))
#     730
#
# ~/anaconda3/lib/python3.6/difflib.py in ratio(self)
#     642         """
#     643
# --> 644         matches = sum(triple[-1] for triple in self.get_matching_blocks())
#     645         return _calculate_ratio(matches, len(self.a) + len(self.b))
#     646
#
# ~/anaconda3/lib/python3.6/difflib.py in get_matching_blocks(self)
#     477         while queue:
#     478             alo, ahi, blo, bhi = queue.pop()
# --> 479             i, j, k = x = self.find_longest_match(alo, ahi, blo, bhi)
#     480             # a[alo:i] vs b[blo:j] unknown
#     481             # a[i:i+k] same as b[j:j+k]
#
# ~/anaconda3/lib/python3.6/difflib.py in find_longest_match(self, alo, ahi, blo, bhi)
#     408                 if j >= bhi:
#     409                     break
# --> 410                 k = newj2len[j] = j2lenget(j-1, 0) + 1
#     411                 if k > bestsize:
#     412                     besti, bestj, bestsize = i-k+1, j-k+1, k
#
# KeyboardInterrupt:

# %%
out_data
# Out:
# {'yakutat_ak': ('akutan_city', 'POPESTIMATE2019'),
#  'fairfield_ia': ('fairfield_town', 'POPESTIMATE2019'),
#  'tupelo_ms': ('tupelo_town', 'POPESTIMATE2019'),
#  'las_cruces_nm': ('las_cruces_city', 'POPESTIMATE2019'),
#  'augustawaterville_me': ('augusta_village', 'POPESTIMATE2019'),
#  'augusta_ga': ('augusta_town', 'POPESTIMATE2019'),
#  'fort_wayne_in': ('fort_wayne_city', 'POPESTIMATE2019'),
#  'nikolai_ak': ('nikolai_city', 'POPESTIMATE2019'),
#  'lynchburg_va': ('lynchburg_town', 'POPESTIMATE2019'),
#  'burlington_ia': ('burlington_town', 'POPESTIMATE2019'),
#  'mcgrath_ak': ('mcgrath_city', 'POPESTIMATE2019'),
#  'lopez_island_wa': ('louds_island_ut', 'POPESTIMATE2019'),
#  'may_creek_ak': ('sandy_creek_town', 'POPESTIMATE2019'),
#  'sun_valleyhaileyketchum_id': None,
#  'santa_ana_ca': ('santa_ana_city', 'POPESTIMATE2019'),
#  'savannah_ga': ('savannah_town', 'POPESTIMATE2019'),
#  'tenakee_ak': None,
#  'farewell_ak': ('farwell_city', 'POPESTIMATE2019'),
#  'fort_meade_md': ('fort_meade_city', 'POPESTIMATE2019'),
#  'red_lake_ak': ('red_lake_county', 'POPESTIMATE2019'),
#  'rogers_ar': ('rogers_town', 'POPESTIMATE2019'),
#  'nelson_lagoon_ak': ('nelson_town', 'POPESTIMATE2019'),
#  'cordova_ak': ('cordova_town', 'POPESTIMATE2019'),
#  'kerrville_tx': ('kerrville_city', 'POPESTIMATE2019'),
#  'martinsville_va': ('martin_village', 'POPESTIMATE2019'),
#  'scottsbluff_ne': ('scottsbluff_city', 'POPESTIMATE2019'),
#  'nondalton_ak': ('uniondale_town', 'POPESTIMATE2019'),
#  'koyuk_ak': ('koyuk_city', 'POPESTIMATE2019'),
#  'lazy_bay_ak': None,
#  'new_orleans_la': ('new_orleans_city', 'POPESTIMATE2019'),
#  'norfolk_va': ('norfolk_town', 'POPESTIMATE2019'),
#  'fort_myers_fl': ('fort_myers_city', 'POPESTIMATE2019'),
#  'durango_co': ('durango_city', 'POPESTIMATE2019'),
#  'hoquiam_wa': ('hoquiam_city', 'POPESTIMATE2019'),
#  'ofu_tt': None,
#  'oklahoma_city_ok': ('oklahoma_county', 'POPESTIMATE2019'),
#  'huntsville_al': ('huntsville_town', 'POPESTIMATE2019'),
#  'mt_pocono_pa': ('mount_pocono_borough', 'POPESTIMATE2019'),
#  'wendover_ut': ('wendover_city', 'POPESTIMATE2019'),
#  'kiluda_bay_ak': None,
#  'northampton_ma': ('northampton_town', 'POPESTIMATE2019'),
#  'la_crosse_wi': ('la_crosse_town', 'POPESTIMATE2019'),
#  'lawrence_ma': ('lawrence_town', 'POPESTIMATE2019'),
#  'westsound_wa': ('west_town', 'POPESTIMATE2019'),
#  'cape_may_nj': ('cape_may_city', 'POPESTIMATE2019'),
#  'las_vegas_nv': ('las_vegas_city', 'POPESTIMATE2019'),
#  'kalispell_mt': ('kalispell_city', 'POPESTIMATE2019'),
#  'princetonbluefield_wv': ('princeton', 'POPESTIMATE2019'),
#  'waterloo_ia': ('waterloo_town', 'POPESTIMATE2019'),
#  'crooked_creek_ak': ('crooked_creek_township', 'POPESTIMATE2019'),
#  'san_diego_ca': ('san_diego_city', 'POPESTIMATE2019'),
#  'wilmington_nc': ('willing_town', 'POPESTIMATE2019'),
#  'coffman_cove_ak': ('coffman_cove_city', 'POPESTIMATE2019'),
#  'seward_ak': ('seward_town', 'POPESTIMATE2019'),
#  'pensacola_fl': ('pensacola_town', 'POPESTIMATE2019'),
#  'kapalua_hi': ('kappa_village', 'POPESTIMATE2019'),
#  'gary_in': ('gary_city', 'POPESTIMATE2019'),
#  'kiavak_ak': None,
#  'delta_junction_ak': ('delta_junction_city', 'POPESTIMATE2019'),
#  'muskegon_mi': ('muskegon_city', 'POPESTIMATE2019'),
#  'niagara_falls_ny': ('niagara_falls_city', 'POPESTIMATE2019'),
#  'moab_ut': ('moab_city', 'POPESTIMATE2019'),
#  'merced_ca': ('merced_city', 'POPESTIMATE2019'),
#  'kalamazoo_mi': ('kalamazoo_city', 'POPESTIMATE2019'),
#  'champaignurbana_il': ('champaign_county', 'POPESTIMATE2019'),
#  'asheville_nc': ('ashley_village', 'POPESTIMATE2019'),
#  'fishers_island_ny': ('fisher_village', 'POPESTIMATE2019'),
#  'rangeley_me': ('rangeley_town', 'POPESTIMATE2019'),
#  'mayaguez_pr': None,
#  'erie_pa': ('erie_town', 'POPESTIMATE2019'),
#  'st_augustine_fl': ('st_augustine_city', 'POPESTIMATE2019'),
#  'muncieandersonnewcastle_in': None,
#  'monterey_ca': ('monterey_town', 'POPESTIMATE2019'),
#  'butler_pa': ('butler_town', 'POPESTIMATE2019'),
#  'point_hope_ak': ('point_hope_city', 'POPESTIMATE2019'),
#  'bendredmond_or': ('redmond_town', 'POPESTIMATE2019'),
#  'saltery_cove_ak': ('staley_town', 'POPESTIMATE2019'),
#  'northeast_cape_ak': ('northeast_slope_ut', 'POPESTIMATE2019'),
#  'greensborohigh_point_nc': ('greensboro_city', 'POPESTIMATE2019'),
#  'sheldon_point_ak': ('sheldon_city', 'POPESTIMATE2019'),
#  'white_plains_ny': ('white_plains_city', 'POPESTIMATE2019'),
#  'berlin_nh': ('berlin_town', 'POPESTIMATE2019'),
#  'kotzebue_ak': ('kotzebue_city', 'POPESTIMATE2019'),
#  'dahl_creek_ak': ('coal_creek_town', 'POPESTIMATE2019'),
#  'saratoga_springs_ny': ('saratoga_springs_city', 'POPESTIMATE2019'),
#  'dubuque_ia': ('dubuque_city', 'POPESTIMATE2019'),
#  'washington_pa': ('washington_town', 'POPESTIMATE2019'),
#  'great_barrington_ma': ('great_barrington_town', 'POPESTIMATE2019'),
#  'view_cove_ak': None,
#  'binghamton_ny': ('bingham_town', 'POPESTIMATE2019'),
#  'fresno_ca': ('fresno_city', 'POPESTIMATE2019'),
#  'juneau_ak': ('juneau_city', 'POPESTIMATE2019'),
#  'mosinee_wi': ('mosinee_town', 'POPESTIMATE2019'),
#  'morganton_nc': ('morgan_town', 'POPESTIMATE2019'),
#  'chefornak_ak': ('chefornak_city', 'POPESTIMATE2019'),
#  'albuquerque_nm': ('albuquerque_city', 'POPESTIMATE2019'),
#  'syracuse_ny': ('syracuse_town', 'POPESTIMATE2019'),
#  'pope_vanoy_ak': ('pope_county', 'POPESTIMATE2019'),
#  'memphis_tn': ('memphis_town', 'POPESTIMATE2019'),
#  'stockton_ca': ('stockton_town', 'POPESTIMATE2019'),
#  'altoona_pa': ('alto_town', 'POPESTIMATE2019'),
#  'medford_or': ('medford_town', 'POPESTIMATE2019'),
#  'morristown_nj': ('morris_town', 'POPESTIMATE2019'),
#  'twin_hills_ak': ('twin_hill_township', 'POPESTIMATE2019'),
#  'sylacauga_al': ('sylacauga_city', 'POPESTIMATE2019'),
#  'astoriaseaside_or': ('astoria_city', 'POPESTIMATE2019'),
#  'durant_ok': ('durant_city', 'POPESTIMATE2019'),
#  'gaithersburg_md': ('gaithersburg_city', 'POPESTIMATE2019'),
#  'whitmore_az': ('whittemore_city', 'POPESTIMATE2019'),
#  'mesquite_tx': ('mesquite_city', 'POPESTIMATE2019'),
#  'latrobe_pa': ('latrobe_borough', 'POPESTIMATE2019'),
#  'marble_canyon_az': ('marble_city_town', 'POPESTIMATE2019'),
#  'guam_tt': None,
#  'kalskag_ak': ('kalkaska_village', 'POPESTIMATE2019'),
#  'nulato_ak': ('nucla_town', 'POPESTIMATE2019'),
#  'topeka_ks': ('topeka_town', 'POPESTIMATE2019'),
#  'hawthorne_ca': ('hawthorne_town', 'POPESTIMATE2019'),
#  'goodyear_az': ('goodyear_city', 'POPESTIMATE2019'),
#  'gainesville_tx': ('gaines_village', 'POPESTIMATE2019'),
#  'colorado_city_az': ('colorado_county', 'POPESTIMATE2019'),
#  'chevak_ak': ('chevak_city', 'POPESTIMATE2019'),
#  'ocean_city_nj': ('olean_city', 'POPESTIMATE2019'),
#  'mitchell_sd': ('mitchell_ut', 'POPESTIMATE2019'),
#  'holy_cross_ak': ('holy_cross_city', 'POPESTIMATE2019'),
#  'glendale_az': ('glendale_town', 'POPESTIMATE2019'),
#  'lebanon-hanover_nh': ('lebanon_village', 'POPESTIMATE2019'),
#  'newport_newshampton_va': ('newport_news_city', 'POPESTIMATE2019'),
#  'toledo_oh': ('toledo_city', 'POPESTIMATE2019'),
#  'marquette_mi': ('marquette_town', 'POPESTIMATE2019'),
#  'lewiston_id': ('lewis_town', 'POPESTIMATE2019'),
#  'scrantonwilkes-barre_pa': ('wilkes-barre_city', 'POPESTIMATE2019'),
#  'watertown_sd': ('waite_town', 'POPESTIMATE2019'),
#  'shageluk_ak': ('shageluk_city', 'POPESTIMATE2019'),
#  'aspen_co': ('aspen_city', 'POPESTIMATE2019'),
#  'shishmaref_ak': ('shishmaref_city', 'POPESTIMATE2019'),
#  'glens_falls_ny': ('glens_falls_city', 'POPESTIMATE2019'),
#  'anderson_sc': ('andes_town', 'POPESTIMATE2019'),
#  'leesburg_fl': ('leesburg_town', 'POPESTIMATE2019'),
#  'brainerd_mn': ('brainerd_city', 'POPESTIMATE2019'),
#  'los_angeles_ca': ('los_angeles_city', 'POPESTIMATE2019'),
#  'show_low_az': ('show_low_city', 'POPESTIMATE2019'),
#  'port_alexander_ak': ('port_alexander_city', 'POPESTIMATE2019'),
#  'bay_city_tx': ('bay_city', 'POPESTIMATE2019'),
#  'kalaupapa_hi': None,
#  'westfield_ma': ('westfield_town', 'POPESTIMATE2019'),
#  'tanana_ak': ('tanana_city', 'POPESTIMATE2019'),
#  'bullhead_city_az': ('bellmead_city', 'POPESTIMATE2019'),
#  'port_graham_ak': None,
#  'butte_mt': ('butte_city', 'POPESTIMATE2019'),
#  'hooper_bay_ak': ('hooper_bay_city', 'POPESTIMATE2019'),
#  'teterboro_nj': ('exeter_borough', 'POPESTIMATE2019'),
#  'fulton_ny': ('ulm_town', 'POPESTIMATE2019'),
#  'pendleton_or': ('pendleton_town', 'POPESTIMATE2019'),
#  'toksook_ak': ('toksook_bay_city', 'POPESTIMATE2019'),
#  'waterfall_ak': ('waterman_village', 'POPESTIMATE2019'),
#  'kenosha_wi': ('kenosha_city', 'POPESTIMATE2019'),
#  'rocky_mount_nc': ('rock_county', 'POPESTIMATE2019'),
#  'mccook_ne': ('mccook_city', 'POPESTIMATE2019'),
#  'manchester_nh': ('manchester_town', 'POPESTIMATE2019'),
#  'blacksburg_va': ('blacksburg_town', 'POPESTIMATE2019'),
#  'gainesville_ga': ('gaines_village', 'POPESTIMATE2019'),
#  'port_bailey_ak': ('port_allen_city', 'POPESTIMATE2019'),
#  'des_moines_ia': ('des_moines_city', 'POPESTIMATE2019'),
#  'smyrna_tn': ('smyrna_town', 'POPESTIMATE2019'),
#  'huslia_ak': ('huslia_city', 'POPESTIMATE2019'),
#  'panama_city_fl': ('panama_city', 'POPESTIMATE2019'),
#  'ugashik_ak': None,
#  'tyonek_ak': None,
#  'flint_mi': ('flint_city', 'POPESTIMATE2019'),
#  'rampart_ak': ('miramar_city', 'POPESTIMATE2019'),
#  'port_williams_ak': ('port_william_village', 'POPESTIMATE2019'),
#  'minneapolisst_paul_mn': ('minneapolis_city', 'POPESTIMATE2019'),
#  'parkersburg_wv': ('parkersburg_city', 'POPESTIMATE2019'),
#  'hillsboro_or': ('hillsboro_town', 'POPESTIMATE2019'),
#  'plymouth_ma': ('plymouth_town', 'POPESTIMATE2019'),
#  'ticonderoga_ny': ('ticonderoga_town', 'POPESTIMATE2019'),
#  'lanai_hi': ('luana_city', 'POPESTIMATE2019'),
#  'madisonville_ky': ('madison_village', 'POPESTIMATE2019'),
#  'pascokennewickrichland_wa': None,
#  'deering_ak': ('deering_town', 'POPESTIMATE2019'),
#  'oxnardventura_ca': ('aventura_city', 'POPESTIMATE2019'),
#  'wichita_ks': ('wichita_city', 'POPESTIMATE2019'),
#  'unalaska_ak': ('unalaska_city', 'POPESTIMATE2019'),
#  'buckland_ak': ('buckland_town', 'POPESTIMATE2019'),
#  'bar_harbor_me': ('bar_harbor_town', 'POPESTIMATE2019'),
#  'concord_nc': ('concord_town', 'POPESTIMATE2019'),
#  'gold_king__ak': ('gooding_city', 'POPESTIMATE2019'),
#  'baton_rouge_la': ('baton_rouge_city', 'POPESTIMATE2019'),
#  'point_lay_ak': ('point_city', 'POPESTIMATE2019'),
#  'borniteruby_creek_ak': ('otter_creek_town', 'POPESTIMATE2019'),
#  'ivotuk_ak': None,
#  'sitka_ak': None,
#  'allentownbethlehemeaston_pa': ('bethlehem_town', 'POPESTIMATE2019'),
#  'chicken_ak': ('hinckley_town', 'POPESTIMATE2019'),
#  'danger_bay_ak': ('sanger_city', 'POPESTIMATE2019'),
#  'terre_haute_in': ('terre_haute_city', 'POPESTIMATE2019'),
#  'tacoma_wa': ('tacoma_city', 'POPESTIMATE2019'),
#  'montrosedelta_co': ('montrose_town', 'POPESTIMATE2019'),
#  'blue_bell_pa': ('blue_hill_town', 'POPESTIMATE2019'),
#  'poughkeepsie_ny': ('poughkeepsie_town', 'POPESTIMATE2019'),
#  'powell_wy': ('powell_town', 'POPESTIMATE2019'),
#  'saipan_tt': None,
#  'hays_ks': ('hays_city', 'POPESTIMATE2019'),
#  'karluk_portage_ak': ('arkport_village', 'POPESTIMATE2019'),
#  'rock_hill_sc': ('rock_hill_city', 'POPESTIMATE2019'),
#  'lubbock_tx': ('lubbock_city', 'POPESTIMATE2019'),
#  'metlakatla_ak': None,
#  'fort_worth_tx': ('fort_worth_city', 'POPESTIMATE2019'),
#  'madison_wi': ('madison_town', 'POPESTIMATE2019'),
#  'everett_wa': ('everett_city', 'POPESTIMATE2019'),
#  'missionmcallenedinburg_tx': None,
#  'fairbanksft_wainwright_ak': ('fairbanks_city', 'POPESTIMATE2019'),
#  'ontario_ca': ('ontario_town', 'POPESTIMATE2019'),
#  'corpus_christi_tx': ('corpus_christi_city', 'POPESTIMATE2019'),
#  'rockford_il': ('rockford_town', 'POPESTIMATE2019'),
#  'waukegan_il': ('waukegan_city', 'POPESTIMATE2019'),
#  'tulsa_ok': ('tulsa_city', 'POPESTIMATE2019'),
#  'craig_ak': ('craig_city', 'POPESTIMATE2019'),
#  'dowagiac_mi': ('dowagiac_city', 'POPESTIMATE2019'),
#  'clear_lake_ca': ('clear_lake_town', 'POPESTIMATE2019'),
#  'hogatza_ak': None,
#  'traverse_city_mi': ('traer_city', 'POPESTIMATE2019'),
#  'marshall_mn': ('marshall_town', 'POPESTIMATE2019'),
#  'hydaburg_ak': ('hydaburg_city', 'POPESTIMATE2019'),
#  'rhinelander_wi': ('rhinelander_city', 'POPESTIMATE2019'),
#  'homestead_fl': ('homestead_town', 'POPESTIMATE2019'),
#  'pueblo_co': ('pueblo_city', 'POPESTIMATE2019'),
#  'albany_ny': ('albany_town', 'POPESTIMATE2019'),
#  'edgartown_ma': ('eagar_town', 'POPESTIMATE2019'),
#  'saginawbay_citymidland_mi': ('saginaw_city', 'POPESTIMATE2019'),
#  'sparta_tn': ('sparta_town', 'POPESTIMATE2019'),
#  'bangor_me': ('bangor_town', 'POPESTIMATE2019'),
#  'circle_ak': ('circle_town', 'POPESTIMATE2019'),
#  'hyannis_ma': ('hyannis_village', 'POPESTIMATE2019'),
#  'eau_claire_wi': ('eau_claire_city', 'POPESTIMATE2019'),
#  'killeen_tx': ('killeen_city', 'POPESTIMATE2019'),
#  'montpelierbarre_vt': ('montpelier_village', 'POPESTIMATE2019'),
#  'norwich_ny': ('norwich_town', 'POPESTIMATE2019'),
#  'ocala_fl': ('ocala_city', 'POPESTIMATE2019'),
#  'hattiesburglaurel_ms': ('hattiesburg_city', 'POPESTIMATE2019'),
#  'hibbing_mn': ('hibbing_city', 'POPESTIMATE2019'),
#  'camp_douglas_wi': ('camp_douglas_village', 'POPESTIMATE2019'),
#  'washington_dc': ('washington_town', 'POPESTIMATE2019'),
#  'bakersfield_ca': ('bakersfield_town', 'POPESTIMATE2019'),
#  'glendive_mt': ('glendive_city', 'POPESTIMATE2019'),
#  'new_bedfordfall_river_ma': ('new_bedford_city', 'POPESTIMATE2019'),
#  'poplar_bluff_mo': ('poplar_bluff_city', 'POPESTIMATE2019'),
#  'escanaba_mi': ('escanaba_city', 'POPESTIMATE2019'),
#  'koyukuk_ak': ('koyukuk_city', 'POPESTIMATE2019'),
#  'eugene_or': ('eugene_city', 'POPESTIMATE2019'),
#  'reno_nv': ('reno_city', 'POPESTIMATE2019'),
#  'roanoke_va': ('roanoke_town', 'POPESTIMATE2019'),
#  'newport_newswilliamsburg_va': ('newport_village', 'POPESTIMATE2019'),
#  'roswell_nm': ('roswell_city', 'POPESTIMATE2019'),
#  'farmington_nm': ('farmington_town', 'POPESTIMATE2019'),
#  'skaneateles_ny': ('skaneateles_town', 'POPESTIMATE2019'),
#  'gustavus_ak': ('gustavus_city', 'POPESTIMATE2019'),
#  'college_stationbryan_tx': ('college_station_city', 'POPESTIMATE2019'),
#  'terrell_tx': ('terrell_city', 'POPESTIMATE2019'),
#  'goodnews_bay_ak': ('goodnews_bay_city', 'POPESTIMATE2019'),
#  'kamuela_hi': None,
#  'hilo_hi': ('hill_town', 'POPESTIMATE2019'),
#  'cullman_al': ('cullman_city', 'POPESTIMATE2019'),
#  'levelock_ak': ('lovelock_city', 'POPESTIMATE2019'),
#  'clovis_nm': ('clovis_city', 'POPESTIMATE2019'),
#  'el_paso_tx': ('el_paso_town', 'POPESTIMATE2019'),
#  'greeneville_tn': ('greene_village', 'POPESTIMATE2019'),
#  'tucumcari_nm': ('tucumcari_city', 'POPESTIMATE2019'),
#  'watsonville_ca': ('watson_village', 'POPESTIMATE2019'),
#  'chuathbaluk_ak': ('chuathbaluk_city', 'POPESTIMATE2019'),
#  'wisconsin_rapids_wi': ('wisconsin_rapids_city', 'POPESTIMATE2019'),
#  'mountain_home_id': ('mountain_home_city', 'POPESTIMATE2019'),
#  'kobuk_ak': ('kobuk_city', 'POPESTIMATE2019'),
#  'valparaiso_in': ('valparaiso_city', 'POPESTIMATE2019'),
#  'riverside_ca': ('riverside_town', 'POPESTIMATE2019'),
#  'moser_bay_ak': ('mosier_city', 'POPESTIMATE2019'),
#  'san_juan_pr': ('san_juan_city', 'POPESTIMATE2019'),
#  'ponce_pr': None,
#  'petersburg_ak': ('petersburg_town', 'POPESTIMATE2019'),
#  'palm_springs_ca': ('palm_springs_city', 'POPESTIMATE2019'),
#  'jamestown_nd': ('ames_town', 'POPESTIMATE2019'),
#  'islip_ny': ('islip_town', 'POPESTIMATE2019'),
#  'mount_vernon_oh': ('mount_vernon_town', 'POPESTIMATE2019'),
#  'atqasuk_ak': ('atqasuk_city', 'POPESTIMATE2019'),
#  'seattle_wa': ('seattle_city', 'POPESTIMATE2019'),
#  'kingston_ny': ('king_town', 'POPESTIMATE2019'),
#  'wake_island_tt': ('oak_island_town', 'POPESTIMATE2019'),
#  'iliamna_ak': ('williams_town', 'POPESTIMATE2019'),
#  'north_kingstown_ri': ('north_kingstown_town', 'POPESTIMATE2019'),
#  'charlestondunbar_wv': ('charleston_county', 'POPESTIMATE2019'),
#  'beverly_ma': ('beverly_town', 'POPESTIMATE2019'),
#  'calexico_ca': ('calexico_city', 'POPESTIMATE2019'),
#  'hickory_nc': ('hickory_town', 'POPESTIMATE2019'),
#  'venice_fl': ('venice_town', 'POPESTIMATE2019'),
#  'cold_bay_ak': ('cold_bay_city', 'POPESTIMATE2019'),
#  'napakiak_ak': ('napakiak_city', 'POPESTIMATE2019'),
#  'new_york_ny': ('new_york_city', 'POPESTIMATE2019'),
#  'great_bend_ks': ('great_bend_city', 'POPESTIMATE2019'),
#  'branson_mo': ('branson_town', 'POPESTIMATE2019'),
#  'wolf_point_mt': ('wolf_point_city', 'POPESTIMATE2019'),
#  'west_palm_beach_fl': ('west_palm_beach_city', 'POPESTIMATE2019'),
#  'birch_creek_ak': ('birch_creek_town', 'POPESTIMATE2019'),
#  'rochester_mn': ('rochester_town', 'POPESTIMATE2019'),
#  'nantucket_ma': ('nantucket_town', 'POPESTIMATE2019'),
#  'kwigillingok_ak': ('willing_town', 'POPESTIMATE2019'),
#  'hallo_bay_ak': ('hallock_city', 'POPESTIMATE2019'),
#  'appleton_wi': ('maple_town', 'POPESTIMATE2019'),
#  'st_paul_ak': ('st_paul_town', 'POPESTIMATE2019'),
#  'salina_ks': ('salina_town', 'POPESTIMATE2019'),
#  'dover-cheswold_de': None,
#  'lexington_parsons_tn': ('lexington_town', 'POPESTIMATE2019'),
#  'elko_nv': ('elk_town', 'POPESTIMATE2019'),
#  'millbrook_ny': ('millbrook_city', 'POPESTIMATE2019'),
#  'dodge_city_ks': ('dodge_city', 'POPESTIMATE2019'),
#  'melbourne_fl': ('melbourne_city', 'POPESTIMATE2019'),
#  'statesville_nc': ('statesville_city', 'POPESTIMATE2019'),
#  'sitkinak_ak': None,
#  'wenatchee_wa': ('wenatchee_city', 'POPESTIMATE2019'),
#  'marco_island_fl': ('marco_island_city', 'POPESTIMATE2019'),
#  'onion_bay_ak': ('union_city', 'POPESTIMATE2019'),
#  'alakanuk_ak': ('alakanuk_city', 'POPESTIMATE2019'),
#  'orlando_fl': ('orland_town', 'POPESTIMATE2019'),
#  'camp_orkila_eastsound_wa': ('camp_hill_town', 'POPESTIMATE2019'),
#  'shaktoolik_ak': ('shaktoolik_city', 'POPESTIMATE2019'),
#  'plattsburgh_ny': ('plattsburgh_town', 'POPESTIMATE2019'),
#  'dora_bay_ak': ('dora_city', 'POPESTIMATE2019'),
#  'seldovia_ak': ('seldovia_city', 'POPESTIMATE2019'),
#  'smithfield_ri': ('smithfield_town', 'POPESTIMATE2019'),
#  'marshall_tx': ('marshall_town', 'POPESTIMATE2019'),
#  'ehpriam_wi': None,
#  'rochester_ny': ('rochester_town', 'POPESTIMATE2019'),
#  'pellston_mi': ('wells_town', 'POPESTIMATE2019'),
#  'portland_or': ('portland_town', 'POPESTIMATE2019'),
#  'dickinson_nd': ('dickinson_town', 'POPESTIMATE2019'),
#  'alton_il': ('yale_town', 'POPESTIMATE2019'),
#  'big_bay_ak': ('big_lake_city', 'POPESTIMATE2019'),
#  'chignik_ak': ('chignik_city', 'POPESTIMATE2019'),
#  'chicago_il': ('chicago_city', 'POPESTIMATE2019'),
#  'college_park_md': ('college_park_city', 'POPESTIMATE2019'),
#  'great_falls_mt': ('great_falls_town', 'POPESTIMATE2019'),
#  'larsen_bay_ak': ('larsen_bay_city', 'POPESTIMATE2019'),
#  'sanford_me': ('sanford_town', 'POPESTIMATE2019'),
#  'billings_mt': ('billings_town', 'POPESTIMATE2019'),
#  'houston_tx': ('houston_town', 'POPESTIMATE2019'),
#  'culebra_pr': None,
#  'oxford_me': ('oxford_town', 'POPESTIMATE2019'),
#  'olga_bay_ak': ('volga_city', 'POPESTIMATE2019'),
#  'georgetown_tx': ('gore_town', 'POPESTIMATE2019'),
#  'healy_ak': None,
#  'morrisville_vt': ('morris_village', 'POPESTIMATE2019'),
#  'cincinnati_oh': ('cincinnati_city', 'POPESTIMATE2019'),
#  'west_yellowstone_mt': ('west_yellowstone_town', 'POPESTIMATE2019'),
#  'ashland_wv': ('ashland_town', 'POPESTIMATE2019'),
#  'athens_oh': ('athens_town', 'POPESTIMATE2019'),
#  'perryville_ak': ('perry_village', 'POPESTIMATE2019'),
#  'jackson_wy': ('jackson_town', 'POPESTIMATE2019'),
#  'whitefield_nh': ('whitefield_town', 'POPESTIMATE2019'),
#  'takotna_ak': ('taos_town', 'POPESTIMATE2019'),
#  'fitchburg_ma': ('fitchburg_city', 'POPESTIMATE2019'),
#  'thermal_ca': None,
#  'bradford_pa': ('bradford_town', 'POPESTIMATE2019'),
#  'katmai_lodge_ak': None,
#  'atmautluak_ak': None,
#  'keene_nh': ('keene_town', 'POPESTIMATE2019'),
#  'togiak_ak': ('togiak_city', 'POPESTIMATE2019'),
#  'tatalina_ak': ('castalia_ut', 'POPESTIMATE2019'),
#  'poulsbo_wa': ('poulsbo_city', 'POPESTIMATE2019'),
#  'port_moller_ak': ('port_hope_village', 'POPESTIMATE2019'),
#  'gerlach_nv': None,
#  'frankfort_ky': ('frankfort_town', 'POPESTIMATE2019'),
#  'brooks_lodge_ak': ('brooks_town', 'POPESTIMATE2019'),
#  'lihue_hi': None,
#  'stuart_fl': ('stuart_town', 'POPESTIMATE2019'),
#  'columbus_oh': ('columbus_town', 'POPESTIMATE2019'),
#  'candle_ak': ('chandler_town', 'POPESTIMATE2019'),
#  'half_moon_bay_ca': ('half_moon_bay_city', 'POPESTIMATE2019'),
#  'baltimore_md': ('baltimore_town', 'POPESTIMATE2019'),
#  'aurora_or': ('aurora_town', 'POPESTIMATE2019'),
#  'lafayette_la': ('lafayette_town', 'POPESTIMATE2019'),
#  'false_pass_ak': ('false_pass_city', 'POPESTIMATE2019'),
#  'sugar_land_tx': ('sugar_land_city', 'POPESTIMATE2019'),
#  'schenectady_ny': ('schenectady_city', 'POPESTIMATE2019'),
#  'goldsboro_nc': ('goldsboro_town', 'POPESTIMATE2019'),
#  'buffalo_ny': ('buffalo_town', 'POPESTIMATE2019'),
#  'brevig_mission_ak': ('brevig_mission_city', 'POPESTIMATE2019'),
#  'egegik_ak': ('egegik_city', 'POPESTIMATE2019'),
#  'page_az': ('page_city', 'POPESTIMATE2019'),
#  'hornell_ny': ('hornell_city', 'POPESTIMATE2019'),
#  'gainesville_fl': ('gaines_village', 'POPESTIMATE2019'),
#  'thief_river_falls_mn': ('thief_river_falls_city', 'POPESTIMATE2019'),
#  'long_island_ak': ('long_island_town', 'POPESTIMATE2019'),
#  'west_chester_pa': ('west_chester_city', 'POPESTIMATE2019'),
#  'wrangell_ak': ('orange_village', 'POPESTIMATE2019'),
#  'waukesha_wi': ('waukesha_town', 'POPESTIMATE2019'),
#  'del_rio_tx': ('del_rio_city', 'POPESTIMATE2019'),
#  'monroe_ga': ('monroe_town', 'POPESTIMATE2019'),
#  'belleville_il': ('belleville_city', 'POPESTIMATE2019'),
#  'unalakleet_ak': ('unalakleet_city', 'POPESTIMATE2019'),
#  'providence_ri': ('providence_town', 'POPESTIMATE2019'),
#  'carbondale_il': ('carbondale_town', 'POPESTIMATE2019'),
#  'el_dorado_ar': ('el_dorado_city', 'POPESTIMATE2019'),
#  'emmonak_ak': ('emmonak_city', 'POPESTIMATE2019'),
#  'central_ak': ('central_town', 'POPESTIMATE2019'),
#  'seal_bay_ak': ('seal_beach_city', 'POPESTIMATE2019'),
#  'middlebury_vt': ('middlebury_town', 'POPESTIMATE2019'),
#  'fort_pierce_fl': ('fort_pierce_city', 'POPESTIMATE2019'),
#  'pullman_wa': ('pullman_town', 'POPESTIMATE2019'),
#  'murray_ky': ('murray_town', 'POPESTIMATE2019'),
#  'rock_springs_wy': ('rock_springs_city', 'POPESTIMATE2019'),
#  'mary_esther_fl': ('mary_esther_city', 'POPESTIMATE2019'),
#  'sussex_nj': ('sussex_county', 'POPESTIMATE2019'),
#  'block_island_ri': ('rock_island_town', 'POPESTIMATE2019'),
#  'hopkinsville_ky': ('hopkins_village', 'POPESTIMATE2019'),
#  'marion_in': ('marie_town', 'POPESTIMATE2019'),
#  'newtok_ak': ('newry_town', 'POPESTIMATE2019'),
#  'tullahoma_tn': ('tullahoma_city', 'POPESTIMATE2019'),
#  'akun_ak': None,
#  'napa_ca': ('napa_city', 'POPESTIMATE2019'),
#  'wichita_falls_tx': ('wichita_falls_city', 'POPESTIMATE2019'),
#  'jamestown_ny': ('ames_town', 'POPESTIMATE2019'),
#  'illinois_creek_ak': ('williams_creek_town', 'POPESTIMATE2019'),
#  'drift_river_ak': ('priest_river_city', 'POPESTIMATE2019'),
#  'port_angeles_wa': ('port_angeles_city', 'POPESTIMATE2019'),
#  'vieques_pr': None,
#  'angoon_ak': ('bangor_town', 'POPESTIMATE2019'),
#  'kivalina_ak': ('kivalina_city', 'POPESTIMATE2019'),
#  'kenmore_wa': ('kenmore_city', 'POPESTIMATE2019'),
#  'chalkyitsik_ak': None,
#  'beaufort_sc': ('beaufort_town', 'POPESTIMATE2019'),
#  'stevens_point_wi': ('stevens_point_city', 'POPESTIMATE2019'),
#  'caldwell_nj': ('caldwell_town', 'POPESTIMATE2019'),
#  'kahului_hi': ('kahlotus_city', 'POPESTIMATE2019'),
#  'ambler_ak': ('ambler_city', 'POPESTIMATE2019'),
#  'kako_ak': None,
#  'chinitna_bay_ak': ('chino_city', 'POPESTIMATE2019'),
#  'massena_ny': ('massena_town', 'POPESTIMATE2019'),
#  'hobbs_nm': ('hobbs_city', 'POPESTIMATE2019'),
#  'pogo_mines_ak': None,
#  'kasaan_ak': ('kasaan_city', 'POPESTIMATE2019'),
#  'bermuda_dunes_ca': ('bermuda_run_town', 'POPESTIMATE2019'),
#  'birmingham_al': ('birmingham_city', 'POPESTIMATE2019'),
#  'baranof_ak': ('boardman_town', 'POPESTIMATE2019'),
#  'ekuk_ak': None,
#  'st_michael_ak': ('st_michael_city', 'POPESTIMATE2019'),
#  'helena_mt': ('helena_town', 'POPESTIMATE2019'),
#  'phoenix_az': ('phoenix_ut', 'POPESTIMATE2019'),
#  'cedar_rapidsiowa_city_ia': ('cedar_rapids_city', 'POPESTIMATE2019'),
#  'anvik_ak': ('anvik_city', 'POPESTIMATE2019'),
#  'farmington_pa': ('farmington_town', 'POPESTIMATE2019'),
#  'kaltag_ak': ('kaltag_city', 'POPESTIMATE2019'),
#  'olympia_wa': ('olympia_city', 'POPESTIMATE2019'),
#  'rivertonlander_wy': ('riverton_village', 'POPESTIMATE2019'),
#  'atlantic_city_nj': ('atlantic_city', 'POPESTIMATE2019'),
#  'atka_ak': ('atka_city', 'POPESTIMATE2019'),
#  'watertown_ny': ('waite_town', 'POPESTIMATE2019'),
#  'belfast_me': ('belfast_town', 'POPESTIMATE2019'),
#  'hayward_wi': ('hayward_town', 'POPESTIMATE2019'),
#  'kodiak_ak': ('kodiak_city', 'POPESTIMATE2019'),
#  'charlottesville_va': ('charlottesville_city', 'POPESTIMATE2019'),
#  'chignik_lake_ak': ('chignik_city', 'POPESTIMATE2019'),
#  'mount_vernon_il': ('mount_vernon_town', 'POPESTIMATE2019'),
#  'trading_bay_ak': ('reading_city', 'POPESTIMATE2019'),
#  'provincetown_ma': ('providence_town', 'POPESTIMATE2019'),
#  'umiat_ak': ('media_ut', 'POPESTIMATE2019'),
#  'lorainelyria_oh': ('loraine_village', 'POPESTIMATE2019'),
#  'johnstown_pa': ('johnson_town', 'POPESTIMATE2019'),
#  'fort_jefferson_fl': ('port_jefferson_village', 'POPESTIMATE2019'),
#  'truckee_ca': ('truckee_town', 'POPESTIMATE2019'),
#  'beaumontport_arthur_tx': ('port_arthur_city', 'POPESTIMATE2019'),
#  'millington_tn': ('willing_town', 'POPESTIMATE2019'),
#  'ogden_ut': ('ogden_town', 'POPESTIMATE2019'),
#  'moultonboro_nh': ('moultonborough_town', 'POPESTIMATE2019'),
#  'state_college_pa': ('state_college_borough', 'POPESTIMATE2019'),
#  'pittsburgh_pa': ('pittsburgh_city', 'POPESTIMATE2019'),
#  'blue_fox_bay_ak': None,
#  'renton_wa': ('trent_town', 'POPESTIMATE2019'),
#  'boulder_city_nv': ('boulder_city', 'POPESTIMATE2019'),
#  'port_protection_ak': ('fort_peck_town', 'POPESTIMATE2019'),
#  'fort_payne_al': ('fort_payne_city', 'POPESTIMATE2019'),
#  'jacksonville_fl': ('jackson_village', 'POPESTIMATE2019'),
#  'sheridan_wy': ('sheridan_town', 'POPESTIMATE2019'),
#  'tununak_ak': None,
#  'belmarfarmingdale_nj': ('farmingdale_town', 'POPESTIMATE2019'),
#  'atlanta_ga': ('atlanta_town', 'POPESTIMATE2019'),
#  'corvallis_or': ('corvallis_city', 'POPESTIMATE2019'),
#  'hyder_ak': None,
#  'patuxent_river_md': None,
#  'newburghpoughkeepsie_ny': ('poughkeepsie_town', 'POPESTIMATE2019'),
#  'eagle_ak': ('eagle_town', 'POPESTIMATE2019'),
#  'boca_raton_fl': ('boca_raton_city', 'POPESTIMATE2019'),
#  'klawock_ak': ('klawock_city', 'POPESTIMATE2019'),
#  'morgantown_wv': ('morgan_town', 'POPESTIMATE2019'),
#  'kongiganak_ak': None,
#  'ironwood_mi': ('ironwood_city', 'POPESTIMATE2019'),
#  'boston_ma': ('bow_town', 'POPESTIMATE2019'),
#  'fort_drum_ny': None,
#  'burlington_vt': ('burlington_town', 'POPESTIMATE2019'),
#  'new_bernmoreheadbeaufort_nc': None,
#  'florence_sc': ('florence_town', 'POPESTIMATE2019'),
#  'chignik_lagoon_ak': ('chignik_city', 'POPESTIMATE2019'),
#  'harrison_ar': ('harris_town', 'POPESTIMATE2019'),
#  'king_cove_ak': ('king_cove_city', 'POPESTIMATE2019'),
#  'manokotak_ak': ('manokotak_city', 'POPESTIMATE2019'),
#  'mccarthy_ak': ('mccall_city', 'POPESTIMATE2019'),
#  'saranac_lakelake_placid_ny': ('saranac_lake_village_pt', 'POPESTIMATE2019'),
#  'ann_arbor_mi': ('ann_arbor_city', 'POPESTIMATE2019'),
#  'minot_nd': ('minot_town', 'POPESTIMATE2019'),
#  'fayetteville_ar': ('fayette_village', 'POPESTIMATE2019'),
#  'selawik_ak': ('selawik_city', 'POPESTIMATE2019'),
#  'miami_fl': ('miami_town', 'POPESTIMATE2019'),
#  'grand_island_ne': ('grand_island_town', 'POPESTIMATE2019'),
#  'gulkana_ak': None,
#  'clevland_tn': ('cleveland_town', 'POPESTIMATE2019'),
#  'st_louis_mo': ('st_louis_town', 'POPESTIMATE2019'),
#  'logan_ut': ('logan_city', 'POPESTIMATE2019'),
#  'greenville_ms': ('greene_village', 'POPESTIMATE2019'),
#  'salem_or': ('salem_town', 'POPESTIMATE2019'),
#  'westerly_ri': ('westerly_town', 'POPESTIMATE2019'),
#  'laredo_tx': ('laredo_city', 'POPESTIMATE2019'),
#  'indianapolis_in': ('indianapolis_city', 'POPESTIMATE2019'),
#  'athens_ga': ('athens_town', 'POPESTIMATE2019'),
#  'alpena_mi': ('alpena_town', 'POPESTIMATE2019'),
#  'minto_ak': ('mina_town', 'POPESTIMATE2019'),
#  'lexington_ky': ('lexington_town', 'POPESTIMATE2019'),
#  'hoolehua_hi': None,
#  'mountain_village_ak': ('fountain_village', 'POPESTIMATE2019'),
#  'edwards_ca': ('edwards_town', 'POPESTIMATE2019'),
#  'point_baker_ak': ('point_blank_city', 'POPESTIMATE2019'),
#  'south_haven_mi': ('south_haven_city', 'POPESTIMATE2019'),
#  'fort_yukon_ak': ('fort_yukon_city', 'POPESTIMATE2019'),
#  'kulik_lake_ak': ('mulliken_village', 'POPESTIMATE2019'),
#  'lincoln_ne': ('lincoln_town', 'POPESTIMATE2019'),
#  'richmond_va': ('richmond_town', 'POPESTIMATE2019'),
#  'missoula_mt': ('missoula_city', 'POPESTIMATE2019'),
#  'fargo_nd': ('fargo_town', 'POPESTIMATE2019'),
#  'paducah_ky': ('paducah_town', 'POPESTIMATE2019'),
#  'lakeland_fl': ('lakeland_town', 'POPESTIMATE2019'),
#  'wainwright_ak': ('wainwright_town', 'POPESTIMATE2019'),
#  'montauk_point_ny': ('montague_county', 'POPESTIMATE2019'),
#  'naukiti_ak': ('nashwauk_city', 'POPESTIMATE2019'),
#  'dayton_oh': ('day_town', 'POPESTIMATE2019'),
#  'wales_ak': ('wales_town', 'POPESTIMATE2019'),
#  'clemson_sc': ('clemson_city', 'POPESTIMATE2019'),
#  'prospect_creek_ak': ('prospect_city', 'POPESTIMATE2019'),
#  'brownsville_tx': ('browns_village', 'POPESTIMATE2019'),
#  'saratoga_wy': ('saratoga_town', 'POPESTIMATE2019'),
#  'honolulu_hi': ('honolulu_county', 'POPESTIMATE2019'),
#  'granite_point_ak': ('granite_county', 'POPESTIMATE2019'),
#  'springfield_mo': ('springfield_town', 'POPESTIMATE2019'),
#  'gastonia_nc': ('gastonia_city', 'POPESTIMATE2019'),
#  'omaha_ne': ('omaha_town', 'POPESTIMATE2019'),
#  'yakima_wa': ('yakima_city', 'POPESTIMATE2019'),
#  'boise_id': None,
#  'michellville_md': ('mitchellville_city', 'POPESTIMATE2019'),
#  'chatham_ak': ('chatham_town', 'POPESTIMATE2019'),
#  'soldotna_ak': ('soldotna_city', 'POPESTIMATE2019'),
#  'chattanooga_tn': ('chattanooga_town', 'POPESTIMATE2019'),
#  'texarkana_ar': ('texarkana_city', 'POPESTIMATE2019'),
#  'whale_pass_ak': ('whale_pass_city', 'POPESTIMATE2019'),
#  'marvel_creek_mine_ak': ('cave_creek_town', 'POPESTIMATE2019'),
#  'decatur_il': ('decatur_town', 'POPESTIMATE2019'),
#  'meridian_ms': ('meridian_town', 'POPESTIMATE2019'),
#  'fryeburg_me': ('fryeburg_town', 'POPESTIMATE2019'),
#  'albany_ga': ('albany_town', 'POPESTIMATE2019'),
#  'flagstaff_az': ('flagstaff_city', 'POPESTIMATE2019'),
#  'idaho_falls_id': ('idaho_falls_city', 'POPESTIMATE2019'),
#  'chadron_ne': ('chadron_city', 'POPESTIMATE2019'),
#  'princeton_nj': ('princeton', 'POPESTIMATE2019'),
#  'camarillo_ca': ('camarillo_city', 'POPESTIMATE2019'),
#  'tuntutuliak_ak': None,
#  'burlingtonmount_vernon_wa': ('burlington_county', 'POPESTIMATE2019'),
#  'selinsgrove_pa': ('selinsgrove_borough', 'POPESTIMATE2019'),
#  'south_bend_in': ('south_bend_city', 'POPESTIMATE2019'),
#  'san_bernardino_ca': ('san_bernardino_city', 'POPESTIMATE2019'),
#  'alliance_ne': ('alliance_town', 'POPESTIMATE2019'),
#  'fairbanks_ak': ('fairbanks_town', 'POPESTIMATE2019'),
#  'oneonta_ny': ('oneonta_town', 'POPESTIMATE2019'),
#  'eagle_co': ('eagle_town', 'POPESTIMATE2019'),
#  'greenville_sc': ('greene_village', 'POPESTIMATE2019'),
#  'hayden_co': ('hayden_town', 'POPESTIMATE2019'),
#  'hurricane_ut': ('hurricane_city', 'POPESTIMATE2019'),
#  'quinhagak_ak': ('quinhagak_city', 'POPESTIMATE2019'),
#  'bristoljohnson_citykingsport_tn': ('johnson_city_city', 'POPESTIMATE2019'),
#  'cheyenne_wy': ('cheyenne_town', 'POPESTIMATE2019'),
#  'green_bay_wi': ('green_bay_town', 'POPESTIMATE2019'),
#  'hancockhoughton_mi': ('hancock_town', 'POPESTIMATE2019'),
#  'key_west_fl': ('key_west_city', 'POPESTIMATE2019'),
#  'east_hampton_ny': ('eastham_town', 'POPESTIMATE2019'),
#  'santa_fe_nm': ('santa_fe_city', 'POPESTIMATE2019'),
#  'rosario_wa': ('rosalia_town', 'POPESTIMATE2019'),
#  'international_falls_mn': ('international_falls_city', 'POPESTIMATE2019'),
#  'meyers_chuck_ak': None,
#  'greenville_nc': ('greene_village', 'POPESTIMATE2019'),
#  'wasilla_ak': ('wasilla_city', 'POPESTIMATE2019'),
#  'cape_lisburne_ak': ('campbellsburg_town', 'POPESTIMATE2019'),
#  'greer_sc': ('greer_city', 'POPESTIMATE2019'),
#  'colorado_springs_co': ('colorado_springs_city', 'POPESTIMATE2019'),
#  'iron_mountainkingsfd_mi': ('iron_mountain_city', 'POPESTIMATE2019'),
#  'ketchikan_ak': ('ketchikan_city', 'POPESTIMATE2019'),
#  'little_rock_ar': ('little_rock_city', 'POPESTIMATE2019'),
#  'lawrenceville_ga': ('lawrence_village', 'POPESTIMATE2019'),
#  'benton_harborst_joseph_mi': ('benton_harbor_city', 'POPESTIMATE2019'),
#  'pilot_station_ak': ('pilot_station_city', 'POPESTIMATE2019'),
#  'jacksonvicksburg_ms': ('jackson_village', 'POPESTIMATE2019'),
#  'tallahassee_fl': ('tallahassee_city', 'POPESTIMATE2019'),
#  'kavik_river_ak': ('park_river_city', 'POPESTIMATE2019'),
#  'valparaiso_fl': ('valparaiso_city', 'POPESTIMATE2019'),
#  'kearney_ne': ('kearney_city', 'POPESTIMATE2019'),
#  'eek_ak': None,
#  'trenton_nj': ('trent_town', 'POPESTIMATE2019'),
#  'leonardtown_md': ('onward_town', 'POPESTIMATE2019'),
#  'yuma_az': ('yuma_city', 'POPESTIMATE2019'),
#  'kona_hi': None,
#  'san_francisco_ca': ('san_francisco_city', 'POPESTIMATE2019'),
#  'sioux_city_ia': ('scio_city', 'POPESTIMATE2019'),
#  'rutland_vt': ('rutland_town', 'POPESTIMATE2019'),
#  'redding_ca': ('redding_town', 'POPESTIMATE2019'),
#  'heber_ut': ('heber_city', 'POPESTIMATE2019'),
#  'cedar_city_ut': ('cedar_city', 'POPESTIMATE2019'),
#  'kipnuk_ak': None,
#  'norwood_ma': ('norwood_town', 'POPESTIMATE2019'),
#  'pontiac_mi': ('pontiac_city', 'POPESTIMATE2019'),
#  'quincy_il': ('qulin_city', 'POPESTIMATE2019'),
#  'salt_lake_city_ut': ('shasta_lake_city', 'POPESTIMATE2019'),
#  'west_palm_beachpalm_beach_fl': ('west_palm_beach_city', 'POPESTIMATE2019'),
#  'marathon_fl': ('marathon_town', 'POPESTIMATE2019'),
#  'galbraith_lake_ak': ('gilbert_village', 'POPESTIMATE2019'),
#  'dallasfort_worth_tx': ('dallas_borough', 'POPESTIMATE2019'),
#  'carlsbad_ca': ('carlsbad_city', 'POPESTIMATE2019'),
#  'rockland_me': ('rockland_town', 'POPESTIMATE2019'),
#  'midlandodessa_tx': ('midland_town', 'POPESTIMATE2019'),
#  'murrietatemecula_ca': ('murrieta_city', 'POPESTIMATE2019'),
#  'liberal_ks': ('liberal_city', 'POPESTIMATE2019'),
#  'kanab_ut': ('kanab_city', 'POPESTIMATE2019'),
#  'toms_river_nj': ('toms_river_township', 'POPESTIMATE2019'),
#  'gunnison_co': ('gunnison_town', 'POPESTIMATE2019'),
#  'fort_smith_ar': ('fort_smith_city', 'POPESTIMATE2019'),
#  'cape_girardeau_mo': ('cape_girardeau_city', 'POPESTIMATE2019'),
#  'paso_robles_ca': None,
#  'san_carlos_ca': ('san_carlos_city', 'POPESTIMATE2019'),
#  'carry_inlet_ak': ('cary_village', 'POPESTIMATE2019'),
#  'tatitlek_ak': None,
#  'hollis_ak': ('hollis_town', 'POPESTIMATE2019'),
#  'nashville_tn': ('nashville_town', 'POPESTIMATE2019'),
#  'grand_rapids_mi': ('grand_rapids_town', 'POPESTIMATE2019'),
#  'king_salmon_ak': ('king_town', 'POPESTIMATE2019'),
#  'telluride_co': ('telluride_town', 'POPESTIMATE2019'),
#  'west_milford_nj': ('west_milford_town', 'POPESTIMATE2019'),
#  'lawtonfort_sill_ok': ('lawton_village', 'POPESTIMATE2019'),
#  'bainbridge_ga': ('bainbridge_town', 'POPESTIMATE2019'),
#  'bemidji_mn': ('bemidji_city', 'POPESTIMATE2019'),
#  'owensboro_ky': ('owensboro_city', 'POPESTIMATE2019'),
#  'sault_ste_marie_mi': ('sault_ste_marie_city', 'POPESTIMATE2019'),
#  'barrow_ak': ('barre_town', 'POPESTIMATE2019'),
#  'hilton_head_sc': ('hilton_head_island_town', 'POPESTIMATE2019'),
#  'denver_co': ('denver_town', 'POPESTIMATE2019'),
#  'terror_lake_ak': ('waterford_village', 'POPESTIMATE2019'),
#  'nikolski_ak': ('nikolai_city', 'POPESTIMATE2019'),
#  'hot_springs_ar': ('hot_springs_town', 'POPESTIMATE2019'),
#  'lake_charles_la': ('lake_charles_city', 'POPESTIMATE2019'),
#  'hammond_la': ('hammond_town', 'POPESTIMATE2019'),
#  'long_beach_ca': ('long_beach_town', 'POPESTIMATE2019'),
#  'pelican_ak': ('pelican_town', 'POPESTIMATE2019'),
#  'hattiesburg_ms': ('hattiesburg_city', 'POPESTIMATE2019'),
#  'kodiak_island_ak': ('kodiak_island_borough', 'POPESTIMATE2019'),
#  'new_richmond_wi': ('new_richmond_town', 'POPESTIMATE2019'),
#  'harrisburg_pa': ('harrisburg_town', 'POPESTIMATE2019'),
#  'tinian_tt': ('ionia_town', 'POPESTIMATE2019'),
#  'abilene_tx': ('abilene_city', 'POPESTIMATE2019'),
#  'fort_dodge_ia': ('fort_dodge_city', 'POPESTIMATE2019'),
#  'houma_la': ('houma_city', 'POPESTIMATE2019'),
#  'ouzinkie_ak': ('ouzinkie_city', 'POPESTIMATE2019'),
#  'mountain_view_ca': ('mountain_view_town', 'POPESTIMATE2019'),
#  'nyac_ak': None,
#  'louisville_ky': ('louisville_town', 'POPESTIMATE2019'),
#  'bridgeport_ct': ('bridgeport_town', 'POPESTIMATE2019'),
#  'springfield_il': ('springfield_town', 'POPESTIMATE2019'),
#  'shungnak_ak': ('shungnak_city', 'POPESTIMATE2019'),
#  'tuscaloosa_al': ('tuscaloosa_city', 'POPESTIMATE2019'),
#  'portland_tn': ('portland_town', 'POPESTIMATE2019'),
#  'shelton_wa': ('shelby_town', 'POPESTIMATE2019'),
#  'kake_ak': ('kake_city', 'POPESTIMATE2019'),
#  'provo_ut': ('provo_city', 'POPESTIMATE2019'),
#  'lake_tahoe_ca': ('lake_town', 'POPESTIMATE2019'),
#  'jonesboro_ar': ('jonesboro_town', 'POPESTIMATE2019'),
#  'blytheville_ar': ('blytheville_city', 'POPESTIMATE2019'),
#  'ocean_city_md': ('olean_city', 'POPESTIMATE2019'),
#  'longview_tx': ('longview_city', 'POPESTIMATE2019'),
#  'lancaster_cove_ak': ('lancaster_county', 'POPESTIMATE2019'),
#  'concord_ca': ('concord_town', 'POPESTIMATE2019'),
#  'charleston_sc': ('st_charles_town', 'POPESTIMATE2019'),
#  'port_lions_ak': ('port_lions_city', 'POPESTIMATE2019'),
#  'sanford_fl': ('sanford_town', 'POPESTIMATE2019'),
#  'aguadilla_pr': ('augusta_village', 'POPESTIMATE2019'),
#  'funter_bay_alaska_ak': None,
#  'skagway_ak': None,
#  'kasigluk_ak': None,
#  'laconia_nh': ('laconia_town', 'POPESTIMATE2019'),
#  'fort_lauderdale_fl': ('fort_lauderdale_city', 'POPESTIMATE2019'),
#  'quincy_ma': ('qulin_city', 'POPESTIMATE2019'),
#  'montgomery_al': ('montgomery_town', 'POPESTIMATE2019'),
#  'philadelphia_pa': ('philadelphia_town', 'POPESTIMATE2019'),
#  'waco_tx': ('waco_town', 'POPESTIMATE2019'),
#  'moroe_wi': ('monroe_town', 'POPESTIMATE2019'),
#  'talkeetna_ak': ('albee_town', 'POPESTIMATE2019'),
#  'north_platte_ne': ('north_platte_city', 'POPESTIMATE2019'),
#  'valdosta_ga': ('valdosta_city', 'POPESTIMATE2019'),
#  'anchorage_ak': ('anchorage_city', 'POPESTIMATE2019'),
#  'elmiracorning_ny': ('elmira_town', 'POPESTIMATE2019'),
#  'allakaket_ak': ('allakaket_city', 'POPESTIMATE2019'),
#  'shreveport_la': ('shreveport_city', 'POPESTIMATE2019'),
#  'ceiba_pr': None,
#  'kingman_az': ('kingman_ut', 'POPESTIMATE2019'),
#  'jackson_tn': ('jackson_town', 'POPESTIMATE2019'),
#  'nashua_nh': ('nashua_town', 'POPESTIMATE2019'),
#  'brunswick_me': ('brunswick_town', 'POPESTIMATE2019'),
#  'tuluksak_ak': None,
#  'bremerton_wa': ('bremen_town', 'POPESTIMATE2019'),
#  'chatham_ma': ('chatham_town', 'POPESTIMATE2019'),
#  'pickens_sc': ('pickens_town', 'POPESTIMATE2019'),
#  'findlay_oh': ('findlay_city', 'POPESTIMATE2019'),
#  'marshfield_ma': ('marshfield_town', 'POPESTIMATE2019'),
#  'south_naknek_ak': ('south_nyack_village', 'POPESTIMATE2019'),
#  'santa_monica_ca': ('santa_monica_city', 'POPESTIMATE2019'),
#  'austin_tx': ('austin_city', 'POPESTIMATE2019'),
#  'santa_barbara_ca': ('santa_barbara_city', 'POPESTIMATE2019'),
#  'marshall_ak': ('marshall_town', 'POPESTIMATE2019'),
#  'st_george_island_ak': ('st_george_town', 'POPESTIMATE2019'),
#  'detroit_mi': ('detroit_town', 'POPESTIMATE2019'),
#  'noorvik_ak': ('noorvik_city', 'POPESTIMATE2019'),
#  'manhattanft_riley_ks': ('manhattan_city', 'POPESTIMATE2019'),
#  'reading_pa': ('reading_town', 'POPESTIMATE2019'),
#  'mason_city_ia': ('mason_city', 'POPESTIMATE2019'),
#  'akhiok_ak': ('akhiok_city', 'POPESTIMATE2019'),
#  'gillette_wy': ('gillette_city', 'POPESTIMATE2019'),
#  'sunriver_or': ('sunrise_city', 'POPESTIMATE2019'),
#  'wide_bay_ak': ('winder_city', 'POPESTIMATE2019'),
#  'donlin_creek_mine_ak': ('linn_creek_city', 'POPESTIMATE2019'),
#  'coatesville_pa': ('coatesville_town', 'POPESTIMATE2019'),
#  'karluk_lake_ak': ('carlock_village', 'POPESTIMATE2019'),
#  'peach_springs_az': ('heath_springs_town', 'POPESTIMATE2019'),
#  'elim_ak': ('elim_city', 'POPESTIMATE2019'),
#  'sheboygan_wi': ('sheboygan_town', 'POPESTIMATE2019'),
#  'klamath_falls_or': ('klamath_falls_city', 'POPESTIMATE2019'),
#  'pago_pago_tt': None,
#  'pinehurstsouthern_pines_nc': ('southern_pines_town', 'POPESTIMATE2019'),
#  'skwentna_ak': ('sweden_town', 'POPESTIMATE2019'),
#  'pack_creek_ak': ('duck_creek_ut', 'POPESTIMATE2019'),
#  'vernal_ut': ('vernal_city', 'POPESTIMATE2019'),
#  'charlotte_nc': ('charlotte_town', 'POPESTIMATE2019'),
#  'tok_ak': None,
#  'marionherrin_il': ('marion_town', 'POPESTIMATE2019'),
#  'arlington_tx': ('arlington_town', 'POPESTIMATE2019'),
#  'naknek_ak': None,
#  'elizabeth_city_nc': ('elizabeth_city', 'POPESTIMATE2019'),
#  'russellville_ar': ('russellville_town', 'POPESTIMATE2019'),
#  'karluk_ak': None,
#  'silver_salmon_creek_ak': ('silver_creek_town', 'POPESTIMATE2019'),
#  'aiken_sc': ('aiken_city', 'POPESTIMATE2019'),
#  'napaskiak_ak': ('napaskiak_city', 'POPESTIMATE2019'),
#  'spokane_wa': ('spokane_city', 'POPESTIMATE2019'),
#  'lafayette_in': ('lafayette_town', 'POPESTIMATE2019'),
#  'brunswick_ga': ('brunswick_town', 'POPESTIMATE2019'),
#  'lancaster_pa': ('lancaster_town', 'POPESTIMATE2019'),
#  'anaktuvuk_pass_ak': ('anaktuvuk_pass_city', 'POPESTIMATE2019'),
#  'rifle_co': ('rifle_city', 'POPESTIMATE2019'),
#  'peachtree_city_ga': ('peachtree_city_city', 'POPESTIMATE2019'),
#  'eagle_harbor_ak': ('eagle_harbor_town', 'POPESTIMATE2019'),
#  'albemarle_nc': ('albemarle_city', 'POPESTIMATE2019'),
#  'coldfoot_ak': None,
#  'chandler_az': ('chandler_town', 'POPESTIMATE2019'),
#  'dillingham_ak': ('dillingham_city', 'POPESTIMATE2019'),
#  'marysville_ca': ('marysville_city', 'POPESTIMATE2019'),
#  'new_haven_ct': ('new_haven_town', 'POPESTIMATE2019'),
#  'pierre_sd': ('pierre_city', 'POPESTIMATE2019'),
#  'ithacacortland_ny': ('ithaca_town', 'POPESTIMATE2019'),
#  'coeur_dalene_id': ('coeur_dalene_city', 'POPESTIMATE2019'),
#  'olive_branch_ms': ('olive_branch_city', 'POPESTIMATE2019'),
#  'nenana_ak': ('nenana_city', 'POPESTIMATE2019'),
#  'milwaukee_wi': ('milwaukee_city', 'POPESTIMATE2019'),
#  'shemya_ak': None,
#  'el_centro_ca': ('el_centro_city', 'POPESTIMATE2019'),
#  'akron_oh': ('akron_town', 'POPESTIMATE2019'),
#  'lake_placid_ny': ('lake_placid_town', 'POPESTIMATE2019'),
#  'bryce_canyon_ut': ('bryce_canyon_city_town', 'POPESTIMATE2019'),
#  'mobile_al': ('mobile_city', 'POPESTIMATE2019'),
#  'kokhanok_ak': None,
#  'rome_ny': ('rome_town', 'POPESTIMATE2019'),
#  'haines_ak': ('haines_city', 'POPESTIMATE2019'),
#  'stony_river_ak': ('stony_river_township', 'POPESTIMATE2019'),
#  'russian_mission_ak': ('russian_mission_city', 'POPESTIMATE2019'),
#  'worcester_ma': ('worcester_town', 'POPESTIMATE2019'),
#  'bozeman_mt': ('bozeman_city', 'POPESTIMATE2019'),
#  'bettles_ak': ('bettles_city', 'POPESTIMATE2019'),
#  'dothan_al': ('dothan_city', 'POPESTIMATE2019'),
#  'lansing_mi': ('lansing_town', 'POPESTIMATE2019'),
#  'kwethluk_ak': ('kwethluk_city', 'POPESTIMATE2019'),
#  'mount_holly_nj': ('mount_holly_town', 'POPESTIMATE2019'),
#  'raleighdurham_nc': None,
#  'macon_ga': ('macy_town', 'POPESTIMATE2019'),
#  'ruby_ak': ('ruby_town', 'POPESTIMATE2019'),
#  'dover_de': ('dover_town', 'POPESTIMATE2019'),
#  'pilot_point_ak': ('pilot_point_city', 'POPESTIMATE2019'),
#  'jackson_ms': ('jackson_town', 'POPESTIMATE2019'),
#  'cleveland_oh': ('cleveland_town', 'POPESTIMATE2019'),
#  'stillwater_ok': ('stillwater_town', 'POPESTIMATE2019'),
#  'laura_lake_ak': ('laura_village', 'POPESTIMATE2019'),
#  'deland_fl': ('deland_city', 'POPESTIMATE2019'),
#  'dallas_tx': ('dallas_town', 'POPESTIMATE2019'),
#  'broomfield_co': ('broomfield_city', 'POPESTIMATE2019'),
#  'sioux_falls_sd': ('sioux_falls_city', 'POPESTIMATE2019'),
#  'chandalar_ak': ('chandler_town', 'POPESTIMATE2019'),
#  'annapolis_md': ('annapolis_city', 'POPESTIMATE2019'),
#  'adak_island_ak': ('oak_island_town', 'POPESTIMATE2019'),
#  'bellingham_wa': ('bellingham_town', 'POPESTIMATE2019'),
#  'nome_ak': ('nome_city', 'POPESTIMATE2019'),
#  'beaver_ak': ('beaver_town', 'POPESTIMATE2019'),
#  'myrtle_beach_sc': ('myrtle_beach_city', 'POPESTIMATE2019'),
#  'waterbury_ct': ('waterbury_town', 'POPESTIMATE2019'),
#  'nunapitchuk_ak': ('nunapitchuk_city', 'POPESTIMATE2019'),
#  'santa_rosa_ca': ('santa_rosa_town', 'POPESTIMATE2019'),
#  'carlsbad_nm': ('carlsbad_city', 'POPESTIMATE2019'),
#  'st_petersburg_fl': ('st_petersburg_city', 'POPESTIMATE2019'),
#  'peoria_il': ('peoria_town', 'POPESTIMATE2019'),
#  'tucson_az': ('tucson_city', 'POPESTIMATE2019'),
#  'hopedale_ma': ('hopedale_town', 'POPESTIMATE2019'),
#  'flora_il': ('flora_town', 'POPESTIMATE2019'),
#  'dubois_pa': ('dubois_town', 'POPESTIMATE2019'),
#  'minchumina_ak': None,
#  'clarksburgfairmont_wv': ('clarksburg_city', 'POPESTIMATE2019'),
#  'monticello_ny': ('monticello_town', 'POPESTIMATE2019'),
#  'portsmouth_nh': ('portsmouth_town', 'POPESTIMATE2019'),
#  'sandpoint_ak': ('sandpoint_city', 'POPESTIMATE2019'),
#  'north_adams_ma': ('north_adams_city', 'POPESTIMATE2019'),
#  'manassas_va': ('manassas_city', 'POPESTIMATE2019'),
#  'devils_lake_nd': ('devils_lake_city', 'POPESTIMATE2019'),
#  'clarks_point_ak': ('clarks_point_city', 'POPESTIMATE2019'),
#  'san_antonio_tx': ('san_antonio_city', 'POPESTIMATE2019'),
#  'auburn_al': ('auburn_town', 'POPESTIMATE2019'),
#  'fort_leonard_wood_mo': ('mount_leonard_town', 'POPESTIMATE2019'),
#  'salinasmonterey_ca': ('salinas_city', 'POPESTIMATE2019'),
#  'bismarckmandan_nd': ('bismarck_village', 'POPESTIMATE2019'),
#  'lewistonauburn_me': ('lewiston_town', 'POPESTIMATE2019'),
#  'seneca_falls_ny': ('seneca_falls_town', 'POPESTIMATE2019'),
#  'hagerstown_md': ('hague_town', 'POPESTIMATE2019'),
#  'chicopee_falls_ma': ('chippewa_falls_city', 'POPESTIMATE2019'),
#  'savoonga_ak': ('savoonga_city', 'POPESTIMATE2019'),
#  'casper_wy': ('casper_city', 'POPESTIMATE2019'),
#  'clover_bay_ak': ('plover_city', 'POPESTIMATE2019'),
#  'fayetteville_nc': ('fayette_village', 'POPESTIMATE2019'),
#  'anacortes_wa': ('anacortes_city', 'POPESTIMATE2019'),
#  'new_londongroton_ct': ('new_london_town', 'POPESTIMATE2019'),
#  'glasgow_mt': ('glasgow_town', 'POPESTIMATE2019'),
#  'york_pa': ('york_town', 'POPESTIMATE2019'),
#  'chomondely_sound_ak': ('richmond_county', 'POPESTIMATE2019'),
#  'easton_md': ('eads_town', 'POPESTIMATE2019'),
#  'bloomingtonnormal_il': ('bloomington_town', 'POPESTIMATE2019'),
#  'hamilton_oh': ('hamilton_town', 'POPESTIMATE2019'),
#  'girdwood_ak': None,
#  'red_devil_ak': ('red_creek_village', 'POPESTIMATE2019'),
#  'duluth_mn': ('duluth_city', 'POPESTIMATE2019'),
#  'grand_junction_co': ('grand_junction_city', 'POPESTIMATE2019'),
#  'west_point_ak': ('west_point_town', 'POPESTIMATE2019'),
#  'port_alsworth_ak': ('port_royal_borough', 'POPESTIMATE2019'),
#  'st_marys_ak': ('st_marys_city', 'POPESTIMATE2019'),
#  'livengood_ak': None,
#  'searcy_ar': ('seward_city', 'POPESTIMATE2019'),
#  'kirksville_mo': ('kirksville_city', 'POPESTIMATE2019'),
#  'southampton_ny': ('southampton_town', 'POPESTIMATE2019'),
#  'homer_ak': ('homer_town', 'POPESTIMATE2019'),
#  'port_heiden_ak': ('port_heiden_city', 'POPESTIMATE2019'),
#  'walla_walla_wa': ('walla_walla_city', 'POPESTIMATE2019'),
#  'san_angelo_tx': ('san_angelo_city', 'POPESTIMATE2019'),
#  'marietta_ga': ('marietta_town', 'POPESTIMATE2019'),
#  'corner_bay_ak': ('corder_city', 'POPESTIMATE2019'),
#  'winston-salem_nc': ('winston-salem_city', 'POPESTIMATE2019'),
#  'danbury_ct': ('danbury_town', 'POPESTIMATE2019'),
#  'st_george_ut': ('st_george_town', 'POPESTIMATE2019'),
#  'east_farmingdale_ny': ('farmingdale_town', 'POPESTIMATE2019'),
#  'grand_forks_nd': ('grand_forks_city', 'POPESTIMATE2019'),
#  'cooper_lodge_ak': ('cooper_town', 'POPESTIMATE2019'),
#  'joplin_mo': ('joplin_city', 'POPESTIMATE2019'),
#  'beckley_wv': ('beckley_city', 'POPESTIMATE2019'),
#  'destin_fl': ('destin_city', 'POPESTIMATE2019'),
#  'golovin_ak': ('golovin_city', 'POPESTIMATE2019'),
#  'columbia_sc': ('columbia_town', 'POPESTIMATE2019'),
#  'vero_beach_fl': ('vero_beach_city', 'POPESTIMATE2019'),
#  'hamilton_ny': ('hamilton_town', 'POPESTIMATE2019'),
#  'tin_city_ak': ('turin_city', 'POPESTIMATE2019'),
#  'anniston_al': ('ennis_town', 'POPESTIMATE2019'),
#  'fitiuta_village_tt': ('fithian_village', 'POPESTIMATE2019'),
#  'santa_maria_ca': ('santa_maria_city', 'POPESTIMATE2019'),
#  'raspberry_strait_ak': ('casselberry_city', 'POPESTIMATE2019'),
#  'little_squaw_ak': ('little_suamico_town', 'POPESTIMATE2019'),
#  'westhampton_ny': ('westhampton_town', 'POPESTIMATE2019'),
#  'uganik_ak': None,
#  'san_jose_ca': ('san_jose_city', 'POPESTIMATE2019'),
#  'oxford_ms': ('oxford_town', 'POPESTIMATE2019'),
#  'gulfportbiloxi_ms': ('gulfport_city', 'POPESTIMATE2019'),
#  'pedro_bay_ak': None,
#  'hudson_ny': ('hudson_town', 'POPESTIMATE2019'),
#  'evansville_in': ('evansville_town', 'POPESTIMATE2019'),
#  'ekwok_ak': ('ekwok_city', 'POPESTIMATE2019'),
#  'new_roads_la': ('new_roads_city', 'POPESTIMATE2019'),
#  'van_horn_tx': ('van_horn_town', 'POPESTIMATE2019'),
#  'palmer_ak': ('palmer_town', 'POPESTIMATE2019'),
#  'stebbins_ak': ('stebbins_city', 'POPESTIMATE2019'),
#  'nanwalek_ak': None,
#  'hartford_ct': ('hartford_town', 'POPESTIMATE2019'),
#  'marana_az': ('marana_town', 'POPESTIMATE2019'),
#  'victoria_tx': ('victoria_town', 'POPESTIMATE2019'),
#  'rapid_city_sd': ('trail_city', 'POPESTIMATE2019'),
#  'fort_collinsloveland_co': ('north_collins_town', 'POPESTIMATE2019'),
#  'williamsport_pa': ('williamsport_town', 'POPESTIMATE2019'),
#  'youngstownwarren_oh': ('youngtown_town', 'POPESTIMATE2019'),
#  'charlotte_amalie_vi': ('charlotte_city', 'POPESTIMATE2019'),
#  'manley_hot_springs_ak': ('lava_hot_springs_city', 'POPESTIMATE2019'),
#  'victorville_ca': ('victor_village', 'POPESTIMATE2019'),
#  'red_dog_ak': ('reid_town', 'POPESTIMATE2019'),
#  'laramie_wy': ('laramie_city', 'POPESTIMATE2019'),
#  'key_largo_fl': ('oakley_village', 'POPESTIMATE2019'),
#  'cortez_co': ('cortez_city', 'POPESTIMATE2019'),
#  'cody_wy': ('cody_city', 'POPESTIMATE2019'),
#  'sidney_mt': ('sidney_town', 'POPESTIMATE2019'),
#  'ogdensburg_ny': ('ogdensburg_city', 'POPESTIMATE2019'),
#  'venetie_ak': ('veneta_city', 'POPESTIMATE2019'),
#  'minneapolis_mn': ('minneapolis_city', 'POPESTIMATE2019'),
#  'berlin_nj': ('berlin_town', 'POPESTIMATE2019'),
#  'moline_il': ('moline_city', 'POPESTIMATE2019'),
#  'lompoc_ca': ('lompoc_city', 'POPESTIMATE2019'),
#  'concord_nh': ('concord_town', 'POPESTIMATE2019'),
#  'sleetmute_ak': None,
#  'bedford_ma': ('bedford_town', 'POPESTIMATE2019'),
#  'frederick_md': ('frederick_town', 'POPESTIMATE2019'),
#  'pocatello_id': ('pocatello_city', 'POPESTIMATE2019'),
#  'monroe_nc': ('monroe_town', 'POPESTIMATE2019'),
#  'brigham_city_ut': ('braham_city', 'POPESTIMATE2019'),
#  'marthas_vineyard_ma': ('marthasville_city', 'POPESTIMATE2019'),
#  'gambell_ak': ('gambell_city', 'POPESTIMATE2019'),
#  'eastsound_wa': ('pleasants_county', 'POPESTIMATE2019'),
#  'knoxville_tn': ('knoxville_town', 'POPESTIMATE2019'),
#  'hoonah_ak': ('hoonah_city', 'POPESTIMATE2019'),
#  'daytona_beach_fl': ('daytona_beach_city', 'POPESTIMATE2019'),
#  'platinum_ak': ('platinum_city', 'POPESTIMATE2019'),
#  'zephyrhills_fl': ('zephyrhills_city', 'POPESTIMATE2019'),
#  'new_stuyahok_ak': ('new_stuyahok_city', 'POPESTIMATE2019'),
#  'torrance_ca': ('torrance_city', 'POPESTIMATE2019'),
#  'mammoth_lakes_ca': ('mammoth_lakes_town', 'POPESTIMATE2019'),
#  'north_bendcoos_bay_or': ('north_bend_city', 'POPESTIMATE2019'),
#  'chicagoromeoville_il': ('chicago_ridge_village', 'POPESTIMATE2019'),
#  'williston_nd': ('williams_town', 'POPESTIMATE2019'),
#  'gettysburg_pa': ('gettysburg_city', 'POPESTIMATE2019'),
#  'cambridge_md': ('cambridge_town', 'POPESTIMATE2019'),
#  'arctic_village_ak': ('martin_village', 'POPESTIMATE2019'),
#  'sacramento_ca': ('sacramento_city', 'POPESTIMATE2019'),
#  'beaver_falls_pa': ('beaver_falls_city', 'POPESTIMATE2019'),
#  'silver_cityhurley_nm': ('silver_city_city', 'POPESTIMATE2019'),
#  'akiak_ak': ('akiak_city', 'POPESTIMATE2019'),
#  'akutan_ak': ('akutan_city', 'POPESTIMATE2019'),
#  'blakely_island_wa': ('blakely_city', 'POPESTIMATE2019'),
#  'okeechobee_fl': ('okeechobee_city', 'POPESTIMATE2019'),
#  'taos_nm': ('taos_town', 'POPESTIMATE2019'),
#  'middletown_de': ('middleton_town', 'POPESTIMATE2019'),
#  'oakland_ca': ('oakland_town', 'POPESTIMATE2019'),
#  'white_mountain_ak': ('white_mountain_city', 'POPESTIMATE2019'),
#  'grayling_ak': ('grayling_city', 'POPESTIMATE2019'),
#  'walterboro_sc': ('walterboro_city', 'POPESTIMATE2019'),
#  'jackson_mi': ('jackson_town', 'POPESTIMATE2019'),
#  'old_harbor_ak': ('old_harbor_city', 'POPESTIMATE2019'),
#  'christiansted_vi': ('christiana_town', 'POPESTIMATE2019'),
#  'peru_in': ('peru_town', 'POPESTIMATE2019'),
#  'sarasotabradenton_fl': ('braden_town', 'POPESTIMATE2019'),
#  'columbus_ga': ('columbus_town', 'POPESTIMATE2019'),
#  'tyler_tx': ('tyler_city', 'POPESTIMATE2019'),
#  'hayward_ca': ('hayward_town', 'POPESTIMATE2019'),
#  'pittsfield_ma': ('pittsfield_town', 'POPESTIMATE2019'),
#  'wilmington_de': ('willing_town', 'POPESTIMATE2019'),
#  'amarillo_tx': ('amarillo_city', 'POPESTIMATE2019'),
#  'bloomington_in': ('bloomington_town', 'POPESTIMATE2019'),
#  'sulphur_springs_tx': ('sulphur_springs_town', 'POPESTIMATE2019'),
#  'salisbury_md': ('salisbury_town', 'POPESTIMATE2019'),
#  'aberdeen_sd': ('aberdeen_town', 'POPESTIMATE2019'),
#  'gallup_nm': ('gallup_city', 'POPESTIMATE2019'),
#  'stevens_village_ak': ('steuben_village', 'POPESTIMATE2019'),
#  'kenai_ak': ('kenai_city', 'POPESTIMATE2019'),
#  'grand_canyon_az': ('grand_county', 'POPESTIMATE2019'),
#  'hughes_ak': ('hughes_town', 'POPESTIMATE2019'),
#  'portland_me': ('portland_town', 'POPESTIMATE2019'),
#  'harlingensan_benito_tx': ('harlingen_city', 'POPESTIMATE2019'),
#  'excursion_inlet_ak': ('excelsior_city', 'POPESTIMATE2019'),
#  'chisana_ak': ('christiana_town', 'POPESTIMATE2019'),
#  'pagosa_springs_co': ('pagosa_springs_town', 'POPESTIMATE2019'),
#  'visalia_ca': ('visalia_city', 'POPESTIMATE2019'),
#  'granite_creek_mine_ak': ('granite_city', 'POPESTIMATE2019'),
#  'arcataeureka_ca': None,
#  'scammon_bay_ak': ('scammon_bay_city', 'POPESTIMATE2019'),
#  'noatak_ak': None,
#  'roche_harbor_wa': ('rochester_borough', 'POPESTIMATE2019'),
#  'monroe_la': ('monroe_town', 'POPESTIMATE2019'),
#  'buena_co': None,
#  ...}

# %%
pd.DataFrame(out_data).to_pickle('/home/weihua/Research/Link_Dynamics/data/us_air_population.pkl')
