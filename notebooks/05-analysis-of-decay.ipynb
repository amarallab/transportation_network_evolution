# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container {width:80% !important; }</style>"))
# Out:
# <style>.container {width:80% !important; }</style>

# %%
import warnings
warnings.simplefilter(action='ignore')

# %%
import seaborn as sns
import matplotlib.mlab as ml
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import ticker
import matplotlib.ticker as plticker

def stdfigsize(scale=1, nx=1, ny=1, ratio=1.3):
    """
    Returns a tuple to be used as figure size.
    -------
    returns (7*ratio*scale*nx, 7.*scale*ny)
    By default: ratio=1.3
    If ratio<0 them ratio = golden ratio
    """
    if ratio < 0:
        ratio = 1.61803398875
    return((7*ratio*scale*nx, 7*scale*ny))

def stdrcparams(usetex=False):
    """
    Set several mpl.rcParams and sns.set_style for my taste.
    ----
    usetex = True
    ----
    """
    sns.set_style("white")
    sns.set_style({"xtick.direction": "in",
                 "ytick.direction": "in"})
    rcparams = {'text.usetex': usetex,
              'font.family': 'sans-serif',
              'font.sans-serif': ['Helvetica'],
             # 'text.latex.unicode': True,
              'text.latex.preamble': [r"\usepackage[T1]{fontenc}",
                                      r"\usepackage{lmodern}",
                                      r"\usepackage{amsmath}",
                                      r"\usepackage{mathptmx}"
                                      ],
              'axes.labelsize': 30,
              'axes.titlesize': 30,
              'ytick.right': 'on',
              'xtick.top': 'on',
              'xtick.labelsize': '25',
              'ytick.labelsize': '25',
              'axes.linewidth': 1.8,
              'xtick.major.width': 1.8,
              'xtick.minor.width': 1.8,
              'xtick.major.size': 14,
              'xtick.minor.size': 7,
              'xtick.major.pad': 10,
              'xtick.minor.pad': 10,
              'ytick.major.width': 1.8,
              'ytick.minor.width': 1.8,
              'ytick.major.size': 14,
              'ytick.minor.size': 7,
              'ytick.major.pad': 10,
              'ytick.minor.pad': 10,
              'axes.labelpad': 15,
              'axes.titlepad': 15,
              "xtick.direction": "in",
              "ytick.direction": "in",
              'legend.fontsize': 20}
    mpl.rcParams.update(rcparams) 

mpl.rcParams['lines.linewidth'] = 5
mpl.rcParams['lines.color'] = '#3690c0'

stdrcparams(usetex=True)
figsize=stdfigsize(ratio=-1)
xs,ys=figsize

def custom_frame(ax):
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.get_xaxis().tick_bottom()
    ax.get_yaxis().tick_left()
    ax.tick_params(axis='x',length=10,direction='out')
    ax.tick_params(axis='x',which='minor',direction='out')
    ax.tick_params(axis='y',length=10,direction='out')
    ax.tick_params(axis='y',which='minor',direction='out')

# %%
import pickle
import itertools
import math
import random
import pandas as pd
import numpy as np
import networkx as nx

from datetime import date

# %%
df_air = pd.read_pickle('../data/networks/US_air_1990_2018.pkl')
nodes = set(df_air.source.unique())|set(df_air.target.unique())
df_air = df_air[df_air.source != df_air.target]
year = list(df_air.index.get_level_values(0).unique())
month = list(df_air.index.get_level_values(1).unique())
graphs_air = []
date_air = []
for y in year:
    for m in month:
#        if y != 2018 or m != 12:
        df = df_air.loc[y,m]
        date_air.append(date(y,m,1))
        G = nx.from_pandas_edgelist(df_air.loc[y,m], edge_attr=True)
        G.add_nodes_from(nodes)
        graphs_air.append(G)
        

n = date_air.index(date(2004,1,1))
graphs_air = graphs_air[n:][1:-1]
date_air =  date_air[n:][1:-1]

del df_air

# %%
graphs_decay = pickle.load(open('../scripts1/results/new_graphs_modeled_decay0.pickle.dat','rb'))

# %%
graphs_data = pickle.load(open('../scripts1/results/new_graphs_modeled_data0.pickle.dat','rb'))[1::]

# %%
graphs_data = pickle.load(open('../scripts1/results/new_graphs_modeled_data0.pickle.dat','rb'))[1::]

# %%
len(graphs_air),len(graphs_decay),len(graphs_data)
# Out:
# (178, 250, 121)

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
plt.plot(date_air,[G.number_of_edges() for G in graphs_decay[0:178]],label = 'decay')
plt.plot(date_air,[G.number_of_edges() for G in graphs_air],label='data')
plt.plot(date_air,[G.number_of_edges() for G in graphs_data[0:178]],label='model data')
plt.xlabel('Time')
plt.ylabel("Number of edges")
plt.legend()
custom_frame(ax)
plt.show()

# %%
N = graphs_air[0].number_of_nodes()
gcc_decay = [max(nx.connected_component_subgraphs(G),key=len).number_of_nodes()/N for G in graphs_decay]
gcc_data = [max(nx.connected_component_subgraphs(G),key=len).number_of_nodes()/N for G in graphs_air]

# %%
gcc_model = [max(nx.connected_component_subgraphs(G),key=len).number_of_nodes()/N for G in graphs_data]

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
#plt.plot([add_months(date_air[0],i) for i in range(len(gcc_decay))],gcc_decay,label='decay')
plt.plot(date_air,gcc_data,label='data')
plt.plot([add_months(date_air[0],i) for i in range(len(gcc_model))],gcc_model,label='model data')
plt.xlabel('Time')
plt.ylabel("Size of GCC")
plt.legend()
custom_frame(ax)
plt.show()

# %%
ass_decay = [nx.degree_pearson_correlation_coefficient(G) for G in graphs_decay]
ass_data = [nx.degree_pearson_correlation_coefficient(G) for G in graphs_air]

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
plt.plot([add_months(date_air[0],i) for i in range(len(gcc_decay))],ass_decay,label='decay')
plt.plot(date_air,ass_data,label='data')
plt.xlabel('Time')
plt.ylabel("Degree assortativity")
plt.legend()
custom_frame(ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-451-4f9421946ff3> in <module>
#       1 fig,ax = plt.subplots(figsize=(xs,ys))
# ----> 2 plt.plot([add_months(date_air[0],i) for i in range(len(gcc_decay))],ass_decay,label='decay')
#       3 plt.plot(date_air,ass_data,label='data')
#       4 plt.xlabel('Time')
#       5 plt.ylabel("Degree assortativity")
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2809     return gca().plot(
#    2810         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2811         is not None else {}), **kwargs)
#    2812
#    2813
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (249,) and (250,)

# %%
iso_decay = [list(nx.isolates(G)) for G in graphs_decay]
iso_data = [list(nx.isolates(G)) for G in graphs_air]

# %%
plt.plot([len(iso_decay[i]) for i in range(len(graphs_decay))])

# %%
from collections import Counter
Counter([make_node_name(i)[-2::] for i in iso_decay[1]])
# Out:
# Counter({'AK': 217,
#          'VT': 8,
#          'TT': 5,
#          'AR': 12,
#          'HI': 5,
#          'RI': 3,
#          'PR': 2,
#          'OR': 20,
#          'PA': 22,
#          'NC': 22,
#          'TX': 43,
#          'CA': 62,
#          'OH': 21,
#          'NE': 10,
#          'AZ': 14,
#          'ME': 16,
#          'WA': 24,
#          'CO': 11,
#          'TN': 24,
#          'MN': 10,
#          'FL': 24,
#          'MS': 14,
#          'UT': 10,
#          'WI': 15,
#          'MD': 12,
#          'IN': 14,
#          'LA': 5,
#          'NM': 10,
#          'NY': 20,
#          'MI': 21,
#          'NH': 5,
#          'VA': 13,
#          'GA': 17,
#          'ID': 11,
#          'MO': 11,
#          'SC': 12,
#          'KY': 14,
#          'IL': 16,
#          'SD': 4,
#          'WY': 6,
#          'IA': 14,
#          'NV': 13,
#          'MA': 21,
#          'CT': 6,
#          'NJ': 17,
#          'AL': 11,
#          'WV': 5,
#          'KS': 11,
#          'OK': 15,
#          'MT': 9,
#          'ND': 5,
#          'DE': 3})

# %%
evc_decay = [nx.eigenvector_centrality(G) for G in graphs_decay]
evc_data = [nx.eigenvector_centrality(G) for G in graphs_air]

# %%
sorted_evc_decay = [sorted(d.items(),key = lambda x:x[1],reverse=True) for d in evc_decay]
sorted_evc_data = [sorted(d.items(),key = lambda x:x[1],reverse=True) for d in evc_data]

# %%
for d in sorted_evc_decay[::10]:
    fig,ax = plt.subplots()
    plt.hist

# %%
for d in sorted_evc_decay:
    top = [i for i,j in d[0:10]]
    print(top,end='\n')
# Out:
# ['wilmington_oh', 'austin_tx', 'albuquerque_nm', 'omaha_ne', 'dayton_oh', 'milwaukee_wi', 'ontario_ca', 'el_paso_tx', 'oklahoma_city_ok', 'columbus_oh']
# ['austin_tx', 'providence_ri', 'raleighdurham_nc', 'hartford_ct', 'omaha_ne', 'ontario_ca', 'wilmington_oh', 'tampa_fl', 'sacramento_ca', 'el_paso_tx']
# ['west_palm_beachpalm_beach_fl', 'grand_rapids_mi', 'reno_nv', 'buffalo_ny', 'fort_myers_fl', 'santa_ana_ca', 'san_diego_ca', 'manchester_nh', 'san_jose_ca', 'richmond_va']
# ['richmond_va', 'rochester_ny', 'reno_nv', 'san_diego_ca', 'west_palm_beachpalm_beach_fl', 'birmingham_al', 'buffalo_ny', 'fort_myers_fl', 'little_rock_ar', 'atlanta_ga']
# ['atlanta_ga', 'chicago_il', 'minneapolis_mn', 'memphis_tn', 'washington_dc', 'eagle_co', 'indianapolis_in', 'houston_tx', 'detroit_mi', 'phoenix_az']
# ['atlanta_ga', 'memphis_tn', 'chicago_il', 'dallasfort_worth_tx', 'houston_tx', 'minneapolis_mn', 'washington_dc', 'indianapolis_in', 'phoenix_az', 'valparaiso_fl']
# ['atlanta_ga', 'chicago_il', 'houston_tx', 'washington_dc', 'philadelphia_pa', 'phoenix_az', 'memphis_tn', 'valparaiso_fl', 'long_beach_ca', 'denver_co']
# ['washington_dc', 'dallasfort_worth_tx', 'minneapolis_mn', 'atlanta_ga', 'houston_tx', 'chicago_il', 'anchorage_ak', 'eagle_co', 'phoenix_az', 'green_bay_wi']
# ['new_york_ny', 'atlanta_ga', 'chicago_il', 'dallasfort_worth_tx', 'anchorage_ak', 'minneapolis_mn', 'houston_tx', 'eagle_co', 'phoenix_az', 'denver_co']
# ['houston_tx', 'chicago_il', 'eagle_co', 'minneapolis_mn', 'denver_co', 'tucson_az', 'dallasfort_worth_tx', 'anchorage_ak', 'phoenix_az', 'gunnison_co']
# ['chicago_il', 'new_york_ny', 'eagle_co', 'anchorage_ak', 'washington_dc', 'detroit_mi', 'atlanta_ga', 'seattle_wa', 'rapid_city_sd', 'minneapolis_mn']
# ['chicago_il', 'austin_tx', 'anchorage_ak', 'new_york_ny', 'eagle_co', 'daytona_beach_fl', 'atlanta_ga', 'sioux_falls_sd', 'tucson_az', 'detroit_mi']
# ['chicago_il', 'atlanta_ga', 'eagle_co', 'denver_co', 'austin_tx', 'new_york_ny', 'rapid_city_sd', 'daytona_beach_fl', 'college_stationbryan_tx', 'dallasfort_worth_tx']
# ['chicago_il', 'atlanta_ga', 'new_york_ny', 'ontario_ca', 'denver_co', 'eagle_co', 'rapid_city_sd', 'washington_dc', 'minneapolis_mn', 'sioux_falls_sd']
# ['atlanta_ga', 'new_york_ny', 'chicago_il', 'washington_dc', 'daytona_beach_fl', 'rapid_city_sd', 'detroit_mi', 'eagle_co', 'college_stationbryan_tx', 'austin_tx']
# ['atlanta_ga', 'college_stationbryan_tx', 'washington_dc', 'chicago_il', 'ontario_ca', 'eagle_co', 'minneapolis_mn', 'new_york_ny', 'houston_tx', 'rapid_city_sd']
# ['ontario_ca', 'washington_dc', 'eagle_co', 'atlanta_ga', 'chicago_il', 'minneapolis_mn', 'new_york_ny', 'bismarckmandan_nd', 'boston_ma', 'dallasfort_worth_tx']
# ['chicago_il', 'atlanta_ga', 'daytona_beach_fl', 'washington_dc', 'ontario_ca', 'new_york_ny', 'roche_harbor_wa', 'eagle_co', 'nashville_tn', 'minneapolis_mn']
# ['chicago_il', 'new_york_ny', 'atlanta_ga', 'washington_dc', 'ontario_ca', 'daytona_beach_fl', 'lake_jackson_tx', 'eagle_co', 'dallasfort_worth_tx', 'tucson_az']
# ['chicago_il', 'washington_dc', 'new_york_ny', 'eagle_co', 'atlanta_ga', 'daytona_beach_fl', 'detroit_mi', 'lake_jackson_tx', 'newark_nj', 'fargo_nd']
# ['chicago_il', 'eagle_co', 'lake_jackson_tx', 'atlanta_ga', 'new_york_ny', 'washington_dc', 'dallasfort_worth_tx', 'detroit_mi', 'boston_ma', 'manhattanft_riley_ks']
# ['detroit_mi', 'eagle_co', 'lake_jackson_tx', 'chicago_il', 'new_york_ny', 'washington_dc', 'rangely_co', 'dallasfort_worth_tx', 'newark_nj', 'minneapolis_mn']
# ['lake_jackson_tx', 'chicago_il', 'washington_dc', 'nashville_tn', 'new_york_ny', 'eagle_co', 'rapid_city_sd', 'detroit_mi', 'santa_ana_ca', 'college_stationbryan_tx']
# ['lake_jackson_tx', 'washington_dc', 'new_york_ny', 'boston_ma', 'eagle_co', 'rapid_city_sd', 'chicago_il', 'detroit_mi', 'nashville_tn', 'atlanta_ga']
# ['lake_jackson_tx', 'atlanta_ga', 'rapid_city_sd', 'newark_nj', 'chicago_il', 'washington_dc', 'nashville_tn', 'new_york_ny', 'eagle_co', 'detroit_mi']
# ['lake_jackson_tx', 'newark_nj', 'atlanta_ga', 'detroit_mi', 'college_stationbryan_tx', 'eagle_co', 'new_york_ny', 'rapid_city_sd', 'chicago_il', 'dallasfort_worth_tx']
# ['lake_jackson_tx', 'newark_nj', 'atlanta_ga', 'detroit_mi', 'college_stationbryan_tx', 'chicago_il', 'hayden_co', 'dallasfort_worth_tx', 'sheldon_point_ak', 'tallahassee_fl']
# ['lake_jackson_tx', 'atlanta_ga', 'chicago_il', 'bozeman_mt', 'rangely_co', 'hayden_co', 'newark_nj', 'detroit_mi', 'myrtle_beach_sc', 'arctic_village_ak']
# ['lake_jackson_tx', 'atlanta_ga', 'medford_or', 'hayden_co', 'bozeman_mt', 'arctic_village_ak', 'new_york_ny', 'detroit_mi', 'devils_lake_nd', 'teterboro_nj']
# ['atlanta_ga', 'lake_jackson_tx', 'bozeman_mt', 'arctic_village_ak', 'new_york_ny', 'chicago_il', 'stuart_fl', 'tallahassee_fl', 'apple_valley_ca', 'newark_nj']
# ['lake_jackson_tx', 'bozeman_mt', 'atlanta_ga', 'tallahassee_fl', 'arctic_village_ak', 'aztec_nm', 'san_luis_obispo_ca', 'new_york_ny', 'medford_or', 'christiansted_vi']
# ['lake_jackson_tx', 'bozeman_mt', 'atlanta_ga', 'arctic_village_ak', 'new_york_ny', 'teterboro_nj', 'detroit_mi', 'stuart_fl', 'tallahassee_fl', 'hayden_co']
# ['stuart_fl', 'atlanta_ga', 'lake_jackson_tx', 'new_york_ny', 'christiansted_vi', 'arctic_village_ak', 'tallahassee_fl', 'chicago_il', 'bozeman_mt', 'oscoda_mi']
# ['atlanta_ga', 'arctic_village_ak', 'lake_jackson_tx', 'teterboro_nj', 'oscoda_mi', 'devils_lake_nd', 'new_york_ny', 'nuiqsut_ak', 'tallahassee_fl', 'bozeman_mt']
# ['new_york_ny', 'atlanta_ga', 'arctic_village_ak', 'denver_co', 'lake_jackson_tx', 'christiansted_vi', 'teterboro_nj', 'bozeman_mt', 'devils_lake_nd', 'bullhead_city_az']
# ['atlanta_ga', 'lake_jackson_tx', 'new_york_ny', 'bullhead_city_az', 'arctic_village_ak', 'teterboro_nj', 'hartsville_sc', 'pellston_mi', 'stuart_fl', 'daytona_beach_fl']
# ['new_york_ny', 'atlanta_ga', 'lake_jackson_tx', 'port_alsworth_ak', 'arctic_village_ak', 'bullhead_city_az', 'bozeman_mt', 'daytona_beach_fl', 'shishmaref_ak', 'pocatello_id']
# ['lake_jackson_tx', 'atlanta_ga', 'hartsville_sc', 'new_york_ny', 'devils_lake_nd', 'arctic_village_ak', 'pocatello_id', 'illinois_creek_ak', 'apple_valley_ca', 'tallahassee_fl']
# ['atlanta_ga', 'tallahassee_fl', 'arctic_village_ak', 'new_york_ny', 'minneapolis_mn', 'gillette_wy', 'hartsville_sc', 'bozeman_mt', 'daytona_beach_fl', 'lake_jackson_tx']
# ['minneapolis_mn', 'atlanta_ga', 'arctic_village_ak', 'bozeman_mt', 'lake_jackson_tx', 'port_alsworth_ak', 'pocatello_id', 'mobile_al', 'gillette_wy', 'tallahassee_fl']
# ['atlanta_ga', 'arctic_village_ak', 'bozeman_mt', 'lake_jackson_tx', 'pocatello_id', 'minneapolis_mn', 'mobile_al', 'rocky_mount_nc', 'owensboro_ky', 'washington_dc']
# ['atlanta_ga', 'bozeman_mt', 'hartsville_sc', 'apple_valley_ca', 'lihue_hi', 'williston_nd', 'mobile_al', 'minneapolis_mn', 'schenectady_ny', 'mekoryuk_ak']
# ['atlanta_ga', 'tallahassee_fl', 'pellston_mi', 'minneapolis_mn', 'arctic_village_ak', 'schenectady_ny', 'mobile_al', 'new_york_ny', 'apple_valley_ca', 'daytona_beach_fl']
# ['atlanta_ga', 'tallahassee_fl', 'princetonbluefield_wv', 'apple_valley_ca', 'arctic_village_ak', 'gainesville_fl', 'minneapolis_mn', 'schenectady_ny', 'nuiqsut_ak', 'pellston_mi']
# ['atlanta_ga', 'arctic_village_ak', 'minneapolis_mn', 'rocky_mount_nc', 'apple_valley_ca', 'tallahassee_fl', 'pellston_mi', 'gainesville_fl', 'hana_hi', 'bozeman_mt']
# ['atlanta_ga', 'apple_valley_ca', 'arctic_village_ak', 'unalaska_ak', 'kasigluk_ak', 'charleston_sc', 'hana_hi', 'minneapolis_mn', 'visalia_ca', 'binghamton_ny']
# ['atlanta_ga', 'minneapolis_mn', 'arctic_village_ak', 'apple_valley_ca', 'hana_hi', 'aztec_nm', 'kwigillingok_ak', 'mobile_al', 'newark_nj', 'bozeman_mt']
# ['atlanta_ga', 'apple_valley_ca', 'mobile_al', 'schenectady_ny', 'arctic_village_ak', 'kwigillingok_ak', 'newark_nj', 'minneapolis_mn', 'fort_dodge_ia', 'south_bend_in']
# ['atlanta_ga', 'mobile_al', 'apple_valley_ca', 'newark_nj', 'kwigillingok_ak', 'arctic_village_ak', 'minneapolis_mn', 'oscoda_mi', 'dodge_city_ks', 'fort_dodge_ia']
# ['atlanta_ga', 'apple_valley_ca', 'minneapolis_mn', 'dodge_city_ks', 'mobile_al', 'newark_nj', 'kwigillingok_ak', 'quincy_wa', 'owensboro_ky', 'south_bend_in']
# ['apple_valley_ca', 'atlanta_ga', 'snettisham_ak', 'decatur_island_wa', 'minneapolis_mn', 'dodge_city_ks', 'newark_nj', 'quincy_wa', 'south_bend_in', 'bozeman_mt']
# ['apple_valley_ca', 'atlanta_ga', 'snettisham_ak', 'merced_ca', 'newark_nj', 'dodge_city_ks', 'kivalina_ak', 'mobile_al', 'quincy_wa', 'south_bend_in']
# ['apple_valley_ca', 'snettisham_ak', 'merced_ca', 'aniak_ak', 'dodge_city_ks', 'atlanta_ga', 'arctic_village_ak', 'mobile_al', 'pellston_mi', 'aztec_nm']
# ['apple_valley_ca', 'atlanta_ga', 'dodge_city_ks', 'decatur_island_wa', 'merced_ca', 'prosser_wa', 'south_bend_in', 'indianapolis_in', 'aniak_ak', 'snettisham_ak']
# ['apple_valley_ca', 'dover_de', 'prosser_wa', 'dodge_city_ks', 'south_bend_in', 'owensboro_ky', 'snettisham_ak', 'bismarckmandan_nd', 'ponca_city_ok', 'atlanta_ga']
# ['apple_valley_ca', 'daggett_ca', 'dover_de', 'snettisham_ak', 'prosser_wa', 'eureka_ca', 'newark_nj', 'goodnews_bay_ak', 'gainesville_fl', 'aniak_ak']
# ['apple_valley_ca', 'dover_de', 'snettisham_ak', 'prosser_wa', 'newark_nj', 'gainesville_fl', 'bismarckmandan_nd', 'williamsport_pa', 'owensboro_ky', 'bozeman_mt']
# ['dover_de', 'prosser_wa', 'newark_nj', 'bismarckmandan_nd', 'apple_valley_ca', 'snettisham_ak', 'owensboro_ky', 'traverse_city_mi', 'south_bend_in', 'fort_collinsloveland_co']
# ['dover_de', 'newark_nj', 'apple_valley_ca', 'bismarckmandan_nd', 'williamsport_pa', 'owensboro_ky', 'bullhead_city_az', 'prosser_wa', 'snettisham_ak', 'havre_mt']
# ['dover_de', 'apple_valley_ca', 'savoonga_ak', 'newark_nj', 'decatur_island_wa', 'bismarckmandan_nd', 'gainesville_fl', 'prosser_wa', 'fort_collinsloveland_co', 'fort_dodge_ia']
# ['dover_de', 'gainesville_fl', 'apple_valley_ca', 'newark_nj', 'bismarckmandan_nd', 'owensboro_ky', 'decatur_il', 'savoonga_ak', 'prosser_wa', 'beaufort_sc']
# ['dover_de', 'gainesville_fl', 'newark_nj', 'savoonga_ak', 'yes_bay_ak', 'prosser_wa', 'havre_mt', 'valparaiso_in', 'dodge_city_ks', 'kinston_nc']
# ['dover_de', 'gainesville_fl', 'newark_nj', 'savoonga_ak', 'prosser_wa', 'havre_mt', 'montrosedelta_co', 'beaufort_sc', 'valparaiso_in', 'kaktovik_ak']
# ['dover_de', 'bristoljohnson_citykingsport_tn', 'savoonga_ak', 'havre_mt', 'prosser_wa', 'newark_nj', 'decatur_island_wa', 'gainesville_fl', 'santa_ana_ca', 'daggett_ca']
# ['dover_de', 'savoonga_ak', 'prosser_wa', 'bristoljohnson_citykingsport_tn', 'santa_ana_ca', 'newark_nj', 'havre_mt', 'kapalua_hi', 'bozeman_mt', 'bullhead_city_az']
# ['dover_de', 'savoonga_ak', 'prosser_wa', 'bristoljohnson_citykingsport_tn', 'aniak_ak', 'santa_ana_ca', 'kapalua_hi', 'montrosedelta_co', 'lawrenceburg_tn', 'princetonbluefield_wv']
# ['dover_de', 'montrosedelta_co', 'lawrenceburg_tn', 'quincy_il', 'kapalua_hi', 'oscoda_mi', 'savoonga_ak', 'bullhead_city_az', 'prosser_wa', 'bristoljohnson_citykingsport_tn']
# ['dover_de', 'oscoda_mi', 'lawrenceburg_tn', 'quincy_il', 'savoonga_ak', 'lewistown_mt', 'montrosedelta_co', 'havre_mt', 'mobile_al', 'santa_ana_ca']
# ['dover_de', 'oscoda_mi', 'lawrenceburg_tn', 'kapalua_hi', 'bristoljohnson_citykingsport_tn', 'princetonbluefield_wv', 'santa_ana_ca', 'savoonga_ak', 'lewistown_mt', 'south_bend_in']
# ['dover_de', 'lawrenceburg_tn', 'kapalua_hi', 'santa_ana_ca', 'oscoda_mi', 'princetonbluefield_wv', 'bristoljohnson_citykingsport_tn', 'prosser_wa', 'dodge_city_ks', 'lewistown_mt']
# ['dover_de', 'lewistown_mt', 'oscoda_mi', 'kapalua_hi', 'lawrenceburg_tn', 'bristoljohnson_citykingsport_tn', 'dodge_city_ks', 'south_bend_in', 'santa_ana_ca', 'bar_harbor_me']
# ['dover_de', 'lewistown_mt', 'dodge_city_ks', 'bristoljohnson_citykingsport_tn', 'lawrenceburg_tn', 'prosser_wa', 'kapalua_hi', 'south_bend_in', 'savoonga_ak', 'togiak_ak']
# ['dover_de', 'bristoljohnson_citykingsport_tn', 'prosser_wa', 'lewistown_mt', 'lawrenceburg_tn', 'bar_harbor_me', 'oscoda_mi', 'santa_ana_ca', 'williston_nd', 'dodge_city_ks']
# ['dover_de', 'lewistown_mt', 'bristoljohnson_citykingsport_tn', 'lawrenceburg_tn', 'prosser_wa', 'dodge_city_ks', 'bar_harbor_me', 'williston_nd', 'kearney_ne', 'oscoda_mi']
# ['dover_de', 'lewistown_mt', 'oscoda_mi', 'bristoljohnson_citykingsport_tn', 'dodge_city_ks', 'santa_ana_ca', 'bar_harbor_me', 'south_bend_in', 'togiak_ak', 'lawrenceburg_tn']
# ['dover_de', 'lewistown_mt', 'dodge_city_ks', 'south_bend_in', 'oscoda_mi', 'bristoljohnson_citykingsport_tn', 'togiak_ak', 'lawrenceburg_tn', 'kwethluk_ak', 'prosser_wa']
# ['lewistown_mt', 'dover_de', 'bristoljohnson_citykingsport_tn', 'dodge_city_ks', 'kinston_nc', 'south_bend_in', 'prosser_wa', 'state_college_pa', 'oscoda_mi', 'great_bend_ks']
# ['lewistown_mt', 'dover_de', 'bristoljohnson_citykingsport_tn', 'state_college_pa', 'lawrenceburg_tn', 'kinston_nc', 'la_crosse_wi', 'santa_ana_ca', 'dodge_city_ks', 'prosser_wa']
# ['lewistown_mt', 'dover_de', 'dodge_city_ks', 'bristoljohnson_citykingsport_tn', 'state_college_pa', 'smyrna_tn', 'tinian_tt', 'muscle_shoals_al', 'yuma_az', 'thomasville_ga']
# ['dodge_city_ks', 'lewistown_mt', 'dover_de', 'smyrna_tn', 'bristoljohnson_citykingsport_tn', 'red_devil_ak', 'cambridge_md', 'tinian_tt', 'thomasville_ga', 'muscle_shoals_al']
# ['lewistown_mt', 'dodge_city_ks', 'dover_de', 'cambridge_md', 'smyrna_tn', 'yuma_az', 'bristoljohnson_citykingsport_tn', 'tinian_tt', 'apple_valley_ca', 'decatur_il']
# ['lewistown_mt', 'dodge_city_ks', 'dover_de', 'yuma_az', 'cambridge_md', 'red_devil_ak', 'bristoljohnson_citykingsport_tn', 'morgantown_wv', 'muscle_shoals_al', 'decatur_il']
# ['cambridge_md', 'lewistown_mt', 'dodge_city_ks', 'yuma_az', 'decatur_il', 'red_devil_ak', 'bristoljohnson_citykingsport_tn', 'great_bend_ks', 'daggett_ca', 'state_college_pa']
# ['cambridge_md', 'lewistown_mt', 'dodge_city_ks', 'red_devil_ak', 'great_bend_ks', 'kwigillingok_ak', 'la_crosse_wi', 'yuma_az', 'west_dover_vt', 'kinston_nc']
# ['cambridge_md', 'dodge_city_ks', 'lewistown_mt', 'great_bend_ks', 'red_devil_ak', 'yuma_az', 'enid_ok', 'kwigillingok_ak', 'west_dover_vt', 'thermal_ca']
# ['dodge_city_ks', 'cambridge_md', 'lewistown_mt', 'decatur_il', 'yuma_az', 'kwigillingok_ak', 'prosser_wa', 'great_bend_ks', 'thermal_ca', 'cape_lisburne_ak']
# ['dodge_city_ks', 'cambridge_md', 'lewistown_mt', 'great_bend_ks', 'yuma_az', 'bishop_ca', 'decatur_il', 'kwigillingok_ak', 'anniston_al', 'prosser_wa']
# ['lewistown_mt', 'dodge_city_ks', 'cambridge_md', 'yuma_az', 'great_bend_ks', 'decatur_il', 'prosser_wa', 'kwigillingok_ak', 'pembina_nd', 'chignik_bay_ak']
# ['dodge_city_ks', 'lewistown_mt', 'cambridge_md', 'great_bend_ks', 'yuma_az', 'cape_greig_ak', 'decatur_il', 'koyuk_ak', 'kwigillingok_ak', 'worcester_ma']
# ['dodge_city_ks', 'lewistown_mt', 'cambridge_md', 'yuma_az', 'great_bend_ks', 'worcester_ma', 'thermal_ca', 'mountain_view_ca', 'kwigillingok_ak', 'kake_ak']
# ['dodge_city_ks', 'great_bend_ks', 'lewistown_mt', 'cambridge_md', 'kake_ak', 'clarksville_tn', 'yuma_az', 'koyuk_ak', 'cocoa_beach_fl', 'kwigillingok_ak']
# ['dodge_city_ks', 'clarksville_tn', 'mountain_view_ca', 'lewistown_mt', 'cocoa_beach_fl', 'kake_ak', 'yuma_az', 'great_bend_ks', 'worcester_ma', 'ukiah_ca']
# ['dodge_city_ks', 'lewistown_mt', 'mountain_view_ca', 'cambridge_md', 'worcester_ma', 'cocoa_beach_fl', 'clarksville_tn', 'great_bend_ks', 'pembina_nd', 'yuma_az']
# ['dodge_city_ks', 'lewistown_mt', 'cocoa_beach_fl', 'cambridge_md', 'worcester_ma', 'mountain_view_ca', 'clarksville_tn', 'thermal_ca', 'la_crosse_wi', 'douglas_az']
# ['lewistown_mt', 'dodge_city_ks', 'la_crosse_wi', 'cocoa_beach_fl', 'worcester_ma', 'thermal_ca', 'merritt_island_fl', 'cambridge_md', 'hilo_hi', 'clarksville_tn']
# ['dodge_city_ks', 'lewistown_mt', 'worcester_ma', 'thermal_ca', 'cocoa_beach_fl', 'la_crosse_wi', 'clarksville_tn', 'kake_ak', 'cambridge_md', 'staunton_va']
# ['worcester_ma', 'lewistown_mt', 'kake_ak', 'thermal_ca', 'la_crosse_wi', 'fort_smith_ar', 'dodge_city_ks', 'hope_ak', 'clarksville_tn', 'yuma_az']
# ['lewistown_mt', 'worcester_ma', 'cocoa_beach_fl', 'la_crosse_wi', 'fort_smith_ar', 'kake_ak', 'decatur_island_wa', 'staunton_va', 'cambridge_md', 'willmar_mn']
# ['worcester_ma', 'lewistown_mt', 'kake_ak', 'la_crosse_wi', 'staunton_va', 'thermal_ca', 'international_falls_mn', 'clarksville_tn', 'state_college_pa', 'carlsbad_ca']
# ['worcester_ma', 'lewistown_mt', 'kake_ak', 'la_crosse_wi', 'danger_bay_ak', 'willmar_mn', 'jefferson_city_mo', 'teller_ak', 'kasaan_ak', 'ozona_tx']
# ['worcester_ma', 'lewistown_mt', 'kake_ak', 'brunswick_me', 'salida_co', 'black_river_falls_wi', 'edenton_nc', 'tetlin_ak', 'hopkinsville_ky', 'teller_ak']
# ['worcester_ma', 'kake_ak', 'lewistown_mt', 'tacoma_wa', 'edenton_nc', 'salida_co', 'naples_fl', 'de_kalb_il', 'kingman_az', 'hilo_hi']
# ['lewistown_mt', 'worcester_ma', 'tacoma_wa', 'kake_ak', 'millville_nj', 'international_falls_mn', 'danger_bay_ak', 'edenton_nc', 'port_armstrong_ak', 'hilo_hi']
# ['lewistown_mt', 'worcester_ma', 'kake_ak', 'hilo_hi', 'west_palm_beach_fl', 'prospect_creek_ak', 'umiat_ak', 'danger_bay_ak', 'greensboro_ga', 'council_bluffs_ia']
# ['lewistown_mt', 'worcester_ma', 'de_kalb_il', 'rome_ga', 'craig_ak', 'international_falls_mn', 'reading_pa', 'prospect_creek_ak', 'whitmore_az', 'davenport_ia']
# ['prospect_creek_ak', 'worcester_ma', 'lewistown_mt', 'edenton_nc', 'reading_pa', 'davenport_ia', 'jackson_mi', 'hilo_hi', 'de_kalb_il', 'spencer_ia']
# ['jackson_mi', 'edenton_nc', 'garrison_nd', 'reading_pa', 'davenport_ia', 'international_falls_mn', 'twin_hills_ak', 'laconia_nh', 'kingman_az', 'battle_creek_mi']
# ['edenton_nc', 'jackson_mi', 'laconia_nh', 'pendleton_or', 'gaylord_mi', 'reading_pa', 'cheraw_sc', 'davenport_ia', 'worcester_ma', 'rome_ga']
# ['gaylord_mi', 'edenton_nc', 'southampton_ny', 'pendleton_or', 'jackson_mi', 'chelatna_lake_lodge_ak', 'west_palm_beach_fl', 'rome_ga', 'laconia_nh', 'marquette_mi']
# ['pendleton_or', 'laconia_nh', 'edenton_nc', 'gaylord_mi', 'jackson_mi', 'marquette_mi', 'southampton_ny', 'hilo_hi', 'garrison_nd', 'battle_creek_mi']
# ['pendleton_or', 'jackson_mi', 'hilo_hi', 'edenton_nc', 'chelatna_lake_lodge_ak', 'false_pass_ak', 'southampton_ny', 'marquette_mi', 'gaylord_mi', 'manley_hot_springs_ak']
# ['jackson_mi', 'monte_vista_co', 'marquette_mi', 'gaylord_mi', 'pendleton_or', 'wisconsin_rapids_wi', 'hilo_hi', 'edenton_nc', 'rockford_il', 'battle_creek_mi']
# ['pendleton_or', 'marquette_mi', 'jackson_mi', 'monte_vista_co', 'edenton_nc', 'wisconsin_rapids_wi', 'battle_creek_mi', 'fort_leonard_wood_mo', 'southampton_ny', 'flagstaff_az']
# ['pendleton_or', 'marquette_mi', 'wisconsin_rapids_wi', 'brunswick_me', 'garrison_nd', 'edenton_nc', 'jefferson_city_mo', 'fort_leonard_wood_mo', 'southampton_ny', 'danville_il']
# ['brunswick_me', 'edenton_nc', 'batesville_ar', 'park_rapids_mn', 'rawlins_wy', 'lanai_hi', 'pendleton_or', 'cheraw_sc', 'jefferson_city_mo', 'telida_ak']
# ['edenton_nc', 'rawlins_wy', 'cheraw_sc', 'ticonderoga_ny', 'victoria_tx', 'batesville_ar', 'brunswick_me', 'marquette_mi', 'garrison_nd', 'andalusiaopp_al']
# ['edenton_nc', 'anniston_al', 'cheraw_sc', 'shell_lake_ak', 'salem_or', 'brunswick_me', 'anderson_in', 'pueblo_co', 'yankton_sd', 'escanaba_mi']
# ['cocoa_beach_fl', 'edenton_nc', 'paducah_ky', 'anniston_al', 'yankton_sd', 'pueblo_co', 'point_baker_ak', 'port_graham_ak', 'eagle_river_wi', 'selief_bay_ak']
# ['edenton_nc', 'yankton_sd', 'ninilchik_ak', 'bear_lake_ak', 'jamestown_nd', 'cocoa_beach_fl', 'williamsport_pa', 'eagle_river_wi', 'leesburg_va', 'manley_hot_springs_ak']
# ['jamestown_nd', 'yankton_sd', 'ekuk_ak', 'southampton_ny', 'hot_springs_ar', 'cocoa_beach_fl', 'manley_hot_springs_ak', 'williamsport_pa', 'willmar_mn', 'quincy_wa']
# ['jamestown_nd', 'cheraw_sc', 'summerville_sc', 'cocoa_beach_fl', 'bear_lake_ak', 'willmar_mn', 'skagway_ak', 'iron_mountainkingsfd_mi', 'port_vita_ak', 'false_island_ak']
# ['east_hampton_ny', 'jamestown_nd', 'summerville_sc', 'devils_lake_nd', 'cheraw_sc', 'williamsport_pa', 'marionherrin_il', 'albemarle_nc', 'iron_mountainkingsfd_mi', 'sevierville_tn']
# ['summerville_sc', 'jamestown_nd', 'ballinger_tx', 'marana_az', 'devils_lake_nd', 'key_largo_fl', 'chomondely_sound_ak', 'davenport_ia', 'brooks_lodge_ak', 'williamsport_pa']
# ['pellston_mi', 'mount_holly_nj', 'danville_va', 'sevierville_tn', 'rockford_il', 'williamsport_pa', 'pine_bluff_ar', 'notchitoches_la', 'washington_pa', 'san_marcos_tx']
# ['san_marcos_tx', 'truckee_ca', 'danville_va', 'rockwood_tn', 'washington_pa', 'pellston_mi', 'notchitoches_la', 'del_rio_tx', 'moab_ut', 'yukon_charley_rivvers_ak']
# ['black_river_falls_wi', 'pellston_mi', 'washington_pa', 'phillips_wi', 'lawtonfort_sill_ok', 'danville_va', 'point_baker_ak', 'wilkesboro_nc', 'gaylord_mi', 'mccomb_ms']
# ['danville_va', 'washington_pa', 'phillips_wi', 'marquette_mi', 'santa_barbara_ca', 'donlin_creek_ak', 'davenport_ia', 'wilkesboro_nc', 'south_haven_mi', 'fort_meade_md']
# ['washington_pa', 'marquette_mi', 'telida_ak', 'south_haven_mi', 'big_rapids_mi', 'chico_ca', 'notchitoches_la', 'reserve_la', 'phillips_wi', 'kamuela_hi']
# ['chico_ca', 'notchitoches_la', 'washington_pa', 'south_haven_mi', 'rockwood_tn', 'phillips_wi', 'mason_city_ia', 'donlin_creek_ak', 'west_dover_vt', 'ely_mn']
# ['south_haven_mi', 'fallon_nv', 'mason_city_ia', 'rockwood_tn', 'joplin_mo', 'west_dover_vt', 'mccarthy_ak', 'blaine_wa', 'mccomb_ms', 'washington_pa']
# ['rodman_bay_ak', 'mccomb_ms', 'fallon_nv', 'mason_city_ia', 'washington_pa', 'blaine_wa', 'lawtonfort_sill_ok', 'joplin_mo', 'south_haven_mi', 'fort_smith_ar']
# ['fallon_nv', 'mccomb_ms', 'santa_maria_ca', 'washington_pa', 'rodman_bay_ak', 'fort_smith_ar', 'saltery_cove_ak', 'apple_valley_ca', 'south_haven_mi', 'thorne_bay_ak']
# ['fallon_nv', 'telida_ak', 'point_baker_ak', 'rodman_bay_ak', 'port_vita_ak', 'mason_city_ia', 'washington_pa', 'mccomb_ms', 'ouzinkie_ak', 'manistique_mi']
# ['point_baker_ak', 'manistique_mi', 'mason_city_ia', 'walnut_ridge_ar', 'washington_pa', 'fallon_nv', 'dodge_city_ks', 'mccall_id', 'lawtonfort_sill_ok', 'buffalo_wy']
# ['bay_st_louis_ms', 'point_baker_ak', 'battle_creek_mi', 'fallon_nv', 'millinocket_me', 'dodge_city_ks', 'mason_city_ia', 'washington_pa', 'galbraith_lake_ak', 'labouchere_bay_ak']
# ['millinocket_me', 'rome_ga', 'bay_st_louis_ms', 'lemoore_ca', 'mason_city_ia', 'fallon_nv', 'point_baker_ak', 'tifton_ga', 'hanalei_hi', 'washington_pa']
# ['mason_city_ia', 'red_wing_mn', 'millinocket_me', 'fallon_nv', 'bay_st_louis_ms', 'point_baker_ak', 'vieques_pr', 'toledo_oh', 'false_island_ak', 'coeur_dalene_id']
# ['fallon_nv', 'mason_city_ia', 'zephyrhills_fl', 'yankton_sd', 'wake_island_tt', 'reading_pa', 'red_wing_mn', 'bay_st_louis_ms', 'coeur_dalene_id', 'hanalei_hi']
# ['ouzinkie_ak', 'red_wing_mn', 'hanalei_hi', 'mason_city_ia', 'yankton_sd', 'telida_ak', 'muskegon_mi', 'reading_pa', 'bay_st_louis_ms', 'wake_island_tt']
# ['red_wing_mn', 'mason_city_ia', 'hanalei_hi', 'tetlin_ak', 'belfast_me', 'vieques_pr', 'victoria_tx', 'wake_island_tt', 'zuni_pueblo_nm', 'anderson_in']
# ['victoria_tx', 'red_wing_mn', 'false_island_ak', 'westhampton_ny', 'vieques_pr', 'zephyrhills_fl', 'port_graham_ak', 'imperial_ne', 'mason_city_ia', 'kako_ak']
# ['vieques_pr', 'port_graham_ak', 'petaluma_ca', 'red_wing_mn', 'danville_va', 'ekwok_ak', 'ganes_creek_ak', 'elfin_cove_ak', 'kamuela_hi', 'aztec_nm']
# ['vieques_pr', 'mason_city_ia', 'torrance_ca', 'victoria_tx', 'petaluma_ca', 'ekwok_ak', 'hawk_inlet_ak', 'batesville_ar', 'taylor_mountain_mine_ak', 'aztec_nm']
# ['vieques_pr', 'victoria_tx', 'mesquite_nv', 'eveleth_mn', 'rawlins_wy', 'torrance_ca', 'palmdale_ca', 'false_pass_ak', 'franklinoil_city_pa', 'santa_maria_ca']
# ['vieques_pr', 'mesquite_nv', 'monroe_ga', 'vernal_ut', 'kamuela_hi', 'ellensburg_wa', 'telida_ak', 'torrance_ca', 'williamsport_pa', 'coeur_dalene_id']
# ['vieques_pr', 'mesquite_nv', 'muskegon_mi', 'dune_lake_ak', 'ivatuk_ak', 'gull_cove_ak', 'roseburg_or', 'rawlins_wy', 'gettysburg_pa', 'mount_holly_nj']
# ['vieques_pr', 'muskegon_mi', 'greenville_mi', 'red_wing_mn', 'newcastle_wy', 'williston_nd', 'greenwood_sc', 'syracuse_ny', 'albemarle_nc', 'bermuda_dunes_ca']
# ['vieques_pr', 'northeast_cape_ak', 'westfield_ma', 'chincoteague_va', 'mayaguez_pr', 'port_graham_ak', 'sumter_sc', 'pembina_nd', 'willits_ca', 'malta_mt']
# ['vieques_pr', 'saratoga_springs_ny', 'sumter_sc', 'westfield_ma', 'wheeling_wv', 'port_graham_ak', 'view_cove_ak', 'mena_ar', 'coeur_dalene_id', 'bear_lake_ak']
# ['san_bernardino_ca', 'westfield_ma', 'cosna_river_ak', 'coeur_dalene_id', 'porterville_ca', 'brewster_wa', 'dodge_city_ks', 'vieques_pr', 'view_cove_ak', 'st_augustine_fl']
# ['wiseman_ak', 'tupelo_ms', 'pompano_beach_fl', 'cosna_river_ak', 'galbraith_lake_ak', 'natchez_ms', 'st_augustine_fl', 'bennington_vt', 'selinsgrove_pa', 'eveleth_mn']
# ['kingman_az', 'natchez_ms', 'heber_ut', 'wiseman_ak', 'wilmington_de', 'homestead_fl', 'haycock_ak', 'cosna_river_ak', 'pompano_beach_fl', 'greenville_tx']
# ['wilmington_de', 'mount_holly_nj', 'pompano_beach_fl', 'lawrenceburg_tn', 'cosna_river_ak', 'hanus_bay_ak', 'burns_or', 'wiseman_ak', 'port_vita_ak', 'view_cove_ak']
# ['wilmington_de', 'pompano_beach_fl', 'rome_ga', 'hanus_bay_ak', 'muskegon_mi', 'novato_ca', 'tracy_arm_ak', 'burns_or', 'kenansville_nc', 'bay_city_tx']
# ['novato_ca', 'ozona_tx', 'wilmington_de', 'homestead_fl', 'broken_bow_ne', 'chillicothe_oh', 'cosna_river_ak', 'lawrenceburg_tn', 'burns_or', 'tracy_arm_ak']
# ['ozona_tx', 'troutdale_or', 'cosna_river_ak', 'pembina_nd', 'albemarle_nc', 'broken_bow_ne', 'wilmington_de', 'dowagiac_mi', 'mccomb_ms', 'gambell_ak']
# ['rome_ga', 'hartsville_sc', 'troutdale_or', 'muskegon_mi', 'the_dalles_or', 'elizabethtown_ky', 'salina_ks', 'granite_mountain_ak', 'tullahoma_tn', 'whalers_cove_lodge_ak']
# ['tullahoma_tn', 'gambell_ak', 'st_augustine_fl', 'sherman-denison_tx', 'salina_ks', 'wilkesboro_nc', 'stehekin_wa', 'elizabethtown_ky', 'metlakatla_ak', 'hollis_ak']
# ['gambell_ak', 'wilkesboro_nc', 'stehekin_wa', 'corner_bay_ak', 'sequim_wa', 'stillwater_ok', 'hoquiam_wa', 'pompano_beach_fl', 'cannery_bay_ak', 'cape_yakataga_ak']
# ['wilmington_de', 'stehekin_wa', 'fortuna_ca', 'wheeling_wv', 'ivatuk_ak', 'coffman_cove_ak', 'sturgis_mi', 'yukon_charley_rivvers_ak', 'troutdale_or', 'wilkesboro_nc']
# ['sturgis_mi', 'zephyrhills_fl', 'wheeling_wv', 'macomb_il', 'clinton_ia', 'troutdale_or', 'williams_az', 'ivatuk_ak', 'minocquawoodruff_wi', 'coffman_cove_ak']
# ['sturgis_mi', 'prosser_wa', 'jefferson_city_mo', 'wheeling_wv', 'brooksville_fl', 'greenville_mi', 'williams_az', 'laramie_wy', 'port_graham_ak', 'macomb_il']
# ['wheeling_wv', 'prospect_creek_ak', 'jefferson_city_mo', 'greenville_mi', 'malina_bay_ak', 'williams_az', 'coffman_cove_ak', 'lewistonauburn_me', 'haycock_ak', 'port_graham_ak']
# ['elizabethtown_ky', 'poughkeepsie_ny', 'jefferson_city_mo', 'hartsville_sc', 'wheeling_wv', 'prospect_creek_ak', 'brawley_ca', 'paragould_ar', 'kiluda_bay_ak', 'sequim_wa']
# ['brooksville_fl', 'reserve_la', 'wheeling_wv', 'fitchburg_ma', 'albemarle_nc', 'mccord_ak', 'beaufort_nc', 'londoncorbin_ky', 'bay_city_tx', 'quincy_wa']
# ['brooksville_fl', 'wilkesboro_nc', 'albemarle_nc', 'wheeling_wv', 'petaluma_ca', 'wilmington_de', 'carroll_ia', 'williams_az', 'moneta_va', 'west_yellowstone_mt']
# ['sheldon_point_ak', 'brooksville_fl', 'zephyrhills_fl', 'albemarle_nc', 'beaufort_nc', 'gorham_nh', 'wilkesboro_nc', 'wilmington_de', 'quincy_wa', 'smith_bay_ak']
# ['brooksville_fl', 'prosser_wa', 'wilmington_de', 'the_dalles_or', 'port_graham_ak', 'zephyrhills_fl', 'beaufort_nc', 'mcpherson_ks', 'gorham_nh', 'wilkesboro_nc']
# ['brooksville_fl', 'gorham_nh', 'eagle_nest_nm', 'mayport_fl', 'volcano_bay_ak', 'lancaster_pa', 'whitebear_ak', 'albemarle_nc', 'beaufort_nc', 'jefferson_city_mo']
# ['gorham_nh', 'port_vita_ak', 'minden_nv', 'dune_lake_ak', 'reserve_la', 'starkville_ms', 'roma_tx', 'brooksville_fl', 'miami_ok', 'mesquite_nv']
# ['starkville_ms', 'wilmington_de', 'aleneva_ak', 'minden_nv', 'waterbury_ct', 'granite_mountain_ak', 'laramie_wy', 'shafter_ca', 'paragould_ar', 'pompano_beach_fl']
# ['petaluma_ca', 'benton_harborst_joseph_mi', 'poughkeepsie_ny', 'calexico_ca', 'osceola_wi', 'horseshoe_bay_tx', 'brooks_lodge_ak', 'mcpherson_ks', 'wasilla_ak', 'miami_ok']
# ['santa_monica_ca', 'poughkeepsie_ny', 'batesville_ar', 'katmai_lodge_ak', 'stehekin_wa', 'little_port_walter_ak', 'calder_bay_ak', 'miami_ok', 'castroville__tx', 'okeechobee_fl']
# ['viekoda_bay_ak', 'little_port_walter_ak', 'winters_tx', 'kugururok_river_ak', 'okeechobee_fl', 'ocean_shores_wa', 'miami_ok', 'dalhart_tx', 'malta_mt', 'warren_vt']
# ['daviswoodlandwinters_ca', 'viekoda_bay_ak', 'kugururok_river_ak', 'novato_ca', 'dalhart_tx', 'zephyrhills_fl', 'malta_mt', 'ocean_shores_wa', 'little_port_walter_ak', 'rocksprings_tx']
# ['ocean_shores_wa', 'dalhart_tx', 'viekoda_bay_ak', 'mena_ar', 'manassas_va', 'yantarni_bay_ak', 'bradley_lake_project_ak', 'goodyear_az', 'moneta_va', 'miami_ok']
# ['viekoda_bay_ak', 'malad_city_id', 'calder_bay_ak', 'dalhart_tx', 'taylor_az', 'ocean_shores_wa', 'manassas_va', 'mccord_ak', 'homestead_fl', 'lagrange_ga']
# ['lebanon_tn', 'sanford_nc', 'gambell_ak', 'manistique_mi', 'whitebear_ak', 'bennington_vt', 'minden_nv', 'sugar_land_tx', 'goodyear_az', 'londoncorbin_ky']

# %%
evc_decay plt.subplots(figsize=(xs,ys))
plt.plot(date_air,com_decay,label='decay')
plt.plot(date_air,com_data,label='data')
plt.xlabel('Time')
plt.ylabel("Communicability")
plt.legend()
custom_frame(ax)
plt.show()

# %%
# import essential packages
import cartopy.crs as ccrs
import cartopy as cartopy
import cartopy.io.shapereader as shpreader
import cartopy.crs as ccrs
from cartopy.io import shapereader
from matplotlib.lines import Line2D

# %%
#function to convert node name to readable form
def make_node_name(node):
    node = node.title()
    text = node.split('_')    
    if len(text)<3:
        return ','.join([text[0],text[1].upper()])
    else:
        city = ' '.join(text[0:-1])
        state = text[-1]
        state = state.upper()
        return ','.join([city,state])
    
def plot_graph(G,H):
    #nodes position information
    pos = pd.read_pickle('../data/US_air_geo_information.pkl')

    #prepare labels for edges
    labels = ['Retained Edge', 'Removed Edge'] # this order is fixed
    colors = ['black', 'red']
    styles = ['solid', 'dashed']
    lines = [Line2D([0], [0], color=c, linewidth=3, linestyle= s) for c,s in zip(colors,styles)]

    #select snapshot for displaying 
    year = date(2014,1,1)
    G.remove_nodes_from(['payson_az','hanapepe_hi'])

    #edges separation
    ## the edges that are in mainland us
    edges_in_land = [edge for edge in G.edges() if (pos[edge[0]].lng >= -128 and pos[edge[0]].lng <= -65 and pos[edge[1]].lng >= -128 and pos[edge[1]].lng <=-65)]
    edges_in_land = [edge for edge in edges_in_land if (pos[edge[0]].lat >= 23 and pos[edge[1]].lat >= 23)]


    #plot
    border = [-125,-67,25,50] # xmin_xmax_ymin_ymax
    # sizey = 8
    # sizex = sizey * (border[1]-border[0])/(border[3]-border[2])
    sizex = stdfigsize(ratio=-1)[0]
    sizey = sizex*(border[3]-border[2])/(border[1]-border[0])
    fig = plt.figure(figsize=(xs,ys))

    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    shapename = 'admin_1_states_provinces_lakes_shp'
    states_shp = shpreader.natural_earth(resolution='110m',
                                         category='cultural', name=shapename)

    shp = shapereader.Reader(states_shp)
    ax.background_patch.set_visible(False)
    ax.outline_patch.set_visible(False)
    for record, state in zip(shp.records(), shp.geometries()):
        name = record.attributes['name']
        facecolor = '#f0f0f0'
        ax.add_geometries([state], ccrs.PlateCarree(),
                          facecolor=facecolor, edgecolor='none',zorder=-1)
    ax.set_extent(border, crs=ccrs.PlateCarree())

    #draw edges
    nx.draw(G,
            pos = pos,
            width= 0.1,
            alpha= 0.2,
            node_size = 0,
            edgelist= edges_in_land,
            edge_color = 'black',
            style = 'solid')

    #draw nodes
    nx.draw(G,
            pos = pos,
            node_color = '#377eb8',
            width= 0,
            alpha= 1,
            node_size = np.array(list(dict(H.degree()).values()))/2)
    
    nx.draw(G,
        pos = pos,
        node_color = 'grey',               
        alpha= 1,
        edgelist = [],
        labels = dict([(node,make_node_name(node)) for node in G.nodes]),
        node_size = 0,
        font_color = 'black')
    
    ax.background_patch.set_visible(False)
    ax.outline_patch.set_visible(False)
    #plt.title('Data')
    plt.tight_layout()
    #plt.savefig('../figures/Fig.1_US_Domestic_Flights_Network_v2.png',bbox_inches='tight',dpi=500,transparent=True)
    plt.show()

# %%
node = 'chicago_il'
for G in graphs_decay[0::10]:
    plot_graph(nx.from_edgelist([(node,v) for v in G.neighbors(node)],create_using=nx.Graph()),G)
    fig,ax = plt.subplots()
    plt.hist([d for n,d in G.degree()])
    plt.yscale('log')
    custom_frame(ax)
    plt.show()

    fig,ax = plt.subplots()
    plt.hist(nx.eigenvector_centrality_numpy(G).values())
    plt.yscale('log')
    custom_frame(ax)
    plt.show()

# %%
import datetime
import calendar

def add_months(sourcedate, months):
    month = sourcedate.month - 1 + months
    year = sourcedate.year + month // 12
    month = month % 12 + 1
    day = min(sourcedate.day, calendar.monthrange(year,month)[1])
    return datetime.date(year, month, day)

# %%
import glob, os

df = pd.DataFrame()#{'time':[],'Nedges':[],'Gcc':[]})
N = graphs_air[-1].number_of_nodes()

for f in glob.glob('../simulation/results/*.pickle.dat'):
    graphs_prediction = pickle.load(open(f,'rb'))
    
    df_temp = pd.DataFrame({})
    df_temp['time'] = [add_months(date_air[-1],j) for j in range(len(graphs_prediction))]
    df_temp['Nedges'] = [G.number_of_edges() for G in graphs_prediction]
    df_temp['Gcc'] = [max(nx.connected_component_subgraphs(G),key=len).number_of_nodes()/N for G in graphs_prediction]
    df_temp['Niso'] = [len(list(nx.isolates(G))) for G in graphs_prediction]
    if 'null' in f:
        df_temp['graph'] = ['null'] *len(graphs_prediction)
    else:
        df_temp['graph'] = ['model'] *len(graphs_prediction)
    df_temp['fr'] = [f.strip('.pickle.dat').split('_')[-2].strip('fr')] *len(graphs_prediction)
    df_temp['fa'] = [f.strip('.pickle.dat').split('_')[-1][2]] *len(graphs_prediction)
    df = df.append(df_temp)

# %%
data  = df[df.fa =='1']
data = data[data.graph =='model']

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit([[i] for i in range(len(graphs_air))], [G.number_of_edges() for G in graphs_air])

# %%
reg.coef_
# Out:
# array([-5.7848529])

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
plt.plot(date_air,[G.number_of_edges() for G in graphs_air],c='r')
ax = sns.lineplot(x="time", y="Nedges",hue='fr',palette=["r", 'g',"b"], legend = 'full', data=data)
plt.xlabel('Time')
plt.ylabel("Number of edges")
custom_frame(ax)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
plt.plot(date_air,[len(list(nx.isolates(G))) for G in graphs_air],c='r')
ax = sns.lineplot(x="time", y="Niso",hue='fr',palette=["r", 'g',"b"], legend = 'full', data=data)
plt.xlabel('Time')
plt.ylabel("Number of isolated nodes")
custom_frame(ax)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
plt.plot(date_air,[max(nx.connected_component_subgraphs(G),key=len).number_of_nodes()/N for G in graphs_air],c='r')
ax = sns.lineplot(x="time", y="Gcc",hue='fr',palette=["r", 'g',"b"],legend = 'full',data=data)
plt.plot([add_months(date_air[1],i) for i in range(len(gcc_decay))],gcc_decay,label='decay')
plt.plot(date_air,gcc_data,label='data')
plt.plot([add_months(date_air[0],i) for i in range(len(gcc_model))],gcc_model,label='model data')
plt.xlabel('Time')
plt.ylabel("Size of Gcc")
custom_frame(ax)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(xs,ys))
plt.plot(date_air,[max(nx.connected_component_subgraphs(G),key=len).number_of_nodes()/N for G in graphs_air],c='r')
ax = sns.lineplot(x="time", y="Gcc",hue='fr',palette=["r", 'g',"b"],legend = 'full',data=data)
plt.xlabel('Time')
plt.ylabel("Size of Gcc")
plt.xlim(date(2018,10,1),date(2020,1,1))
custom_frame(ax)
plt.show()

# %%
node = 'chicago_il'
for G in pickle.load(open('../simulation/results/model_graphs_fr1.0025_fa10.pickle.dat','rb'))[-10::]:
    plot_graph(nx.from_edgelist([(node,v) for v in G.neighbors(node)],create_using=nx.Graph()),G)
    fig,ax = plt.subplots()
    plt.hist([d for n,d in G.degree()])
    plt.yscale('log')
    custom_frame(ax)
    plt.show()

    fig,ax = plt.subplots()
    plt.hist(nx.eigenvector_centrality_numpy(G).values())
    plt.yscale('log')
    custom_frame(ax)
    plt.show()
